# %%
# Vizuelna podešavanja okruženja (samo razvuče notebook na širinu ekrana)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import pandas as pd

# %%
#import dataset
data2020 = pd.read_csv("../podaci/atp_matches_2020.csv")
data2020.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2020-8888      Atp Cup    Hard         24             A      20200106
# 1  2020-8888      Atp Cup    Hard         24             A      20200106
# 2  2020-8888      Atp Cup    Hard         24             A      20200106
# 3  2020-8888      Atp Cup    Hard         24             A      20200106
# 4  2020-8888      Atp Cup    Hard         24             A      20200106
#
#    match_num  winner_id winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        300     104925         NaN          NaN  ...    51.0     39.0
# 1        299     105138         NaN          NaN  ...    35.0     21.0
# 2        298     104925         NaN          NaN  ...    57.0     35.0
# 3        297     105583         NaN          NaN  ...    54.0     39.0
# 4        296     104745         NaN          NaN  ...    55.0     37.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced winner_rank winner_rank_points  \
# 0       6.0    10.0        6.0        8.0         2.0             9055.0
# 1       6.0     9.0        5.0       10.0        10.0             2335.0
# 2      25.0    14.0        6.0       11.0         2.0             9055.0
# 3      14.0    12.0        0.0        1.0        34.0             1251.0
# 4      10.0    14.0        1.0        5.0         1.0             9985.0
#
#   loser_rank loser_rank_points
# 0        1.0            9985.0
# 1       34.0            1251.0
# 2        5.0            5705.0
# 3       17.0            1840.0
# 4       18.0            1775.0
#
# [5 rows x 49 columns]

# %%
data2020cleared = data2020[['tourney_id','tourney_name','surface','match_num','winner_id','loser_id','winner_rank','loser_rank']]

# %%
print(data2020cleared.dtypes)
# Out:
# tourney_id       object
# tourney_name     object
# surface          object
# match_num         int64
# winner_id         int64
# loser_id          int64
# winner_rank     float64
# loser_rank      float64
# dtype: object

# %%
print("Broj redova: ", data2020cleared.shape[0])
print("Broj kolona: ", data2020cleared.shape[1])
# Out:
# Broj redova:  1447
# Broj kolona:  8

# %%
#empty field
data2020cleared.isna().any()
# Out:
# tourney_id      False
# tourney_name    False
# surface         False
# match_num       False
# winner_id       False
# loser_id        False
# winner_rank      True
# loser_rank       True
# dtype: bool

# %%
data2020cleared = data2020cleared.dropna()

# %%
#check if match number is unique
print(data2020cleared['match_num'].isnull().values.any())
print(data2020cleared['match_num'].is_unique)
# Out:
# False
# False

# %%
#add column match_id as unique
data2020cleared['match_id'] = data2020cleared.index
data2020cleared.head()
# Out:
#   tourney_id tourney_name surface  match_num  winner_id  loser_id  \
# 0  2020-8888      Atp Cup    Hard        300     104925    104745
# 1  2020-8888      Atp Cup    Hard        299     105138    105583
# 2  2020-8888      Atp Cup    Hard        298     104925    106421
# 3  2020-8888      Atp Cup    Hard        297     105583    111575
# 4  2020-8888      Atp Cup    Hard        296     104745    200282
#
#    winner_rank  loser_rank  match_id
# 0          2.0         1.0         0
# 1         10.0        34.0         1
# 2          2.0         5.0         2
# 3         34.0        17.0         3
# 4          1.0        18.0         4

# %%
data2020cleared.to_csv(r'../podaciExport/atp_matches_2020_cleared.csv')

# %%
dataPlayers = pd.read_csv("../podaci/atp_players.csv")
dataPlayers.head()
# Out:
#    100001         Gardnar    Mulloy  R    19131122  USA
# 0  100002          Pancho    Segura  R  19210620.0  ECU
# 1  100003           Frank   Sedgman  R  19271002.0  AUS
# 2  100004        Giuseppe     Merlo  R  19271011.0  ITA
# 3  100005  Richard Pancho  Gonzales  R  19280509.0  USA
# 4  100006           Grant    Golden  R  19290821.0  USA

# %%
dataPlayers.columns=['player_id','first_name','last_name','hand','birth_date','country_code']
dataPlayers.head()
# Out:
#    player_id      first_name last_name hand  birth_date country_code
# 0     100002          Pancho    Segura    R  19210620.0          ECU
# 1     100003           Frank   Sedgman    R  19271002.0          AUS
# 2     100004        Giuseppe     Merlo    R  19271011.0          ITA
# 3     100005  Richard Pancho  Gonzales    R  19280509.0          USA
# 4     100006           Grant    Golden    R  19290821.0          USA

# %%
dataPlayerscleared = dataPlayers[['player_id','first_name','last_name','country_code']]
dataPlayerscleared.head()
# Out:
#    player_id      first_name last_name country_code
# 0     100002          Pancho    Segura          ECU
# 1     100003           Frank   Sedgman          AUS
# 2     100004        Giuseppe     Merlo          ITA
# 3     100005  Richard Pancho  Gonzales          USA
# 4     100006           Grant    Golden          USA

# %%
print(dataPlayerscleared.dtypes)
# Out:
# player_id        int64
# first_name      object
# last_name       object
# country_code    object
# dtype: object

# %%
print("Broj redova: ", dataPlayerscleared.shape[0])
print("Broj kolona: ", dataPlayerscleared.shape[1])
# Out:
# Broj redova:  54974
# Broj kolona:  4

# %%
#is there any empty field
dataPlayerscleared.isna().any()
# Out:
# player_id       False
# first_name       True
# last_name        True
# country_code     True
# dtype: bool

# %%
dataPlayerscleared=dataPlayerscleared.dropna()
dataPlayerscleared.head()
# Out:
#    player_id      first_name last_name country_code
# 0     100002          Pancho    Segura          ECU
# 1     100003           Frank   Sedgman          AUS
# 2     100004        Giuseppe     Merlo          ITA
# 3     100005  Richard Pancho  Gonzales          USA
# 4     100006           Grant    Golden          USA

# %%
print(dataPlayerscleared['player_id'].is_unique)
# Out:
# True

# %%
#add new column winner with full name
dataPlayerscleared["full_name"] = dataPlayerscleared["first_name"] + " " + dataPlayerscleared["last_name"]
dataPlayerscleared.head()
# Out:
#    player_id      first_name last_name country_code                full_name
# 0     100002          Pancho    Segura          ECU            Pancho Segura
# 1     100003           Frank   Sedgman          AUS            Frank Sedgman
# 2     100004        Giuseppe     Merlo          ITA           Giuseppe Merlo
# 3     100005  Richard Pancho  Gonzales          USA  Richard Pancho Gonzales
# 4     100006           Grant    Golden          USA             Grant Golden

# %%
dataPlayerscleared.to_csv(r'../podaciExport/atp_players_cleared.csv')

# %%
import pyodbc 
cstr = "DRIVER={Microsoft Access Text Driver (*.txt, *.csv)};Extensions=csv;Dbq=C:\\Users\\brank_000\\Desktop\\ASM\\Projekat\\python\\podaciExport"
connection = pyodbc.connect(cstr, autocommit=True)
cursor = connection.cursor()

query = " SELECT M.winner_id, P.full_name, COUNT(*) FROM atp_matches_2020_cleared.csv M left join atp_players_cleared.csv P on P.player_id = M.winner_id GROUP BY M.winner_id, P.full_name ORDER BY 3 DESC"

cursor.execute(query)

row = cursor.fetchone() 
while row: 

    print(row)
    #print(row[1])
    row = cursor.fetchone()
    

cursor.close()
connection.close()
# Out:
# (104925, 'Novak Djokovic', 41)
# (126094, 'Andrey Rublev', 41)
# (126774, 'Stefanos Tsitsipas', 29)
# (100644, 'Alexander Zverev', 28)
# (106421, 'Daniil Medvedev', 28)
# (104745, 'Rafael Nadal', 27)
# (106043, 'Diego Sebastian Schwartzman', 25)
# (106233, 'Dominic Thiem', 25)
# (200000, 'Felix Auger Aliassime', 23)
# (105683, 'Milos Raonic', 21)
# (134770, 'Casper Ruud', 21)
# (105807, 'Pablo Carreno Busta', 20)
# (206173, 'Jannik Sinner', 20)
# (105138, 'Roberto Bautista Agut', 19)
# (200005, 'Ugo Humbert', 19)
# (111575, 'Karen Khachanov', 18)
# (105357, 'John Millman', 18)
# (106426, 'Christian Garin', 18)
# (105777, 'Grigor Dimitrov', 17)
# (133430, 'Denis Shapovalov', 17)
# (200175, 'Miomir Kecmanovic', 17)
# (105554, 'Daniel Evans', 16)
# (105577, 'Vasek Pospisil', 16)
# (105936, 'Filip Krajinovic', 16)
# (106432, 'Borna Coric', 16)
# (128034, 'Hubert Hurkacz', 15)
# (105583, 'Dusan Lajovic', 15)
# (105526, 'Jan Lennard Struff', 15)
# (104792, 'Gael Monfils', 15)
# (126205, 'Tommy Paul', 15)
# (104527, 'Stanislas Wawrinka', 15)
# (105227, 'Marin Cilic', 15)
# (122330, 'Alexander Bublik', 14)
# (126203, 'Taylor Harry Fritz', 14)
# (106415, 'Yoshihito Nishioka', 14)
# (105916, 'Marton Fucsovics', 14)
# (105173, 'Adrian Mannarino', 14)
# (200221, 'Alejandro Davidovich Fokina', 13)
# (111513, 'Laslo Djere', 13)
# (106078, 'Egor Gerasimov', 13)
# (106210, 'Jiri Vesely', 12)
# (124187, 'Reilly Opelka', 12)
# (105676, 'David Goffin', 12)
# (132283, 'Lorenzo Sonego', 12)
# (105379, 'Aljaz Bedene', 11)
# (111442, 'Jordan Thompson', 11)
# (104468, 'Gilles Simon', 11)
# (104755, 'Richard Gasquet', 11)
# (144895, 'Corentin Moutet', 11)
# (105332, 'Benoit Paire', 10)
# (106378, 'Kyle Edmund', 10)
# (104545, 'John Isner', 10)
# (104731, 'Kevin Anderson', 10)
# (105732, 'Pierre Hugues Herbert', 10)
# (144750, 'Lloyd George Muirhead Harris', 10)
# (105643, 'Federico Delbonis', 9)
# (106228, 'Juan Ignacio Londero', 9)
# (200282, 'Alex De Minaur', 9)
# (124079, 'Pedro Martinez Portero', 9)
# (105077, 'Albert Ramos', 9)
# (126610, 'Matteo Berrettini', 9)
# (126952, 'Soon Woo Kwon', 8)
# (126207, 'Francis Tiafoe', 8)
# (106329, 'Thiago Monteiro', 8)
# (104655, 'Pablo Cuevas', 8)
# (106099, 'Salvatore Caruso', 8)
# (106065, 'Marco Cecchinato', 8)
# (105613, 'Norbert Gombos', 7)
# (106218, 'Marcos Giron', 7)
# (200325, 'Emil Ruusuvuori', 7)
# (105815, 'Tennys Sandgren', 7)
# (105870, 'Yannick Hanfmann', 7)
# (105550, 'Guido Pella', 7)
# (105430, 'Radu Albot', 7)
# (103852, 'Feliciano Lopez', 7)
# (104312, 'Andreas Seppi', 7)
# (111815, 'Cameron Norrie', 7)
# (105575, 'Ricardas Berankis', 7)
# (105948, 'Federico Coria', 6)
# (105882, 'Stefano Travaglia', 6)
# (110602, 'Dennis Novak', 6)
# (104269, 'Fernando Verdasco', 6)
# (106401, 'Nick Kyrgios', 6)
# (205734, 'Thiago Seyboth Wild', 6)
# (106148, 'Roberto Carballes Baena', 6)
# (144707, 'Mikael Ymer', 6)
# (105062, 'Mikhail Kukushkin', 6)
# (105226, 'Attila Balazs', 6)
# (136440, 'Dominik Koepfer', 6)
# (105155, 'Pedro Sousa', 5)
# (105449, 'Steve Johnson', 5)
# (103819, 'Roger Federer', 5)
# (207518, 'Lorenzo Musetti', 5)
# (104926, 'Fabio Fognini', 5)
# (126149, 'Gianluca Mager', 5)
# (106198, 'Hugo Dellien', 4)
# (123755, 'Daniel Elahi Galan Riveros', 4)
# (105216, 'Yuichi Sugita', 4)
# (105932, 'Nikoloz Basilashvili', 4)
# (105902, 'James Duckworth', 4)
# (105413, 'Andrej Martin', 4)
# (106296, 'Gregoire Barrere', 4)
# (144817, 'Marc Andrea Huesler', 4)
# (111456, 'Mackenzie Mcdonald', 4)
# (105208, 'Ernests Gulbis', 4)
# (104665, 'Pablo Andujar', 3)
# (105952, 'Renzo Olivo', 3)
# (105453, 'Kei Nishikori', 3)
# (104918, 'Andy Murray', 3)
# (105359, 'Jason Jung', 3)
# (105023, 'Sam Querrey', 3)
# (144719, 'Jaume Munar', 3)
# (127157, 'Daniel Altmaier', 3)
# (200384, 'Hugo Gaston', 3)
# (200624, 'Sebastian Korda', 3)
# (122669, 'Juan Pablo Varillas Patino Samudio', 3)
# (125802, 'Ilya Ivashka', 3)
# (106220, 'Dimitar Kuzmanov', 3)
# (206909, 'Brandon Nakashima', 3)
# (126214, 'Alejandro Tabilo', 3)
# (106109, 'Alex Bolt', 3)
# (117360, 'Marc Polmans', 2)
# (109739, 'Maximilian Marterer', 2)
# (200615, 'Alexei Popyrin', 2)
# (126204, 'Gerardo Lopez Villasenor', 2)
# (105649, 'Cedrik Marcel Stebe', 2)
# (104871, 'Jeremy Chardy', 2)
# (111581, 'Michael Mmoh', 2)
# (105406, 'Roberto Marcora', 2)
# (133975, 'Benjamin Hassan', 2)
# (106214, 'Oscar Otte', 2)
# (105656, 'Marcelo Arevalo', 2)
# (126127, 'Benjamin Bonzi', 2)
# (200514, 'Jurij Rodionov', 2)
# (105905, 'Danilo Petrovic', 2)
# (200670, 'Jeffrey John Wolf', 2)
# (110748, 'Nikola Milojevic', 2)
# (105967, 'Henri Laaksonen', 2)
# (106000, 'Damir Dzumhur', 2)
# (104424, 'Go Soeda', 2)
# (106058, 'Jack Sock', 2)
# (104327, 'Steve Darcis', 2)
# (106234, 'Aslan Karatsev', 2)
# (104259, 'Philipp Kohlschreiber', 2)
# (104999, 'Mischa Zverev', 1)
# (105011, 'Illya Marchenko', 1)
# (207797, 'Jonas Forejtek', 1)
# (144642, 'Marcelo Tomas Barrios Vera', 1)
# (104898, 'Robin Haase', 1)
# (105074, 'Ruben Bemelmans', 1)
# (131951, 'Daniel Cukierman', 1)
# (127339, 'Borna Gojo', 1)
# (105147, 'Tatsuma Ito', 1)
# (103333, 'Ivo Karlovic', 1)
# (103893, 'Paolo Lorenzi', 1)
# (200247, 'Alexandar Lazarov', 1)
# (104586, 'Lukas Rosol', 1)
# (202358, 'Chun Hsin Tseng', 1)
# (200267, 'Zizou Bergs', 1)
# (104291, 'Malek Jaziri', 1)
# (200390, 'Kacper Zuk', 1)
# (202261, 'Otto Virtanen', 1)
# (104678, 'Viktor Troicki', 1)
# (104467, 'Lamine Ouahab', 1)
# (202195, 'Maxime Cressy', 1)
# (202065, 'Petros Tsitsipas', 1)
# (104660, 'Sergiy Stakhovsky', 1)
# (144932, 'Kristjan Tamm', 1)
# (106283, 'Mitchell Krueger', 1)
# (108739, 'Wilfredo Gonzalez', 1)
# (106398, 'Pedro Cachin', 1)
# (106397, 'Wishaya Trongcharoenchaikul', 1)
# (106393, 'Frederico Ferreira Silva', 1)
# (105841, 'Lorenzo Giustino', 1)
# (106331, 'Christopher Oconnell', 1)
# (126128, 'Roman Safiullin', 1)
# (106293, 'Kimmer Coppejans', 1)
# (111511, 'Noah Rubin', 1)
# (106249, 'Joao Domingues', 1)
# (105933, 'Roberto Quiroz', 1)
# (106232, 'Roberto Cid', 1)
# (207989, 'Carlos Alcaraz Garfia', 1)
# (105992, 'Ryan Harrison', 1)
# (106034, 'Yasutaka Uchiyama', 1)
# (106121, 'Taro Daniel', 1)
# (105877, 'Emilio Gomez', 1)
# (124014, 'Ernesto Escobedo', 1)
# (126555, 'Tung Lin Wu', 1)
# (126535, 'Carlos Taberner', 1)
# (126504, 'Andrea Pellegrino', 1)
# (126340, 'Viktor Durasovic', 1)
# (105311, 'Joao Sousa', 1)
# (105376, 'Peter Gojowczyk', 1)
# (106075, 'Jozef Kovalik', 1)
# (110686, 'Finn Tearney', 1)
# (105432, 'Prajnesh Gunneswaran', 1)
# (105668, 'Jerzy Janowicz', 1)
# (123795, 'Altug Celikbilek', 1)
# (105487, 'Facundo Bagnis', 1)
# (105539, 'Evgeny Donskoy', 1)
# (122548, 'Edan Leshem', 1)
# (117356, 'Cem Ilkel', 1)
# (111576, 'Sumit Nagal', 1)
# (126609, 'Patrik Niklas Salminen', 1)
# (124116, 'Sebastian Ofner', 1)

# %%
import pyodbc 
cstr = "DRIVER={Microsoft Access Text Driver (*.txt, *.csv)};Extensions=csv;Dbq=C:\\Users\\brank_000\\Desktop\\ASM\\Projekat\\python\\podaciExport"
connection = pyodbc.connect(cstr, autocommit=True)
cursor = connection.cursor()

query = " SELECT M.loser_id, P.full_name, COUNT(*) FROM atp_matches_2020_cleared.csv M left join atp_players_cleared.csv P on P.player_id = M.loser_id GROUP BY M.loser_id, P.full_name ORDER BY 3 DESC"

cursor.execute(query)

row = cursor.fetchone() 
while row: 

    print(row)
    #print(row[1])
    row = cursor.fetchone()
    

cursor.close()
connection.close()
# Out:
# (200000, 'Felix Auger Aliassime', 19)
# (105173, 'Adrian Mannarino', 17)
# (106043, 'Diego Sebastian Schwartzman', 16)
# (122330, 'Alexander Bublik', 16)
# (105526, 'Jan Lennard Struff', 15)
# (133430, 'Denis Shapovalov', 15)
# (105583, 'Dusan Lajovic', 15)
# (104655, 'Pablo Cuevas', 14)
# (132283, 'Lorenzo Sonego', 14)
# (126203, 'Taylor Harry Fritz', 14)
# (105077, 'Albert Ramos', 14)
# (126774, 'Stefanos Tsitsipas', 14)
# (111575, 'Karen Khachanov', 14)
# (105554, 'Daniel Evans', 14)
# (105815, 'Tennys Sandgren', 13)
# (105357, 'John Millman', 13)
# (134770, 'Casper Ruud', 13)
# (111815, 'Cameron Norrie', 13)
# (128034, 'Hubert Hurkacz', 13)
# (200005, 'Ugo Humbert', 13)
# (106065, 'Marco Cecchinato', 13)
# (105932, 'Nikoloz Basilashvili', 13)
# (126205, 'Tommy Paul', 13)
# (105332, 'Benoit Paire', 13)
# (110602, 'Dennis Novak', 12)
# (105936, 'Filip Krajinovic', 12)
# (105643, 'Federico Delbonis', 12)
# (106432, 'Borna Coric', 12)
# (106426, 'Christian Garin', 12)
# (144750, 'Lloyd George Muirhead Harris', 12)
# (105227, 'Marin Cilic', 12)
# (105430, 'Radu Albot', 12)
# (106099, 'Salvatore Caruso', 12)
# (104468, 'Gilles Simon', 12)
# (104665, 'Pablo Andujar', 12)
# (106415, 'Yoshihito Nishioka', 12)
# (111442, 'Jordan Thompson', 12)
# (200175, 'Miomir Kecmanovic', 12)
# (100644, 'Alexander Zverev', 11)
# (126207, 'Francis Tiafoe', 11)
# (206173, 'Jannik Sinner', 11)
# (105916, 'Marton Fucsovics', 11)
# (105807, 'Pablo Carreno Busta', 11)
# (105379, 'Aljaz Bedene', 11)
# (105062, 'Mikhail Kukushkin', 10)
# (105413, 'Andrej Martin', 10)
# (104926, 'Fabio Fognini', 10)
# (126094, 'Andrey Rublev', 10)
# (105550, 'Guido Pella', 10)
# (105577, 'Vasek Pospisil', 10)
# (105777, 'Grigor Dimitrov', 10)
# (105882, 'Stefano Travaglia', 10)
# (104545, 'John Isner', 10)
# (106228, 'Juan Ignacio Londero', 10)
# (106421, 'Daniil Medvedev', 10)
# (106078, 'Egor Gerasimov', 10)
# (106329, 'Thiago Monteiro', 10)
# (104731, 'Kevin Anderson', 10)
# (200282, 'Alex De Minaur', 10)
# (105732, 'Pierre Hugues Herbert', 10)
# (200221, 'Alejandro Davidovich Fokina', 10)
# (144895, 'Corentin Moutet', 10)
# (105683, 'Milos Raonic', 10)
# (105676, 'David Goffin', 10)
# (104755, 'Richard Gasquet', 9)
# (105311, 'Joao Sousa', 9)
# (106378, 'Kyle Edmund', 9)
# (106233, 'Dominic Thiem', 9)
# (103852, 'Feliciano Lopez', 9)
# (111513, 'Laslo Djere', 9)
# (106000, 'Damir Dzumhur', 8)
# (105902, 'James Duckworth', 8)
# (124079, 'Pedro Martinez Portero', 8)
# (105948, 'Federico Coria', 8)
# (106148, 'Roberto Carballes Baena', 8)
# (106218, 'Marcos Giron', 8)
# (105449, 'Steve Johnson', 8)
# (105613, 'Norbert Gombos', 8)
# (111456, 'Mackenzie Mcdonald', 8)
# (124187, 'Reilly Opelka', 8)
# (106296, 'Gregoire Barrere', 8)
# (200325, 'Emil Ruusuvuori', 8)
# (104919, 'Leonardo Mayer', 8)
# (105138, 'Roberto Bautista Agut', 8)
# (104259, 'Philipp Kohlschreiber', 8)
# (144719, 'Jaume Munar', 8)
# (104527, 'Stanislas Wawrinka', 8)
# (105575, 'Ricardas Berankis', 7)
# (144707, 'Mikael Ymer', 7)
# (104792, 'Gael Monfils', 7)
# (126952, 'Soon Woo Kwon', 7)
# (104745, 'Rafael Nadal', 7)
# (106034, 'Yasutaka Uchiyama', 7)
# (104312, 'Andreas Seppi', 7)
# (104269, 'Fernando Verdasco', 7)
# (106198, 'Hugo Dellien', 7)
# (106210, 'Jiri Vesely', 6)
# (106075, 'Jozef Kovalik', 6)
# (105216, 'Yuichi Sugita', 6)
# (105359, 'Jason Jung', 6)
# (105967, 'Henri Laaksonen', 6)
# (126149, 'Gianluca Mager', 6)
# (136440, 'Dominik Koepfer', 6)
# (126610, 'Matteo Berrettini', 6)
# (105226, 'Attila Balazs', 6)
# (104925, 'Novak Djokovic', 5)
# (200615, 'Alexei Popyrin', 5)
# (104871, 'Jeremy Chardy', 5)
# (125802, 'Ilya Ivashka', 5)
# (105023, 'Sam Querrey', 5)
# (111576, 'Sumit Nagal', 5)
# (105453, 'Kei Nishikori', 4)
# (117360, 'Marc Polmans', 4)
# (105432, 'Prajnesh Gunneswaran', 4)
# (106121, 'Taro Daniel', 4)
# (111794, 'Kamil Majchrzak', 4)
# (104424, 'Go Soeda', 4)
# (111581, 'Michael Mmoh', 4)
# (105487, 'Facundo Bagnis', 4)
# (103333, 'Ivo Karlovic', 4)
# (104918, 'Andy Murray', 4)
# (105633, 'Mohamed Safwat', 4)
# (103893, 'Paolo Lorenzi', 4)
# (105539, 'Evgeny Donskoy', 4)
# (200670, 'Jeffrey John Wolf', 3)
# (106223, 'Aleksandre Metreveli', 3)
# (105877, 'Emilio Gomez', 3)
# (105943, 'Federico Gaio', 3)
# (106234, 'Aslan Karatsev', 3)
# (126214, 'Alejandro Tabilo', 3)
# (207518, 'Lorenzo Musetti', 3)
# (106109, 'Alex Bolt', 3)
# (123755, 'Daniel Elahi Galan Riveros', 3)
# (205734, 'Thiago Seyboth Wild', 3)
# (106401, 'Nick Kyrgios', 3)
# (117356, 'Cem Ilkel', 3)
# (126156, 'Antonie Hoang', 3)
# (105376, 'Peter Gojowczyk', 3)
# (106110, 'Filip Horansky', 3)
# (134868, 'Tallon Griekspoor', 3)
# (105649, 'Cedrik Marcel Stebe', 3)
# (105155, 'Pedro Sousa', 3)
# (105870, 'Yannick Hanfmann', 3)
# (200624, 'Sebastian Korda', 3)
# (111797, 'Nicolas Jarry', 3)
# (126340, 'Viktor Durasovic', 3)
# (200514, 'Jurij Rodionov', 3)
# (104797, 'Denis Istomin', 3)
# (106293, 'Kimmer Coppejans', 3)
# (104678, 'Viktor Troicki', 3)
# (133018, 'Michail Pervolarakis', 3)
# (126612, 'Alexander Cozbinov', 3)
# (127157, 'Daniel Altmaier', 3)
# (200384, 'Hugo Gaston', 3)
# (104291, 'Malek Jaziri', 2)
# (105373, 'Martin Klizan', 2)
# (104898, 'Robin Haase', 2)
# (104999, 'Mischa Zverev', 2)
# (105905, 'Danilo Petrovic', 2)
# (105688, 'Manuel Sanchez', 2)
# (105899, 'Martin Cuevas', 2)
# (104542, 'Jo Wilfried Tsonga', 2)
# (104660, 'Sergiy Stakhovsky', 2)
# (105827, 'Laurynas Grigelis', 2)
# (105841, 'Lorenzo Giustino', 2)
# (105011, 'Illya Marchenko', 2)
# (105208, 'Ernests Gulbis', 2)
# (110748, 'Nikola Milojevic', 2)
# (126127, 'Benjamin Bonzi', 2)
# (126535, 'Carlos Taberner', 2)
# (132374, 'Jesse Flores', 2)
# (144642, 'Marcelo Tomas Barrios Vera', 2)
# (144817, 'Marc Andrea Huesler', 2)
# (111460, 'Quentin Halys', 2)
# (200611, 'Elliot Benchetrit', 2)
# (206909, 'Brandon Nakashima', 2)
# (106368, 'Ramkumar Ramanathan', 2)
# (106331, 'Christopher Oconnell', 2)
# (106058, 'Jack Sock', 2)
# (106249, 'Joao Domingues', 2)
# (106150, 'Jeson Patrombon', 2)
# (106220, 'Dimitar Kuzmanov', 2)
# (106214, 'Oscar Otte', 2)
# (208004, 'Harold Mayot', 2)
# (126663, 'Juan Pablo Ficovich', 1)
# (104901, 'Vladimir Ivanov', 1)
# (133979, 'Hasan Ibrahim', 1)
# (103819, 'Roger Federer', 1)
# (127326, 'Ben Fatael', 1)
# (127143, 'Jirat Navasirisomboon', 1)
# (126964, 'Vitaliy Sachko', 1)
# (126846, 'Aleksandar Vukic', 1)
# (105053, 'Santiago Giraldo', 1)
# (200303, 'Pavel Kotov', 1)
# (105074, 'Ruben Bemelmans', 1)
# (126555, 'Tung Lin Wu', 1)
# (103565, 'Stephane Robert', 1)
# (105147, 'Tatsuma Ito', 1)
# (126504, 'Andrea Pellegrino', 1)
# (105156, 'Federico Zeballos', 1)
# (126239, 'Arthur Rinderknech', 1)
# (126204, 'Gerardo Lopez Villasenor', 1)
# (208134, 'Luca Nardi', 1)
# (126845, 'Max Purcell', 1)
# (104586, 'Lukas Rosol', 1)
# (207830, 'Tomas Machac', 1)
# (207797, 'Jonas Forejtek', 1)
# (207680, 'Facundo Diaz Acosta', 1)
# (207608, 'Timofey Skatov', 1)
# (104327, 'Steve Darcis', 1)
# (207989, 'Carlos Alcaraz Garfia', 1)
# (206748, 'Giulio Zeppieri', 1)
# (202358, 'Chun Hsin Tseng', 1)
# (144826, 'Aziz Dougaz', 1)
# (202195, 'Maxime Cressy', 1)
# (200390, 'Kacper Zuk', 1)
# (202120, 'Rowland Phillips', 1)
# (202103, 'Francisco Cerundolo', 1)
# (202090, 'Adrian Andreev', 1)
# (105349, 'Harri Heliovaara', 1)
# (126190, 'Nicolas Alvarez', 1)
# (200335, 'Felipe Meligeni Rodrigues Alves', 1)
# (104229, 'Yen Hsun Lu', 1)
# (200265, 'Ulises Blanch', 1)
# (202261, 'Otto Virtanen', 1)
# (105747, 'Karim Mohamed Maamoun', 1)
# (126120, 'Nino Serdarusic', 1)
# (111153, 'Christopher Eubanks', 1)
# (109739, 'Maximilian Marterer', 1)
# (105614, 'Bradley Klahn', 1)
# (108772, 'Julius Tverijonas', 1)
# (108739, 'Wilfredo Gonzalez', 1)
# (106408, 'Mario Vilella Martinez', 1)
# (106398, 'Pedro Cachin', 1)
# (106397, 'Wishaya Trongcharoenchaikul', 1)
# (111459, 'Arjun Kadhe', 1)
# (105731, 'Steven Diez', 1)
# (111505, 'Enzo Couacaud', 1)
# (105757, 'Sandro Ehrat', 1)
# (105806, 'Mirza Basic', 1)
# (106302, 'Andrew Harris', 1)
# (106283, 'Mitchell Krueger', 1)
# (209080, 'Blaise Bicknell', 1)
# (106232, 'Roberto Cid', 1)
# (106071, 'Bernard Tomic', 1)
# (106045, 'Denis Kudla', 1)
# (105992, 'Ryan Harrison', 1)
# (105985, 'Darian King', 1)
# (106388, 'Pak Long Yeung', 1)
# (122078, 'Dmitry Popko', 1)
# (126125, 'Maxime Janvier', 1)
# (106281, 'Liam Broady', 1)
# (105341, 'Thomas Fabbiano', 1)
# (105952, 'Renzo Olivo', 1)
# (124154, 'Sasi Kumar Mukund', 1)
# (124116, 'Sebastian Ofner', 1)
# (124014, 'Ernesto Escobedo', 1)
# (122669, 'Juan Pablo Varillas Patino Samudio', 1)
# (122533, 'Nam Hoang Ly', 1)
# (111200, 'Elias Ymer', 1)
# (122109, 'Sanjar Fayziev', 1)
# (126128, 'Roman Safiullin', 1)
# (120424, 'Yannick Maden', 1)
# (105434, 'Ruan Roelofse', 1)
# (105441, 'John Patrick Smith', 1)
# (111790, 'Brayden Schnur', 1)
# (111578, 'Stefan Kozlov', 1)
# (105467, 'Jordi Munoz Abreu', 1)
# (105477, 'Marco Trungelliti', 1)
# (111515, 'Thai Son Kwiatkowski', 1)
# (105497, 'Jose Hernandez', 1)
# (111511, 'Noah Rubin', 1)
# (105406, 'Roberto Marcora', 1)

# %%
#add new column winner with full name
dataPlayerscleared["winner_full_name"] = dataPlayerscleared["first_name"] + " " + dataPlayerscleared["last_name"]
dataPlayerscleared.head()
# Out:
#    player_id      first_name last_name country_code                full_name  \
# 0     100002          Pancho    Segura          ECU            Pancho Segura
# 1     100003           Frank   Sedgman          AUS            Frank Sedgman
# 2     100004        Giuseppe     Merlo          ITA           Giuseppe Merlo
# 3     100005  Richard Pancho  Gonzales          USA  Richard Pancho Gonzales
# 4     100006           Grant    Golden          USA             Grant Golden
#
#           winner_full_name
# 0            Pancho Segura
# 1            Frank Sedgman
# 2           Giuseppe Merlo
# 3  Richard Pancho Gonzales
# 4             Grant Golden

# %%
#add new column winner with full name
dataPlayerscleared["loser_full_name"] = dataPlayerscleared["first_name"] + " " + dataPlayerscleared["last_name"]
dataPlayerscleared.head()
# Out:
#    player_id      first_name last_name country_code                full_name  \
# 0     100002          Pancho    Segura          ECU            Pancho Segura
# 1     100003           Frank   Sedgman          AUS            Frank Sedgman
# 2     100004        Giuseppe     Merlo          ITA           Giuseppe Merlo
# 3     100005  Richard Pancho  Gonzales          USA  Richard Pancho Gonzales
# 4     100006           Grant    Golden          USA             Grant Golden
#
#           winner_full_name          loser_full_name
# 0            Pancho Segura            Pancho Segura
# 1            Frank Sedgman            Frank Sedgman
# 2           Giuseppe Merlo           Giuseppe Merlo
# 3  Richard Pancho Gonzales  Richard Pancho Gonzales
# 4             Grant Golden             Grant Golden

# %%
data_short2020=data2020cleared[['match_num','winner_id','loser_id','match_id']]
data_short2020.head()
# Out:
#    match_num  winner_id  loser_id  match_id
# 0        300     104925    104745         0
# 1        299     105138    105583         1
# 2        298     104925    106421         2
# 3        297     105583    111575         3
# 4        296     104745    200282         4

# %%
dataPlayerscleared.head()
# Out:
#    player_id      first_name last_name country_code                full_name  \
# 0     100002          Pancho    Segura          ECU            Pancho Segura
# 1     100003           Frank   Sedgman          AUS            Frank Sedgman
# 2     100004        Giuseppe     Merlo          ITA           Giuseppe Merlo
# 3     100005  Richard Pancho  Gonzales          USA  Richard Pancho Gonzales
# 4     100006           Grant    Golden          USA             Grant Golden
#
#           winner_full_name          loser_full_name
# 0            Pancho Segura            Pancho Segura
# 1            Frank Sedgman            Frank Sedgman
# 2           Giuseppe Merlo           Giuseppe Merlo
# 3  Richard Pancho Gonzales  Richard Pancho Gonzales
# 4             Grant Golden             Grant Golden

# %%
dataPlayers_short_winner = dataPlayerscleared[['player_id','winner_full_name']]
dataPlayers_short_winner.head()
# Out:
#    player_id         winner_full_name
# 0     100002            Pancho Segura
# 1     100003            Frank Sedgman
# 2     100004           Giuseppe Merlo
# 3     100005  Richard Pancho Gonzales
# 4     100006             Grant Golden

# %%
dataPlayers_short_loser=dataPlayerscleared[['player_id','loser_full_name']]
dataPlayers_short_loser.head()
# Out:
#    player_id          loser_full_name
# 0     100002            Pancho Segura
# 1     100003            Frank Sedgman
# 2     100004           Giuseppe Merlo
# 3     100005  Richard Pancho Gonzales
# 4     100006             Grant Golden

# %%
#merge three tables
merged_data=data_short2020.merge(dataPlayers_short_winner,left_on='winner_id', right_on='player_id').drop('player_id', axis=1).merge(dataPlayers_short_loser,left_on='loser_id', right_on='player_id').drop('player_id', axis=1)
merged_data.head()
# Out:
#    match_num  winner_id  loser_id  match_id winner_full_name loser_full_name
# 0        300     104925    104745         0   Novak Djokovic    Rafael Nadal
# 1        299     106421    104745      1324  Daniil Medvedev    Rafael Nadal
# 2        288     105676    104745        12     David Goffin    Rafael Nadal
# 3        220     106233    104745       287    Dominic Thiem    Rafael Nadal
# 4        291     106233    104745      1332    Dominic Thiem    Rafael Nadal

# %%
player_asm = merged_data[['winner_id','loser_id','match_id','winner_full_name','loser_full_name']]
player_asm.head()
# Out:
#    winner_id  loser_id  match_id winner_full_name loser_full_name
# 0     104925    104745         0   Novak Djokovic    Rafael Nadal
# 1     106421    104745      1324  Daniil Medvedev    Rafael Nadal
# 2     105676    104745        12     David Goffin    Rafael Nadal
# 3     106233    104745       287    Dominic Thiem    Rafael Nadal
# 4     106233    104745      1332    Dominic Thiem    Rafael Nadal

# %%
#id player unique
list_winner = set(player_asm['winner_full_name'].unique())
list_loser = set(player_asm['loser_full_name'].unique())

skup_id = list_winner.union(list_loser)
print(f"Postoji { len(skup_id) } različitih igrača") # formatiranje ispisa pomoću fstringa
# Out:
# Postoji 289 različitih igrača

# %%
import numpy as np
import matplotlib.pyplot as plt

data_reduced = player_asm[['winner_full_name','loser_full_name','match_id']]

# %%
import networkx as nx
G = nx.Graph() # pravi praznu mrežu
G.add_nodes_from(skup_id) # dodaje čvorove čije su labele u "skup_id"

# %%
#agregacija brojanjem
for _, winner_full_name, loser_full_name, _ in data_reduced.itertuples():
    if (winner_full_name, loser_full_name) in G.edges:
        G.edges[winner_full_name, loser_full_name]['weight'] += 1
    else:
        G.add_edge(winner_full_name, loser_full_name, weight=1)

# %%
print(G.edges.data("weight"))

#nx.draw_networkx(G)#-> crta mrežu, ne pokušavati za mrežu sa ovoliko čvorova i grana!
# Out:
# [('Cameron Norrie', 'Diego Sebastian Schwartzman', 1), ('Cameron Norrie', 'Miomir Kecmanovic', 1), ('Cameron Norrie', 'Taylor Harry Fritz', 2), ('Cameron Norrie', 'Nick Kyrgios', 1), ('Cameron Norrie', 'Steve Darcis', 1), ('Cameron Norrie', 'Andrey Rublev', 1), ('Cameron Norrie', 'Pierre Hugues Herbert', 1), ('Cameron Norrie', 'Thiago Monteiro', 1), ('Cameron Norrie', 'Jordan Thompson', 1), ('Cameron Norrie', 'Alejandro Davidovich Fokina', 1), ('Cameron Norrie', 'Adrian Mannarino', 1), ('Cameron Norrie', 'Emil Ruusuvuori', 1), ('Cameron Norrie', 'Jason Jung', 1), ('Cameron Norrie', 'Reilly Opelka', 1), ('Cameron Norrie', 'Brandon Nakashima', 1), ('Cameron Norrie', 'Daniel Elahi Galan Riveros', 1), ('Cameron Norrie', 'Alexander Cozbinov', 1), ('Cameron Norrie', 'Dimitar Kuzmanov', 1), ('Cameron Norrie', 'Federico Coria', 1), ('Federico Gaio', 'Pedro Martinez Portero', 1), ('Federico Gaio', 'Ricardas Berankis', 1), ('Federico Gaio', 'Joao Domingues', 1), ('Christian Garin', 'Novak Djokovic', 1), ('Christian Garin', 'Karen Khachanov', 1), ('Christian Garin', 'Kevin Anderson', 1), ('Christian Garin', 'Gael Monfils', 1), ('Christian Garin', 'Lloyd George Muirhead Harris', 1), ('Christian Garin', 'Borna Coric', 2), ('Christian Garin', 'Dominic Thiem', 1), ('Christian Garin', 'Stefanos Tsitsipas', 1), ('Christian Garin', 'Aljaz Bedene', 1), ('Christian Garin', 'Mikhail Kukushkin', 1), ('Christian Garin', 'Milos Raonic', 1), ('Christian Garin', 'Thiago Seyboth Wild', 1), ('Christian Garin', 'Diego Sebastian Schwartzman', 1), ('Christian Garin', 'Philipp Kohlschreiber', 1), ('Christian Garin', 'Attila Balazs', 1), ('Christian Garin', 'Marc Polmans', 1), ('Christian Garin', 'Alejandro Davidovich Fokina', 1), ('Christian Garin', 'Gianluca Mager', 1), ('Christian Garin', 'Pablo Cuevas', 1), ('Christian Garin', 'Federico Delbonis', 1), ('Christian Garin', 'Stefano Travaglia', 1), ('Christian Garin', 'Alexander Bublik', 1), ('Christian Garin', 'Andrej Martin', 2), ('Christian Garin', 'Stanislas Wawrinka', 1), ('Christian Garin', 'Federico Coria', 1), ('Christian Garin', 'Kei Nishikori', 1), ('Christian Garin', 'Yannick Hanfmann', 1), ('Christian Garin', 'Ulises Blanch', 1), ('Andreas Seppi', 'Damir Dzumhur', 1), ('Andreas Seppi', 'Miomir Kecmanovic', 1), ('Andreas Seppi', 'Steve Johnson', 1), ('Andreas Seppi', 'Adrian Mannarino', 1), ('Andreas Seppi', 'Jordan Thompson', 1), ('Andreas Seppi', 'Jason Jung', 1), ('Andreas Seppi', 'Aslan Karatsev', 1), ('Andreas Seppi', 'Stanislas Wawrinka', 1), ('Andreas Seppi', 'Kyle Edmund', 2), ('Andreas Seppi', 'Federico Delbonis', 1), ('Andreas Seppi', 'Francis Tiafoe', 1), ('Andreas Seppi', 'Mackenzie Mcdonald', 1), ('Andreas Seppi', 'Sebastian Korda', 1), ('John Millman', 'Karen Khachanov', 1), ('John Millman', 'Michael Mmoh', 1), ('John Millman', 'Nikoloz Basilashvili', 1), ('John Millman', 'Hubert Hurkacz', 1), ('John Millman', 'Gilles Simon', 1), ('John Millman', 'Felix Auger Aliassime', 1), ('John Millman', 'Adrian Mannarino', 2), ('John Millman', 'Francis Tiafoe', 2), ('John Millman', 'Thiago Seyboth Wild', 1), ('John Millman', 'Benoit Paire', 1), ('John Millman', 'Yoshihito Nishioka', 1), ('John Millman', 'Taylor Harry Fritz', 1), ('John Millman', 'Diego Sebastian Schwartzman', 1), ('John Millman', 'Miomir Kecmanovic', 1), ('John Millman', 'Pablo Carreno Busta', 1), ('John Millman', 'John Isner', 1), ('John Millman', 'Vasek Pospisil', 1), ('John Millman', 'Alexander Zverev', 1), ('John Millman', 'Jordan Thompson', 1), ('John Millman', 'Roger Federer', 1), ('John Millman', 'Mischa Zverev', 1), ('John Millman', 'Thiago Monteiro', 1), ('John Millman', 'Joao Sousa', 1), ('John Millman', 'Tommy Paul', 1), ('John Millman', 'Ugo Humbert', 1), ('John Millman', 'Michail Pervolarakis', 1), ('John Millman', 'Fernando Verdasco', 2), ('John Millman', 'Adrian Andreev', 1), ('Pablo Andujar', 'Rafael Nadal', 1), ('Pablo Andujar', 'Yoshihito Nishioka', 1), ('Pablo Andujar', 'Stefano Travaglia', 1), ('Pablo Andujar ...

# %%
output = "models/undirected_count_aggregation2020.gml"

nx.write_gml(G, output)

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 289
# Number of edges: 1281
# Average degree:   8.8651

# %%
# možemo iskoristiti networkx.draw_network da predstavimo egomrežu tog čvora
ego_mreza = nx.ego_graph(G, 'Novak Djokovic')
print(f"Čvorovi ego mreže igrača Novak Djokovic su {ego_mreza.nodes}")
plt.figure(figsize=(15,10))
tezine_grana = nx.get_edge_attributes(ego_mreza,'weight')
pos = nx.circular_layout(ego_mreza)
#pos = nx.spring_layout(ego_mreza)
#print(pos)
nx.draw_networkx(ego_mreza, pos)
nx.draw_networkx_edge_labels(ego_mreza, pos, edge_labels = tezine_grana)
# Out:
# Čvorovi ego mreže igrača Novak Djokovic su ['Filip Krajinovic', 'Christian Garin', 'Borna Coric', 'Alexander Zverev', 'Roberto Bautista Agut', 'Denis Shapovalov', 'Tatsuma Ito', 'Tennys Sandgren', 'Milos Raonic', 'Salvatore Caruso', 'Dominic Thiem', 'Gael Monfils', 'Malek Jaziri', 'Daniil Medvedev', 'Diego Sebastian Schwartzman', 'Rafael Nadal', 'Dominik Koepfer', 'Roger Federer', 'Mikael Ymer', 'Kevin Anderson', 'Novak Djokovic', 'Stefanos Tsitsipas', 'Philipp Kohlschreiber', 'Casper Ruud', 'Damir Dzumhur', 'Karen Khachanov', 'Lorenzo Sonego', 'Daniel Elahi Galan Riveros', 'Jan Lennard Struff', 'Yoshihito Nishioka', 'Ricardas Berankis', 'Pablo Carreno Busta', 'Kyle Edmund']
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# {('Filip Krajinovic',
#   'Dominic Thiem'): Text(0.33646603175824125, 0.47250041392801, '1'),
#  ('Filip Krajinovic',
#   'Kyle Edmund'): Text(0.9909643531182246, -0.09462558239668559, '1'),
#  ('Filip Krajinovic',
#   'Novak Djokovic'): Text(0.10697344278181553, -0.30907946506688744, '2'),
#  ('Filip Krajinovic',
#   'Gael Monfils'): Text(0.24999997299164545, 0.4330126945392856, '2'),
#  ('Filip Krajinovic',
#   'Roger Federer'): Text(0.0022640265440045937, -0.047527966674482405, '1'),
#  ('Filip Krajinovic',
#   'Milos Raonic'): Text(0.5237909498669544, 0.4994336666391077, '1'),
#  ('Filip Krajinovic',
#   'Salvatore Caruso'): Text(0.42884258393629426, 0.49491071719878843, '1'),
#  ('Filip Krajinovic',
#   'Mikael Ymer'): Text(0.020253512932905893, -0.14086627704530646, '2'),
#  ('Christian Garin',
#   'Novak Djokovic'): Text(0.09793779590004015, -0.21445384338532245, '1'),
#  ('Christian Garin',
#   'Karen Khachanov'): Text(0.5147552713202116, -0.4048080408935898, '1'),
#  ('Christian Garin',
#   'Kevin Anderson'): Text(0.04654664156382293, -0.134487671107269, '1'),
#  ('Christian Garin',
#   'Gael Monfils'): Text(0.24096432610987006, 0.5276383162208506, '1'),
#  ('Christian Garin',
#   'Borna Coric'): Text(0.9551483096363086, 0.2804568568803284, '2'),
#  ('Christian Garin',
#   'Dominic Thiem'): Text(0.32743038487646586, 0.567126035609575, '1'),
#  ('Christian Garin',
#   'Stefanos Tsitsipas'): Text(0.16353398873085534, -0.28324916650092713, '1'),
#  ('Christian Garin',
#   'Milos Raonic'): Text(0.514755302985179, 0.5940592883206727, '1'),
#  ('Christian Garin',
#   'Diego Sebastian Schwartzman'): Text(0.046546611761500656, 0.3237388440285463, '1'),
#  ('Christian Garin',
#   'Philipp Kohlschreiber'): Text(0.24096440061567576, -0.33838709859608995, '1'),
#  ('Borna Coric',
#   'Milos Raonic'): Text(0.4879749063850384, 0.6852648998058947, '1'),
#  ('Borna Coric',
#   'Dominic Thiem'): Text(0.3006499882763252, 0.658331647094797, '1'),
#  ('Borna Coric',
#   'Stefanos Tsitsipas'): Text(0.1367535921307147, -0.19204355501570516, '1'),
#  ('Borna Coric',
#   'Novak Djokovic'): Text(0.0711573992998995, -0.12324823190010051, '1'),
#  ('Borna Coric',
#   'Diego Sebastian Schwartzman'): Text(0.019766215161360012, 0.41494445551376824, '1'),
#  ('Borna Coric',
#   'Alexander Zverev'): Text(0.8848107163428861, 0.4561516198862453, '1'),
#  ('Borna Coric',
#   'Lorenzo Sonego'): Text(0.5820634306145331, -0.3000745592805404, '1'),
#  ('Alexander Zverev',
#   'Rafael Nadal'): Text(-0.059119727242291975, 0.4111866955990636, '1'),
#  ('Alexander Zverev',
#   'Kevin Anderson'): Text(-0.023790951729599552, 0.04120709189864788, '1'),
#  ('Alexander Zverev',
#   'Diego Sebastian Schwartzman'): Text(-0.02379098153192183, 0.49943360703446316, '2'),
#  ('Alexander Zverev',
#   'Pablo Carreno Busta'): Text(0.8848107163428861, 0.08448915355267148, '1'),
#  ('Alexander Zverev',
#   'Novak Djokovic'): Text(0.027600202606617663, -0.038759080379405564, '1'),
#  ('Alexander Zverev',
#   'Daniil Medvedev'): Text(0.027600202606617663, 0.5793998836206445, '2'),
#  ('Alexander Zverev',
#   'Dominic Thiem'): Text(0.2570927915830434, 0.7428207986154919, '2'),
#  ('Alexander Zverev',
#   'Stefanos Tsitsipas'): Text(0.09319639543743286, -0.10755440349501022, '1'),
#  ('Alexander Zverev',
#   'Denis Shapovalov'): Text(0.7106552134802371, 0.6776083702886334, '1'),
#  ('Roberto Bautista Agut',
#   'Daniil Medvedev'): Text(-0.031159546110184677, 0.6541190143351835, '1'),
#  ('Roberto Bautista Agut',
#   'Karen Khachanov'): Text(0.38565792930998677, -0.15439414717313393, '1'),
#  ('Roberto Bautista Agut',
#   'Novak Djokovic'): Text(-0.031159546110184677, 0.03596005033513339, '1'),
#  ('Roberto Bautista Agut',
#   'Jan Lennard Struff'): Text(0.6518955541704016, -0.06224840653053321, '1'),
#  ('Roberto Bautista Agut',
#   'Pablo Carreno Busta'): Text(0.8260509676260838, 0.15920828426721043, '2'),
#  ('Roberto Bautista Agut',
#   'Tennys Sandgren'): Text(0.4797464554021267, 0.8309453119133011, '1'),
#  ('Roberto Bautista Agut',
#   'Dominik Koepfer'): Text(-0.13586896234799561, 0.3925675196680688, '1'),
#  ('Denis Shapovalov',
#   'Novak Djokovic'): Text(-0.10299810356274952, 0.09820851850228762, '1'),
#  ('Denis Shapovalov',
#   'Diego Sebastian Schwartzman'): Text(-0.154389287701289, 0.6364012059161563, '1'),
#  ('Denis Shapovalov',
#   'Jan Lennard Struff'): Text(0.5800569967178367, 6.163662102931511e-08, '1'),
#  ('Denis Shapovalov',
#   'Pablo Carreno Busta'): Text(0.7542124101735189, 0.22145675243436466, '1'),
#  ('Denis Shapovalov',
#   'Stefanos Tsitsipas'): Text(-0.03740191073193433, 0.029413195386682967, '1'),
#  ('Tatsuma Ito',
#   'Novak Djokovic'): Text(-0.18531903182968856, 0.14573651701106882, '1'),
#  ('Tennys Sandgren',
#   'Novak Djokovic'): Text(-0.2751471129240576, 0.17682632941241638, '1'),
#  ('Tennys Sandgren',
#   'Roger Federer'): Text(-0.3798565291618685, 0.4383778278048214, '1'),
#  ('Tennys Sandgren',
#   'Salvatore Caruso'): Text(0.04672202823042115, 0.9808165116780923, '1'),
#  ('Tennys Sandgren',
#   'Daniel Elahi Galan Riveros'): Text(0.32558699948494507, 0.031089814433324037, '1'),
#  ('Tennys Sandgren',
#   'Lorenzo Sonego'): Text(0.2357589183905761, 2.0319764759690884e-09, '1'),
#  ('Milos Raonic',
#   'Novak Djokovic'): Text(-0.36923560735123007, 0.1903541995402438, '2'),
#  ('Milos Raonic',
#   'Daniil Medvedev'): Text(-0.36923560735123007, 0.8085131635402939, '1'),
#  ('Milos Raonic',
#   'Stefanos Tsitsipas'): Text(-0.3036394145204149, 0.12155887642463914, '2'),
#  ('Milos Raonic',
#   'Karen Khachanov'): Text(0.04758186806894143, 2.0319764759690884e-09, '1'),
#  ('Salvatore Caruso',
#   'Novak Djokovic'): Text(-0.4641839732818902, 0.18583125009992452, '1'),
#  ('Salvatore Caruso',
#   'Stefanos Tsitsipas'): Text(-0.398587780451075, 0.11703592698431986, '1'),
#  ('Salvatore Caruso',
#   'Jan Lennard Struff'): Text(0.21887112699869601, 0.08762279323425792, '1'),
#  ('Dominic Thiem',
#   'Rafael Nadal'): Text(-0.6432804553088529, 0.6133667228076153, '2'),
#  ('Dominic Thiem',
#   'Daniil Medvedev'): Text(-0.5565605254599433, 0.7815799108291962, '2'),
#  ('Dominic Thiem',
#   'Gael Monfils'): Text(-0.4135339952501133, 0.9055131064353191, '1'),
#  ('Dominic Thiem',
#   'Diego Sebastian Schwartzman'): Text(-0.6079517095984828, 0.7016136342430148, '2'),
#  ('Dominic Thiem',
#   'Novak Djokovic'): Text(-0.5565605254599433, 0.1634209468291461, '2'),
#  ('Dominic Thiem',
#   'Stefanos Tsitsipas'): Text(-0.49096433262912803, 0.09462562371354144, '1'),
#  ('Dominic Thiem',
#   'Casper Ruud'): Text(-0.3270678470765507, -2.7770345800703922e-08, '1'),
#  ('Gael Monfils',
#   'Novak Djokovic'): Text(-0.643026584226539, 0.12393322744042168, '2'),
#  ('Gael Monfils',
#   'Pablo Carreno Busta'): Text(0.21418392950972942, 0.24718146137249872, '1'),
#  ('Gael Monfils',
#   'Dominik Koepfer'): Text(-0.74773600046435, 0.4805406967733571, '1'),
#  ('Malek Jaziri',
#   'Novak Djokovic'): Text(-0.7204568918032315, 0.06879535494990341, '1'),
#  ('Daniil Medvedev',
#   'Rafael Nadal'): Text(-0.8727730442852786, 0.44994580781276794, '1'),
#  ('Daniil Medvedev',
#   'Novak Djokovic'): Text(-0.7860531144363689, 3.18342987526421e-08, '2'),
#  ('Daniil Medvedev',
#   'Kevin Anderson'): Text(-0.8374442687725862, 0.0799662041123522, '2'),
#  ('Daniil Medvedev',
#   'Diego Sebastian Schwartzman'): Text(-0.8374442985749084, 0.5381927192481675, '3'),
#  ('Daniil Medvedev',
#   'Casper Ruud'): Text(-0.5565604360529763, -0.16342094276519314, '1'),
#  ('Diego Sebastian Schwartzman',
#   'Rafael Nadal'): Text(-0.9241642284238181, 0.3699795312265866, '2'),
#  ('Diego Sebastian Schwartzman',
#   'Novak Djokovic'): Text(-0.8374442985749084, -0.0799662447518826, '3'),
#  ('Diego Sebastian Schwartzman',
#   'Casper Ruud'): Text(-0.6079516201915158, -0.2433872193513745, '1'),
#  ('Diego Sebastian Schwartzman',
#   'Lorenzo Sonego'): Text(-0.3265382672602748, -0.25679257213232254, '1'),
#  ('Rafael Nadal',
#   'Novak Djokovic'): Text(-0.8727730442852786, -0.16821315618728214, '2'),
#  ('Rafael Nadal',
#   'Yoshihito Nishioka'): Text(-0.11787953556373887, -0.2041732640950836, '1'),
#  ('Rafael Nadal',
#   'Stefanos Tsitsipas'): Text(-0.8071768514544634, -0.2370084793028868, '1'),
#  ('Rafael Nadal',
#   'Pablo Carreno Busta'): Text(-0.015562530549010134, -0.0449649222552051, '3'),
#  ('Dominik Koepfer',
#   'Yoshihito Nishioka'): Text(-0.13586902195264017, -0.2975115707406174, '1'),
#  ('Dominik Koepfer',
#   'Novak Djokovic'): Text(-0.8907625306741799, -0.26155146283281594, '1'),
#  ('Dominik Koepfer',
#   'Kyle Edmund'): Text(-0.0067716203377707895, -0.04709758016261411, '1'),
#  ('Roger Federer',
#   'Novak Djokovic'): Text(-0.8907625306741799, -0.35660743377334636, '1'),
#  ('Mikael Ymer',
#   'Novak Djokovic'): Text(-0.8727730442852786, -0.44994574414417043, '1'),
#  ('Mikael Ymer',
#   'Karen Khachanov'): Text(-0.45595556886510713, -0.6402999416524378, '1'),
#  ('Mikael Ymer',
#   'Stefanos Tsitsipas'): Text(-0.8071768514544634, -0.5187410672597751, '1'),
#  ('Kevin Anderson',
#   'Novak Djokovic'): Text(-0.8374442687725862, -0.5381927598876979, '1'),
#  ('Kevin Anderson',
#   'Stefanos Tsitsipas'): Text(-0.771848075941771, -0.6069880830033025, '1'),
#  ('Kevin Anderson',
#   'Kyle Edmund'): Text(0.04654664156382293, -0.32373887721749606, '1'),
#  ('Kevin Anderson',
#   'Pablo Carreno Busta'): Text(0.01976624496368229, -0.41494452595562087, '1'),
#  ('Novak Djokovic',
#   'Jan Lennard Struff'): Text(-0.10299801415578269, -0.716367389031418, '3'),
#  ('Novak Djokovic',
#   'Yoshihito Nishioka'): Text(-0.03115960571482923, -0.6541190400735528, '1'),
#  ('Novak Djokovic',
#   'Stefanos Tsitsipas'): Text(-0.7204569216055537, -0.686954255281356, '2'),
#  ('Novak Djokovic',
#   'Karen Khachanov'): Text(-0.3692356390161975, -0.8085131296740187, '2'),
#  ('Novak Djokovic',
#   'Philipp Kohlschreiber'): Text(-0.6430265097207333, -0.7420921873765188, '1'),
#  ('Novak Djokovic',
#   'Ricardas Berankis'): Text(0.027600172804295386, -0.5793999093590139, '2'),
#  ('Novak Djokovic',
#   'Damir Dzumhur'): Text(-0.46418406268885704, -0.8039901802336994, '1'),
#  ('Novak Djokovic',
#   'Kyle Edmund'): Text(0.09793779590004015, -0.40370504949554953, '1'),
#  ('Novak Djokovic',
#   'Casper Ruud'): Text(-0.5565604360529763, -0.7815799067652432, '1'),
#  ('Novak Djokovic',
#   'Daniel Elahi Galan Riveros'): Text(-0.1853190020273663, -0.7638954471448437, '1'),
#  ('Novak Djokovic',
#   'Pablo Carreno Busta'): Text(0.0711573992998995, -0.4949106982336743, '2'),
#  ('Novak Djokovic',
#   'Lorenzo Sonego'): Text(-0.2751470831217353, -0.7949852595461913, '1'),
#  ('Stefanos Tsitsipas',
#   'Jan Lennard Struff'): Text(-0.0374018213249675, -0.7851627121470226, '2'),
#  ('Stefanos Tsitsipas',
#   'Philipp Kohlschreiber'): Text(-0.5774303168899182, -0.8108875104921235, '1'),
#  ('Stefanos Tsitsipas',
#   'Pablo Carreno Busta'): Text(0.1367535921307147, -0.5637060213492789, '1'),
#  ('Casper Ruud',
#   'Karen Khachanov'): Text(-0.13974296063280492, -0.9719341042735106, '1'),
#  ('Casper Ruud',
#   'Lorenzo Sonego'): Text(-0.04565440473834273, -0.9584062341456832, '1'),
#  ('Karen Khachanov',
#   'Jan Lennard Struff'): Text(0.31381946126438875, -0.9067215865396853, '1'),
#  ('Karen Khachanov',
#   'Pablo Carreno Busta'): Text(0.48797487472007095, -0.6852648957419416, '1'),
#  ('Jan Lennard Struff',
#   'Yoshihito Nishioka'): Text(0.651895494565757, -0.7523274969392194, '1'),
#  ('Jan Lennard Struff',
#   'Pablo Carreno Busta'): Text(0.7542124995804858, -0.5931191550993409, '1'),
#  ('Yoshihito Nishioka',
#   'Kyle Edmund'): Text(0.8528313046215799, -0.439665157403351, '1'),
#  ('Ricardas Berankis',
#   'Pablo Carreno Busta'): Text(0.8848106865405638, -0.4561516754269368, '1')}

# %%
from collections import Counter
from operator import itemgetter
def plot_deg_frequency(G, weighted=False, xscale = "log", yscale = "log"):

    if weighted:
        degrees = G.degree(weight="weight")
    else:
        degrees = G.degree()
    _, deg_list = zip(*degrees)
    deg_counts = Counter(deg_list)     
    print(deg_counts)
    x, y = zip(*deg_counts.items())                                                      

    plt.figure(1)   

    # prep axes   
    if weighted:
        plt.xlabel('weighted degree')  
    else:
        plt.xlabel('degree')                                                                                                             
    plt.xscale(xscale)                                                                                                                
    plt.xlim(1, max(x))  

    plt.ylabel('frequency')                                                                                                          
    plt.yscale(yscale)                                                                                                                
    plt.ylim(1, max(y))                                                                                                             
                                                                                                                                                                                                    
    plt.scatter(x, y, marker='.')                                                                                                    
    plt.show()

# %%
 plot_deg_frequency(G)
# Out:
# Counter({1: 75, 2: 34, 3: 23, 4: 15, 5: 13, 6: 12, 19: 8, 10: 7, 8: 7, 20: 7, 17: 7, 15: 6, 7: 6, 26: 6, 13: 5, 14: 5, 27: 5, 21: 5, 28: 4, 25: 4, 12: 4, 11: 4, 30: 4, 23: 4, 22: 3, 16: 3, 18: 3, 29: 2, 9: 2, 24: 2, 32: 1, 33: 1, 37: 1, 43: 1})

# %%
plot_deg_frequency(G, weighted = True)
# Out:
# Counter({1: 75, 2: 34, 3: 23, 4: 15, 6: 12, 5: 12, 20: 8, 15: 7, 8: 7, 23: 7, 22: 6, 7: 6, 30: 5, 14: 5, 31: 5, 10: 5, 19: 5, 28: 5, 12: 5, 16: 3, 27: 3, 11: 3, 32: 3, 18: 3, 34: 3, 13: 3, 9: 3, 26: 3, 17: 3, 21: 3, 25: 1, 39: 1, 41: 1, 46: 1, 43: 1, 38: 1, 42: 1, 29: 1, 51: 1})

# %%
#slucajno generisana mreza Gnm ima normalnu distribuciju!
n = G.number_of_nodes()
m = G.number_of_edges()
Gnm = nx.gnm_random_graph(n, m) 

plot_deg_frequency(Gnm, xscale = 'linear', yscale = 'linear')
plot_deg_frequency(Gnm, xscale = 'log', yscale = 'log')
# Out:
# Counter({8: 39, 10: 38, 9: 37, 7: 29, 6: 28, 11: 23, 12: 22, 5: 22, 13: 21, 4: 10, 14: 6, 15: 5, 3: 5, 17: 2, 2: 1, 16: 1})
# Counter({8: 39, 10: 38, 9: 37, 7: 29, 6: 28, 11: 23, 12: 22, 5: 22, 13: 21, 4: 10, 14: 6, 15: 5, 3: 5, 17: 2, 2: 1, 16: 1})

# %%
#Kako bi se ponašala Erdos-Renyi mreža sa koja ima isti broj čvorova n, a verovatnoća formiranja grane je takva da je očekivani broj grana u mreži m?
p = ( 2*float(m) ) / ( n* (n-1) )
print(p)

er_mreza = nx.erdos_renyi_graph(n,p)

delta_m = m - er_mreza.number_of_edges()
print(f"Broj čvorova originalne mreže minus broj čvorova u ER mreži iznosi {delta_m}, što je odstupanje od {abs(float(delta_m)) * 100 / m}%")

plot_deg_frequency(er_mreza, xscale = 'linear', yscale = 'linear')
plot_deg_frequency(er_mreza, xscale = 'log', yscale = 'log')
#Šta nam informacije o raspodeli stepena čvora govore o ovoj mreži?

# Da je mreža bila sa slučajnim vezivanjem, očekivali bismo da raspodela bude slična normalnoj raspodeli! Sto i lici!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Out:
# 0.03078143021914648
# Broj čvorova originalne mreže minus broj čvorova u ER mreži iznosi -31, što je odstupanje od 2.419984387197502%
# Counter({9: 34, 7: 34, 8: 33, 10: 30, 11: 30, 12: 28, 6: 26, 5: 19, 13: 12, 4: 12, 15: 8, 16: 6, 14: 5, 3: 5, 18: 4, 1: 1, 2: 1, 19: 1})
# Counter({9: 34, 7: 34, 8: 33, 10: 30, 11: 30, 12: 28, 6: 26, 5: 19, 13: 12, 4: 12, 15: 8, 16: 6, 14: 5, 3: 5, 18: 4, 1: 1, 2: 1, 19: 1})

# %%
#Asortativnost (eng. assortativity) meri stepen tendencije čvorova mreže da se vezuju sa sličnim čvorovima. 
#U ovoj analizi ćemo prvo sprovesti analizu asortativnosti na osnovu stepena čvora, jer nas interesuje da li se međusobno vezuju čvorovi koji su sličnog stepena, 
#ili habovi (čvorovi velikog stepena) teže da se slabo međusobno vezuju, a mnogo vezuju sa čvorovima malog stepena.
#Uvodi se koeficijent asortativnosti r, koji je u opsegu od -1 do 1. 
#Mreža sa r = 1 iskazuje savršeno asortativno mešanje (perfect assortative mixing pattern), kad je r = 0 mreža je neasortativna ili neutralna, dok je u slučaju r = −1 mreža potpuno disasortativna.
# asortativnost na osnovu netežinskog stepena čvora
r1 = nx.degree_assortativity_coefficient(G)
print(f"Koeficijent asortativnosti na osnovu netežinskog stepena čvora: {r1}")

# asortativnost na osnovu težinskog stepena čvora
r2 = nx.degree_assortativity_coefficient(G, weight='weight')
print(f"Koeficijent asortativnosti na osnovu težinskog stepena čvora: {r2}")
# Out:
# Koeficijent asortativnosti na osnovu netežinskog stepena čvora: 0.187717202898284
# Koeficijent asortativnosti na osnovu težinskog stepena čvora: 0.192366245435689

# %%
#Kao što vidimo, mreža je neutralna tj. neasortativna, odnosno, čvorovi sličnog stepena uglavnom se ne vezuju međusobno.

# %%
#ANALIZA KOMUNA
#Stepen klasterisanja može se proceniti na osnovu koeficijenta klasterisanja.
id_igraca, clustering_coef = zip(*nx.clustering(G, weight = "weight").items())

nenula = [(id_ig, cc)  for id_ig, cc in zip(id_igraca, clustering_coef) if cc > 0]

df = pd.DataFrame(nenula, columns = ["id", "cc"])
df.sort_values('cc', inplace = True)

max_lokalni_stepen_klasterisanja = max(clustering_coef)

prosecni_stepen_klasterisanja = nx.average_clustering(G)

print(f"Max lokalni cc: {max_lokalni_stepen_klasterisanja}")
print(f"Prosečan cc: {prosecni_stepen_klasterisanja}")
print("Lokalni stepeni klasterisanja koji nisu nula:")
print(df)
# Out:
# Max lokalni cc: 0.33333333333333337
# Prosečan cc: 0.10539553936157692
# Lokalni stepeni klasterisanja koji nisu nula:
#                          id        cc
# 152            Hugo Dellien  0.006061
# 51        Ricardas Berankis  0.011057
# 97        Yasutaka Uchiyama  0.011905
# 10              Pedro Sousa  0.011905
# 105  Pedro Martinez Portero  0.022059
# ..                      ...       ...
# 74       Alexander Cozbinov  0.333333
# 130            Steve Darcis  0.333333
# 95            Mischa Zverev  0.333333
# 115           Quentin Halys  0.333333
# 30               Kacper Zuk  0.333333
#
# [156 rows x 2 columns]

# %%
# možemo iskoristiti networkx.draw_network da predstavimo egomrežu tog čvora
ego_mreza = nx.ego_graph(G, 'Kacper Zuk')
print(f"Čvorovi ego mreže igrača Kacper Zuk su {ego_mreza.nodes}")
plt.figure(figsize=(15,10))
tezine_grana = nx.get_edge_attributes(ego_mreza,'weight')
pos = nx.circular_layout(ego_mreza)
#pos = nx.spring_layout(ego_mreza)
#print(pos)
nx.draw_networkx(ego_mreza, pos)
nx.draw_networkx_edge_labels(ego_mreza, pos, edge_labels = tezine_grana)
# Out:
# Čvorovi ego mreže igrača Kacper Zuk su ['Marin Cilic', 'Kacper Zuk', 'Dennis Novak']
# {('Marin Cilic',
#   'Dennis Novak'): Text(0.2500000372529033, -0.43301270835610933, '1'),
#  ('Marin Cilic',
#   'Kacper Zuk'): Text(0.24999996274709668, 0.43301271829021687, '1'),
#  ('Kacper Zuk', 'Dennis Novak'): Text(-0.5, -9.934107536579972e-09, '1')}

# %%
# možemo iskoristiti networkx.draw_network da predstavimo egomrežu tog čvora
ego_mreza = nx.ego_graph(G, 'Alexander Cozbinov')
print(f"Čvorovi ego mreže igrača Alexander Cozbinov su {ego_mreza.nodes}")
plt.figure(figsize=(15,10))
tezine_grana = nx.get_edge_attributes(ego_mreza,'weight')
pos = nx.circular_layout(ego_mreza)
#pos = nx.spring_layout(ego_mreza)
#print(pos)
nx.draw_networkx(ego_mreza, pos)
nx.draw_networkx_edge_labels(ego_mreza, pos, edge_labels = tezine_grana)
# Out:
# Čvorovi ego mreže igrača Alexander Cozbinov su ['Cameron Norrie', 'Alexander Cozbinov', 'Dimitar Kuzmanov', 'Steve Darcis']
# {('Cameron Norrie',
#   'Steve Darcis'): Text(0.50000000298122, -0.49999996721645945, '1'),
#  ('Cameron Norrie',
#   'Alexander Cozbinov'): Text(0.4999999751630862, 0.5000000109278468, '1'),
#  ('Cameron Norrie',
#   'Dimitar Kuzmanov'): Text(7.946626690014114e-09, -2.1855693665697605e-08, '1'),
#  ('Alexander Cozbinov',
#   'Steve Darcis'): Text(-7.946626738379675e-09, 2.1855693699279755e-08, '1'),
#  ('Alexander Cozbinov',
#   'Dimitar Kuzmanov'): Text(-0.50000000298122, 0.4999999672164595, '1'),
#  ('Dimitar Kuzmanov',
#   'Steve Darcis'): Text(-0.49999997516308625, -0.5000000109278468, '1')}

# %%
# možemo iskoristiti networkx.draw_network da predstavimo egomrežu tog čvora
ego_mreza = nx.ego_graph(G, 'Rafael Nadal')
print(f"Čvorovi ego mreže igrača Rafael Nadal su {ego_mreza.nodes}")
plt.figure(figsize=(15,10))
tezine_grana = nx.get_edge_attributes(ego_mreza,'weight')
pos = nx.circular_layout(ego_mreza)
#pos = nx.spring_layout(ego_mreza)
#print(pos)
nx.draw_networkx(ego_mreza, pos)
nx.draw_networkx_edge_labels(ego_mreza, pos, edge_labels = tezine_grana)
# Out:
# Čvorovi ego mreže igrača Rafael Nadal su ['Miomir Kecmanovic', 'Alexander Zverev', 'Dusan Lajovic', 'Pablo Andujar', 'Stefano Travaglia', 'Dominic Thiem', 'Feliciano Lopez', 'Daniil Medvedev', 'Diego Sebastian Schwartzman', 'Pablo Cuevas', 'Rafael Nadal', 'Jordan Thompson', 'Sebastian Korda', 'Taylor Harry Fritz', 'Novak Djokovic', 'Stefanos Tsitsipas', 'Andrey Rublev', 'Soon Woo Kwon', 'Nikoloz Basilashvili', 'Egor Gerasimov', 'Jannik Sinner', 'Hugo Dellien', 'Alex De Minaur', 'David Goffin', 'Federico Delbonis', 'Mackenzie Mcdonald', 'Yoshihito Nishioka', 'Nick Kyrgios', 'Grigor Dimitrov', 'Pablo Carreno Busta']
# {('Miomir Kecmanovic',
#   'Rafael Nadal'): Text(0.2499999718740583, 0.43301270997439123, '1'),
#  ('Miomir Kecmanovic',
#   'Yoshihito Nishioka'): Text(0.8345653716447232, -0.37157235764517443, '1'),
#  ('Miomir Kecmanovic',
#   'Diego Sebastian Schwartzman'): Text(0.4477357466942018, 0.49726097366669214, '1'),
#  ('Miomir Kecmanovic',
#   'Andrey Rublev'): Text(0.010926219051496211, -0.10395587765443091, '1'),
#  ('Miomir Kecmanovic',
#   'Alexander Zverev'): Text(0.9890738129860002, 0.10395586659463336, '1'),
#  ('Miomir Kecmanovic',
#   'Alex De Minaur'): Text(0.4477358323758785, -0.49726094002300625, '1'),
#  ('Miomir Kecmanovic',
#   'Federico Delbonis'): Text(0.6545085616681533, -0.475528222319126, '1'),
#  ('Miomir Kecmanovic',
#   'Jordan Thompson'): Text(0.16543466039277316, 0.37157242109118266, '3'),
#  ('Alexander Zverev',
#   'Rafael Nadal'): Text(0.23907378486005854, 0.5369685597471816, '1'),
#  ('Alexander Zverev',
#   'Diego Sebastian Schwartzman'): Text(0.436809559680202, 0.6012168234394826, '2'),
#  ('Alexander Zverev',
#   'Pablo Carreno Busta'): Text(0.9781475961696782, -1.2980479358049024e-08, '1'),
#  ('Alexander Zverev',
#   'Novak Djokovic'): Text(2.235174156872688e-09, 0.20791167166394028, '1'),
#  ('Alexander Zverev',
#   'Daniil Medvedev'): Text(0.5413380238234892, 0.6012168234394826, '2'),
#  ('Alexander Zverev',
#   'Dominic Thiem'): Text(0.7390737986436325, 0.536968589549504, '2'),
#  ('Alexander Zverev',
#   'Stefanos Tsitsipas'): Text(-0.010926184778825565, 0.10395582288324517, '1'),
#  ('Alexander Zverev',
#   'Alex De Minaur'): Text(0.4368096453618787, -0.3933050902502158, '1'),
#  ('Alexander Zverev',
#   'Jannik Sinner'): Text(0.23907385936586434, -0.3290568563602372, '2'),
#  ('Alexander Zverev',
#   'Egor Gerasimov'): Text(0.15450856278574038, -0.2676165674770286, '1'),
#  ('Alexander Zverev',
#   'Andrey Rublev'): Text(3.20374964335457e-08, -2.7881640524141105e-08, '1'),
#  ('Dusan Lajovic',
#   'Rafael Nadal'): Text(0.2067726868239655, 0.636381030580962, '1'),
#  ('Dusan Lajovic',
#   'Diego Sebastian Schwartzman'): Text(0.404508461644109, 0.7006292942732628, '1'),
#  ('Dusan Lajovic',
#   'Stefanos Tsitsipas'): Text(-0.04322728281491861, 0.20336829371702544, '1'),
#  ('Dusan Lajovic',
#   'Pablo Carreno Busta'): Text(0.9458464981335851, 0.09941245785330093, '1'),
#  ('Dusan Lajovic',
#   'Egor Gerasimov'): Text(0.12220746474964733, -0.16820409664324834, '1'),
#  ('Dusan Lajovic',
#   'Soon Woo Kwon'): Text(2.2351741013615367e-09, -2.788164055189668e-08, '1'),
#  ('Pablo Andujar',
#   'Rafael Nadal'): Text(0.15450847337877344, 0.7269053313115086, '1'),
#  ('Pablo Andujar',
#   'Yoshihito Nishioka'): Text(0.7390738731494384, -0.07767973630805708, '1'),
#  ('Pablo Andujar',
#   'Stefano Travaglia'): Text(0.7390737837424715, 0.6654650722306223, '1'),
#  ('Pablo Andujar',
#   'Feliciano Lopez'): Text(0.5590169886670626, 0.7694209071022515, '1'),
#  ('Pablo Andujar',
#   'Federico Delbonis'): Text(0.5590170631728685, -0.18163560098200865, '1'),
#  ('Stefano Travaglia',
#   'Taylor Harry Fritz'): Text(-0.12220746027929902, 0.5749407416977534, '2'),
#  ('Stefano Travaglia',
#   'Rafael Nadal'): Text(0.08456525411181465, 0.8045851440460533, '1'),
#  ('Stefano Travaglia',
#   'Alex De Minaur'): Text(0.28230111461363483, -0.12568850595134418, '1'),
#  ('Stefano Travaglia',
#   'Jordan Thompson'): Text(-5.7369470507495635e-08, 0.7431448551628448, '1'),
#  ('Dominic Thiem',
#   'Rafael Nadal'): Text(-4.2468309341403554e-08, 0.8660254329292618, '2'),
#  ('Dominic Thiem',
#   'Daniil Medvedev'): Text(0.30226419649512126, 0.9302736966215628, '2'),
#  ('Dominic Thiem',
#   'Diego Sebastian Schwartzman'): Text(0.19773573235183414, 0.9302736966215628, '2'),
#  ('Dominic Thiem',
#   'Novak Djokovic'): Text(-0.23907382509319372, 0.5369685448460205, '2'),
#  ('Dominic Thiem',
#   'Andrey Rublev'): Text(-0.23907379529087144, 0.3290568453004397, '2'),
#  ('Dominic Thiem',
#   'Stefanos Tsitsipas'): Text(-0.25000001210719347, 0.4330126960653254, '1'),
#  ('Dominic Thiem',
#   'Alex De Minaur'): Text(0.1977358180335108, -0.0642482170681356, '1'),
#  ('Dominic Thiem',
#   'Taylor Harry Fritz'): Text(-0.206772756859423, 0.636381030580962, '1'),
#  ('Feliciano Lopez',
#   'Rafael Nadal'): Text(-0.09549154096359416, 0.9085409789176826, '1'),
#  ('Daniil Medvedev',
#   'Rafael Nadal'): Text(-0.1977358172884528, 0.9302736668192404, '1'),
#  ('Daniil Medvedev',
#   'Novak Djokovic'): Text(-0.4368095999133372, 0.6012167787359991, '2'),
#  ('Daniil Medvedev',
#   'Diego Sebastian Schwartzman'): Text(-4.246830929977019e-08, 0.9945219305115414, '3'),
#  ('Daniil Medvedev',
#   'Alex De Minaur'): Text(4.32133673775037e-08, 1.6821842974135137e-08, '1'),
#  ('Daniil Medvedev',
#   'Federico Delbonis'): Text(0.20677277250564222, 0.02173273452572322, '1'),
#  ('Daniil Medvedev',
#   'Jannik Sinner'): Text(-0.197735742782647, 0.06424825071182161, '1'),
#  ('Daniil Medvedev',
#   'Andrey Rublev'): Text(-0.4368095701110149, 0.3933050791904183, '1'),
#  ('Diego Sebastian Schwartzman',
#   'Rafael Nadal'): Text(-0.3022642814317399, 0.9302736668192404, '2'),
#  ('Diego Sebastian Schwartzman',
#   'Novak Djokovic'): Text(-0.5413380640566242, 0.6012167787359991, '3'),
#  ('Diego Sebastian Schwartzman',
#   'Pablo Cuevas'): Text(-0.20677276803529387, 0.9727892128076612, '1'),
#  ('Diego Sebastian Schwartzman',
#   'Federico Delbonis'): Text(0.10224430836235512, 0.02173273452572322, '1'),
#  ('Pablo Cuevas',
#   'Rafael Nadal'): Text(-0.40450854285543736, 0.9085409491153602, '1'),
#  ('Pablo Cuevas',
#   'Yoshihito Nishioka'): Text(0.1800568569152276, 0.10395588149579454, '1'),
#  ('Pablo Cuevas',
#   'Nikoloz Basilashvili'): Text(-0.5590169841967143, 0.18163557502105, '1'),
#  ('Pablo Cuevas',
#   'Stefanos Tsitsipas'): Text(-0.6545085124943215, 0.4755282122514237, '2'),
#  ('Pablo Cuevas',
#   'Federico Delbonis'): Text(4.693865765514893e-08, 1.6821842974135137e-08, '1'),
#  ('Pablo Cuevas',
#   'Taylor Harry Fritz'): Text(-0.611281257246551, 0.6788965467670602, '1'),
#  ('Rafael Nadal',
#   'Novak Djokovic'): Text(-0.7390738388767677, 0.5369685150436981, '2'),
#  ('Rafael Nadal',
#   'David Goffin'): Text(-0.19773584709077513, -0.06424824687045794, '1'),
#  ('Rafael Nadal',
#   'Yoshihito Nishioka'): Text(0.08456534351878159, 0.06144033550737388, '1'),
#  ('Rafael Nadal',
#   'Stefanos Tsitsipas'): Text(-0.7500000258907675, 0.43301266626300305, '1'),
#  ('Rafael Nadal',
#   'Pablo Carreno Busta'): Text(0.23907375505773626, 0.3290568303992785, '3'),
#  ('Rafael Nadal',
#   'Nick Kyrgios'): Text(0.1545084435764511, 0.1391200588349516, '1'),
#  ('Rafael Nadal',
#   'Nikoloz Basilashvili'): Text(-0.6545084975931603, 0.13912002903262932, '1'),
#  ('Rafael Nadal',
#   'Alex De Minaur'): Text(-0.3022641957500632, -0.06424824687045794, '1'),
#  ('Rafael Nadal',
#   'Hugo Dellien'): Text(-0.4045085726577597, -0.04251552916657769, '1'),
#  ('Rafael Nadal',
#   'Federico Delbonis'): Text(-0.09549146645778836, -0.04251552916657769, '1'),
#  ('Rafael Nadal',
#   'Taylor Harry Fritz'): Text(-0.706772770642997, 0.6363810007786397, '1'),
#  ('Rafael Nadal',
#   'Grigor Dimitrov'): Text(0.20677274642861015, 0.22964446387362633, '1'),
#  ('Rafael Nadal',
#   'Soon Woo Kwon'): Text(-0.7067727408406748, 0.22964434466433706, '1'),
#  ('Rafael Nadal',
#   'Egor Gerasimov'): Text(-0.5845652783262015, 0.06144027590272927, '1'),
#  ('Rafael Nadal',
#   'Mackenzie Mcdonald'): Text(-7.227063164583214e-08, -1.2980479302537873e-08, '1'),
#  ('Rafael Nadal',
#   'Sebastian Korda'): Text(-0.654508557197805, 0.7269053015091862, '1'),
#  ('Rafael Nadal',
#   'Jannik Sinner'): Text(-0.49999998174607757, -1.2980479302537873e-08, '1'),
#  ('Rafael Nadal',
#   'Jordan Thompson'): Text(-0.5845653677331686, 0.804585114243731, '1'),
#  ('Rafael Nadal',
#   'Andrey Rublev'): Text(-0.7390738090744455, 0.3290568154981174, '1'),
#  ('Jordan Thompson',
#   'Federico Delbonis'): Text(-0.18005677793907351, -0.10395581804978626, '1'),
#  ('Jordan Thompson',
#   'Egor Gerasimov'): Text(-0.6691305898074866, -1.2980479302537873e-08, '1'),
#  ('Novak Djokovic',
#   'Yoshihito Nishioka'): Text(-0.1545084391061028, -0.2676165525758675, '1'),
#  ('Novak Djokovic',
#   'Stefanos Tsitsipas'): Text(-0.9890738085156519, 0.1039557781797617, '2'),
#  ('Novak Djokovic',
#   'Pablo Carreno Busta'): Text(-2.7567148119800322e-08, -5.768396282856969e-08, '2'),
#  ('Stefanos Tsitsipas',
#   'Nick Kyrgios'): Text(-0.095491526062433, -0.2938926780289849, '1'),
#  ('Stefanos Tsitsipas',
#   'Grigor Dimitrov'): Text(-0.043227223210273946, -0.20336827299031016, '2'),
#  ('Stefanos Tsitsipas',
#   'Andrey Rublev'): Text(-0.9890737787133296, -0.1039559213658191, '3'),
#  ('Stefanos Tsitsipas',
#   'Jannik Sinner'): Text(-0.7499999513849617, -0.4330127498444158, '1'),
#  ('Stefanos Tsitsipas',
#   'Pablo Carreno Busta'): Text(-0.010926214581147842, -0.10395590646465794, '1'),
#  ('Andrey Rublev',
#   'Nikoloz Basilashvili'): Text(-0.8935822504157225, -0.39784855859619284, '1'),
#  ('Andrey Rublev',
#   'Jannik Sinner'): Text(-0.7390737345686397, -0.5369686006093015, '1'),
#  ('Andrey Rublev',
#   'David Goffin'): Text(-0.43680959991333723, -0.6012168344992801, '1'),
#  ('Soon Woo Kwon',
#   'Nikoloz Basilashvili'): Text(-0.8612811821819517, -0.4972610294299732, '1'),
#  ('Soon Woo Kwon',
#   'Egor Gerasimov'): Text(-0.7913379629149929, -0.5749407825598732, '1'),
#  ('Nikoloz Basilashvili',
#   'Yoshihito Nishioka'): Text(-0.06994309782249536, -0.6654650385869363, '1'),
#  ('Nikoloz Basilashvili',
#   'Federico Delbonis'): Text(-0.2499999077990653, -0.7694209032608879, '1'),
#  ('Egor Gerasimov',
#   'David Goffin'): Text(-0.2823010691650933, -0.8688333740946682, '1'),
#  ('Jannik Sinner',
#   'Alex De Minaur'): Text(-0.3022641212442574, -0.9302736629778767, '1'),
#  ('Jannik Sinner',
#   'Grigor Dimitrov'): Text(0.20677282093441596, -0.6363809522337925, '1'),
#  ('Jannik Sinner',
#   'Pablo Carreno Busta'): Text(0.23907382956354206, -0.5369685857081403, '1'),
#  ('Jannik Sinner',
#   'David Goffin'): Text(-0.19773577258496933, -0.9302736629778767, '2'),
#  ('Hugo Dellien',
#   'Federico Delbonis'): Text(1.713633532296477e-08, -0.9510564614600949, '1'),
#  ('David Goffin',
#   'Grigor Dimitrov'): Text(0.5090369555897184, -0.7006291861237711, '1'),
#  ('Yoshihito Nishioka',
#   'Grigor Dimitrov'): Text(0.7913381461992751, -0.5749406037459394, '1')}

# %%
# možemo iskoristiti networkx.draw_network da predstavimo egomrežu tog čvora
ego_mreza = nx.ego_graph(G, 'Roger Federer')
print(f"Čvorovi ego mreže igrača Roger Federer su {ego_mreza.nodes}")
plt.figure(figsize=(15,10))
tezine_grana = nx.get_edge_attributes(ego_mreza,'weight')
pos = nx.circular_layout(ego_mreza)
#pos = nx.spring_layout(ego_mreza)
#print(pos)
nx.draw_networkx(ego_mreza, pos)
nx.draw_networkx_edge_labels(ego_mreza, pos, edge_labels = tezine_grana)
# Out:
# Čvorovi ego mreže igrača Roger Federer su ['Filip Krajinovic', 'Novak Djokovic', 'John Millman', 'Tennys Sandgren', 'Marton Fucsovics', 'Roger Federer', 'Steve Johnson']
# {('Filip Krajinovic',
#   'Novak Djokovic'): Text(0.8117449033666108, 0.3909157499862803, '2'),
#  ('Filip Krajinovic',
#   'Roger Federer'): Text(0.3887395120840538, -0.48746393014369865, '1'),
#  ('Filip Krajinovic',
#   'Steve Johnson'): Text(0.8117448437619674, -0.39091579256102543, '1'),
#  ('Filip Krajinovic',
#   'Marton Fucsovics'): Text(0.04951559945049633, -0.2169418641428812, '1'),
#  ('Novak Djokovic',
#   'Roger Federer'): Text(0.20048441545066453, -0.09654818867236742, '1'),
#  ('Novak Djokovic',
#   'Tennys Sandgren'): Text(-0.1387394971828929, 0.6078576524464321, '1'),
#  ('John Millman',
#   'Roger Federer'): Text(-0.2225209460295708, 8.514949079163614e-09, '1'),
#  ('Tennys Sandgren',
#   'Roger Federer'): Text(-0.5617448884654499, -0.27052202768354683, '1'),
#  ('Tennys Sandgren',
#   'Steve Johnson'): Text(-0.1387395567875362, -0.1739738901008736, '1'),
#  ('Marton Fucsovics',
#   'Roger Federer'): Text(-0.5617448884654499, -0.7044058028015289, '1'),
#  ('Roger Federer',
#   'Steve Johnson'): Text(0.20048435584602126, -0.8783797312196732, '1')}

# %%
#CENTRALNOSTI
def calculate_centralities(G):

    DC_dict = nx.degree_centrality(G)
    CC_dict = nx.closeness_centrality(G)
    BC_dict = nx.betweenness_centrality(G)
    EVC_dict = nx.eigenvector_centrality(G)

    df1 = pd.DataFrame.from_dict(DC_dict, orient='index', columns=['DC'])
    df2 = pd.DataFrame.from_dict(CC_dict, orient='index', columns=['CC'])
    df3 = pd.DataFrame.from_dict(BC_dict, orient='index', columns=['BC'])
    df4 = pd.DataFrame.from_dict(EVC_dict, orient='index', columns=['EVC'])
    df = pd.concat([df1, df2, df3, df4], axis=1)
    return df
df = calculate_centralities(G)
print(df)
# Out:
#                        DC        CC        BC       EVC
# Cameron Norrie   0.065972  0.371279  0.025431  0.069060
# Federico Gaio    0.010417  0.279461  0.000329  0.004991
# Christian Garin  0.097222  0.395690  0.019209  0.121551
# Andreas Seppi    0.045139  0.348762  0.003371  0.043520
# John Millman     0.097222  0.396904  0.021825  0.125439
# ...                   ...       ...       ...       ...
# Timofey Skatov   0.003472  0.262989  0.000000  0.002646
# Nick Kyrgios     0.031250  0.353044  0.001062  0.055992
# Yuichi Sugita    0.034722  0.347824  0.010568  0.039727
# Ruben Bemelmans  0.006944  0.285001  0.000031  0.007407
# Emilio Gomez     0.013889  0.294739  0.000680  0.010448
#
# [289 rows x 4 columns]

# %%
#Korelacija - kako jedna metrika zavisi od druge, pozitivna korelacija znači da veća vrednost jedne od metrikka povlači veću vrednost druge metrike. 
#Interesantno je posmatrati Kendalovu tau korelaciju (korelaciju po rangu, ne po numeričkoj vrednosti) između različitih mera centralnosti ove mreže.
import scipy.stats as stats
labele = ['DC', 'CC', 'BC', 'EVC']
cross_correlation_matrix = pd.DataFrame(columns = ['DC', 'CC', 'BC', 'EVC'], index = ['DC', 'CC', 'BC', 'EVC'])
p_val_matrix = pd.DataFrame(columns = ['DC', 'CC', 'BC', 'EVC'], index = ['DC', 'CC', 'BC', 'EVC'])
for ind in labele:
    for col in labele:
        cross_correlation_matrix[ind][col], p_val_matrix[ind][col] =  stats.kendalltau(df[ind], df[col])
print(cross_correlation_matrix)
# Out:
#            DC        CC        BC       EVC
# DC          1  0.861485  0.798196  0.851408
# CC   0.861485         1  0.682901  0.958187
# BC   0.798196  0.682901         1    0.6657
# EVC  0.851408  0.958187    0.6657         1

# %%
#BC-posmatra samo puteve, najslabije sa EVC

# %%
print(p_val_matrix)
#p treba da bude sto manji, kako ne bi bilo da se slucajno desilo
# Out:
#                DC            CC            BC           EVC
# DC   1.92374e-120   3.57023e-97   2.55876e-79   3.65919e-95
# CC    3.57023e-97  7.30838e-141   2.98392e-63  8.98196e-130
# BC    2.55876e-79   2.98392e-63  2.01056e-126   2.52227e-60
# EVC   3.65919e-95  8.98196e-130   2.52227e-60  1.79138e-141

# %%
df = calculate_centralities(G)

df_ = df
for metric in labele:
    df_[f"{metric}_rank"] = df[f"{metric}"].rank(ascending=False) 
    
df_['composite_rank'] = df_['DC_rank'] * df_['CC_rank'] * df_['BC_rank'] * df_['EVC_rank']

df_.sort_values(['composite_rank'], ascending = True)
df_.sort_values(['CC'], ascending = False, inplace=True)
print(df_)
# Out:
#                              DC        CC        BC           EVC  DC_rank  \
# Andrey Rublev          0.149306  0.427738  0.034853  2.155424e-01      1.0
# Novak Djokovic         0.111111  0.415379  0.037248  1.587957e-01      4.0
# Felix Auger Aliassime  0.128472  0.415379  0.033573  1.804368e-01      2.0
# Casper Ruud            0.104167  0.410113  0.033000  1.347474e-01      6.5
# Stefanos Tsitsipas     0.114583  0.409464  0.030033  1.817233e-01      3.0
# ...                         ...       ...       ...           ...      ...
# Jordi Munoz Abreu      0.003472  0.003472  0.000000  5.908308e-13    252.0
# Pak Long Yeung         0.003472  0.003472  0.000000  5.908308e-13    252.0
# Jerzy Janowicz         0.003472  0.003472  0.000000  5.908308e-13    252.0
# Ben Fatael             0.003472  0.003472  0.000000  5.908308e-13    252.0
# Nam Hoang Ly           0.003472  0.003472  0.000000  5.908308e-13    252.0
#
#                        CC_rank  BC_rank  EVC_rank  composite_rank
# Andrey Rublev              1.0      3.0       1.0    3.000000e+00
# Novak Djokovic             2.5      2.0       5.0    1.000000e+02
# Felix Auger Aliassime      2.5      4.0       3.0    6.000000e+01
# Casper Ruud                4.0      5.0      12.0    1.560000e+03
# Stefanos Tsitsipas         5.0      7.0       2.0    2.100000e+02
# ...                        ...      ...       ...             ...
# Jordi Munoz Abreu        285.5    249.5     285.5    5.124875e+09
# Pak Long Yeung           285.5    249.5     285.5    5.124875e+09
# Jerzy Janowicz           285.5    249.5     285.5    5.124875e+09
# Ben Fatael               285.5    249.5     285.5    5.124875e+09
# Nam Hoang Ly             285.5    249.5     285.5    5.124875e+09
#
# [289 rows x 9 columns]
