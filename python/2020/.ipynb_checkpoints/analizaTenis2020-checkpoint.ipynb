# %%
# Vizuelna podešavanja okruženja (samo razvuče notebook na širinu ekrana)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import pandas as pd

# %%
data2020 = pd.read_csv("../podaci/atp_matches_2020.csv")
data2020.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2020-8888      Atp Cup    Hard         24             A      20200106
# 1  2020-8888      Atp Cup    Hard         24             A      20200106
# 2  2020-8888      Atp Cup    Hard         24             A      20200106
# 3  2020-8888      Atp Cup    Hard         24             A      20200106
# 4  2020-8888      Atp Cup    Hard         24             A      20200106
#
#    match_num  winner_id winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        300     104925         NaN          NaN  ...    51.0     39.0
# 1        299     105138         NaN          NaN  ...    35.0     21.0
# 2        298     104925         NaN          NaN  ...    57.0     35.0
# 3        297     105583         NaN          NaN  ...    54.0     39.0
# 4        296     104745         NaN          NaN  ...    55.0     37.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced winner_rank winner_rank_points  \
# 0       6.0    10.0        6.0        8.0         2.0             9055.0
# 1       6.0     9.0        5.0       10.0        10.0             2335.0
# 2      25.0    14.0        6.0       11.0         2.0             9055.0
# 3      14.0    12.0        0.0        1.0        34.0             1251.0
# 4      10.0    14.0        1.0        5.0         1.0             9985.0
#
#   loser_rank loser_rank_points
# 0        1.0            9985.0
# 1       34.0            1251.0
# 2        5.0            5705.0
# 3       17.0            1840.0
# 4       18.0            1775.0
#
# [5 rows x 49 columns]

# %%
print(data2020.dtypes)
# Out:
# tourney_id             object
# tourney_name           object
# surface                object
# draw_size               int64
# tourney_level          object
# tourney_date            int64
# match_num               int64
# winner_id               int64
# winner_seed            object
# winner_entry           object
# winner_name            object
# winner_hand            object
# winner_ht             float64
# winner_ioc             object
# winner_age            float64
# loser_id                int64
# loser_seed             object
# loser_entry            object
# loser_name             object
# loser_hand             object
# loser_ht              float64
# loser_ioc              object
# loser_age             float64
# score                  object
# best_of                 int64
# round                  object
# minutes               float64
# w_ace                 float64
# w_df                  float64
# w_svpt                float64
# w_1stIn               float64
# w_1stWon              float64
# w_2ndWon              float64
# w_SvGms               float64
# w_bpSaved             float64
# w_bpFaced             float64
# l_ace                 float64
# l_df                  float64
# l_svpt                float64
# l_1stIn               float64
# l_1stWon              float64
# l_2ndWon              float64
# l_SvGms               float64
# l_bpSaved             float64
# l_bpFaced             float64
# winner_rank           float64
# winner_rank_points    float64
# loser_rank            float64
# loser_rank_points     float64
# dtype: object

# %%
print("Broj redova: ", data2020.shape[0])
print("Broj kolona: ", data2020.shape[1])
# Out:
# Broj redova:  1447
# Broj kolona:  49

# %%
#is there any empty field
data2020.isna().any()
# Out:
# tourney_id            False
# tourney_name          False
# surface               False
# draw_size             False
# tourney_level         False
# tourney_date          False
# match_num             False
# winner_id             False
# winner_seed            True
# winner_entry           True
# winner_name           False
# winner_hand            True
# winner_ht              True
# winner_ioc            False
# winner_age             True
# loser_id              False
# loser_seed             True
# loser_entry            True
# loser_name            False
# loser_hand             True
# loser_ht               True
# loser_ioc             False
# loser_age              True
# score                  True
# best_of               False
# round                 False
# minutes                True
# w_ace                  True
# w_df                   True
# w_svpt                 True
# w_1stIn                True
# w_1stWon               True
# w_2ndWon               True
# w_SvGms                True
# w_bpSaved              True
# w_bpFaced              True
# l_ace                  True
# l_df                   True
# l_svpt                 True
# l_1stIn                True
# l_1stWon               True
# l_2ndWon               True
# l_SvGms                True
# l_bpSaved              True
# l_bpFaced              True
# winner_rank            True
# winner_rank_points     True
# loser_rank             True
# loser_rank_points      True
# dtype: bool

# %%
dataPlayers = pd.read_csv("../podaci/atp_players.csv")
dataPlayers.head()
# Out:
#    100001         Gardnar    Mulloy  R    19131122  USA
# 0  100002          Pancho    Segura  R  19210620.0  ECU
# 1  100003           Frank   Sedgman  R  19271002.0  AUS
# 2  100004        Giuseppe     Merlo  R  19271011.0  ITA
# 3  100005  Richard Pancho  Gonzales  R  19280509.0  USA
# 4  100006           Grant    Golden  R  19290821.0  USA

# %%
dataPlayers.columns=['player_id','first_name','last_name','hand','birth_date','country_code']
dataPlayers.head()
# Out:
#    player_id      first_name last_name hand  birth_date country_code
# 0     100002          Pancho    Segura    R  19210620.0          ECU
# 1     100003           Frank   Sedgman    R  19271002.0          AUS
# 2     100004        Giuseppe     Merlo    R  19271011.0          ITA
# 3     100005  Richard Pancho  Gonzales    R  19280509.0          USA
# 4     100006           Grant    Golden    R  19290821.0          USA

# %%
print(dataPlayers.dtypes)
# Out:
# player_id         int64
# first_name       object
# last_name        object
# hand             object
# birth_date      float64
# country_code     object
# dtype: object

# %%
print("Broj redova: ", dataPlayers.shape[0])
print("Broj kolona: ", dataPlayers.shape[1])
# Out:
# Broj redova:  54974
# Broj kolona:  6

# %%
#is there any empty field
dataPlayers.isna().any()
# Out:
# player_id       False
# first_name       True
# last_name        True
# hand             True
# birth_date       True
# country_code     True
# dtype: bool

# %%
print(dataPlayers['player_id'].isnull().values.any())
print(dataPlayers['player_id'].is_unique)
# Out:
# False
# True

# %%
#add new column winner with full name
dataPlayers["winner_full_name"] = dataPlayers["first_name"] + " " + dataPlayers["last_name"]
dataPlayers.head()
# Out:
#    player_id      first_name last_name hand  birth_date country_code  \
# 0     100002          Pancho    Segura    R  19210620.0          ECU
# 1     100003           Frank   Sedgman    R  19271002.0          AUS
# 2     100004        Giuseppe     Merlo    R  19271011.0          ITA
# 3     100005  Richard Pancho  Gonzales    R  19280509.0          USA
# 4     100006           Grant    Golden    R  19290821.0          USA
#
#           winner_full_name
# 0            Pancho Segura
# 1            Frank Sedgman
# 2           Giuseppe Merlo
# 3  Richard Pancho Gonzales
# 4             Grant Golden

# %%
#add new column winner with full name
dataPlayers["loser_full_name"] = dataPlayers["first_name"] + " " + dataPlayers["last_name"]
dataPlayers.head()
# Out:
#    player_id      first_name last_name hand  birth_date country_code  \
# 0     100002          Pancho    Segura    R  19210620.0          ECU
# 1     100003           Frank   Sedgman    R  19271002.0          AUS
# 2     100004        Giuseppe     Merlo    R  19271011.0          ITA
# 3     100005  Richard Pancho  Gonzales    R  19280509.0          USA
# 4     100006           Grant    Golden    R  19290821.0          USA
#
#           winner_full_name          loser_full_name
# 0            Pancho Segura            Pancho Segura
# 1            Frank Sedgman            Frank Sedgman
# 2           Giuseppe Merlo           Giuseppe Merlo
# 3  Richard Pancho Gonzales  Richard Pancho Gonzales
# 4             Grant Golden             Grant Golden

# %%
#check if match number is unique
print(data2020['match_num'].isnull().values.any())
print(data2020['match_num'].is_unique)
# Out:
# False
# False

# %%
#add column match_id as unique
data2020['match_id'] = data2020.index
data2020.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2020-8888      Atp Cup    Hard         24             A      20200106
# 1  2020-8888      Atp Cup    Hard         24             A      20200106
# 2  2020-8888      Atp Cup    Hard         24             A      20200106
# 3  2020-8888      Atp Cup    Hard         24             A      20200106
# 4  2020-8888      Atp Cup    Hard         24             A      20200106
#
#    match_num  winner_id winner_seed winner_entry  ... l_1stWon l_2ndWon  \
# 0        300     104925         NaN          NaN  ...     39.0      6.0
# 1        299     105138         NaN          NaN  ...     21.0      6.0
# 2        298     104925         NaN          NaN  ...     35.0     25.0
# 3        297     105583         NaN          NaN  ...     39.0     14.0
# 4        296     104745         NaN          NaN  ...     37.0     10.0
#
#    l_SvGms l_bpSaved  l_bpFaced  winner_rank winner_rank_points loser_rank  \
# 0     10.0       6.0        8.0          2.0             9055.0        1.0
# 1      9.0       5.0       10.0         10.0             2335.0       34.0
# 2     14.0       6.0       11.0          2.0             9055.0        5.0
# 3     12.0       0.0        1.0         34.0             1251.0       17.0
# 4     14.0       1.0        5.0          1.0             9985.0       18.0
#
#   loser_rank_points match_id
# 0            9985.0        0
# 1            1251.0        1
# 2            5705.0        2
# 3            1840.0        3
# 4            1775.0        4
#
# [5 rows x 50 columns]

# %%
data_short2020=data2020[['match_num','winner_id','loser_id','match_id']]
data_short2020.head()
# Out:
#    match_num  winner_id  loser_id  match_id
# 0        300     104925    104745         0
# 1        299     105138    105583         1
# 2        298     104925    106421         2
# 3        297     105583    111575         3
# 4        296     104745    200282         4

# %%
dataPlayers.head()
# Out:
#    player_id      first_name last_name hand  birth_date country_code  \
# 0     100002          Pancho    Segura    R  19210620.0          ECU
# 1     100003           Frank   Sedgman    R  19271002.0          AUS
# 2     100004        Giuseppe     Merlo    R  19271011.0          ITA
# 3     100005  Richard Pancho  Gonzales    R  19280509.0          USA
# 4     100006           Grant    Golden    R  19290821.0          USA
#
#           winner_full_name          loser_full_name
# 0            Pancho Segura            Pancho Segura
# 1            Frank Sedgman            Frank Sedgman
# 2           Giuseppe Merlo           Giuseppe Merlo
# 3  Richard Pancho Gonzales  Richard Pancho Gonzales
# 4             Grant Golden             Grant Golden

# %%
dataPlayers_short_winner = dataPlayers[['player_id','winner_full_name']]
dataPlayers_short_winner.head()
# Out:
#    player_id         winner_full_name
# 0     100002            Pancho Segura
# 1     100003            Frank Sedgman
# 2     100004           Giuseppe Merlo
# 3     100005  Richard Pancho Gonzales
# 4     100006             Grant Golden

# %%
dataPlayers_short_loser=dataPlayers[['player_id','loser_full_name']]
dataPlayers_short_loser.head()
# Out:
#    player_id          loser_full_name
# 0     100002            Pancho Segura
# 1     100003            Frank Sedgman
# 2     100004           Giuseppe Merlo
# 3     100005  Richard Pancho Gonzales
# 4     100006             Grant Golden

# %%
#merge three tables
merged_data=data_short2020.merge(dataPlayers_short_winner,left_on='winner_id', right_on='player_id').drop('player_id', axis=1).merge(dataPlayers_short_loser,left_on='loser_id', right_on='player_id').drop('player_id', axis=1)
merged_data.head()
# Out:
#    match_num  winner_id  loser_id  match_id winner_full_name loser_full_name
# 0        300     104925    104745         0   Novak Djokovic    Rafael Nadal
# 1        299     106421    104745      1324  Daniil Medvedev    Rafael Nadal
# 2        288     105676    104745        12     David Goffin    Rafael Nadal
# 3        220     106233    104745       287    Dominic Thiem    Rafael Nadal
# 4        291     106233    104745      1332    Dominic Thiem    Rafael Nadal

# %%
player_asm = merged_data[['winner_id','loser_id','match_id','winner_full_name','loser_full_name']]
player_asm.head()
# Out:
#    winner_id  loser_id  match_id winner_full_name loser_full_name
# 0     104925    104745         0   Novak Djokovic    Rafael Nadal
# 1     106421    104745      1324  Daniil Medvedev    Rafael Nadal
# 2     105676    104745        12     David Goffin    Rafael Nadal
# 3     106233    104745       287    Dominic Thiem    Rafael Nadal
# 4     106233    104745      1332    Dominic Thiem    Rafael Nadal

# %%
#id player unique
list_winner = set(player_asm['winner_full_name'].unique())
list_loser = set(player_asm['loser_full_name'].unique())

skup_id = list_winner.union(list_loser)
print(f"Postoji { len(skup_id) } različitih igrača") # formatiranje ispisa pomoću fstringa
# Out:
# Postoji 345 različitih igrača

# %%
import numpy as np
import matplotlib.pyplot as plt

data_reduced = player_asm[['winner_full_name','loser_full_name','match_id']]

# %%
import networkx as nx
G = nx.Graph() # pravi praznu mrežu
G.add_nodes_from(skup_id) # dodaje čvorove čije su labele u "skup_id"

# %%
#agregacija brojanjem
for _, winner_full_name, loser_full_name, _ in data_reduced.itertuples():
    if (winner_full_name, loser_full_name) in G.edges:
        G.edges[winner_full_name, loser_full_name]['weight'] += 1
    else:
        G.add_edge(winner_full_name, loser_full_name, weight=1)

# %%
print(G.edges.data("weight"))

nx.draw_networkx(G)#-> crta mrežu, ne pokušavati za mrežu sa ovoliko čvorova i grana!
# Out:
# [('Aljaz Bedene', 'Christian Garin', 1), ('Aljaz Bedene', 'Milos Raonic', 2), ('Aljaz Bedene', 'Stefanos Tsitsipas', 2), ('Aljaz Bedene', 'Karen Khachanov', 1), ('Aljaz Bedene', 'Mikael Ymer', 1), ('Aljaz Bedene', 'Taylor Harry Fritz', 1), ('Aljaz Bedene', 'Daniil Medvedev', 1), ('Aljaz Bedene', 'Daniel Evans', 1), ('Aljaz Bedene', 'Gilles Simon', 1), ('Aljaz Bedene', 'Felix Auger Aliassime', 1), ('Aljaz Bedene', 'Stanislas Wawrinka', 1), ('Aljaz Bedene', 'Tommy Paul', 1), ('Aljaz Bedene', 'Vasek Pospisil', 1), ('Aljaz Bedene', 'Ernests Gulbis', 1), ('Aljaz Bedene', 'Emil Ruusuvuori', 1), ('Aljaz Bedene', 'Alexander Bublik', 1), ('Aljaz Bedene', 'James Duckworth', 1), ('Aljaz Bedene', 'Benoit Paire', 1), ('Aljaz Bedene', 'Arthur Rinderknech', 1), ('Aljaz Bedene', 'Nikola Milojevic', 1), ('Tomas Machac', 'Taylor Harry Fritz', 1), ('Emilio Gomez', 'Go Soeda', 1), ('Emilio Gomez', 'Francis Tiafoe', 1), ('Emilio Gomez', 'Lorenzo Sonego', 1), ('Emilio Gomez', 'Roman Safiullin', 1), ('Michael Venus', 'Tennys Sandgren', 1), ('Zura Tkemaladze', 'Kristjan Tamm', 1), ('Robert Strombachs', 'Amr Elsayed Abdou Ahmed Mohamed', 1), ('Thiago Seyboth Wild', 'Christian Garin', 1), ('Thiago Seyboth Wild', 'Casper Ruud', 1), ('Thiago Seyboth Wild', 'Alejandro Davidovich Fokina', 1), ('Thiago Seyboth Wild', 'Juan Ignacio Londero', 1), ('Thiago Seyboth Wild', 'Daniel Evans', 1), ('Thiago Seyboth Wild', 'Borna Coric', 1), ('Thiago Seyboth Wild', 'John Millman', 1), ('Thiago Seyboth Wild', 'Facundo Bagnis', 1), ('Thiago Seyboth Wild', 'Renzo Olivo', 1), ('Sumit Nagal', 'Marin Cilic', 1), ('Sumit Nagal', 'Dominic Thiem', 1), ('Sumit Nagal', 'Miomir Kecmanovic', 1), ('Sumit Nagal', 'Laslo Djere', 1), ('Sumit Nagal', 'Viktor Troicki', 1), ('Sumit Nagal', 'Bradley Klahn', 1), ('Gael Monfils', 'Novak Djokovic', 2), ('Gael Monfils', 'Dominic Thiem', 1), ('Gael Monfils', 'Alexander Bublik', 1), ('Gael Monfils', 'Pablo Carreno Busta', 1), ('Gael Monfils', 'Dominik Koepfer', 1), ('Gael Monfils', 'Yannick Hanfmann', 1), ('Gael Monfils', 'Christian Garin', 1), ('Gael Monfils', 'Filip Krajinovic', 2), ('Gael Monfils', 'Marton Fucsovics', 1), ('Gael Monfils', 'Richard Gasquet', 1), ('Gael Monfils', 'Gilles Simon', 1), ('Gael Monfils', 'Felix Auger Aliassime', 1), ('Gael Monfils', 'Adrian Mannarino', 1), ('Gael Monfils', 'Vasek Pospisil', 1), ('Gael Monfils', 'Yen Hsun Lu', 1), ('Gael Monfils', 'Ivo Karlovic', 1), ('Gael Monfils', 'Ernests Gulbis', 1), ('Gael Monfils', 'Norbert Gombos', 1), ('Gael Monfils', 'Daniel Evans', 1), ('Gael Monfils', 'Joao Sousa', 1), ('Gael Monfils', 'Yasutaka Uchiyama', 1), ('Martin Klizan', 'Federico Delbonis', 1), ('Martin Klizan', 'Adrian Mannarino', 1), ('Facundo Diaz Acosta', 'Pedro Sousa', 1), ('Viktor Durasovic', 'Karen Khachanov', 1), ('Viktor Durasovic', 'Stefano Travaglia', 1), ('Viktor Durasovic', 'Taylor Harry Fritz', 1), ('Viktor Durasovic', 'Darian King', 1), ('Amer Naow', 'Benjamin Lock', 1), ('Gregoire Barrere', 'Grigor Dimitrov', 2), ('Gregoire Barrere', 'Benoit Paire', 1), ('Gregoire Barrere', 'Guido Pella', 1), ('Gregoire Barrere', 'Andrey Rublev', 1), ('Gregoire Barrere', 'Jeremy Chardy', 1), ('Gregoire Barrere', 'Alexander Bublik', 1), ('Gregoire Barrere', 'Filip Krajinovic', 1), ('Gregoire Barrere', 'Sam Querrey', 1), ('Gregoire Barrere', 'Mohamed Safwat', 1), ('Gregoire Barrere', 'Joao Sousa', 1), ('Gregoire Barrere', 'Taro Daniel', 1), ('Marton Fucsovics', 'Daniil Medvedev', 1), ('Marton Fucsovics', 'Denis Shapovalov', 1), ('Marton Fucsovics', 'Kimmer Coppejans', 1), ('Marton Fucsovics', 'Roberto Bautista Agut', 1), ('Marton Fucsovics', 'Gilles Simon', 1), ('Marton Fucsovics', 'Borna Coric', 1), ('Marton Fucsovics', 'Andrey Rublev', 1), ('Marton Fucsovics', 'Miomir Kecmanovic', 1), ('Marton Fucsovics', 'Alexander Bublik', 1), ('Marton Fucsovics', 'Filip Krajinovic', 1), ('Marton Fucsovics', 'Jannik Sinner', 2), ('Marton Fucsovics', 'Roger Federer', 1), ('Marton Fucsovics', 'Francis Tiafoe', 2), ('Marton Fucsovic ...
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
output = "models/undirected_count_aggregation2020.gml"

nx.write_gml(G, output)

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 345
# Number of edges: 1325
# Average degree:   7.6812

# %%
# možemo iskoristiti networkx.draw_network da predstavimo egomrežu tog čvora
ego_mreza = nx.ego_graph(G, 'Novak Djokovic')
print(f"Čvorovi ego mreže igrača Novak Djokovic su {ego_mreza.nodes}")
plt.figure(figsize=(15,10))
tezine_grana = nx.get_edge_attributes(ego_mreza,'weight')
pos = nx.circular_layout(ego_mreza)
#pos = nx.spring_layout(ego_mreza)
#print(pos)
nx.draw_networkx(ego_mreza, pos)
nx.draw_networkx_edge_labels(ego_mreza, pos, edge_labels = tezine_grana)
# Out:
# Čvorovi ego mreže igrača Novak Djokovic su ['Diego Sebastian Schwartzman', 'Dominik Koepfer', 'Lorenzo Sonego', 'Salvatore Caruso', 'Malek Jaziri', 'Stefanos Tsitsipas', 'Casper Ruud', 'Daniel Elahi Galan Riveros', 'Filip Krajinovic', 'Ricardas Berankis', 'Damir Dzumhur', 'Tennys Sandgren', 'Roberto Bautista Agut', 'Milos Raonic', 'Kevin Anderson', 'Christian Garin', 'Gael Monfils', 'Dominic Thiem', 'Mikael Ymer', 'Yoshihito Nishioka', 'Pablo Carreno Busta', 'Denis Shapovalov', 'Daniil Medvedev', 'Jan Lennard Struff', 'Kyle Edmund', 'Alexander Zverev', 'Roger Federer', 'Borna Coric', 'Novak Djokovic', 'Tatsuma Ito', 'Philipp Kohlschreiber', 'Rafael Nadal', 'Karen Khachanov']
# {('Diego Sebastian Schwartzman',
#   'Rafael Nadal'): Text(0.964183956518084, -0.18583123113481037, '2'),
#  ('Diego Sebastian Schwartzman',
#   'Denis Shapovalov'): Text(0.17256963561263072, -0.3778747881824921, '1'),
#  ('Diego Sebastian Schwartzman',
#   'Novak Djokovic'): Text(0.7900285430624018, -0.40728792193255403, '3'),
#  ('Diego Sebastian Schwartzman',
#   'Daniil Medvedev'): Text(0.25000004749745114, -0.4330127202776549, '3'),
#  ('Diego Sebastian Schwartzman',
#   'Dominic Thiem'): Text(0.0022640265440045937, -0.047527966674482405, '2'),
#  ('Diego Sebastian Schwartzman',
#   'Alexander Zverev'): Text(0.523790918201987, -0.49943366257515476, '2'),
#  ('Diego Sebastian Schwartzman',
#   'Christian Garin'): Text(0.020253512932905893, 0.1408663109115818, '1'),
#  ('Diego Sebastian Schwartzman',
#   'Casper Ruud'): Text(0.7077075253884959, 0.45481598410993274, '1'),
#  ('Diego Sebastian Schwartzman',
#   'Borna Coric'): Text(0.7077075551908182, -0.4548159800459798, '1'),
#  ('Diego Sebastian Schwartzman',
#   'Lorenzo Sonego'): Text(0.964183956518084, 0.18583123519876343, '1'),
#  ('Dominik Koepfer',
#   'Gael Monfils'): Text(-0.0067716203377707895, 0.14215362594761297, '1'),
#  ('Dominik Koepfer',
#   'Yoshihito Nishioka'): Text(0.04654664156382293, -0.134487671107269, '1'),
#  ('Dominik Koepfer',
#   'Novak Djokovic'): Text(0.7809928961806264, -0.31266230025098907, '1'),
#  ('Dominik Koepfer',
#   'Roberto Bautista Agut'): Text(0.16353401853317762, 0.4725004437303323, '1'),
#  ('Dominik Koepfer',
#   'Kyle Edmund'): Text(0.41980684764755205, -0.4002850914532705, '1'),
#  ('Lorenzo Sonego',
#   'Novak Djokovic'): Text(0.7542124995804858, -0.2214566887657671, '1'),
#  ('Lorenzo Sonego',
#   'Casper Ruud'): Text(0.6718914819065799, 0.6406472172767197, '1'),
#  ('Lorenzo Sonego',
#   'Borna Coric'): Text(0.6718915117089022, -0.2689847468791928, '1'),
#  ('Lorenzo Sonego',
#   'Tennys Sandgren'): Text(0.21418392950972942, 0.6188439277060725, '1'),
#  ('Salvatore Caruso',
#   'Tennys Sandgren'): Text(0.17062673281644758, 0.7033330792267675, '1'),
#  ('Salvatore Caruso',
#   'Novak Djokovic'): Text(0.7106553028872039, -0.13696753724507216, '1'),
#  ('Salvatore Caruso',
#   'Stefanos Tsitsipas'): Text(0.7106552134802371, 0.6776083702886334, '1'),
#  ('Salvatore Caruso',
#   'Jan Lennard Struff'): Text(0.2570928809900102, -0.20218005497889746, '1'),
#  ('Salvatore Caruso',
#   'Filip Krajinovic'): Text(0.44441770969175654, 0.7697540513265896, '1'),
#  ('Malek Jaziri',
#   'Novak Djokovic'): Text(0.6518955541704016, -0.06224840653053321, '1'),
#  ('Stefanos Tsitsipas',
#   'Kevin Anderson'): Text(-0.154389287701289, 0.6364012059161563, '1'),
#  ('Stefanos Tsitsipas',
#   'Christian Garin'): Text(-0.18971803341165916, 0.5481542944807568, '1'),
#  ('Stefanos Tsitsipas',
#   'Jan Lennard Struff'): Text(0.12649457482064302, -0.06521245609720427, '2'),
#  ('Stefanos Tsitsipas',
#   'Novak Djokovic'): Text(0.5800569967178367, 6.163662102931511e-08, '2'),
#  ('Stefanos Tsitsipas',
#   'Rafael Nadal'): Text(0.7542124101735189, 0.22145675243436466, '1'),
#  ('Stefanos Tsitsipas',
#   'Borna Coric'): Text(0.49773600884625313, -0.047527996476804724, '1'),
#  ('Stefanos Tsitsipas',
#   'Dominic Thiem'): Text(-0.20770751980056046, 0.3597600168946926, '1'),
#  ('Stefanos Tsitsipas',
#   'Denis Shapovalov'): Text(-0.03740191073193433, 0.029413195386682967, '1'),
#  ('Stefanos Tsitsipas',
#   'Milos Raonic'): Text(-0.10299810356274952, 0.7163674825023377, '2'),
#  ('Stefanos Tsitsipas',
#   'Philipp Kohlschreiber'): Text(0.7106551836779148, 0.1369675413090251, '1'),
#  ('Stefanos Tsitsipas',
#   'Mikael Ymer'): Text(-0.18971803341165916, 0.26642170652386854, '1'),
#  ('Stefanos Tsitsipas',
#   'Pablo Carreno Busta'): Text(-0.10299810356274952, 0.09820851850228762, '1'),
#  ('Stefanos Tsitsipas',
#   'Alexander Zverev'): Text(0.3138193718574219, -0.0921456790059797, '1'),
#  ('Casper Ruud',
#   'Karen Khachanov'): Text(0.6986718785067205, 0.36019039968127065, '1'),
#  ('Casper Ruud',
#   'Novak Djokovic'): Text(0.4977360684508977, 0.04752806014540223, '1'),
#  ('Casper Ruud',
#   'Daniil Medvedev'): Text(-0.042292427114052955, 0.021803261800301343, '1'),
#  ('Casper Ruud',
#   'Dominic Thiem'): Text(-0.2900284480674995, 0.4072880154034738, '1'),
#  ('Daniel Elahi Galan Riveros',
#   'Tennys Sandgren'): Text(-0.13212058271422764, 0.9189184890185894, '1'),
#  ('Daniel Elahi Galan Riveros',
#   'Novak Djokovic'): Text(0.40790798735652867, 0.07861787254674979, '1'),
#  ('Filip Krajinovic',
#   'Dominic Thiem'): Text(-0.473945023589041, 0.4519056979326488, '1'),
#  ('Filip Krajinovic',
#   'Kyle Edmund'): Text(-0.04736655560371817, 0.004522951472295755, '1'),
#  ('Filip Krajinovic',
#   'Novak Djokovic'): Text(0.3138194929293562, 0.0921457426745772, '2'),
#  ('Filip Krajinovic',
#   'Gael Monfils'): Text(-0.473945023589041, 0.5469616688731792, '2'),
#  ('Filip Krajinovic',
#   'Roger Federer'): Text(0.14167042396340362, 0.013527872159803889, '1'),
#  ('Filip Krajinovic',
#   'Milos Raonic'): Text(-0.36923560735123007, 0.8085131635402939, '1'),
#  ('Filip Krajinovic',
#   'Mikael Ymer'): Text(-0.4559555372001397, 0.3585673875618247, '2'),
#  ('Ricardas Berankis',
#   'Novak Djokovic'): Text(0.21887112699869601, 0.08762279323425792, '2'),
#  ('Ricardas Berankis',
#   'Pablo Carreno Busta'): Text(-0.4641839732818902, 0.18583125009992452, '1'),
#  ('Damir Dzumhur',
#   'Novak Djokovic'): Text(0.12649457482064302, 0.0652124899634795, '1'),
#  ('Tennys Sandgren',
#   'Novak Djokovic'): Text(0.040028516054047225, 0.025724770574755085, '1'),
#  ('Tennys Sandgren',
#   'Roberto Bautista Agut'): Text(-0.5774303615934016, 0.8108875145560764, '1'),
#  ('Tennys Sandgren',
#   'Roger Federer'): Text(-0.13212055291190536, -0.05289309994001823, '1'),
#  ('Roberto Bautista Agut',
#   'Daniil Medvedev'): Text(-0.5774302870875958, -0.05513790026086407, '1'),
#  ('Roberto Bautista Agut',
#   'Karen Khachanov'): Text(0.16353401853317762, 0.28324923762010523, '1'),
#  ('Roberto Bautista Agut',
#   'Novak Djokovic'): Text(-0.03740179152264522, -0.029413101915763185, '1'),
#  ('Roberto Bautista Agut',
#   'Jan Lennard Struff'): Text(-0.4909642134198389, -0.09462561964958849, '1'),
#  ('Roberto Bautista Agut',
#   'Pablo Carreno Busta'): Text(-0.7204568918032315, 0.06879535494990341, '2'),
#  ('Milos Raonic',
#   'Christian Garin'): Text(-0.8727730442852786, 0.44994580781276794, '1'),
#  ('Milos Raonic',
#   'Novak Djokovic'): Text(-0.10299801415578269, -0.09820842503136784, '2'),
#  ('Milos Raonic',
#   'Daniil Medvedev'): Text(-0.6430265097207333, -0.12393322337646873, '1'),
#  ('Milos Raonic',
#   'Borna Coric'): Text(-0.1853190020273663, -0.1457364831447936, '1'),
#  ('Milos Raonic',
#   'Karen Khachanov'): Text(0.09793779590004015, 0.21445391450450058, '1'),
#  ('Kevin Anderson',
#   'Daniil Medvedev'): Text(-0.6944176938592728, -0.20389949996265008, '2'),
#  ('Kevin Anderson',
#   'Novak Djokovic'): Text(-0.15438919829432218, -0.1781747016175492, '1'),
#  ('Kevin Anderson',
#   'Alexander Zverev'): Text(-0.420626823154737, -0.27032044226014995, '1'),
#  ('Kevin Anderson',
#   'Christian Garin'): Text(-0.9241642284238181, 0.3699795312265866, '1'),
#  ('Kevin Anderson',
#   'Kyle Edmund'): Text(-0.5155752468273965, -0.26579749281983067, '1'),
#  ('Kevin Anderson',
#   'Pablo Carreno Busta'): Text(-0.8374442985749084, -0.0799662447518826, '1'),
#  ('Christian Garin',
#   'Novak Djokovic'): Text(-0.18971794400469233, -0.26642161305294876, '1'),
#  ('Christian Garin',
#   'Karen Khachanov'): Text(0.01121786605113051, 0.046240726482919686, '1'),
#  ('Christian Garin',
#   'Gael Monfils'): Text(-0.9774824605230895, 0.18839431314565327, '1'),
#  ('Christian Garin',
#   'Borna Coric'): Text(-0.2720389318762759, -0.3139496711663745, '2'),
#  ('Christian Garin',
#   'Dominic Thiem'): Text(-0.9774824605230895, 0.09333834220512288, '1'),
#  ('Christian Garin',
#   'Philipp Kohlschreiber'): Text(-0.05911975704461425, -0.12945413338054465, '1'),
#  ('Gael Monfils',
#   'Novak Djokovic'): Text(-0.20770743039359363, -0.35975991969848253, '2'),
#  ('Gael Monfils',
#   'Dominic Thiem'): Text(-0.9954719469119908, 3.555958907885959e-08, '1'),
#  ('Gael Monfils',
#   'Pablo Carreno Busta'): Text(-0.8907625306741799, -0.26155146283281594, '1'),
#  ('Dominic Thiem',
#   'Rafael Nadal'): Text(-0.03355201693791143, -0.2333591998412693, '2'),
#  ('Dominic Thiem',
#   'Daniil Medvedev'): Text(-0.7477359259585443, -0.48054068898411384, '2'),
#  ('Dominic Thiem',
#   'Novak Djokovic'): Text(-0.20770743039359363, -0.45481589063901295, '2'),
#  ('Dominic Thiem',
#   'Borna Coric'): Text(-0.2900284182651772, -0.5023439487524387, '1'),
#  ('Dominic Thiem',
#   'Alexander Zverev'): Text(-0.47394505525400843, -0.5469616312816137, '2'),
#  ('Mikael Ymer',
#   'Novak Djokovic'): Text(-0.18971794400469233, -0.548154201009837, '1'),
#  ('Mikael Ymer',
#   'Karen Khachanov'): Text(0.01121786605113051, -0.23549186147396858, '1'),
#  ('Yoshihito Nishioka',
#   'Jan Lennard Struff'): Text(-0.6079515903891937, -0.7016137344871898, '1'),
#  ('Yoshihito Nishioka',
#   'Novak Djokovic'): Text(-0.1543891684919999, -0.6364012167533645, '1'),
#  ('Yoshihito Nishioka',
#   'Rafael Nadal'): Text(0.01976624496368229, -0.41494452595562087, '1'),
#  ('Yoshihito Nishioka',
#   'Kyle Edmund'): Text(-0.5155752170250743, -0.7240240079556459, '1'),
#  ('Pablo Carreno Busta',
#   'Denis Shapovalov'): Text(-0.7204569216055537, -0.686954255281356, '1'),
#  ('Pablo Carreno Busta',
#   'Jan Lennard Struff'): Text(-0.5565604360529763, -0.7815799067652432, '1'),
#  ('Pablo Carreno Busta',
#   'Novak Djokovic'): Text(-0.10299801415578269, -0.716367389031418, '2'),
#  ('Pablo Carreno Busta',
#   'Rafael Nadal'): Text(0.0711573992998995, -0.4949106982336743, '3'),
#  ('Pablo Carreno Busta',
#   'Karen Khachanov'): Text(0.09793779590004015, -0.40370504949554953, '1'),
#  ('Pablo Carreno Busta',
#   'Alexander Zverev'): Text(-0.3692356390161975, -0.8085131296740187, '1'),
#  ('Denis Shapovalov',
#   'Novak Djokovic'): Text(-0.0374018213249675, -0.7851627121470226, '1'),
#  ('Denis Shapovalov',
#   'Jan Lennard Struff'): Text(-0.4909642432221612, -0.8503752298808479, '1'),
#  ('Denis Shapovalov',
#   'Alexander Zverev'): Text(-0.3036394461853823, -0.8773084527896233, '1'),
#  ('Daniil Medvedev',
#   'Rafael Nadal'): Text(0.2141840040155351, -0.6188439534444418, '1'),
#  ('Daniil Medvedev',
#   'Novak Djokovic'): Text(0.04002859055985292, -0.8403006442421854, '2'),
#  ('Daniil Medvedev',
#   'Alexander Zverev'): Text(-0.22620903430056186, -0.9324463848847862, '2'),
#  ('Jan Lennard Struff',
#   'Novak Djokovic'): Text(0.12649466422760985, -0.8797883636309098, '3'),
#  ('Jan Lennard Struff',
#   'Karen Khachanov'): Text(0.3274304742834327, -0.5671260240950414, '1'),
#  ('Kyle Edmund',
#   'Novak Djokovic'): Text(0.21887103759172918, -0.902198637099366, '1'),
#  ('Alexander Zverev',
#   'Rafael Nadal'): Text(0.48797487472007095, -0.6852648957419416, '1'),
#  ('Alexander Zverev',
#   'Borna Coric'): Text(0.2314984733928052, -0.954249644653111, '1'),
#  ('Alexander Zverev',
#   'Novak Djokovic'): Text(0.31381946126438875, -0.9067215865396853, '1'),
#  ('Roger Federer',
#   'Novak Djokovic'): Text(0.40790801715885094, -0.8931937164118579, '1'),
#  ('Borna Coric',
#   'Novak Djokovic'): Text(0.49773609825321996, -0.8621039040105103, '1'),
#  ('Novak Djokovic',
#   'Rafael Nadal'): Text(0.7542124995804858, -0.5931191550993409, '2'),
#  ('Novak Djokovic',
#   'Tatsuma Ito'): Text(0.651895494565757, -0.7523274969392194, '1'),
#  ('Novak Djokovic',
#   'Karen Khachanov'): Text(0.7809928961806264, -0.5019135063612161, '2'),
#  ('Novak Djokovic',
#   'Philipp Kohlschreiber'): Text(0.7106552730848816, -0.6776083662246805, '1')}

# %%
from collections import Counter
from operator import itemgetter
def plot_deg_frequency(G, weighted=False, xscale = "log", yscale = "log"):

    if weighted:
        degrees = G.degree(weight="weight")
    else:
        degrees = G.degree()
    _, deg_list = zip(*degrees)
    deg_counts = Counter(deg_list)  #broji koliko ima odigranih meceva?????????????????      
    print(deg_counts)
    x, y = zip(*deg_counts.items())                                                      

    plt.figure(1)   

    # prep axes   
    if weighted:
        plt.xlabel('weighted degree')  
    else:
        plt.xlabel('degree')                                                                                                             
    plt.xscale(xscale)                                                                                                                
    plt.xlim(1, max(x))  

    plt.ylabel('frequency')                                                                                                          
    plt.yscale(yscale)                                                                                                                
    plt.ylim(1, max(y))                                                                                                             
                                                                                                                                                                                                    
    plt.scatter(x, y, marker='.')                                                                                                    
    plt.show()

# %%
 plot_deg_frequency(G)
# Out:
# Counter({1: 119, 2: 45, 3: 22, 4: 15, 6: 13, 5: 13, 20: 9, 8: 8, 26: 7, 10: 7, 17: 7, 21: 6, 7: 6, 14: 6, 15: 5, 27: 5, 13: 5, 19: 5, 11: 4, 16: 4, 28: 4, 23: 4, 22: 3, 18: 3, 12: 3, 25: 3, 9: 2, 29: 2, 24: 2, 31: 2, 30: 2, 32: 1, 43: 1, 37: 1, 34: 1})

# %%
plot_deg_frequency(G, weighted = True)
# Out:
# Counter({1: 119, 2: 45, 3: 22, 4: 15, 6: 13, 5: 12, 23: 8, 20: 7, 7: 7, 15: 6, 8: 6, 28: 6, 14: 6, 22: 5, 31: 5, 21: 5, 10: 5, 30: 5, 9: 4, 12: 4, 19: 4, 16: 4, 13: 3, 26: 3, 17: 3, 18: 3, 11: 3, 34: 2, 32: 2, 27: 2, 25: 1, 29: 1, 39: 1, 35: 1, 46: 1, 41: 1, 38: 1, 51: 1, 33: 1, 42: 1, 44: 1})

# %%
#slucajno generisana mreza Gnm ima normalnu distribuciju!
n = G.number_of_nodes()
m = G.number_of_edges()
Gnm = nx.gnm_random_graph(n, m) 

plot_deg_frequency(Gnm, xscale = 'linear', yscale = 'linear')
plot_deg_frequency(Gnm, xscale = 'log', yscale = 'log')
# Out:
# Counter({6: 52, 8: 49, 9: 45, 5: 44, 7: 39, 10: 28, 11: 28, 4: 20, 12: 13, 3: 8, 13: 7, 14: 5, 2: 3, 1: 2, 15: 1, 16: 1})
# Counter({6: 52, 8: 49, 9: 45, 5: 44, 7: 39, 10: 28, 11: 28, 4: 20, 12: 13, 3: 8, 13: 7, 14: 5, 2: 3, 1: 2, 15: 1, 16: 1})

# %%
#Kako bi se ponašala Erdos-Renyi mreža sa koja ima isti broj čvorova n, a verovatnoća formiranja grane je takva da je očekivani broj grana u mreži m?
p = ( 2*float(m) ) / ( n* (n-1) )
print(p)

er_mreza = nx.erdos_renyi_graph(n,p)

delta_m = m - er_mreza.number_of_edges()
print(f"Broj čvorova originalne mreže minus broj čvorova u ER mreži iznosi {delta_m}, što je odstupanje od {abs(float(delta_m)) * 100 / m}%")

plot_deg_frequency(er_mreza, xscale = 'linear', yscale = 'linear')
plot_deg_frequency(er_mreza, xscale = 'log', yscale = 'log')
#Šta nam informacije o raspodeli stepena čvora govore o ovoj mreži?

# Da je mreža bila sa slučajnim vezivanjem, očekivali bismo da raspodela bude slična normalnoj raspodeli! Sto i lici!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Out:
# 0.022328951803168184
# Broj čvorova originalne mreže minus broj čvorova u ER mreži iznosi -57, što je odstupanje od 4.30188679245283%
# Counter({8: 51, 7: 42, 9: 42, 10: 38, 6: 36, 5: 33, 4: 25, 12: 18, 11: 17, 13: 17, 3: 12, 14: 8, 15: 3, 2: 3})
# Counter({8: 51, 7: 42, 9: 42, 10: 38, 6: 36, 5: 33, 4: 25, 12: 18, 11: 17, 13: 17, 3: 12, 14: 8, 15: 3, 2: 3})

# %%
#Asortativnost (eng. assortativity) meri stepen tendencije čvorova mreže da se vezuju sa sličnim čvorovima. 
#U ovoj analizi ćemo prvo sprovesti analizu asortativnosti na osnovu stepena čvora, jer nas interesuje da li se međusobno vezuju čvorovi koji su sličnog stepena, 
#ili habovi (čvorovi velikog stepena) teže da se slabo međusobno vezuju, a mnogo vezuju sa čvorovima malog stepena.
#Uvodi se koeficijent asortativnosti r, koji je u opsegu od -1 do 1. 
#Mreža sa r = 1 iskazuje savršeno asortativno mešanje (perfect assortative mixing pattern), kad je r = 0 mreža je neasortativna ili neutralna, dok je u slučaju r = −1 mreža potpuno disasortativna.
# asortativnost na osnovu netežinskog stepena čvora
r1 = nx.degree_assortativity_coefficient(G)
print(f"Koeficijent asortativnosti na osnovu netežinskog stepena čvora: {r1}")

# asortativnost na osnovu težinskog stepena čvora
r2 = nx.degree_assortativity_coefficient(G, weight='weight')
print(f"Koeficijent asortativnosti na osnovu težinskog stepena čvora: {r2}")
# Out:
# Koeficijent asortativnosti na osnovu netežinskog stepena čvora: 0.23815555973416275
# Koeficijent asortativnosti na osnovu težinskog stepena čvora: 0.23637924173286778

# %%
#Kao što vidimo, mreža je neutralna tj. neasortativna, odnosno, čvorovi sličnog stepena uglavnom se ne vezuju međusobno.

# %%
#ANALIZA KOMUNA
#Stepen klasterisanja može se proceniti na osnovu koeficijenta klasterisanja.
id_igraca, clustering_coef = zip(*nx.clustering(G, weight = "weight").items())

nenula = [(id_ig, cc)  for id_ig, cc in zip(id_igraca, clustering_coef) if cc > 0]

df = pd.DataFrame(nenula, columns = ["id", "cc"])
df.sort_values('cc', inplace = True)

max_lokalni_stepen_klasterisanja = max(clustering_coef)

prosecni_stepen_klasterisanja = nx.average_clustering(G)

print(f"Max lokalni cc: {max_lokalni_stepen_klasterisanja}")
print(f"Prosečan cc: {prosecni_stepen_klasterisanja}")
print("Lokalni stepeni klasterisanja koji nisu nula:")
print(df)
# Out:
# Max lokalni cc: 0.33333333333333337
# Prosečan cc: 0.09086792378213672
# Lokalni stepeni klasterisanja koji nisu nula:
#                          id        cc
# 84             Hugo Dellien  0.006061
# 59        Ricardas Berankis  0.011057
# 145             Pedro Sousa  0.011905
# 108  Pedro Martinez Portero  0.022059
# 142         Sebastian Korda  0.022222
# ..                      ...       ...
# 150           Mischa Zverev  0.333333
# 117      Alexander Cozbinov  0.333333
# 35        Franco Roncadelli  0.333333
# 62              Yen Hsun Lu  0.333333
# 69            Quentin Halys  0.333333
#
# [158 rows x 2 columns]

# %%
# možemo iskoristiti networkx.draw_network da predstavimo egomrežu tog čvora
ego_mreza = nx.ego_graph(G, 'Mischa Zverev')
print(f"Čvorovi ego mreže igrača Mischa Zverev su {ego_mreza.nodes}")
plt.figure(figsize=(15,10))
tezine_grana = nx.get_edge_attributes(ego_mreza,'weight')
pos = nx.circular_layout(ego_mreza)
#pos = nx.spring_layout(ego_mreza)
#print(pos)
nx.draw_networkx(ego_mreza, pos)
nx.draw_networkx_edge_labels(ego_mreza, pos, edge_labels = tezine_grana)
# Out:
# Čvorovi ego mreže igrača Mischa Zverev su ['John Millman', 'Hubert Hurkacz', 'Mischa Zverev', 'John Isner']
# {('John Millman',
#   'Hubert Hurkacz'): Text(0.4999999751630862, 0.5000000109278468, '1'),
#  ('John Millman',
#   'John Isner'): Text(0.50000000298122, -0.49999996721645945, '1'),
#  ('John Millman',
#   'Mischa Zverev'): Text(7.946626690014114e-09, -2.1855693665697605e-08, '1'),
#  ('Hubert Hurkacz',
#   'John Isner'): Text(-7.946626738379675e-09, 2.1855693699279755e-08, '1'),
#  ('Hubert Hurkacz',
#   'Mischa Zverev'): Text(-0.50000000298122, 0.4999999672164595, '1'),
#  ('Mischa Zverev',
#   'John Isner'): Text(-0.49999997516308625, -0.5000000109278468, '1')}

# %%
# možemo iskoristiti networkx.draw_network da predstavimo egomrežu tog čvora
ego_mreza = nx.ego_graph(G, 'Quentin Halys')
print(f"Čvorovi ego mreže igrača Quentin Halys su {ego_mreza.nodes}")
plt.figure(figsize=(15,10))
tezine_grana = nx.get_edge_attributes(ego_mreza,'weight')
pos = nx.circular_layout(ego_mreza)
#pos = nx.spring_layout(ego_mreza)
#print(pos)
nx.draw_networkx(ego_mreza, pos)
nx.draw_networkx_edge_labels(ego_mreza, pos, edge_labels = tezine_grana)
# Out:
# Čvorovi ego mreže igrača Quentin Halys su ['Marcos Giron', 'Quentin Halys', 'Filip Krajinovic']
# {('Marcos Giron',
#   'Filip Krajinovic'): Text(0.2500000372529033, -0.43301270835610933, '1'),
#  ('Marcos Giron',
#   'Quentin Halys'): Text(0.24999996274709668, 0.43301271829021687, '1'),
#  ('Quentin Halys',
#   'Filip Krajinovic'): Text(-0.5, -9.934107536579972e-09, '1')}

# %%
# možemo iskoristiti networkx.draw_network da predstavimo egomrežu tog čvora
ego_mreza = nx.ego_graph(G, 'Rafael Nadal')
print(f"Čvorovi ego mreže igrača Rafael Nadal su {ego_mreza.nodes}")
plt.figure(figsize=(15,10))
tezine_grana = nx.get_edge_attributes(ego_mreza,'weight')
pos = nx.circular_layout(ego_mreza)
#pos = nx.spring_layout(ego_mreza)
#print(pos)
nx.draw_networkx(ego_mreza, pos)
nx.draw_networkx_edge_labels(ego_mreza, pos, edge_labels = tezine_grana)
# Out:
# Čvorovi ego mreže igrača Rafael Nadal su ['Diego Sebastian Schwartzman', 'Egor Gerasimov', 'Nick Kyrgios', 'Pablo Cuevas', 'Grigor Dimitrov', 'Stefanos Tsitsipas', 'Federico Delbonis', 'Jordan Thompson', 'Soon Woo Kwon', 'Hugo Dellien', 'Alex De Minaur', 'Pablo Andujar', 'Jannik Sinner', 'Dusan Lajovic', 'Dominic Thiem', 'Miomir Kecmanovic', 'Yoshihito Nishioka', 'Pablo Carreno Busta', 'Feliciano Lopez', 'Nikoloz Basilashvili', 'David Goffin', 'Daniil Medvedev', 'Andrey Rublev', 'Taylor Harry Fritz', 'Alexander Zverev', 'Sebastian Korda', 'Novak Djokovic', 'Mackenzie Mcdonald', 'Rafael Nadal', 'Stefano Travaglia']
# {('Diego Sebastian Schwartzman',
#   'Rafael Nadal'): Text(0.9567727745545518, -0.20336822927892195, '2'),
#  ('Diego Sebastian Schwartzman',
#   'Novak Djokovic'): Text(0.8345653716447232, -0.37157235764517443, '3'),
#  ('Diego Sebastian Schwartzman',
#   'Daniil Medvedev'): Text(0.345491455468182, -0.475528222319126, '3'),
#  ('Diego Sebastian Schwartzman',
#   'Dominic Thiem'): Text(0.010926189249173934, 0.1039558218911499, '2'),
#  ('Diego Sebastian Schwartzman',
#   'Alexander Zverev'): Text(0.6545085616681533, -0.475528222319126, '2'),
#  ('Diego Sebastian Schwartzman',
#   'Dusan Lajovic'): Text(0.04322725748294465, 0.20336830762609134, '1'),
#  ('Diego Sebastian Schwartzman',
#   'Miomir Kecmanovic'): Text(2.235174212383839e-09, -2.688954522659477e-08, '1'),
#  ('Diego Sebastian Schwartzman',
#   'Pablo Cuevas'): Text(0.9045085015047152, 0.2938926381589603, '1'),
#  ('Diego Sebastian Schwartzman',
#   'Federico Delbonis'): Text(0.6545084871623476, 0.47552828576513423, '1'),
#  ('Egor Gerasimov',
#   'Dusan Lajovic'): Text(0.03230107046894487, 0.30732415739888175, '1'),
#  ('Egor Gerasimov',
#   'Soon Woo Kwon'): Text(0.436809559680202, 0.6012168234394826, '1'),
#  ('Egor Gerasimov',
#   'Rafael Nadal'): Text(0.9458465875405521, -0.09941237950613156, '1'),
#  ('Egor Gerasimov',
#   'Alexander Zverev'): Text(0.6435823746541536, -0.37157237254633557, '1'),
#  ('Egor Gerasimov',
#   'Jordan Thompson'): Text(0.5413380238234892, 0.6012168234394826, '1'),
#  ('Egor Gerasimov',
#   'David Goffin'): Text(0.23907385936586434, -0.3290568563602372, '1'),
#  ('Nick Kyrgios',
#   'Stefanos Tsitsipas'): Text(0.7067727006075395, 0.6363810603832842, '1'),
#  ('Nick Kyrgios',
#   'Rafael Nadal'): Text(0.913545489504459, 9.132764872132881e-08, '1'),
#  ('Pablo Cuevas',
#   'Rafael Nadal'): Text(0.861281276059267, 0.09052439205819537, '1'),
#  ('Pablo Cuevas',
#   'Yoshihito Nishioka'): Text(-0.08456527944378867, 0.18993674368268643, '1'),
#  ('Pablo Cuevas',
#   'Nikoloz Basilashvili'): Text(0.06994325130445528, -0.07767979591270169, '1'),
#  ('Pablo Cuevas',
#   'Stefanos Tsitsipas'): Text(0.6545084871623474, 0.726905361113831, '2'),
#  ('Pablo Cuevas',
#   'Federico Delbonis'): Text(0.5590169886670626, 0.7694209071022515, '1'),
#  ('Pablo Cuevas',
#   'Taylor Harry Fritz'): Text(0.4567726825398817, -0.2033683186858889, '1'),
#  ('Grigor Dimitrov',
#   'Yoshihito Nishioka'): Text(-0.15450849871074746, 0.26761655641723114, '1'),
#  ('Grigor Dimitrov',
#   'Stefanos Tsitsipas'): Text(0.5845652678953887, 0.8045851738483756, '2'),
#  ('Grigor Dimitrov',
#   'Rafael Nadal'): Text(0.7913380567923082, 0.1682042047927401, '1'),
#  ('Grigor Dimitrov',
#   'David Goffin'): Text(0.08456532861762045, -0.06144027206136554, '1'),
#  ('Grigor Dimitrov',
#   'Jannik Sinner'): Text(-0.06994324683410696, 0.6654650424283, '1'),
#  ('Stefanos Tsitsipas',
#   'Novak Djokovic'): Text(0.5845653573023556, 0.06144036530969621, '2'),
#  ('Stefanos Tsitsipas',
#   'Rafael Nadal'): Text(0.7067727602121842, 0.22964449367594866, '1'),
#  ('Stefanos Tsitsipas',
#   'Dominic Thiem'): Text(-0.23907382509319372, 0.5369685448460205, '1'),
#  ('Stefanos Tsitsipas',
#   'Andrey Rublev'): Text(0.1977358180335108, -0.0642482170681356, '3'),
#  ('Stefanos Tsitsipas',
#   'Jannik Sinner'): Text(-0.15450854341423095, 0.7269053313115086, '1'),
#  ('Stefanos Tsitsipas',
#   'Pablo Carreno Busta'): Text(-0.20677272705710073, 0.2296443744666594, '1'),
#  ('Stefanos Tsitsipas',
#   'Alexander Zverev'): Text(0.4045085473257857, -0.04251549936425536, '1'),
#  ('Stefanos Tsitsipas',
#   'Dusan Lajovic'): Text(-0.206772756859423, 0.636381030580962, '1'),
#  ('Federico Delbonis',
#   'Nikoloz Basilashvili'): Text(-0.18005676303791232, 0.10395585169347227, '1'),
#  ('Federico Delbonis',
#   'Hugo Dellien'): Text(-2.7567148147555898e-08, 0.9510565249061032, '1'),
#  ('Federico Delbonis',
#   'Rafael Nadal'): Text(0.6112812617168993, 0.2721600396643693, '1'),
#  ('Federico Delbonis',
#   'Daniil Medvedev'): Text(-5.736947047974006e-08, 4.66241653063193e-08, '1'),
#  ('Federico Delbonis',
#   'Miomir Kecmanovic'): Text(-0.3454915106024783, 0.47552824205374605, '1'),
#  ('Federico Delbonis',
#   'Jordan Thompson'): Text(0.2067726979998364, 0.9727892426099835, '1'),
#  ('Federico Delbonis',
#   'Pablo Andujar'): Text(-0.18005685244487932, 0.847100690034474, '1'),
#  ('Jordan Thompson',
#   'Stefano Travaglia'): Text(0.5413379940211669, 0.39330509409157943, '1'),
#  ('Jordan Thompson',
#   'Rafael Nadal'): Text(0.5090369853920408, 0.2938927275659272, '1'),
#  ('Jordan Thompson',
#   'Miomir Kecmanovic'): Text(-0.4477357869273369, 0.49726092995530397, '3'),
#  ('Soon Woo Kwon',
#   'Dusan Lajovic'): Text(-0.5090369958228536, 0.7006292644709405, '1'),
#  ('Soon Woo Kwon',
#   'Rafael Nadal'): Text(0.40450852124875364, 0.2938927275659272, '1'),
#  ('Soon Woo Kwon',
#   'Nikoloz Basilashvili'): Text(-0.38682950350605805, 0.12568853959503018, '1'),
#  ('Hugo Dellien',
#   'Rafael Nadal'): Text(0.30226425982505617, 0.272160009862047, '1'),
#  ('Alex De Minaur',
#   'Alexander Zverev'): Text(-0.09549146645778836, -0.04251552916657769, '1'),
#  ('Alex De Minaur',
#   'Rafael Nadal'): Text(0.20677274642861015, 0.22964446387362633, '1'),
#  ('Alex De Minaur',
#   'Daniil Medvedev'): Text(-0.4045085726577597, -0.04251552916657769, '1'),
#  ('Alex De Minaur',
#   'Dominic Thiem'): Text(-0.7390738388767677, 0.5369685150436981, '1'),
#  ('Alex De Minaur',
#   'Miomir Kecmanovic'): Text(-0.7500000258907675, 0.43301266626300305, '1'),
#  ('Alex De Minaur',
#   'Jannik Sinner'): Text(-0.654508557197805, 0.7269053015091862, '1'),
#  ('Alex De Minaur',
#   'Stefano Travaglia'): Text(0.23907375505773626, 0.3290568303992785, '1'),
#  ('Pablo Andujar',
#   'Rafael Nadal'): Text(0.122207434947325, 0.16820417499041776, '1'),
#  ('Pablo Andujar',
#   'Yoshihito Nishioka'): Text(-0.8236391205557306, 0.2676165266149088, '1'),
#  ('Pablo Andujar',
#   'Stefano Travaglia'): Text(0.1545084435764511, 0.26761654151606995, '1'),
#  ('Pablo Andujar',
#   'Feliciano Lopez'): Text(-0.7390738090744455, 0.07767974014942075, '1'),
#  ('Jannik Sinner',
#   'Alexander Zverev'): Text(-0.24999996740370997, -0.18163563078433098, '2'),
#  ('Jannik Sinner',
#   'Rafael Nadal'): Text(0.05226424548268854, 0.09052436225587304, '1'),
#  ('Jannik Sinner',
#   'Daniil Medvedev'): Text(-0.5590170736036812, -0.18163563078433098, '1'),
#  ('Jannik Sinner',
#   'Andrey Rublev'): Text(-0.4567726966959848, -0.20336834848821123, '1'),
#  ('Jannik Sinner',
#   'Pablo Carreno Busta'): Text(-0.8612812417865964, 0.09052424304658377, '1'),
#  ('Jannik Sinner',
#   'David Goffin'): Text(-0.6545084826919991, -0.1391201145982326, '2'),
#  ('Dusan Lajovic',
#   'Rafael Nadal'): Text(3.203749648905685e-08, 6.152532641690023e-08, '1'),
#  ('Dusan Lajovic',
#   'Pablo Carreno Busta'): Text(-0.9135454552317884, -5.7683962856325266e-08, '1'),
#  ('Dominic Thiem',
#   'Rafael Nadal'): Text(-0.032301036196274224, -0.09941242420961503, '2'),
#  ('Dominic Thiem',
#   'Daniil Medvedev'): Text(-0.6435823552826441, -0.37157241724981904, '2'),
#  ('Dominic Thiem',
#   'Novak Djokovic'): Text(-0.1545084391061028, -0.2676165525758675, '2'),
#  ('Dominic Thiem',
#   'Andrey Rublev'): Text(-0.5413379783749476, -0.3933051349536993, '2'),
#  ('Dominic Thiem',
#   'Alexander Zverev'): Text(-0.3345652490826727, -0.37157241724981904, '2'),
#  ('Dominic Thiem',
#   'Taylor Harry Fritz'): Text(-0.4368096297156595, -0.3933051349536993, '1'),
#  ('Miomir Kecmanovic',
#   'Rafael Nadal'): Text(-0.043227223210273946, -0.20336827299031016, '1'),
#  ('Miomir Kecmanovic',
#   'Yoshihito Nishioka'): Text(-0.9890737787133296, -0.1039559213658191, '1'),
#  ('Miomir Kecmanovic',
#   'Andrey Rublev'): Text(-0.5522641653889473, -0.4972609837343944, '1'),
#  ('Miomir Kecmanovic',
#   'Alexander Zverev'): Text(-0.34549143609667243, -0.4755282660305142, '1'),
#  ('Yoshihito Nishioka',
#   'Novak Djokovic'): Text(-0.15450840930378051, -0.4755282521214483, '1'),
#  ('Yoshihito Nishioka',
#   'Rafael Nadal'): Text(-0.03230100639395195, -0.30732412375519585, '1'),
#  ('Yoshihito Nishioka',
#   'Nikoloz Basilashvili'): Text(-0.8236390311487636, -0.4755283117260929, '1'),
#  ('Pablo Carreno Busta',
#   'Novak Djokovic'): Text(-0.1222073410700098, -0.5749407229552286, '2'),
#  ('Pablo Carreno Busta',
#   'Rafael Nadal'): Text(6.183981876572986e-08, -0.40673659458897615, '3'),
#  ('Pablo Carreno Busta',
#   'Alexander Zverev'): Text(-0.3022641510465798, -0.6788965876291801, '1'),
#  ('Feliciano Lopez',
#   'Rafael Nadal'): Text(0.05226430508733321, -0.49726091022068386, '1'),
#  ('Nikoloz Basilashvili',
#   'Rafael Nadal'): Text(0.122207524354292, -0.5749406633505839, '1'),
#  ('Nikoloz Basilashvili',
#   'Andrey Rublev'): Text(-0.38682941782438135, -0.8688333740946682, '1'),
#  ('David Goffin',
#   'Rafael Nadal'): Text(0.20677282093441596, -0.6363809522337925, '1'),
#  ('David Goffin',
#   'Andrey Rublev'): Text(-0.3022641212442574, -0.9302736629778767, '1'),
#  ('Daniil Medvedev',
#   'Rafael Nadal'): Text(0.30226423002273384, -0.6788964684198909, '1'),
#  ('Daniil Medvedev',
#   'Novak Djokovic'): Text(0.18005682711290527, -0.8471005967861434, '2'),
#  ('Daniil Medvedev',
#   'Alexander Zverev'): Text(1.713633532296477e-08, -0.9510564614600949, '2'),
#  ('Daniil Medvedev',
#   'Andrey Rublev'): Text(-0.2067727121559395, -0.9727891791639751, '1'),
#  ('Andrey Rublev',
#   'Rafael Nadal'): Text(0.40450860693043034, -0.7006291861237711, '1'),
#  ('Andrey Rublev',
#   'Alexander Zverev'): Text(0.10224439404403181, -0.9727891791639751, '1'),
#  ('Taylor Harry Fritz',
#   'Rafael Nadal'): Text(0.5090369555897184, -0.7006291861237711, '1'),
#  ('Taylor Harry Fritz',
#   'Stefano Travaglia'): Text(0.5413379642188445, -0.6012168195981189, '2'),
#  ('Alexander Zverev',
#   'Rafael Nadal'): Text(0.6112813362227052, -0.6788964684198909, '1'),
#  ('Alexander Zverev',
#   'Novak Djokovic'): Text(0.48907393331287663, -0.8471005967861434, '1'),
#  ('Sebastian Korda',
#   'Rafael Nadal'): Text(0.7067727304098619, -0.6363809522337925, '1'),
#  ('Novak Djokovic',
#   'Rafael Nadal'): Text(0.7913381461992751, -0.5749406037459394, '2'),
#  ('Mackenzie Mcdonald',
#   'Rafael Nadal'): Text(0.8612812462569446, -0.4972608804183616, '1'),
#  ('Rafael Nadal',
#   'Stefano Travaglia'): Text(0.9458465577382298, -0.30732410885403466, '1')}

# %%
# možemo iskoristiti networkx.draw_network da predstavimo egomrežu tog čvora
ego_mreza = nx.ego_graph(G, 'Roger Federer')
print(f"Čvorovi ego mreže igrača Roger Federer su {ego_mreza.nodes}")
plt.figure(figsize=(15,10))
tezine_grana = nx.get_edge_attributes(ego_mreza,'weight')
pos = nx.circular_layout(ego_mreza)
#pos = nx.spring_layout(ego_mreza)
#print(pos)
nx.draw_networkx(ego_mreza, pos)
nx.draw_networkx_edge_labels(ego_mreza, pos, edge_labels = tezine_grana)
# Out:
# Čvorovi ego mreže igrača Roger Federer su ['Steve Johnson', 'Roger Federer', 'Tennys Sandgren', 'Novak Djokovic', 'Marton Fucsovics', 'John Millman', 'Filip Krajinovic']
# {('Steve Johnson',
#   'Tennys Sandgren'): Text(0.3887395418863754, 0.4874639471735968, '1'),
#  ('Steve Johnson',
#   'Filip Krajinovic'): Text(0.8117448437619674, -0.39091579256102543, '1'),
#  ('Steve Johnson',
#   'Roger Federer'): Text(0.8117449033666108, 0.3909157499862803, '1'),
#  ('Roger Federer',
#   'Novak Djokovic'): Text(-0.1387394971828929, 0.6078576524464321, '1'),
#  ('Roger Federer',
#   'Tennys Sandgren'): Text(0.20048444525298617, 0.878379688644928, '1'),
#  ('Roger Federer',
#   'Filip Krajinovic'): Text(0.6234897471285783, -5.108969419742593e-08, '1'),
#  ('Roger Federer',
#   'Marton Fucsovics'): Text(-0.1387394971828929, 0.17397387732845007, '1'),
#  ('Roger Federer',
#   'John Millman'): Text(0.20048441545066453, -0.09654818867236742, '1'),
#  ('Tennys Sandgren',
#   'Novak Djokovic'): Text(-0.5617448586631283, 0.7044058496337486, '1'),
#  ('Novak Djokovic',
#   'Filip Krajinovic'): Text(-0.1387395567875362, -0.1739738901008736, '2'),
#  ('Marton Fucsovics',
#   'Filip Krajinovic'): Text(-0.1387395567875362, -0.6078576652188556, '1')}

# %%
#CENTRALNOSTI
def calculate_centralities(G):

    DC_dict = nx.degree_centrality(G)
    CC_dict = nx.closeness_centrality(G)
    BC_dict = nx.betweenness_centrality(G)
    EVC_dict = nx.eigenvector_centrality(G)

    df1 = pd.DataFrame.from_dict(DC_dict, orient='index', columns=['DC'])
    df2 = pd.DataFrame.from_dict(CC_dict, orient='index', columns=['CC'])
    df3 = pd.DataFrame.from_dict(BC_dict, orient='index', columns=['BC'])
    df4 = pd.DataFrame.from_dict(EVC_dict, orient='index', columns=['EVC'])
    df = pd.concat([df1, df2, df3, df4], axis=1)
    return df
df = calculate_centralities(G)
print(df)
# Out:
#                        DC        CC        BC           EVC
# Aljaz Bedene     0.058140  0.329334  0.010337  1.004416e-01
# Tomas Machac     0.002907  0.242384  0.000000  5.935426e-03
# Emilio Gomez     0.011628  0.255128  0.000508  1.042295e-02
# Michael Venus    0.002907  0.234960  0.000000  4.041514e-03
# Zura Tkemaladze  0.002907  0.155208  0.000000  1.788695e-05
# ...                   ...       ...       ...           ...
# Nik Razborsek    0.002907  0.002907  0.000000  6.070744e-12
# Francis Tiafoe   0.043605  0.318739  0.003340  6.989480e-02
# Adam Moundir     0.002907  0.002907  0.000000  6.070744e-12
# Andrej Martin    0.037791  0.300986  0.008243  4.414846e-02
# Nicolas Jarry    0.008721  0.263321  0.000027  1.629627e-02
#
# [345 rows x 4 columns]

# %%
#Korelacija - kako jedna metrika zavisi od druge, pozitivna korelacija znači da veća vrednost jedne od metrikka povlači veću vrednost druge metrike. 
#Interesantno je posmatrati Kendalovu tau korelaciju (korelaciju po rangu, ne po numeričkoj vrednosti) između različitih mera centralnosti ove mreže.

# %%
import scipy.stats as stats
labele = ['DC', 'CC', 'BC', 'EVC']
cross_correlation_matrix = pd.DataFrame(columns = ['DC', 'CC', 'BC', 'EVC'], index = ['DC', 'CC', 'BC', 'EVC'])
p_val_matrix = pd.DataFrame(columns = ['DC', 'CC', 'BC', 'EVC'], index = ['DC', 'CC', 'BC', 'EVC'])
for ind in labele:
    for col in labele:
        cross_correlation_matrix[ind][col], p_val_matrix[ind][col] =  stats.kendalltau(df[ind], df[col])
print(cross_correlation_matrix)
# Out:
#            DC        CC        BC       EVC
# DC          1  0.834023  0.828834  0.827414
# CC   0.834023         1  0.686561  0.969378
# BC   0.828834  0.686561         1  0.674216
# EVC  0.827414  0.969378  0.674216         1

# %%
#BC-posmatra samo puteve, najslabije sa EVC

# %%
print(p_val_matrix)
#p treba da bude sto manji, kako ne bi bilo da se slucajno desilo
# Out:
#                DC            CC            BC           EVC
# DC   6.18858e-135  2.20968e-104   2.15927e-95   6.6363e-103
# CC   2.20968e-104  5.82031e-165   6.27112e-73  2.39171e-155
# BC    2.15927e-95   6.27112e-73  4.59552e-141   1.71974e-70
# EVC   6.6363e-103  2.39171e-155   1.71974e-70  2.06459e-165

# %%
df = calculate_centralities(G)

df_ = df
for metric in labele:
    df_[f"{metric}_rank"] = df[f"{metric}"].rank(ascending=False) 
    
df_['composite_rank'] = df_['DC_rank'] * df_['CC_rank'] * df_['BC_rank'] * df_['EVC_rank']

df_.sort_values(['composite_rank'], ascending = True)
df_.sort_values(['CC'], ascending = False, inplace=True)
print(df_)
# Out:
#                                        DC        CC        BC           EVC  \
# Andrey Rublev                    0.125000  0.371530  0.027709  2.152859e-01
# Novak Djokovic                   0.093023  0.361916  0.032802  1.585946e-01
# Felix Auger Aliassime            0.107558  0.359726  0.025945  1.802166e-01
# Stefanos Tsitsipas               0.098837  0.353838  0.031380  1.819023e-01
# Casper Ruud                      0.090116  0.353312  0.028839  1.348908e-01
# ...                                   ...       ...       ...           ...
# Ismael Changawa Ruwa Mzai        0.002907  0.002907  0.000000  6.070744e-12
# Kevin Cheruiyot                  0.002907  0.002907  0.000000  6.070744e-12
# Wai Yu Kai                       0.002907  0.002907  0.000000  6.070744e-12
# Aisam Ul Haq Qureshi             0.002907  0.002907  0.000000  6.070744e-12
# Amr Elsayed Abdou Ahmed Mohamed  0.002907  0.002907  0.000000  6.070744e-12
#
#                                  DC_rank  CC_rank  BC_rank  EVC_rank  \
# Andrey Rublev                        1.0      1.0      5.0       1.0
# Novak Djokovic                       4.0      2.0      1.0       5.0
# Felix Auger Aliassime                2.0      3.0      7.0       3.0
# Stefanos Tsitsipas                   3.0      4.0      3.0       2.0
# Casper Ruud                          5.5      5.0      4.0      13.0
# ...                                  ...      ...      ...       ...
# Ismael Changawa Ruwa Mzai          286.0    326.5    283.0     326.5
# Kevin Cheruiyot                    286.0    326.5    283.0     326.5
# Wai Yu Kai                         286.0    326.5    283.0     326.5
# Aisam Ul Haq Qureshi               286.0    326.5    283.0     326.5
# Amr Elsayed Abdou Ahmed Mohamed    286.0    326.5    283.0     326.5
#
#                                  composite_rank
# Andrey Rublev                      5.000000e+00
# Novak Djokovic                     4.000000e+01
# Felix Auger Aliassime              1.260000e+02
# Stefanos Tsitsipas                 7.200000e+01
# Casper Ruud                        1.430000e+03
# ...                                         ...
# Ismael Changawa Ruwa Mzai          8.628173e+09
# Kevin Cheruiyot                    8.628173e+09
# Wai Yu Kai                         8.628173e+09
# Aisam Ul Haq Qureshi               8.628173e+09
# Amr Elsayed Abdou Ahmed Mohamed    8.628173e+09
#
# [345 rows x 9 columns]
