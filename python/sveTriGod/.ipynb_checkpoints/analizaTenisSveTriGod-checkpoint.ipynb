# %%
# Vizuelna podešavanja okruženja (samo razvuče notebook na širinu ekrana)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import pandas as pd

# %%
data2020 = pd.read_csv("../podaci/atp_matches_2020.csv")
data2020.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2020-8888      Atp Cup    Hard         24             A      20200106
# 1  2020-8888      Atp Cup    Hard         24             A      20200106
# 2  2020-8888      Atp Cup    Hard         24             A      20200106
# 3  2020-8888      Atp Cup    Hard         24             A      20200106
# 4  2020-8888      Atp Cup    Hard         24             A      20200106
#
#    match_num  winner_id winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        300     104925         NaN          NaN  ...    51.0     39.0
# 1        299     105138         NaN          NaN  ...    35.0     21.0
# 2        298     104925         NaN          NaN  ...    57.0     35.0
# 3        297     105583         NaN          NaN  ...    54.0     39.0
# 4        296     104745         NaN          NaN  ...    55.0     37.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced winner_rank winner_rank_points  \
# 0       6.0    10.0        6.0        8.0         2.0             9055.0
# 1       6.0     9.0        5.0       10.0        10.0             2335.0
# 2      25.0    14.0        6.0       11.0         2.0             9055.0
# 3      14.0    12.0        0.0        1.0        34.0             1251.0
# 4      10.0    14.0        1.0        5.0         1.0             9985.0
#
#   loser_rank loser_rank_points
# 0        1.0            9985.0
# 1       34.0            1251.0
# 2        5.0            5705.0
# 3       17.0            1840.0
# 4       18.0            1775.0
#
# [5 rows x 49 columns]

# %%
data2019 = pd.read_csv("../podaci/atp_matches_2019.csv")
data2019.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2019-M020     Brisbane    Hard         32             A      20181231
# 1  2019-M020     Brisbane    Hard         32             A      20181231
# 2  2019-M020     Brisbane    Hard         32             A      20181231
# 3  2019-M020     Brisbane    Hard         32             A      20181231
# 4  2019-M020     Brisbane    Hard         32             A      20181231
#
#    match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        300     105453          2.0          NaN  ...    54.0     34.0
# 1        299     106421          4.0          NaN  ...    52.0     36.0
# 2        298     105453          2.0          NaN  ...    27.0     15.0
# 3        297     104542          NaN           PR  ...    60.0     38.0
# 4        296     106421          4.0          NaN  ...    56.0     46.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank winner_rank_points  \
# 0      20.0    14.0       10.0       15.0          9.0             3590.0
# 1       7.0    10.0       10.0       13.0         16.0             1977.0
# 2       6.0     8.0        1.0        5.0          9.0             3590.0
# 3       9.0    11.0        4.0        6.0        239.0              200.0
# 4      19.0    15.0        2.0        4.0         16.0             1977.0
#
#   loser_rank loser_rank_points
# 0       16.0            1977.0
# 1      239.0             200.0
# 2       40.0            1050.0
# 3       31.0            1298.0
# 4       18.0            1855.0
#
# [5 rows x 49 columns]

# %%
data2018 = pd.read_csv("../podaci/atp_matches_2018.csv")
data2018.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2018-M020     Brisbane    Hard         32             A      20180101
# 1  2018-M020     Brisbane    Hard         32             A      20180101
# 2  2018-M020     Brisbane    Hard         32             A      20180101
# 3  2018-M020     Brisbane    Hard         32             A      20180101
# 4  2018-M020     Brisbane    Hard         32             A      20180101
#
#    match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        271     105992          NaN          NaN  ...    47.0     33.0
# 1        272     111577          NaN          NaN  ...    41.0     25.0
# 2        273     104797          NaN          NaN  ...    53.0     37.0
# 3        275     200282          NaN           WC  ...    43.0     33.0
# 4        276     111581          NaN            Q  ...    35.0     28.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank winner_rank_points  \
# 0      19.0    14.0        1.0        4.0         47.0             1010.0
# 1       7.0     9.0        7.0       11.0         54.0              890.0
# 2      29.0    15.0       10.0       16.0         63.0              809.0
# 3      17.0    11.0        4.0        6.0        208.0              245.0
# 4       5.0     9.0        0.0        2.0        175.0              299.0
#
#   loser_rank loser_rank_points
# 0       52.0             909.0
# 1       94.0             593.0
# 2       30.0            1391.0
# 3       44.0            1055.0
# 4       68.0             755.0
#
# [5 rows x 49 columns]

# %%
data = pd.concat([data2020, data2019, data2018])
data.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2020-8888      Atp Cup    Hard         24             A      20200106
# 1  2020-8888      Atp Cup    Hard         24             A      20200106
# 2  2020-8888      Atp Cup    Hard         24             A      20200106
# 3  2020-8888      Atp Cup    Hard         24             A      20200106
# 4  2020-8888      Atp Cup    Hard         24             A      20200106
#
#    match_num  winner_id winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        300     104925         NaN          NaN  ...    51.0     39.0
# 1        299     105138         NaN          NaN  ...    35.0     21.0
# 2        298     104925         NaN          NaN  ...    57.0     35.0
# 3        297     105583         NaN          NaN  ...    54.0     39.0
# 4        296     104745         NaN          NaN  ...    55.0     37.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced winner_rank winner_rank_points  \
# 0       6.0    10.0        6.0        8.0         2.0             9055.0
# 1       6.0     9.0        5.0       10.0        10.0             2335.0
# 2      25.0    14.0        6.0       11.0         2.0             9055.0
# 3      14.0    12.0        0.0        1.0        34.0             1251.0
# 4      10.0    14.0        1.0        5.0         1.0             9985.0
#
#   loser_rank loser_rank_points
# 0        1.0            9985.0
# 1       34.0            1251.0
# 2        5.0            5705.0
# 3       17.0            1840.0
# 4       18.0            1775.0
#
# [5 rows x 49 columns]

# %%
print("Broj redova: ", data.shape[0])
print("Broj kolona: ", data.shape[1])
# Out:
# Broj redova:  7117
# Broj kolona:  49

# %%
dataPlayers = pd.read_csv("../podaci/atp_players.csv")
dataPlayers.head()
# Out:
#    100001         Gardnar    Mulloy  R    19131122  USA
# 0  100002          Pancho    Segura  R  19210620.0  ECU
# 1  100003           Frank   Sedgman  R  19271002.0  AUS
# 2  100004        Giuseppe     Merlo  R  19271011.0  ITA
# 3  100005  Richard Pancho  Gonzales  R  19280509.0  USA
# 4  100006           Grant    Golden  R  19290821.0  USA

# %%
dataPlayers.columns=['player_id','first_name','last_name','hand','birth_date','country_code']
dataPlayers.head()
# Out:
#    player_id      first_name last_name hand  birth_date country_code
# 0     100002          Pancho    Segura    R  19210620.0          ECU
# 1     100003           Frank   Sedgman    R  19271002.0          AUS
# 2     100004        Giuseppe     Merlo    R  19271011.0          ITA
# 3     100005  Richard Pancho  Gonzales    R  19280509.0          USA
# 4     100006           Grant    Golden    R  19290821.0          USA

# %%
print(dataPlayers.dtypes)
# Out:
# player_id         int64
# first_name       object
# last_name        object
# hand             object
# birth_date      float64
# country_code     object
# dtype: object

# %%
print("Broj redova: ", dataPlayers.shape[0])
print("Broj kolona: ", dataPlayers.shape[1])
# Out:
# Broj redova:  54974
# Broj kolona:  6

# %%
#is there any empty field
dataPlayers.isna().any()
# Out:
# player_id       False
# first_name       True
# last_name        True
# hand             True
# birth_date       True
# country_code     True
# dtype: bool

# %%
print(dataPlayers['player_id'].isnull().values.any())
print(dataPlayers['player_id'].is_unique)
# Out:
# False
# True

# %%
#add new column winner with full name
dataPlayers["winner_full_name"] = dataPlayers["first_name"] + " " + dataPlayers["last_name"]
dataPlayers.head()
# Out:
#    player_id      first_name last_name hand  birth_date country_code  \
# 0     100002          Pancho    Segura    R  19210620.0          ECU
# 1     100003           Frank   Sedgman    R  19271002.0          AUS
# 2     100004        Giuseppe     Merlo    R  19271011.0          ITA
# 3     100005  Richard Pancho  Gonzales    R  19280509.0          USA
# 4     100006           Grant    Golden    R  19290821.0          USA
#
#           winner_full_name
# 0            Pancho Segura
# 1            Frank Sedgman
# 2           Giuseppe Merlo
# 3  Richard Pancho Gonzales
# 4             Grant Golden

# %%
#add new column winner with full name
dataPlayers["loser_full_name"] = dataPlayers["first_name"] + " " + dataPlayers["last_name"]
dataPlayers.head()
# Out:
#    player_id      first_name last_name hand  birth_date country_code  \
# 0     100002          Pancho    Segura    R  19210620.0          ECU
# 1     100003           Frank   Sedgman    R  19271002.0          AUS
# 2     100004        Giuseppe     Merlo    R  19271011.0          ITA
# 3     100005  Richard Pancho  Gonzales    R  19280509.0          USA
# 4     100006           Grant    Golden    R  19290821.0          USA
#
#           winner_full_name          loser_full_name
# 0            Pancho Segura            Pancho Segura
# 1            Frank Sedgman            Frank Sedgman
# 2           Giuseppe Merlo           Giuseppe Merlo
# 3  Richard Pancho Gonzales  Richard Pancho Gonzales
# 4             Grant Golden             Grant Golden

# %%
#check if match number is unique
print(data['match_num'].isnull().values.any())
print(data['match_num'].is_unique)
# Out:
# False
# False

# %%
#add column match_id as unique
data['match_id'] = data.index
data.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2020-8888      Atp Cup    Hard         24             A      20200106
# 1  2020-8888      Atp Cup    Hard         24             A      20200106
# 2  2020-8888      Atp Cup    Hard         24             A      20200106
# 3  2020-8888      Atp Cup    Hard         24             A      20200106
# 4  2020-8888      Atp Cup    Hard         24             A      20200106
#
#    match_num  winner_id winner_seed winner_entry  ... l_1stWon l_2ndWon  \
# 0        300     104925         NaN          NaN  ...     39.0      6.0
# 1        299     105138         NaN          NaN  ...     21.0      6.0
# 2        298     104925         NaN          NaN  ...     35.0     25.0
# 3        297     105583         NaN          NaN  ...     39.0     14.0
# 4        296     104745         NaN          NaN  ...     37.0     10.0
#
#    l_SvGms l_bpSaved  l_bpFaced  winner_rank winner_rank_points loser_rank  \
# 0     10.0       6.0        8.0          2.0             9055.0        1.0
# 1      9.0       5.0       10.0         10.0             2335.0       34.0
# 2     14.0       6.0       11.0          2.0             9055.0        5.0
# 3     12.0       0.0        1.0         34.0             1251.0       17.0
# 4     14.0       1.0        5.0          1.0             9985.0       18.0
#
#   loser_rank_points match_id
# 0            9985.0        0
# 1            1251.0        1
# 2            5705.0        2
# 3            1840.0        3
# 4            1775.0        4
#
# [5 rows x 50 columns]

# %%
data_short=data[['match_num','winner_id','loser_id','match_id']]
data_short.head()
# Out:
#    match_num  winner_id  loser_id  match_id
# 0        300     104925    104745         0
# 1        299     105138    105583         1
# 2        298     104925    106421         2
# 3        297     105583    111575         3
# 4        296     104745    200282         4

# %%
dataPlayers.head()
# Out:
#    player_id      first_name last_name hand  birth_date country_code  \
# 0     100002          Pancho    Segura    R  19210620.0          ECU
# 1     100003           Frank   Sedgman    R  19271002.0          AUS
# 2     100004        Giuseppe     Merlo    R  19271011.0          ITA
# 3     100005  Richard Pancho  Gonzales    R  19280509.0          USA
# 4     100006           Grant    Golden    R  19290821.0          USA
#
#           winner_full_name          loser_full_name
# 0            Pancho Segura            Pancho Segura
# 1            Frank Sedgman            Frank Sedgman
# 2           Giuseppe Merlo           Giuseppe Merlo
# 3  Richard Pancho Gonzales  Richard Pancho Gonzales
# 4             Grant Golden             Grant Golden

# %%
dataPlayers_short_winner = dataPlayers[['player_id','winner_full_name']]
dataPlayers_short_winner.head()
# Out:
#    player_id         winner_full_name
# 0     100002            Pancho Segura
# 1     100003            Frank Sedgman
# 2     100004           Giuseppe Merlo
# 3     100005  Richard Pancho Gonzales
# 4     100006             Grant Golden

# %%
dataPlayers_short_loser=dataPlayers[['player_id','loser_full_name']]
dataPlayers_short_loser.head()
# Out:
#    player_id          loser_full_name
# 0     100002            Pancho Segura
# 1     100003            Frank Sedgman
# 2     100004           Giuseppe Merlo
# 3     100005  Richard Pancho Gonzales
# 4     100006             Grant Golden

# %%
#merge three tables
merged_data=data_short.merge(dataPlayers_short_winner,left_on='winner_id', right_on='player_id').drop('player_id', axis=1).merge(dataPlayers_short_loser,left_on='loser_id', right_on='player_id').drop('player_id', axis=1)
merged_data.head()
# Out:
#    match_num  winner_id  loser_id  match_id winner_full_name loser_full_name
# 0        300     104925    104745         0   Novak Djokovic    Rafael Nadal
# 1        226     104925    104745       139   Novak Djokovic    Rafael Nadal
# 2        225     104925    104745      1838   Novak Djokovic    Rafael Nadal
# 3        299     106421    104745      1324  Daniil Medvedev    Rafael Nadal
# 4        293     106401    104745       528     Nick Kyrgios    Rafael Nadal

# %%
player_asm = merged_data[['winner_id','loser_id','match_id','winner_full_name','loser_full_name']]
player_asm.head()
# Out:
#    winner_id  loser_id  match_id winner_full_name loser_full_name
# 0     104925    104745         0   Novak Djokovic    Rafael Nadal
# 1     104925    104745       139   Novak Djokovic    Rafael Nadal
# 2     104925    104745      1838   Novak Djokovic    Rafael Nadal
# 3     106421    104745      1324  Daniil Medvedev    Rafael Nadal
# 4     106401    104745       528     Nick Kyrgios    Rafael Nadal

# %%
#id player unique
list_winner = set(player_asm['winner_full_name'].unique())
list_loser = set(player_asm['loser_full_name'].unique())

skup_id = list_winner.union(list_loser)
print(f"Postoji { len(skup_id) } različitih igrača") # formatiranje ispisa pomoću fstringa
# Out:
# Postoji 581 različitih igrača

# %%
import numpy as np
import matplotlib.pyplot as plt

data_reduced = player_asm[['winner_full_name','loser_full_name','match_id']]

# %%
import networkx as nx
G = nx.Graph() # pravi praznu mrežu
G.add_nodes_from(skup_id) # dodaje čvorove čije su labele u "skup_id"

# %%
#agregacija brojanjem
for _, winner_full_name, loser_full_name, _ in data_reduced.itertuples():
    if (winner_full_name, loser_full_name) in G.edges:
        G.edges[winner_full_name, loser_full_name]['weight'] += 1
    else:
        G.add_edge(winner_full_name, loser_full_name, weight=1)

# %%
print(G.edges.data("weight"))

nx.draw_networkx(G)#-> crta mrežu, ne pokušavati za mrežu sa ovoliko čvorova i grana!
# Out:
# [('Harri Heliovaara', 'Dennis Novak', 1), ('Harri Heliovaara', 'Ricardas Berankis', 1), ('Harri Heliovaara', 'Gerardo Lopez Villasenor', 1), ('Harri Heliovaara', 'Malek Jaziri', 1), ('Harri Heliovaara', 'Mohamed Safwat', 1), ('Harri Heliovaara', 'Karim Mohamed Maamoun', 1), ('Harri Heliovaara', 'Laurynas Grigelis', 1), ('Harri Heliovaara', 'Moez Chargui', 1), ('Francisco Llanes', 'Brandon Perez', 1), ('Jan Lennard Struff', 'Denis Shapovalov', 5), ('Jan Lennard Struff', 'Novak Djokovic', 4), ('Jan Lennard Struff', 'Roberto Bautista Agut', 2), ('Jan Lennard Struff', 'Rafael Nadal', 1), ('Jan Lennard Struff', 'Daniil Medvedev', 1), ('Jan Lennard Struff', 'Karen Khachanov', 3), ('Jan Lennard Struff', 'Daniel Evans', 1), ('Jan Lennard Struff', 'Nick Kyrgios', 3), ('Jan Lennard Struff', 'David Goffin', 3), ('Jan Lennard Struff', 'Gael Monfils', 1), ('Jan Lennard Struff', 'Yoshihito Nishioka', 2), ('Jan Lennard Struff', 'Go Soeda', 1), ('Jan Lennard Struff', 'Nikoloz Basilashvili', 3), ('Jan Lennard Struff', 'Grigor Dimitrov', 2), ('Jan Lennard Struff', 'Cameron Norrie', 1), ('Jan Lennard Struff', 'Borna Coric', 2), ('Jan Lennard Struff', 'Marin Cilic', 3), ('Jan Lennard Struff', 'Dominic Thiem', 1), ('Jan Lennard Struff', 'Stefanos Tsitsipas', 5), ('Jan Lennard Struff', 'Alex De Minaur', 3), ('Jan Lennard Struff', 'Felix Auger Aliassime', 2), ('Jan Lennard Struff', 'John Millman', 3), ('Jan Lennard Struff', 'Marton Fucsovics', 1), ('Jan Lennard Struff', 'Pierre Hugues Herbert', 1), ('Jan Lennard Struff', 'Jeremy Chardy', 2), ('Jan Lennard Struff', 'Mikhail Kukushkin', 1), ('Jan Lennard Struff', 'Pablo Carreno Busta', 3), ('Jan Lennard Struff', 'Alex Bolt', 1), ('Jan Lennard Struff', 'John Isner', 1), ('Jan Lennard Struff', 'Mikael Ymer', 1), ('Jan Lennard Struff', 'Thiago Monteiro', 2), ('Jan Lennard Struff', 'Marco Cecchinato', 3), ('Jan Lennard Struff', 'Vasek Pospisil', 1), ('Jan Lennard Struff', 'Yuichi Sugita', 2), ('Jan Lennard Struff', 'Alexander Zverev', 3), ('Jan Lennard Struff', 'Matteo Berrettini', 2), ('Jan Lennard Struff', 'Jordan Thompson', 1), ('Jan Lennard Struff', 'Roger Federer', 3), ('Jan Lennard Struff', 'Christian Garin', 1), ('Jan Lennard Struff', 'Milos Raonic', 2), ('Jan Lennard Struff', 'Richard Gasquet', 1), ('Jan Lennard Struff', 'Taro Daniel', 1), ('Jan Lennard Struff', 'Viktor Troicki', 1), ('Jan Lennard Struff', 'Reilly Opelka', 1), ('Jan Lennard Struff', 'Steve Johnson', 1), ('Jan Lennard Struff', 'Francis Tiafoe', 2), ('Jan Lennard Struff', 'Federico Coria', 1), ('Jan Lennard Struff', 'Kei Nishikori', 1), ('Jan Lennard Struff', 'Daniel Altmaier', 1), ('Jan Lennard Struff', 'Oscar Otte', 1), ('Jan Lennard Struff', 'Damir Dzumhur', 1), ('Jan Lennard Struff', 'Jo Wilfried Tsonga', 2), ('Jan Lennard Struff', 'Nicolas Jarry', 1), ('Jan Lennard Struff', 'Matthew Ebden', 1), ('Jan Lennard Struff', 'Rudolf Molleker', 1), ('Jan Lennard Struff', 'Alexey Vatutin', 1), ('Jan Lennard Struff', 'Diego Sebastian Schwartzman', 1), ('Jan Lennard Struff', 'Ricardas Berankis', 1), ('Jan Lennard Struff', 'Casper Ruud', 1), ('Jan Lennard Struff', 'Salvatore Caruso', 1), ('Jan Lennard Struff', 'Lucas Pouille', 1), ('Jan Lennard Struff', 'Taylor Harry Fritz', 1), ('Jan Lennard Struff', 'Henri Laaksonen', 1), ('Jan Lennard Struff', 'Benoit Paire', 1), ('Jan Lennard Struff', 'Feliciano Lopez', 1), ('Jan Lennard Struff', 'Michael Mmoh', 1), ('Jan Lennard Struff', 'Miomir Kecmanovic', 2), ('Jan Lennard Struff', 'Tomas Berdych', 1), ('Jan Lennard Struff', 'Fabio Fognini', 1), ('Jan Lennard Struff', 'Marius Copil', 1), ('Jan Lennard Struff', 'Ivo Karlovic', 2), ('Jan Lennard Struff', 'Laslo Djere', 2), ('Jan Lennard Struff', 'Andrey Rublev', 1), ('Jan Lennard Struff', 'Pedro Martinez Portero', 1), ('Jan Lennard Struff', 'Hugo Dellien', 1), ('Jan Lennard Struff', 'Soon Woo Kwon', 1), ('Jan Lennard Struff', 'Egor Gerasimov', 1), ('Jan Lennard Struff', 'Stefano Travaglia', 1), ('Jan Lennard Struff', 'Leonardo Mayer', 1), ('Jan Lennar ...
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
output = "models/undirected_count_aggregationFull.gml"

nx.write_gml(G, output)

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 581
# Number of edges: 5330
# Average degree:  18.3477

# %%
import matplotlib.pyplot as plt
import networkx as nx

def plot_degree_dist(G):
    degrees = [G.degree(n) for n in G.nodes()]
    plt.hist(degrees)
    plt.xlabel("Degree")
    plt.ylabel("Number of nodes")
    
    plt.show()

plot_degree_dist(G)

# %%
import networkx as nx
import matplotlib.pyplot as plt

degree_freq = nx.degree_histogram(G)
degrees = range(len(degree_freq))
plt.figure(figsize=(12, 8)) 
plt.loglog(degrees, degree_freq,'bo') 
plt.title("Distribution plot")
plt.xlabel('Degree')
plt.ylabel('Frequency of nodes')
#plt.savefig('./output/Gd_degree_distributionLog.pdf')
# Out:
# Text(0, 0.5, 'Frequency of nodes')

# %%
import collections
degree_sequence = sorted([d for n, d in G.degree()], reverse=True)  # degree sequence
degreeCount = collections.Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())
cs = np.cumsum(cnt)
plt.loglog(deg, cs, 'bo')
plt.title("Cumulative Distribution plot")
plt.ylabel("Sample with value > Degree")
plt.xlabel("Degree")
plt.show()

# %%
# možemo iskoristiti networkx.draw_network da predstavimo egomrežu tog čvora
ego_mreza = nx.ego_graph(G, 'Novak Djokovic')
print(f"Čvorovi ego mreže igrača Novak Djokovic su {ego_mreza.nodes}")
plt.figure(figsize=(15,10))
tezine_grana = nx.get_edge_attributes(ego_mreza,'weight')
pos = nx.circular_layout(ego_mreza)
#pos = nx.spring_layout(ego_mreza)
#print(pos)
nx.draw_networkx(ego_mreza, pos)
nx.draw_networkx_edge_labels(ego_mreza, pos, edge_labels = tezine_grana)
# Out:
# Čvorovi ego mreže igrača Novak Djokovic su ['Jan Lennard Struff', 'Rogerio Dutra Silva', 'Salvatore Caruso', 'Stanislas Wawrinka', 'Lucas Pouille', 'Alexandr Dolgopolov', 'Alexander Zverev', 'Richard Gasquet', 'Kyle Edmund', 'Joao Sousa', 'Tennys Sandgren', 'Ricardas Berankis', 'Dominic Thiem', 'Malek Jaziri', 'Filip Krajinovic', 'Martin Klizan', 'Mikael Ymer', 'Taro Daniel', 'Kei Nishikori', 'Tatsuma Ito', 'Juan Ignacio Londero', 'Gael Monfils', 'Roberto Bautista Agut', 'David Goffin', 'Go Soeda', 'Fernando Verdasco', 'Bjorn Fratangelo', 'Marton Fucsovics', 'Pablo Carreno Busta', 'Benoit Paire', 'Jeremy Chardy', 'Denis Kudla', 'Hyeon Chung', 'Jaume Munar', 'Daniel Elahi Galan Riveros', 'Stefanos Tsitsipas', 'Alexei Popyrin', 'Milos Raonic', 'Grigor Dimitrov', 'Kevin Anderson', 'Nikoloz Basilashvili', 'Daniil Medvedev', 'Horacio Zeballos', 'Mitchell Krueger', 'Denis Shapovalov', 'Christian Garin', 'Casper Ruud', 'Albert Ramos', 'Peter Polansky', 'Bernard Tomic', 'Karen Khachanov', 'Rafael Nadal', 'Donald Young', 'Novak Djokovic', 'Roberto Carballes Baena', 'Ugo Humbert', 'Marco Cecchinato', 'John Isner', 'Mirza Basic', 'Dominik Koepfer', 'Juan Martin Del Potro', 'Philipp Kohlschreiber', 'Marin Cilic', 'Jo Wilfried Tsonga', 'Adrian Mannarino', 'Federico Delbonis', 'Taylor Harry Fritz', 'Matteo Berrettini', 'Borna Coric', 'John Millman', 'Steve Johnson', 'Sam Querrey', 'Dusan Lajovic', 'Henri Laaksonen', 'Diego Sebastian Schwartzman', 'Damir Dzumhur', 'Hubert Hurkacz', 'Lorenzo Sonego', 'Roger Federer', 'Yoshihito Nishioka', 'Corentin Moutet']
# {('Jan Lennard Struff',
#   'Denis Shapovalov'): Text(0.018314568201969417, -0.13408630483403422, '5'),
#  ('Jan Lennard Struff',
#   'Novak Djokovic'): Text(0.21719649275680403, -0.41233744670684547, '4'),
#  ('Jan Lennard Struff',
#   'Roberto Bautista Agut'): Text(0.43233434741064314, 0.4954001976566923, '2'),
#  ('Jan Lennard Struff',
#   'Rafael Nadal'): Text(0.1568792147264199, -0.3636868540428589, '1'),
#  ('Jan Lennard Struff',
#   'Daniil Medvedev'): Text(0.0003760138787118894, -0.019387665462395353, '1'),
#  ('Jan Lennard Struff',
#   'Karen Khachanov'): Text(0.12972801747642326, -0.3360039535580674, '3'),
#  ('Jan Lennard Struff',
#   'David Goffin'): Text(0.3941480579633089, 0.48866692914369236, '3'),
#  ('Jan Lennard Struff',
#   'Gael Monfils'): Text(0.47092758757100495, 0.4991540981922428, '1'),
#  ('Jan Lennard Struff',
#   'Yoshihito Nishioka'): Text(0.9939949512360171, -0.07725931834656746, '2'),
#  ('Jan Lennard Struff',
#   'Go Soeda'): Text(0.35659837592578636, 0.47899476420712744, '1'),
#  ('Jan Lennard Struff',
#   'Nikoloz Basilashvili'): Text(0.0003760138787118894, 0.019387709728962258, '3'),
#  ('Jan Lennard Struff',
#   'Grigor Dimitrov'): Text(0.00937235154912347, 0.09635616743452717, '2'),
#  ('Jan Lennard Struff',
#   'Borna Coric'): Text(0.7666021282718181, -0.4229932670981292, '2'),
#  ('Jan Lennard Struff',
#   'Marin Cilic'): Text(0.54840553460527, -0.49765139288817023, '3'),
#  ('Jan Lennard Struff',
#   'Dominic Thiem'): Text(0.7985793050027874, 0.40106160159863036, '1'),
#  ('Jan Lennard Struff',
#   'Stefanos Tsitsipas'): Text(0.04481854841536276, 0.20690541641321444, '5'),
#  ('Jan Lennard Struff',
#   'John Millman'): Text(0.7985793050027874, -0.401061588997031, '3'),
#  ('Jan Lennard Struff',
#   'Marton Fucsovics'): Text(0.24999996867996666, 0.43301270129745756, '1'),
#  ('Jan Lennard Struff',
#   'Jeremy Chardy'): Text(0.15687915512177503, 0.3636868070398133, '2'),
#  ('Jan Lennard Struff',
#   'Pablo Carreno Busta'): Text(0.21719652255912647, 0.41233748911076723, '3'),
#  ('Jan Lennard Struff',
#   'John Isner'): Text(0.35659834612346386, -0.4789947516055281, '1'),
#  ('Jan Lennard Struff',
#   'Mikael Ymer'): Text(0.6618669473242864, 0.47307408581799476, '1'),
#  ('Jan Lennard Struff',
#   'Marco Cecchinato'): Text(0.3199111954516509, -0.4664418643788167, '3'),
#  ('Jan Lennard Struff',
#   'Alexander Zverev'): Text(0.9468163250800599, 0.224399603207611, '3'),
#  ('Jan Lennard Struff',
#   'Matteo Berrettini'): Text(0.733021765407081, -0.442380899745776, '2'),
#  ('Jan Lennard Struff',
#   'Roger Federer'): Text(0.9865224361146945, -0.11530797321825627, '3'),
#  ('Jan Lennard Struff',
#   'Christian Garin'): Text(0.030153689806051154, -0.17101007104492313, '1'),
#  ('Jan Lennard Struff',
#   'Milos Raonic'): Text(0.018314568201969417, 0.134086347237956, '2'),
#  ('Jan Lennard Struff',
#   'Richard Gasquet'): Text(0.9280834494565957, 0.25834969368463806, '1'),
#  ('Jan Lennard Struff',
#   'Taro Daniel'): Text(0.6247205950176139, 0.4841949714510796, '1'),
#  ('Jan Lennard Struff',
#   'Steve Johnson'): Text(0.8287606235853624, -0.3767180089402159, '1'),
#  ('Jan Lennard Struff',
#   'Kei Nishikori'): Text(0.5868241108043446, 0.49240387215777, '1'),
#  ('Jan Lennard Struff',
#   'Damir Dzumhur'): Text(0.9468163548823824, -0.22439953100136675, '1'),
#  ('Jan Lennard Struff',
#   'Jo Wilfried Tsonga'): Text(0.5868240735514416, -0.49240385955617066, '2'),
#  ('Jan Lennard Struff',
#   'Diego Sebastian Schwartzman'): Text(0.9280834196542733, -0.2583497406876836, '1'),
#  ('Jan Lennard Struff',
#   'Ricardas Berankis'): Text(0.8287606831900072, 0.37671796193717033, '1'),
#  ('Jan Lennard Struff',
#   'Casper Ruud'): Text(0.044818518613040315, -0.20690537400929265, '1'),
#  ('Jan Lennard Struff',
#   'Salvatore Caruso'): Text(0.9939949214336947, 0.07725940545397289, '1'),
#  ('Jan Lennard Struff',
#   'Lucas Pouille'): Text(0.9761239289754268, 0.15266301398830895, '1'),
#  ('Jan Lennard Struff',
#   'Taylor Harry Fritz'): Text(0.698039784416453, -0.4591080790684895, '1'),
#  ('Jan Lennard Struff',
#   'Henri Laaksonen'): Text(0.9067760704061383, -0.2907459976769167, '1'),
#  ('Jan Lennard Struff',
#   'Benoit Paire'): Text(0.18609389498039391, 0.3891824256731785, '1'),
#  ('Rogerio Dutra Silva',
#   'Tennys Sandgren'): Text(0.855461328929235, 0.38885490187476524, '1'),
#  ('Rogerio Dutra Silva',
#   'Novak Djokovic'): Text(0.2156929655893023, -0.3735912349506484, '1'),
#  ('Rogerio Dutra Silva',
#   'Denis Shapovalov'): Text(0.016811041034467678, -0.09534009307783714, '1'),
#  ('Rogerio Dutra Silva',
#   'Jeremy Chardy'): Text(0.1553756279542733, 0.4024330187960104, '1'),
#  ('Rogerio Dutra Silva',
#   'Albert Ramos'): Text(0.060717372185634055, -0.20281009904597114, '3'),
#  ('Rogerio Dutra Silva',
#   'Taro Daniel'): Text(0.6232170678501122, 0.5229411832072767, '1'),
#  ('Rogerio Dutra Silva',
#   'Horacio Zeballos'): Text(0.001877305872030166, -0.019300231036268364, '1'),
#  ('Salvatore Caruso',
#   'Tennys Sandgren'): Text(0.8509597775304314, 0.4273680892717414, '1'),
#  ('Salvatore Caruso',
#   'Novak Djokovic'): Text(0.2111914141904987, -0.3350780475536722, '2'),
#  ('Salvatore Caruso',
#   'Dusan Lajovic'): Text(0.8770170805349741, -0.244134472464242, '1'),
#  ('Salvatore Caruso',
#   'Casper Ruud'): Text(0.03881344004673498, -0.12964597485611942, '1'),
#  ('Salvatore Caruso',
#   'Stefanos Tsitsipas'): Text(0.038813469849057425, 0.2841648155663877, '1'),
#  ('Salvatore Caruso',
#   'Corentin Moutet'): Text(0.9924913942661929, 0.03851315644487274, '2'),
#  ('Salvatore Caruso',
#   'Filip Krajinovic'): Text(0.7270166719396144, 0.5196403115005486, '1'),
#  ('Salvatore Caruso',
#   'Federico Delbonis'): Text(0.6558618985603035, -0.39581467406322224, '1'),
#  ('Salvatore Caruso',
#   'Jaume Munar'): Text(0.0762510579012724, 0.3520139302409272, '2'),
#  ('Salvatore Caruso',
#   'Christian Garin'): Text(0.02414861123974582, -0.0937506718917499, '1'),
#  ('Salvatore Caruso',
#   'Richard Gasquet'): Text(0.9220783708902904, 0.33560909283781126, '1'),
#  ('Salvatore Caruso',
#   'Malek Jaziri'): Text(0.7605971391124802, 0.5002526192482568, '1'),
#  ('Salvatore Caruso',
#   'Borna Coric'): Text(0.7605970497055128, -0.345733867944956, '1'),
#  ('Stanislas Wawrinka',
#   'Daniil Medvedev'): Text(-0.013101550006593687, 0.09592026935317688, '2'),
#  ('Stanislas Wawrinka',
#   'Denis Shapovalov'): Text(0.00483700431666384, -0.018778370018461985, '3'),
#  ('Stanislas Wawrinka',
#   'Christian Garin'): Text(0.016676125920745577, -0.0557021362293509, '2'),
#  ('Stanislas Wawrinka',
#   'Diego Sebastian Schwartzman'): Text(0.9146058557689678, -0.1430418058721114, '1'),
#  ('Stanislas Wawrinka',
#   'Milos Raonic'): Text(0.00483700431666384, 0.24939428205352826, '3'),
#  ('Stanislas Wawrinka',
#   'Stefanos Tsitsipas'): Text(0.03134098453005718, 0.3222133512287867, '1'),
#  ('Stanislas Wawrinka',
#   'Karen Khachanov'): Text(0.11625045359111769, -0.22069601874249517, '3'),
#  ('Stanislas Wawrinka',
#   'Ricardas Berankis'): Text(0.8152831193047017, 0.49202589675274255, '1'),
#  ('Stanislas Wawrinka',
#   'Damir Dzumhur'): Text(0.9333387909970767, -0.10909159618579452, '3'),
#  ('Stanislas Wawrinka',
#   'Dominik Koepfer'): Text(0.4188567537230151, -0.38009225023952076, '1'),
#  ('Stanislas Wawrinka',
#   'Marton Fucsovics'): Text(0.23652240479466108, 0.5483206361130298, '4'),
#  ('Stanislas Wawrinka',
#   'Kei Nishikori'): Text(0.5733465469190391, 0.6077118069733423, '3'),
#  ('Stanislas Wawrinka',
#   'Lucas Pouille'): Text(0.9626463650901211, 0.26797094880388117, '1'),
#  ('Stanislas Wawrinka',
#   'Taylor Harry Fritz'): Text(0.6845622205311473, -0.3438001442529173, '1'),
#  ('Stanislas Wawrinka',
#   'Marin Cilic'): Text(0.5349279707199645, -0.382343458072598, '1'),
#  ('Stanislas Wawrinka',
#   'Jeremy Chardy'): Text(0.14340159123646945, 0.47899474185538554, '2'),
#  ('Stanislas Wawrinka',
#   'Ugo Humbert'): Text(0.27082934828068056, -0.33577574972450247, '1'),
#  ('Stanislas Wawrinka',
#   'John Isner'): Text(0.34312078223815834, -0.3636868167899559, '1'),
#  ('Stanislas Wawrinka',
#   'Grigor Dimitrov'): Text(-0.004105212336182107, 0.2116641022500994, '6'),
#  ('Stanislas Wawrinka',
#   'Benoit Paire'): Text(0.17261633109508834, 0.5044903604887507, '1'),
#  ('Stanislas Wawrinka',
#   'Steve Johnson'): Text(0.8152830597000568, -0.2614100741246437, '2'),
#  ('Stanislas Wawrinka',
#   'Novak Djokovic'): Text(0.20371892887149845, -0.29702951189127325, '1'),
#  ('Stanislas Wawrinka',
#   'Roberto Bautista Agut'): Text(0.41885678352533756, 0.6107081324722645, '1'),
#  ('Stanislas Wawrinka',
#   'Rafael Nadal'): Text(0.14340165084111434, -0.24837891922728667, '3'),
#  ('Stanislas Wawrinka',
#   'David Goffin'): Text(0.38067049407800324, 0.6039748639592646, '1'),
#  ('Stanislas Wawrinka',
#   'Gael Monfils'): Text(0.45745002368569937, 0.6144620330078151, '1'),
#  ('Stanislas Wawrinka',
#   'Borna Coric'): Text(0.7531245643865125, -0.30768533228255696, '1'),
#  ('Stanislas Wawrinka',
#   'Corentin Moutet'): Text(0.9850189089471927, 0.07656169210727175, '1'),
#  ('Stanislas Wawrinka',
#   'Filip Krajinovic'): Text(0.7195441866206141, 0.5576888471629475, '1'),
#  ('Stanislas Wawrinka',
#   'Sam Querrey'): Text(0.8434873220137535, -0.23480071289907417, '1'),
#  ('Stanislas Wawrinka',
#   'Tennys Sandgren'): Text(0.8434872922114311, 0.4654166249341404, '1'),
#  ('Stanislas Wawrinka',
#   'Marco Cecchinato'): Text(0.3064336315663453, -0.35113392956324446, '1'),
#  ('Stanislas Wawrinka',
#   'Alexander Zverev'): Text(0.9333387611947543, 0.3397075380231832, '2'),
#  ('Stanislas Wawrinka',
#   'Roger Federer'): Text(0.9730448722293888, -3.840268403276781e-08, '4'),
#  ('Stanislas Wawrinka',
#   'Martin Klizan'): Text(0.6845622950369534, 0.5744159966833386, '2'),
#  ('Stanislas Wawrinka',
#   'Mirza Basic'): Text(0.38067057603439003, -0.37335901152884327, '1'),
#  ('Stanislas Wawrinka',
#   'Donald Young'): Text(0.17261642050205567, -0.27387453786065186, '1'),
#  ('Lucas Pouille',
#   'Daniil Medvedev'): Text(-0.02350005714586134, 0.13327534222511395, '3'),
#  ('Lucas Pouille',
#   'Denis Shapovalov'): Text(-0.005561502822603814, 0.01857670285347507, '1'),
#  ('Lucas Pouille',
#   'Yoshihito Nishioka'): Text(0.9701188802114439, 0.07540368934094183, '1'),
#  ('Lucas Pouille',
#   'Milos Raonic'): Text(-0.005561502822603814, 0.28674935492546527, '3'),
#  ('Lucas Pouille',
#   'Karen Khachanov'): Text(0.10585194645185003, -0.1833409458705581, '4'),
#  ('Lucas Pouille',
#   'Philipp Kohlschreiber'): Text(0.485819571542338, -0.3472429606961749, '2'),
#  ('Lucas Pouille',
#   'Roberto Bautista Agut'): Text(0.4084582763860699, 0.6480632053442016, '2'),
#  ('Lucas Pouille',
#   'Filip Krajinovic'): Text(0.7091456794813464, 0.5950439200348846, '3'),
#  ('Lucas Pouille',
#   'Borna Coric'): Text(0.7427260572472448, -0.2703302594106199, '3'),
#  ('Lucas Pouille',
#   'Novak Djokovic'): Text(0.1933204217322308, -0.2596744390193362, '3'),
#  ('Lucas Pouille',
#   'Benoit Paire'): Text(0.16221782395582068, 0.5418454333606878, '2'),
#  ('Lucas Pouille',
#   'Marin Cilic'): Text(0.5245294635806967, -0.34498838520066094, '1'),
#  ('Lucas Pouille',
#   'Hubert Hurkacz'): Text(0.9389858840661367, -0.03643696877522354, '3'),
#  ('Lucas Pouille',
#   'Stefanos Tsitsipas'): Text(0.020942477390789527, 0.35956842410072376, '1'),
#  ('Lucas Pouille',
#   'John Millman'): Text(0.7747032339782141, -0.2483985813095217, '1'),
#  ('Lucas Pouille',
#   'Albert Ramos'): Text(0.038344828328562564, -0.08889330311465893, '1'),
#  ('Lucas Pouille',
#   'John Isner'): Text(0.33272227509889063, -0.32633174391801884, '1'),
#  ('Lucas Pouille',
#   'Kyle Edmund'): Text(0.8828999695792427, 0.4434090477683478, '1'),
#  ('Lucas Pouille',
#   'Tennys Sandgren'): Text(0.8330887850721636, 0.5027716978060774, '1'),
#  ('Lucas Pouille',
#   'Matteo Berrettini'): Text(0.7091456943825076, -0.2897178920582667, '1'),
#  ('Lucas Pouille',
#   'Roger Federer'): Text(0.9626463650901211, 0.03735503446925302, '1'),
#  ('Lucas Pouille',
#   'Joao Sousa'): Text(0.8591461476813511, 0.4740568024995565, '1'),
#  ('Lucas Pouille',
#   'Jo Wilfried Tsonga'): Text(0.5629480025268684, -0.3397408518686614, '2'),
#  ('Lucas Pouille',
#   'Denis Kudla'): Text(0.10585188684720515, 0.4886669142425311, '3'),
#  ('Lucas Pouille',
#   'Martin Klizan'): Text(0.6741637878976858, 0.6117710695552756, '1'),
#  ('Lucas Pouille',
#   'Alexei Popyrin'): Text(0.006277618781477923, 0.3236731211363542, '1'),
#  ('Lucas Pouille',
#   'Richard Gasquet'): Text(0.9042073784320226, 0.41101270137214735, '2'),
#  ('Lucas Pouille',
#   'Lorenzo Sonego'): Text(0.9522478877531759, 8.08066057955692e-08, '1'),
#  ('Alexandr Dolgopolov',
#   'Diego Sebastian Schwartzman'): Text(0.8909454045473058, -0.06924981752879603, '2'),
#  ('Alexandr Dolgopolov',
#   'Novak Djokovic'): Text(0.18005847764983646, -0.22323752354795787, '1'),
#  ('Alexandr Dolgopolov',
#   'Horacio Zeballos'): Text(-0.033757182067435665, 0.13105348036642214, '1'),
#  ('Alexander Zverev',
#   'Rafael Nadal'): Text(0.10369553980647983, -0.13928725713604756, '4'),
#  ('Alexander Zverev',
#   'Daniil Medvedev'): Text(-0.05280766104122819, 0.20501193144441598, '6'),
#  ('Alexander Zverev',
#   'Denis Shapovalov'): Text(-0.034869106717970666, 0.09031329207277711, '3'),
#  ('Alexander Zverev',
#   'Kevin Anderson'): Text(-0.04980284188040818, 0.28244608582848885, '1'),
#  ('Alexander Zverev',
#   'Diego Sebastian Schwartzman'): Text(0.8748997447343332, -0.0339501437808723, '4'),
#  ('Alexander Zverev',
#   'Roger Federer'): Text(0.9333387611947543, 0.10909162368855506, '2'),
#  ('Alexander Zverev',
#   'Dominic Thiem'): Text(0.7453956300828473, 0.6254611985054417, '5'),
#  ('Alexander Zverev',
#   'Stefanos Tsitsipas'): Text(-0.008365126504577325, 0.4313050133200258, '6'),
#  ('Alexander Zverev',
#   'Karen Khachanov'): Text(0.07654434255648318, -0.11160435665125606, '3'),
#  ('Alexander Zverev',
#   'Philipp Kohlschreiber'): Text(0.45651196764697116, -0.27550637147687285, '2'),
#  ('Alexander Zverev',
#   'Malek Jaziri'): Text(0.7134185427588453, 0.647392817001895, '2'),
#  ('Alexander Zverev',
#   'Roberto Bautista Agut'): Text(0.37915067249070306, 0.7197997945635036, '2'),
#  ('Alexander Zverev',
#   'Ricardas Berankis'): Text(0.7755770082700671, 0.6011175588439817, '1'),
#  ('Alexander Zverev',
#   'Damir Dzumhur'): Text(0.8936326799624423, 6.590544457396597e-08, '1'),
#  ('Alexander Zverev',
#   'Kyle Edmund'): Text(0.8535923656838758, 0.5151456369876498, '2'),
#  ('Alexander Zverev',
#   'Filip Krajinovic'): Text(0.6798380755859796, 0.6667805092541866, '1'),
#  ('Alexander Zverev',
#   'Mikael Ymer'): Text(0.6086832724043463, 0.697473682724806, '1'),
#  ('Alexander Zverev',
#   'Pablo Carreno Busta'): Text(0.1640128476391864, 0.6367370860175785, '2'),
#  ('Alexander Zverev',
#   'Borna Coric'): Text(0.7134184533518779, -0.19859367019131785, '3'),
#  ('Alexander Zverev',
#   'Novak Djokovic'): Text(0.16401281783686394, -0.18793784980003414, '5'),
#  ('Alexander Zverev',
#   'David Goffin'): Text(0.34096438304336874, 0.7130665260505037, '2'),
#  ('Alexander Zverev',
#   'Nikoloz Basilashvili'): Text(-0.05280766104122819, 0.24378730663577358, '3'),
#  ('Alexander Zverev',
#   'Taylor Harry Fritz'): Text(0.6448561094965128, -0.23470848216167817, '2'),
#  ('Alexander Zverev',
#   'John Isner'): Text(0.30341467120352383, -0.2545951546987168, '3'),
#  ('Alexander Zverev',
#   'Jaume Munar'): Text(0.02907246154763765, 0.49915412799456527, '1'),
#  ('Alexander Zverev',
#   'Matteo Berrettini'): Text(0.6798380904871408, -0.21798130283896466, '3'),
#  ('Alexander Zverev',
#   'Christian Garin'): Text(-0.02302998511388893, 0.05338952586188819, '1'),
#  ('Alexander Zverev',
#   'Milos Raonic'): Text(-0.034869106717970666, 0.3584859441447673, '1'),
#  ('Alexander Zverev',
#   'Kei Nishikori'): Text(0.5336404358844046, 0.7168034690645813, '2'),
#  ('Alexander Zverev',
#   'Joao Sousa'): Text(0.8298385437859843, 0.5457933917188585, '1'),
#  ('Alexander Zverev',
#   'Hyeon Chung'): Text(0.05161994503747891, 0.5306998267011324, '2'),
#  ('Alexander Zverev',
#   'Juan Martin Del Potro'): Text(0.41774400019538704, -0.2747544886838322, '1'),
#  ('Alexander Zverev',
#   'Federico Delbonis'): Text(0.6086833022066687, -0.2486744763095841, '2'),
#  ('Alexander Zverev',
#   'Marin Cilic'): Text(0.4952218596853299, -0.2732517959813589, '2'),
#  ('Alexander Zverev',
#   'Jeremy Chardy'): Text(0.10369548020183494, 0.5880864039466247, '2'),
#  ('Alexander Zverev',
#   'Hubert Hurkacz'): Text(0.9096782801707699, 0.0352996204440785, '1'),
#  ('Alexander Zverev',
#   'Sam Querrey'): Text(0.8037812109791191, -0.12570905080783507, '1'),
#  ('Alexander Zverev',
#   'Juan Ignacio Londero'): Text(0.45651199931193875, 0.7243055778920948, '1'),
#  ('Alexander Zverev',
#   'John Millman'): Text(0.7453956300828473, -0.17666199209021965, '2'),
#  ('Alexander Zverev',
#   'Alexei Popyrin'): Text(-0.02302998511388893, 0.39540971035565625, '2'),
#  ('Alexander Zverev',
#   'Dusan Lajovic'): Text(0.8298384841813393, -0.0969942747106039, '2'),
#  ('Alexander Zverev',
#   'Fernando Verdasco'): Text(0.2667274460259047, 0.6908414440849049, '3'),
#  ('Alexander Zverev',
#   'Adrian Mannarino'): Text(0.5715370095046413, -0.25979536194266895, '3'),
#  ('Alexander Zverev',
#   'Peter Polansky'): Text(0.029072431745315208, -0.05035492157934329, '1'),
#  ('Alexander Zverev',
#   'Steve Johnson'): Text(0.7755769486654223, -0.15231841203340457, '1'),
#  ('Alexander Zverev',
#   'Richard Gasquet'): Text(0.8748997745366557, 0.4827492905914494, '1'),
#  ('Alexander Zverev',
#   'Marco Cecchinato'): Text(0.2667275205317108, -0.24204226747200536, '2'),
#  ('Alexander Zverev',
#   'Martin Klizan'): Text(0.6448561840023189, 0.6835076587745776, '1'),
#  ('Richard Gasquet',
#   'Daniil Medvedev'): Text(-0.07154053666469234, 0.23896202192144306, '2'),
#  ('Richard Gasquet',
#   'Denis Shapovalov'): Text(-0.05360198234143482, 0.12426338254980418, '1'),
#  ('Richard Gasquet',
#   'Kevin Anderson'): Text(-0.06853571750387233, 0.3163961763055159, '1'),
#  ('Richard Gasquet',
#   'Diego Sebastian Schwartzman'): Text(0.856166869110869, -5.3303845226615465e-08, '3'),
#  ('Richard Gasquet',
#   'Stefanos Tsitsipas'): Text(-0.027098002128041476, 0.4652551037970528, '2'),
#  ('Richard Gasquet',
#   'Malek Jaziri'): Text(0.6946856671353812, 0.681342907478922, '1'),
#  ('Richard Gasquet',
#   'Roberto Bautista Agut'): Text(0.3604177968672389, 0.7537498850405306, '6'),
#  ('Richard Gasquet',
#   'Damir Dzumhur'): Text(0.8748998043389782, 0.03395015638247165, '1'),
#  ('Richard Gasquet',
#   'Casper Ruud'): Text(-0.02709803193036392, 0.05144431337454575, '1'),
#  ('Richard Gasquet',
#   'Kei Nishikori'): Text(0.5149075602609404, 0.7507535595416084, '2'),
#  ('Richard Gasquet',
#   'Federico Delbonis'): Text(0.5899504265832045, -0.21472438583255704, '1'),
#  ('Richard Gasquet',
#   'Bernard Tomic'): Text(0.032887129018659644, -0.0479505894135282, '1'),
#  ('Richard Gasquet',
#   'Taylor Harry Fritz'): Text(0.6261232338730487, -0.2007583916846511, '2'),
#  ('Richard Gasquet',
#   'Jeremy Chardy'): Text(0.08496260457837079, 0.6220364944236517, '5'),
#  ('Richard Gasquet',
#   'Henri Laaksonen'): Text(0.8348595198627341, -0.03239631029307832, '1'),
#  ('Richard Gasquet',
#   'Denis Kudla'): Text(0.05781140732837414, 0.5943535939388602, '1'),
#  ('Richard Gasquet',
#   'David Goffin'): Text(0.3222315074199046, 0.7470166165275307, '3'),
#  ('Richard Gasquet',
#   'Roberto Carballes Baena'): Text(0.17808349264236853, -0.17466303111434228, '1'),
#  ('Richard Gasquet',
#   'Juan Ignacio Londero'): Text(0.4377791236884746, 0.758255668369122, '3'),
#  ('Richard Gasquet',
#   'Benoit Paire'): Text(0.11417734443698968, 0.6475321130570169, '5'),
#  ('Richard Gasquet',
#   'Novak Djokovic'): Text(0.1452799422133998, -0.15398775932300707, '1'),
#  ('Richard Gasquet',
#   'Dusan Lajovic'): Text(0.8111056085578752, -0.06304418423357683, '1'),
#  ('Richard Gasquet',
#   'Rafael Nadal'): Text(0.08496266418301568, -0.10533716665902049, '1'),
#  ('Richard Gasquet',
#   'Gael Monfils'): Text(0.3990110370276007, 0.7575037855760812, '2'),
#  ('Richard Gasquet',
#   'Borna Coric'): Text(0.6946855777284138, -0.16464357971429078, '1'),
#  ('Richard Gasquet',
#   'Dominic Thiem'): Text(0.7266627544593831, 0.6594112889824688, '1'),
#  ('Richard Gasquet',
#   'Albert Ramos'): Text(-0.00969565119026844, 0.016793376581670183, '1'),
#  ('Richard Gasquet',
#   'Pablo Carreno Busta'): Text(0.14527997201572224, 0.6706871764946056, '1'),
#  ('Richard Gasquet',
#   'Kyle Edmund'): Text(0.8348594900604116, 0.5490957274646768, '2'),
#  ('Richard Gasquet',
#   'Mikael Ymer'): Text(0.5899503967808821, 0.7314237732018332, '1'),
#  ('Richard Gasquet',
#   'Matteo Berrettini'): Text(0.6611052148636767, -0.1840312123619376, '1'),
#  ('Richard Gasquet',
#   'Roger Federer'): Text(0.9146058855712902, 0.14304171416558215, '2'),
#  ('Richard Gasquet',
#   'Philipp Kohlschreiber'): Text(0.437779092023507, -0.24155628099984577, '1'),
#  ('Richard Gasquet',
#   'Lorenzo Sonego'): Text(0.904207408234345, 0.1056867605029349, '2'),
#  ('Richard Gasquet',
#   'Juan Martin Del Potro'): Text(0.3990111245719229, -0.2408043982068051, '1'),
#  ('Kyle Edmund',
#   'Daniil Medvedev'): Text(-0.09284794551747222, 0.2713583683176435, '3'),
#  ('Kyle Edmund',
#   'Denis Shapovalov'): Text(-0.07490939119421469, 0.1566597289460046, '3'),
#  ('Kyle Edmund',
#   'Gael Monfils'): Text(0.37770362817482084, 0.7899001319722816, '1'),
#  ('Kyle Edmund',
#   'Kevin Anderson'): Text(-0.0898431263566522, 0.34879252270171635, '2'),
#  ('Kyle Edmund',
#   'Diego Sebastian Schwartzman'): Text(0.8348594602580892, 0.0323962930923552, '4'),
#  ('Kyle Edmund',
#   'Milos Raonic'): Text(-0.07490939119421469, 0.4248323810179948, '1'),
#  ('Kyle Edmund',
#   'Philipp Kohlschreiber'): Text(0.41647168317072714, -0.20915993460364535, '1'),
#  ('Kyle Edmund',
#   'Malek Jaziri'): Text(0.6733782582826013, 0.7137392538751224, '2'),
#  ('Kyle Edmund',
#   'Ricardas Berankis'): Text(0.7355367237938231, 0.6674639957172092, '1'),
#  ('Kyle Edmund',
#   'Novak Djokovic'): Text(0.12397253336061992, -0.12159141292680664, '4'),
#  ('Kyle Edmund',
#   'Dusan Lajovic'): Text(0.7897981997050953, -0.0306478378373764, '2'),
#  ('Kyle Edmund',
#   'Yoshihito Nishioka'): Text(0.900770991839833, 0.21348671543347136, '1'),
#  ('Kyle Edmund',
#   'Nikoloz Basilashvili'): Text(-0.09284794551747222, 0.3101337435090011, '2'),
#  ('Kyle Edmund',
#   'Grigor Dimitrov'): Text(-0.08385160784706064, 0.387102201214566, '2'),
#  ('Kyle Edmund',
#   'Taylor Harry Fritz'): Text(0.6048158250202689, -0.16836204528845067, '2'),
#  ('Kyle Edmund',
#   'Marin Cilic'): Text(0.45518157520908586, -0.2069053591081314, '1'),
#  ('Kyle Edmund',
#   'Stefanos Tsitsipas'): Text(-0.04840541098082135, 0.4976514501932533, '1'),
#  ('Kyle Edmund',
#   'Fernando Verdasco'): Text(0.22668716154966068, 0.7571878809581324, '3'),
#  ('Kyle Edmund',
#   'Jeremy Chardy'): Text(0.06365519572559092, 0.6544328408198521, '2'),
#  ('Kyle Edmund',
#   'Filip Krajinovic'): Text(0.6397977911097356, 0.7331269461274141, '2'),
#  ('Kyle Edmund',
#   'John Isner'): Text(0.26337438672727975, -0.1882487178254893, '2'),
#  ('Kyle Edmund',
#   'Marco Cecchinato'): Text(0.22668723605546678, -0.17569583059877786, '1'),
#  ('Kyle Edmund',
#   'Matteo Berrettini'): Text(0.6397978060108969, -0.15163486596573716, '2'),
#  ('Kyle Edmund',
#   'Roger Federer'): Text(0.8932984767185104, 0.17543806056178257, '1'),
#  ('Kyle Edmund',
#   'Christian Garin'): Text(-0.06307026959013295, 0.11973596273511569, '1'),
#  ('Kyle Edmund',
#   'Steve Johnson'): Text(0.7355366641891783, -0.08597197516017707, '1'),
#  ('Kyle Edmund',
#   'Joao Sousa'): Text(0.7897982593097402, 0.612139828592086, '1'),
#  ('Kyle Edmund',
#   'Jo Wilfried Tsonga'): Text(0.4936001141552575, -0.20165782577613184, '2'),
#  ('Kyle Edmund',
#   'Denis Kudla'): Text(0.03650399847559427, 0.6267499403350607, '1'),
#  ('Kyle Edmund',
#   'Dominik Koepfer'): Text(0.3391103582121366, -0.20465415127505415, '1'),
#  ('Kyle Edmund',
#   'Marton Fucsovics'): Text(0.15677600928378255, 0.7237587350774963, '1'),
#  ('Kyle Edmund',
#   'Ugo Humbert'): Text(0.19108295276980203, -0.16033765076003587, '1'),
#  ('Kyle Edmund',
#   'David Goffin'): Text(0.30092409856712476, 0.7794129629237312, '1'),
#  ('Kyle Edmund',
#   'Roberto Carballes Baena'): Text(0.15677608378958865, -0.14226668471814186, '1'),
#  ('Kyle Edmund',
#   'Albert Ramos'): Text(-0.031003060043048314, 0.04918972297787061, '1'),
#  ('Kyle Edmund',
#   'Jaume Munar'): Text(-0.010967822928606374, 0.5655005648677928, '1'),
#  ('Kyle Edmund',
#   'Hyeon Chung'): Text(0.011579660561234884, 0.5970462635743599, '1'),
#  ('Joao Sousa',
#   'Daniil Medvedev'): Text(-0.11660176741536377, 0.3020061230488522, '3'),
#  ('Joao Sousa',
#   'Denis Shapovalov'): Text(-0.09866321309210624, 0.18730748367721334, '2'),
#  ('Joao Sousa',
#   'Stefanos Tsitsipas'): Text(-0.0721592328787129, 0.528299204924462, '1'),
#  ('Joao Sousa',
#   'Karen Khachanov'): Text(0.012750236182347607, -0.014610165046819834, '1'),
#  ('Joao Sousa',
#   'Philipp Kohlschreiber'): Text(0.3927178612728356, -0.17851217987243662, '1'),
#  ('Joao Sousa',
#   'Malek Jaziri'): Text(0.6496244363847098, 0.7443870086063311, '1'),
#  ('Joao Sousa',
#   'Roberto Bautista Agut'): Text(0.3153565661165675, 0.8167939861679399, '2'),
#  ('Joao Sousa',
#   'Filip Krajinovic'): Text(0.616043969211844, 0.7637747008586229, '3'),
#  ('Joao Sousa',
#   'Mikael Ymer'): Text(0.5448891660302106, 0.7944678743292424, '2'),
#  ('Joao Sousa',
#   'Pablo Carreno Busta'): Text(0.10021874126505081, 0.7337312776220148, '2'),
#  ('Joao Sousa',
#   'Nikoloz Basilashvili'): Text(-0.11660176741536377, 0.3407814982402098, '1'),
#  ('Joao Sousa',
#   'Marin Cilic'): Text(0.4314277533111943, -0.17625760437692267, '2'),
#  ('Joao Sousa',
#   'Hubert Hurkacz'): Text(0.8458841737966343, 0.13229381204851473, '2'),
#  ('Joao Sousa',
#   'David Goffin'): Text(0.2771702766692332, 0.8100607176549399, '2'),
#  ('Joao Sousa',
#   'Juan Ignacio Londero'): Text(0.3927178929378032, 0.821299769496531, '1'),
#  ('Joao Sousa',
#   'Alexei Popyrin'): Text(-0.0868240914880245, 0.4924039019600925, '1'),
#  ('Joao Sousa',
#   'Donald Young'): Text(0.06911620309328559, -0.06778868416497652, '1'),
#  ('Joao Sousa',
#   'Mirza Basic'): Text(0.2771703586256199, -0.16727315783316793, '2'),
#  ('Joao Sousa',
#   'Steve Johnson'): Text(0.7117828422912866, -0.05532422042896834, '1'),
#  ('Joao Sousa',
#   'Novak Djokovic'): Text(0.10021871146272837, -0.09094365819559791, '2'),
#  ('Joao Sousa',
#   'Rafael Nadal'): Text(0.03990143343234426, -0.04229306553161133, '1'),
#  ('Joao Sousa',
#   'Kevin Anderson'): Text(-0.11359694825454375, 0.3794402774329251, '1'),
#  ('Joao Sousa',
#   'Gael Monfils'): Text(0.3539498062769293, 0.8205478867034903, '1'),
#  ('Joao Sousa',
#   'Yoshihito Nishioka'): Text(0.8770171699419415, 0.2441344701646801, '1'),
#  ('Joao Sousa',
#   'Casper Ruud'): Text(-0.07215926268103534, 0.1144884145019549, '2'),
#  ('Joao Sousa',
#   'Borna Coric'): Text(0.6496243469777424, -0.10159947858688162, '2'),
#  ('Joao Sousa',
#   'John Millman'): Text(0.6816015237087116, -0.07966780048578342, '1'),
#  ('Joao Sousa',
#   'Marton Fucsovics'): Text(0.133022187385891, 0.7544064898087051, '1'),
#  ('Joao Sousa',
#   'Albert Ramos'): Text(-0.05475688194093986, 0.07983747770907934, '1'),
#  ('Joao Sousa',
#   'Federico Delbonis'): Text(0.5448891958325331, -0.15168028470514788, '2'),
#  ('Joao Sousa',
#   'Jaume Munar'): Text(-0.03472164482649792, 0.5961483195990015, '1'),
#  ('Joao Sousa',
#   'Roger Federer'): Text(0.8695446548206187, 0.2060858152929913, '1'),
#  ('Joao Sousa',
#   'Milos Raonic'): Text(-0.09866321309210624, 0.45548013574920354, '1'),
#  ('Joao Sousa',
#   'Adrian Mannarino'): Text(0.5077429031305056, -0.16280117033823271, '2'),
#  ('Joao Sousa',
#   'Lorenzo Sonego'): Text(0.8591461774836735, 0.16873086163034406, '1'),
#  ('Joao Sousa',
#   'Kei Nishikori'): Text(0.469846329510269, 0.8137976606690176, '1'),
#  ('Joao Sousa',
#   'Hyeon Chung'): Text(-0.012174161336656664, 0.6276940183055686, '2'),
#  ('Joao Sousa',
#   'Bernard Tomic'): Text(-0.012174101732011777, 0.015093511713880958, '1'),
#  ('Joao Sousa',
#   'Marco Cecchinato'): Text(0.20293341415757524, -0.14504807586756913, '1'),
#  ('Tennys Sandgren',
#   'Dominic Thiem'): Text(0.6555441610995241, 0.7511702854163989, '1'),
#  ('Tennys Sandgren',
#   'Philipp Kohlschreiber'): Text(0.36666049866364797, -0.14979728456591568, '2'),
#  ('Tennys Sandgren',
#   'Novak Djokovic'): Text(0.07416134885354075, -0.06222876288907697, '3'),
#  ('Tennys Sandgren',
#   'Roberto Bautista Agut'): Text(0.28929920350737987, 0.8455088814744608, '1'),
#  ('Tennys Sandgren',
#   'Yoshihito Nishioka'): Text(0.8509598073327538, 0.27284936547120103, '1'),
#  ('Tennys Sandgren',
#   'Grigor Dimitrov'): Text(-0.1336627923541398, 0.4464648512522957, '1'),
#  ('Tennys Sandgren',
#   'Hubert Hurkacz'): Text(0.8198268111874467, 0.16100870735503567, '2'),
#  ('Tennys Sandgren',
#   'Diego Sebastian Schwartzman'): Text(0.78504827575101, 0.09175894313008487, '1'),
#  ('Tennys Sandgren',
#   'Denis Shapovalov'): Text(-0.12472057570129386, 0.21602237898373428, '2'),
#  ('Tennys Sandgren',
#   'John Millman'): Text(0.6555441610995241, -0.050952905179262487, '1'),
#  ('Tennys Sandgren',
#   'Corentin Moutet'): Text(0.855461328929235, 0.311362441109468, '1'),
#  ('Tennys Sandgren',
#   'Sam Querrey'): Text(0.713929741995796, 3.6103122103003926e-08, '2'),
#  ('Tennys Sandgren',
#   'John Isner'): Text(0.21356320222020062, -0.12888606778775963, '2'),
#  ('Tennys Sandgren',
#   'Roger Federer'): Text(0.8434872922114311, 0.23480071059951224, '1'),
#  ('Tennys Sandgren',
#   'Adrian Mannarino'): Text(0.481685540521318, -0.13408627503171178, '2'),
#  ('Tennys Sandgren',
#   'Taro Daniel'): Text(0.4816854511143507, 0.8343036552688481, '1'),
#  ('Tennys Sandgren',
#   'Steve Johnson'): Text(0.6857254796820991, -0.026609325122447403, '2'),
#  ('Tennys Sandgren',
#   'Dominik Koepfer'): Text(0.2892991737050574, -0.14529150123732448, '1'),
#  ('Tennys Sandgren',
#   'Daniel Elahi Galan Riveros'): Text(-0.08081424455012748, 0.5916650370238585, '1'),
#  ('Tennys Sandgren',
#   'Malek Jaziri'): Text(0.6235670737755221, 0.7731019039128522, '1'),
#  ('Tennys Sandgren',
#   'Hyeon Chung'): Text(-0.03823152394584428, 0.6564089136120895, '2'),
#  ('Tennys Sandgren',
#   'Ricardas Berankis'): Text(0.685725539286744, 0.7268266457549388, '1'),
#  ('Tennys Sandgren',
#   'Nikoloz Basilashvili'): Text(-0.14265913002455138, 0.36949639354673075, '1'),
#  ('Tennys Sandgren',
#   'Jo Wilfried Tsonga'): Text(0.4437889296481783, -0.14229517573840217, '1'),
#  ('Tennys Sandgren',
#   'Jeremy Chardy'): Text(0.013844011218511754, 0.7137954908575819, '1'),
#  ('Tennys Sandgren',
#   'Roberto Carballes Baena'): Text(0.10696489928250949, -0.08290403468041219, '1'),
#  ('Tennys Sandgren',
#   'Matteo Berrettini'): Text(0.5899866215038176, -0.0922722159280075, '1'),
#  ('Tennys Sandgren',
#   'Mirza Basic'): Text(0.25111299601643233, -0.138558262526647, '1'),
#  ('Tennys Sandgren',
#   'Marco Cecchinato'): Text(0.17687605154838762, -0.11633318056104819, '1'),
#  ('Tennys Sandgren',
#   'Lorenzo Sonego'): Text(0.8330888148744859, 0.197445756936865, '1'),
#  ('Ricardas Berankis',
#   'Daniil Medvedev'): Text(-0.17086330293128088, 0.35733029017397533, '2'),
#  ('Ricardas Berankis',
#   'Denis Shapovalov'): Text(-0.15292474860802335, 0.24263165080233645, '3'),
#  ('Ricardas Berankis',
#   'Stefanos Tsitsipas'): Text(-0.12642076839463, 0.5836233720495851, '2'),
#  ('Ricardas Berankis',
#   'Novak Djokovic'): Text(0.04595717594681126, -0.035619491070474796, '2'),
#  ('Ricardas Berankis',
#   'Dusan Lajovic'): Text(0.7117828422912866, 0.055324084018955444, '1'),
#  ('Ricardas Berankis',
#   'Karen Khachanov'): Text(-0.04151129933356951, 0.04071400207830328, '1'),
#  ('Ricardas Berankis',
#   'David Goffin'): Text(0.22290874115331608, 0.865384884780063, '2'),
#  ('Ricardas Berankis',
#   'Gael Monfils'): Text(0.2996882707610122, 0.8758720538286136, '1'),
#  ('Ricardas Berankis',
#   'Nikoloz Basilashvili'): Text(-0.17086330293128088, 0.3961056653653329, '1'),
#  ('Ricardas Berankis',
#   'Jeremy Chardy'): Text(-0.014360161688217743, 0.740404762676184, '1'),
#  ('Ricardas Berankis',
#   'Pablo Carreno Busta'): Text(0.0459572057491337, 0.7890554447471378, '2'),
#  ('Ricardas Berankis',
#   'Sam Querrey'): Text(0.6857255690890665, 0.02660930792172428, '1'),
#  ('Ricardas Berankis',
#   'Adrian Mannarino'): Text(0.4534813676145885, -0.1074770032131096, '3'),
#  ('Ricardas Berankis',
#   'Roberto Carballes Baena'): Text(0.07876072637578, -0.05629476286181001, '2'),
#  ('Ricardas Berankis',
#   'Jo Wilfried Tsonga'): Text(0.4155847567414488, -0.11568590391979999, '1'),
#  ('Ricardas Berankis',
#   'Hyeon Chung'): Text(-0.06643569685257378, 0.6830181854306917, '1'),
#  ('Ricardas Berankis',
#   'Denis Kudla'): Text(-0.04151135893821439, 0.7127218621913924, '1'),
#  ('Ricardas Berankis',
#   'Steve Johnson'): Text(0.6575213067753696, -5.3303845226615465e-08, '1'),
#  ('Dominic Thiem',
#   'Rafael Nadal'): Text(-0.044541480270792744, 0.03737474125497181, '8'),
#  ('Dominic Thiem',
#   'Daniil Medvedev'): Text(-0.20104468111850077, 0.38167392983543535, '5'),
#  ('Dominic Thiem',
#   'Denis Shapovalov'): Text(-0.18310612679524324, 0.2669752904637965, '2'),
#  ('Dominic Thiem',
#   'Gael Monfils'): Text(0.2695068925737923, 0.9002156934900736, '5'),
#  ('Dominic Thiem',
#   'Kevin Anderson'): Text(-0.19803986195768075, 0.4591080842195082, '3'),
#  ('Dominic Thiem',
#   'Christian Garin'): Text(-0.1712670051911615, 0.23005152425290756, '1'),
#  ('Dominic Thiem',
#   'Diego Sebastian Schwartzman'): Text(0.7266627246570607, 0.14271185461014707, '5'),
#  ('Dominic Thiem',
#   'Milos Raonic'): Text(-0.18310612679524324, 0.5351479425357867, '2'),
#  ('Dominic Thiem',
#   'Roger Federer'): Text(0.7851017411174818, 0.28575362207957444, '4'),
#  ('Dominic Thiem',
#   'Novak Djokovic'): Text(0.01577579775959137, -0.01127585140901477, '6'),
#  ('Dominic Thiem',
#   'Dusan Lajovic'): Text(0.6816014641040667, 0.07966772368041547, '3'),
#  ('Dominic Thiem',
#   'Karen Khachanov'): Text(-0.0716926775207894, 0.0650576417397633, '3'),
#  ('Dominic Thiem',
#   'Grigor Dimitrov'): Text(-0.1920483434480892, 0.4974177627323579, '1'),
#  ('Dominic Thiem',
#   'Borna Coric'): Text(0.5651814332746055, -0.02193167180029848, '3'),
#  ('Dominic Thiem',
#   'Hubert Hurkacz'): Text(0.7614412600934973, 0.21196161883509787, '2'),
#  ('Dominic Thiem',
#   'Stefanos Tsitsipas'): Text(-0.1566021465818499, 0.6079670117110452, '8'),
#  ('Dominic Thiem',
#   'Fernando Verdasco'): Text(0.11849042594863213, 0.8675034424759243, '3'),
#  ('Dominic Thiem',
#   'Filip Krajinovic'): Text(0.5316010555087071, 0.843442507645206, '1'),
#  ('Dominic Thiem',
#   'Sam Querrey'): Text(0.6555441909018465, 0.050952947583184305, '2'),
#  ('Dominic Thiem',
#   'Alexei Popyrin'): Text(-0.1712670051911615, 0.5720717087466756, '1'),
#  ('Dominic Thiem',
#   'Matteo Berrettini'): Text(0.5316010704098683, -0.04131930444794529, '4'),
#  ('Dominic Thiem',
#   'Kei Nishikori'): Text(0.385403415807132, 0.8934654674556006, '3'),
#  ('Dominic Thiem',
#   'Martin Klizan'): Text(0.49661916392504635, 0.860169657165597, '3'),
#  ('Dominic Thiem',
#   'Juan Martin Del Potro'): Text(0.26950698011811447, -0.0980924902928128, '1'),
#  ('Dominic Thiem',
#   'Roberto Bautista Agut'): Text(0.23091365241343048, 0.896461792954523, '1'),
#  ('Dominic Thiem',
#   'Casper Ruud'): Text(-0.15660217638417234, 0.19415622128853804, '1'),
#  ('Dominic Thiem',
#   'Pablo Carreno Busta'): Text(0.015775827561913813, 0.8133990844085979, '2'),
#  ('Dominic Thiem',
#   'Nikoloz Basilashvili'): Text(-0.20104468111850077, 0.42044930502679295, '1'),
#  ('Dominic Thiem',
#   'Marton Fucsovics'): Text(0.048579273682754, 0.8340742965952883, '1'),
#  ('Dominic Thiem',
#   'Jo Wilfried Tsonga'): Text(0.3854033785542289, -0.09134226425833997, '1'),
#  ('Dominic Thiem',
#   'Federico Delbonis'): Text(0.46044628212939614, -0.07201247791856474, '1'),
#  ('Dominic Thiem',
#   'Taylor Harry Fritz'): Text(0.49661908941924027, -0.0580464837706588, '2'),
#  ('Dominic Thiem',
#   'Marin Cilic'): Text(0.3469848396080573, -0.09658979759033953, '3'),
#  ('Dominic Thiem',
#   'Denis Kudla'): Text(-0.07169273712543428, 0.7370655018528525, '1'),
#  ('Dominic Thiem',
#   'Roberto Carballes Baena'): Text(0.048579348188560106, -0.031951123200349985, '1'),
#  ('Dominic Thiem',
#   'John Millman'): Text(0.5971586100055747, 6.300799715308614e-09, '1'),
#  ('Dominic Thiem',
#   'Corentin Moutet'): Text(0.7970757778352856, 0.3623153525895302, '1'),
#  ('Dominic Thiem',
#   'Benoit Paire'): Text(-0.015326800016818742, 0.7902440209710092, '1'),
#  ('Dominic Thiem',
#   'Albert Ramos'): Text(-0.13919979564407686, 0.15950528449566248, '1'),
#  ('Dominic Thiem',
#   'Jaume Munar'): Text(-0.11916455852963492, 0.6758161263855846, '4'),
#  ('Dominic Thiem',
#   'Adrian Mannarino'): Text(0.42329998942736863, -0.08313336355164958, '2'),
#  ('Dominic Thiem',
#   'Horacio Zeballos'): Text(-0.19803986195768075, 0.34301515250536524, '1'),
#  ('Dominic Thiem',
#   'Mirza Basic'): Text(0.19272744492248292, -0.08760535104658479, '1'),
#  ('Dominic Thiem',
#   'Steve Johnson'): Text(0.6273399285881497, 0.0243435863576148, '1'),
#  ('Dominic Thiem',
#   'Marco Cecchinato'): Text(0.11849050045443824, -0.06538026908098599, '1'),
#  ('Dominic Thiem',
#   'Lorenzo Sonego'): Text(0.7747032637805366, 0.2483986684169272, '1'),
#  ('Malek Jaziri',
#   'Stefanos Tsitsipas'): Text(-0.1885792339058518, 0.6298986302074984, '2'),
#  ('Malek Jaziri',
#   'Novak Djokovic'): Text(-0.016201289564410526, 0.010655767087438484, '1'),
#  ('Malek Jaziri',
#   'Roberto Bautista Agut'): Text(0.19893656508942859, 0.9183934114509762, '1'),
#  ('Malek Jaziri',
#   'Dusan Lajovic'): Text(0.6496243767800649, 0.10159934217686872, '1'),
#  ('Malek Jaziri',
#   'David Goffin'): Text(0.1607502756420943, 0.9116601429379763, '1'),
#  ('Malek Jaziri',
#   'Nikoloz Basilashvili'): Text(-0.23302176844250266, 0.4423809235232462, '1'),
#  ('Malek Jaziri',
#   'Grigor Dimitrov'): Text(-0.22402543077209108, 0.5193493812288111, '2'),
#  ('Malek Jaziri',
#   'Taylor Harry Fritz'): Text(0.46464200209523837, -0.03611486527420554, '1'),
#  ('Malek Jaziri',
#   'Pablo Carreno Busta'): Text(-0.016201259762088083, 0.8353307029050512, '1'),
#  ('Malek Jaziri',
#   'Sam Querrey'): Text(0.6235671035778446, 0.07288456607963756, '1'),
#  ('Malek Jaziri',
#   'Federico Delbonis'): Text(0.42846919480539425, -0.05008085942211149, '1'),
#  ('Malek Jaziri',
#   'Jaume Munar'): Text(-0.15114164585363682, 0.697747744882038, '1'),
#  ('Malek Jaziri',
#   'Milos Raonic'): Text(-0.21508321411924514, 0.55707956103224, '1'),
#  ('Malek Jaziri',
#   'Taro Daniel'): Text(0.3913228126963994, 0.9071881852453636, '1'),
#  ('Malek Jaziri',
#   'Denis Kudla'): Text(-0.10366982444943618, 0.7589971203493058, '1'),
#  ('Malek Jaziri',
#   'Mirza Basic'): Text(0.16075035759848103, -0.06567373255013154, '1'),
#  ('Malek Jaziri',
#   'Marton Fucsovics'): Text(0.016602186358752102, 0.8560059150917415, '1'),
#  ('Malek Jaziri',
#   'Marin Cilic'): Text(0.3150077522840554, -0.07465817909388628, '1'),
#  ('Malek Jaziri',
#   'Fernando Verdasco'): Text(0.08651333862463023, 0.8894350609723776, '1'),
#  ('Malek Jaziri',
#   'Adrian Mannarino'): Text(0.39132290210336673, -0.06120174505519632, '1'),
#  ('Filip Krajinovic',
#   'Daniil Medvedev'): Text(-0.26660223561536844, 0.4229932405841803, '1'),
#  ('Filip Krajinovic',
#   'Yoshihito Nishioka'): Text(0.7270167017419368, 0.3651215877000082, '1'),
#  ('Filip Krajinovic',
#   'Casper Ruud'): Text(-0.22215973088104, 0.235475532037283, '1'),
#  ('Filip Krajinovic',
#   'Novak Djokovic'): Text(-0.04978175673727628, 0.030043459339730183, '2'),
#  ('Filip Krajinovic',
#   'Rafael Nadal'): Text(-0.11009903476766039, 0.07869405200371676, '1'),
#  ('Filip Krajinovic',
#   'Karen Khachanov'): Text(-0.13725023201765704, 0.10637695248850826, '2'),
#  ('Filip Krajinovic',
#   'David Goffin'): Text(0.12716980846922854, 0.931047835190268, '3'),
#  ('Filip Krajinovic',
#   'Gael Monfils'): Text(0.2039493380769246, 0.9415350042388184, '2'),
#  ('Filip Krajinovic',
#   'Grigor Dimitrov'): Text(-0.2576058979449568, 0.5387370734811028, '1'),
#  ('Filip Krajinovic',
#   'Borna Coric'): Text(0.49962387877773773, 0.019387638948446473, '2'),
#  ('Filip Krajinovic',
#   'Hubert Hurkacz'): Text(0.6958837055966297, 0.25328092958384285, '1'),
#  ('Filip Krajinovic',
#   'Stefanos Tsitsipas'): Text(-0.22215970107871755, 0.6492863224597901, '2'),
#  ('Filip Krajinovic',
#   'Denis Shapovalov'): Text(-0.2486636812921109, 0.30829460121254143, '1'),
#  ('Filip Krajinovic',
#   'Fernando Verdasco'): Text(0.05293287145176448, 0.9088227532246692, '2'),
#  ('Filip Krajinovic',
#   'Matteo Berrettini'): Text(0.46604351591300064, 6.3007996597974625e-09, '1'),
#  ('Filip Krajinovic',
#   'Roger Federer'): Text(0.7195441866206141, 0.3270729328283194, '4'),
#  ('Filip Krajinovic',
#   'Milos Raonic'): Text(-0.2486636812921109, 0.5764672532845316, '1'),
#  ('Filip Krajinovic',
#   'Steve Johnson'): Text(0.5617823740912821, 0.06566289710635975, '1'),
#  ('Filip Krajinovic',
#   'Dominik Koepfer'): Text(0.1653560681142404, -0.05301927900851733, '1'),
#  ('Filip Krajinovic',
#   'Juan Martin Del Potro'): Text(0.20394942562124682, -0.05677317954406785, '2'),
#  ('Filip Krajinovic',
#   'Mikael Ymer'): Text(0.3948886978302061, 0.9154549918645705, '2'),
#  ('Filip Krajinovic',
#   'Pablo Carreno Busta'): Text(-0.049781726934953835, 0.8547183951573429, '1'),
#  ('Filip Krajinovic',
#   'Marton Fucsovics'): Text(-0.01697828081411365, 0.8753936073440332, '1'),
#  ('Filip Krajinovic',
#   'Mitchell Krueger'): Text(-0.2576058979449568, 0.34602478101597023, '1'),
#  ('Filip Krajinovic',
#   'Jo Wilfried Tsonga'): Text(0.3198458240573613, -0.050022953509595014, '1'),
#  ('Filip Krajinovic',
#   'Taylor Harry Fritz'): Text(0.43106153492237265, -0.016727173021913844, '1'),
#  ('Filip Krajinovic',
#   'Roberto Carballes Baena'): Text(-0.016978206308307542, 0.009368187548394968, '1'),
#  ('Filip Krajinovic',
#   'Corentin Moutet'): Text(0.731518223338418, 0.40363466333827513, '1'),
#  ('Filip Krajinovic',
#   'Benoit Paire'): Text(-0.08088435451368639, 0.8315633317197542, '1'),
#  ('Filip Krajinovic',
#   'Marco Cecchinato'): Text(0.05293294595757059, -0.024060958332241034, '2'),
#  ('Filip Krajinovic',
#   'Taro Daniel'): Text(0.3577423455235336, 0.9265758774976552, '1'),
#  ('Filip Krajinovic',
#   'Martin Klizan'): Text(0.4310616094281787, 0.9014889679143421, '1'),
#  ('Martin Klizan',
#   'Denis Shapovalov'): Text(-0.2836455728757715, 0.3250217507329325, '2'),
#  ('Martin Klizan',
#   'Damir Dzumhur'): Text(0.6448562138046414, 0.23470852456559996, '1'),
#  ('Martin Klizan',
#   'Federico Delbonis'): Text(0.35990683604886786, -0.01396601764942873, '3'),
#  ('Martin Klizan',
#   'Alexei Popyrin'): Text(-0.2718064512716898, 0.6301181690158116, '1'),
#  ('Martin Klizan',
#   'Dusan Lajovic'): Text(0.5810620180235384, 0.13771418394955148, '1'),
#  ('Martin Klizan',
#   'Jaume Munar'): Text(-0.21970400461016323, 0.7338625866547206, '1'),
#  ('Martin Klizan',
#   'Mirza Basic'): Text(0.09218799884195461, -0.029558890777448776, '3'),
#  ('Martin Klizan',
#   'Steve Johnson'): Text(0.5268004825076213, 0.08239004662675081, '1'),
#  ('Martin Klizan',
#   'Novak Djokovic'): Text(-0.08476364832093694, 0.04677060886012124, '1'),
#  ('Martin Klizan',
#   'Rafael Nadal'): Text(-0.14508092635132105, 0.09542120152410782, '1'),
#  ('Martin Klizan',
#   'Daniil Medvedev'): Text(-0.30158412719902905, 0.43972039010457137, '2'),
#  ('Martin Klizan',
#   'Karen Khachanov'): Text(-0.1722321236013177, 0.12310410200889932, '1'),
#  ('Martin Klizan',
#   'Gael Monfils'): Text(0.16896744649326395, 0.9582621537592095, '1'),
#  ('Martin Klizan',
#   'Marin Cilic'): Text(0.246445393527529, -0.03854333732120352, '2'),
#  ('Martin Klizan',
#   'Marton Fucsovics'): Text(-0.05196017239777431, 0.8921207568644243, '1'),
#  ('Martin Klizan',
#   'Jeremy Chardy'): Text(-0.14508098595596594, 0.82279486260678, '1'),
#  ('Martin Klizan',
#   'Marco Cecchinato'): Text(0.017951054373909925, -0.007333808811849973, '1'),
#  ('Martin Klizan',
#   'Christian Garin'): Text(-0.2718064512716898, 0.2880979845220436, '1'),
#  ('Martin Klizan',
#   'Adrian Mannarino'): Text(0.32276054334684035, -0.025086903282513562, '1'),
#  ('Martin Klizan',
#   'Roberto Carballes Baena'): Text(-0.051960097891968204, 0.02609533706878603, '1'),
#  ('Martin Klizan',
#   'Lorenzo Sonego'): Text(0.6741638177000082, 0.3064451286860632, '1'),
#  ('Martin Klizan',
#   'Jo Wilfried Tsonga'): Text(0.2848639324737006, -0.033295803989203954, '1'),
#  ('Martin Klizan',
#   'Hyeon Chung'): Text(-0.19715652112032198, 0.7654082853612878, '1'),
#  ('Mikael Ymer',
#   'Novak Djokovic'): Text(-0.12093655991890961, 0.06073663281034963, '1'),
#  ('Mikael Ymer',
#   'Karen Khachanov'): Text(-0.20840503519929038, 0.1370701259591277, '1'),
#  ('Mikael Ymer',
#   'Hubert Hurkacz'): Text(0.6247289024149963, 0.28397410305446225, '1'),
#  ('Mikael Ymer',
#   'Stefanos Tsitsipas'): Text(-0.2933145042603509, 0.6799794959304095, '1'),
#  ('Mikael Ymer',
#   'Milos Raonic'): Text(-0.3198184844737442, 0.6071604267551511, '1'),
#  ('Mikael Ymer',
#   'Daniel Elahi Galan Riveros'): Text(-0.27591215332257785, 0.7146304327232851, '1'),
#  ('Taro Daniel',
#   'Christian Garin'): Text(-0.3451257151763349, 0.31318489410535677, '1'),
#  ('Taro Daniel',
#   'Tatsuma Ito'): Text(0.1731260439412069, 0.9818463706400495, '1'),
#  ('Taro Daniel',
#   'Dominik Koepfer'): Text(0.05705491262593464, -0.011205219904813046, '1'),
#  ('Taro Daniel',
#   'Borna Coric'): Text(0.391322723289432, 0.061201698052150755, '1'),
#  ('Taro Daniel',
#   'Jeremy Chardy'): Text(-0.21840024986061102, 0.8478817721900933, '1'),
#  ('Taro Daniel',
#   'Ugo Humbert'): Text(-0.09097249281639992, 0.03311128061020524, '1'),
#  ('Taro Daniel',
#   'Sam Querrey'): Text(0.4816854809166731, 0.13408631743563354, '1'),
#  ('Taro Daniel',
#   'Roberto Carballes Baena'): Text(-0.1252793617966133, 0.05118224665209925, '2'),
#  ('Taro Daniel',
#   'John Millman'): Text(0.4232999000204013, 0.08313337615324895, '2'),
#  ('Taro Daniel',
#   'Matteo Berrettini'): Text(0.35774236042469487, 0.04181406540450394, '1'),
#  ('Taro Daniel',
#   'Novak Djokovic'): Text(-0.15808291222558202, 0.07185751844343446, '1'),
#  ('Taro Daniel',
#   'Roberto Bautista Agut'): Text(0.05705494242825708, 0.9795951628069722, '1'),
#  ('Taro Daniel',
#   'Dusan Lajovic'): Text(0.5077427541188934, 0.1628010935328647, '1'),
#  ('Taro Daniel',
#   'Daniil Medvedev'): Text(-0.37490339110367416, 0.4648072996878846, '1'),
#  ('Taro Daniel',
#   'Gael Monfils'): Text(0.09564818258861886, 0.9833490633425228, '1'),
#  ('Taro Daniel',
#   'Stefanos Tsitsipas'): Text(-0.3304608565670233, 0.6911003815634944, '1'),
#  ('Taro Daniel',
#   'Denis Shapovalov'): Text(-0.35696483678041663, 0.3501086603162457, '1'),
#  ('Taro Daniel',
#   'Fernando Verdasco'): Text(-0.055368284036541274, 0.9506368123283735, '1'),
#  ('Taro Daniel',
#   'Jaume Munar'): Text(-0.2930232685148083, 0.7589494962380339, '1'),
#  ('Taro Daniel',
#   'Philipp Kohlschreiber'): Text(0.1344162375845252, -0.01571100323340424, '1'),
#  ('Taro Daniel',
#   'Milos Raonic'): Text(-0.35696483678041663, 0.6182813123882359, '1'),
#  ('Taro Daniel',
#   'Jo Wilfried Tsonga'): Text(0.21154466856905552, -0.008208894405890732, '1'),
#  ('Kei Nishikori',
#   'Daniil Medvedev'): Text(-0.41279987531694345, 0.473016200394575, '4'),
#  ('Kei Nishikori',
#   'Denis Shapovalov'): Text(-0.3948613209936859, 0.3583175610229361, '2'),
#  ('Kei Nishikori',
#   'Gael Monfils'): Text(0.05775169837534956, 0.9915579640492131, '1'),
#  ('Kei Nishikori',
# ...
#  ('Jaume Munar',
#   'Borna Coric'): Text(-0.1511417352606042, -0.1482387423111749, '2'),
#  ('Jaume Munar',
#   'Hubert Hurkacz'): Text(0.04511809155828772, 0.08565454832422145, '1'),
#  ('Jaume Munar',
#   'Diego Sebastian Schwartzman'): Text(0.010339556121851057, 0.016404784099270653, '2'),
#  ('Jaume Munar',
#   'Stefanos Tsitsipas'): Text(-0.8729253151170595, 0.48165994120016875, '2'),
#  ('Jaume Munar',
#   'Albert Ramos'): Text(-0.8555229641792865, 0.03319821398478606, '2'),
#  ('Jaume Munar',
#   'Alexei Popyrin'): Text(-0.8875901737263712, 0.4457646382357992, '2'),
#  ('Jaume Munar',
#   'Christian Garin'): Text(-0.8875901737263712, 0.10374445374203115, '1'),
#  ('Jaume Munar',
#   'Roberto Carballes Baena'): Text(-0.6677438203466495, -0.1582581937112264, '2'),
#  ('Jaume Munar',
#   'Steve Johnson'): Text(-0.08898323994705992, -0.10196348415326162, '1'),
#  ('Jaume Munar',
#   'Dominik Koepfer'): Text(-0.48540954592410157, -0.2206456602681387, '1'),
#  ('Jaume Munar',
#   'Marco Cecchinato'): Text(-0.5978326680807714, -0.1916873395918624, '1'),
#  ('Daniel Elahi Galan Riveros',
#   'Novak Djokovic'): Text(-0.7205826078900601, -0.17078109980155512, '1'),
#  ('Daniel Elahi Galan Riveros',
#   'Casper Ruud'): Text(-0.8929605820338239, 0.034650972895997695, '1'),
#  ('Daniel Elahi Galan Riveros',
#   'Peter Polansky'): Text(-0.8555229939816089, -0.03319817158086427, '1'),
#  ('Daniel Elahi Galan Riveros',
#   'Steve Johnson'): Text(-0.10901847706150186, -0.13516166203492555, '1'),
#  ('Stefanos Tsitsipas',
#   'Rafael Nadal'): Text(-0.7983022368582173, -0.1567814439304441, '7'),
#  ('Stefanos Tsitsipas',
#   'Daniil Medvedev'): Text(-0.9548054377059254, 0.18751774465001944, '6'),
#  ('Stefanos Tsitsipas',
#   'Denis Shapovalov'): Text(-0.9368668833826679, 0.07281910527838056, '4'),
#  ('Stefanos Tsitsipas',
#   'Kevin Anderson'): Text(-0.9518006185451053, 0.26495189903409233, '4'),
#  ('Stefanos Tsitsipas',
#   'Christian Garin'): Text(-0.925027761778586, 0.03589533906749165, '1'),
#  ('Stefanos Tsitsipas',
#   'Diego Sebastian Schwartzman'): Text(-0.02709803193036392, -0.05144433057526884, '1'),
#  ('Stefanos Tsitsipas',
#   'Roger Federer'): Text(0.03134098453005718, 0.09159743689415852, '5'),
#  ('Stefanos Tsitsipas',
#   'Novak Djokovic'): Text(-0.7379849588278332, -0.20543203659443068, '6'),
#  ('Stefanos Tsitsipas',
#   'Grigor Dimitrov'): Text(-0.9458091000355138, 0.30326157754694194, '2'),
#  ('Stefanos Tsitsipas',
#   'Borna Coric'): Text(-0.18857932331281918, -0.2160878569857144, '2'),
#  ('Stefanos Tsitsipas',
#   'Hubert Hurkacz'): Text(0.0076805035060727445, 0.017805433649681957, '6'),
#  ('Stefanos Tsitsipas',
#   'Ugo Humbert'): Text(-0.670874539418651, -0.2441782744276599, '1'),
#  ('Stefanos Tsitsipas',
#   'John Isner'): Text(-0.5985831054611733, -0.27208934149311337, '3'),
#  ('Stefanos Tsitsipas',
#   'Milos Raonic'): Text(-0.9368668833826679, 0.3409917573503708, '2'),
#  ('Stefanos Tsitsipas',
#   'Adrian Mannarino'): Text(-0.33046076716005596, -0.27728954873706546, '2'),
#  ('Stefanos Tsitsipas',
#   'Damir Dzumhur'): Text(-0.008365096702254882, -0.01749412088895197, '3'),
#  ('Stefanos Tsitsipas',
#   'Juan Martin Del Potro'): Text(-0.4842537764693101, -0.29224867547822875, '1'),
#  ('Stefanos Tsitsipas',
#   'Karen Khachanov'): Text(-0.825453434108214, -0.1290985434456526, '1'),
#  ('Stefanos Tsitsipas',
#   'Philipp Kohlschreiber'): Text(-0.445485809017726, -0.29300055827126936, '3'),
#  ('Stefanos Tsitsipas',
#   'Nikoloz Basilashvili'): Text(-0.9548054377059254, 0.22629311984137704, '2'),
#  ('Stefanos Tsitsipas',
#   'Taylor Harry Fritz'): Text(-0.2571416671681843, -0.2522026689560747, '1'),
#  ('Stefanos Tsitsipas',
#   'Roberto Carballes Baena'): Text(-0.7051814083988645, -0.2261073083857659, '1'),
#  ('Stefanos Tsitsipas',
#   'John Millman'): Text(-0.1566021465818499, -0.1941561788846162, '1'),
#  ('Stefanos Tsitsipas',
#   'Corentin Moutet'): Text(0.04331502124786102, 0.1681591674041143, '1'),
#  ('Stefanos Tsitsipas',
#   'Matteo Berrettini'): Text(-0.22215968617755633, -0.2354754896333612, '1'),
#  ('Stefanos Tsitsipas',
#   'Albert Ramos'): Text(-0.8929605522315014, -0.03465090068975343, '3'),
#  ('Stefanos Tsitsipas',
#   'Dusan Lajovic'): Text(-0.07215929248335784, -0.11448846150500044, '2'),
#  ('Alexei Popyrin',
#   'Jo Wilfried Tsonga'): Text(-0.38302223664250723, -0.3213937524081254, '1'),
#  ('Alexei Popyrin',
#   'Federico Delbonis'): Text(-0.30797933306734004, -0.3020639660683502, '1'),
#  ('Alexei Popyrin',
#   'Ugo Humbert'): Text(-0.6855393980279627, -0.2800735773920294, '1'),
#  ('Alexei Popyrin',
#   'Novak Djokovic'): Text(-0.7526498174371448, -0.2413273395588002, '1'),
#  ('Alexei Popyrin',
#   'Daniil Medvedev'): Text(-0.969470296315237, 0.15162244168564992, '2'),
#  ('Alexei Popyrin',
#   'Denis Shapovalov'): Text(-0.9515317419919794, 0.036923802314011045, '1'),
#  ('Alexei Popyrin',
#   'John Millman'): Text(-0.1712670051911615, -0.23005148184898572, '2'),
#  ('Alexei Popyrin',
#   'John Isner'): Text(-0.613247964070485, -0.30798464445748286, '1'),
#  ('Alexei Popyrin',
#   'Matteo Berrettini'): Text(-0.23682454478686793, -0.2713707925977307, '1'),
#  ('Alexei Popyrin',
#   'Milos Raonic'): Text(-0.9515317419919794, 0.3050964543860013, '1'),
#  ('Alexei Popyrin',
#   'Adrian Mannarino'): Text(-0.34512562576936756, -0.313184851701435, '2'),
#  ('Milos Raonic',
#   'Denis Shapovalov'): Text(-0.9633708635960612, 3.61031221307595e-08, '2'),
#  ('Milos Raonic',
#   'Christian Garin'): Text(-0.9515317419919794, -0.03692373010776678, '1'),
#  ('Milos Raonic',
#   'Diego Sebastian Schwartzman'): Text(-0.05360201214375726, -0.12426339975052728, '1'),
#  ('Milos Raonic',
#   'Novak Djokovic'): Text(-0.7644889390412266, -0.27825110576968914, '3'),
#  ('Milos Raonic',
#   'Dusan Lajovic'): Text(-0.09866327269675118, -0.18730753068025888, '2'),
#  ('Milos Raonic',
#   'Daniil Medvedev'): Text(-0.9813094179193187, 0.11469867547476101, '3'),
#  ('Milos Raonic',
#   'Borna Coric'): Text(-0.21508330352621252, -0.2889069261609728, '1'),
#  ('Milos Raonic',
#   'Marin Cilic'): Text(-0.4332798971927606, -0.36356505195101385, '2'),
#  ('Milos Raonic',
#   'Corentin Moutet'): Text(0.016811041034467678, 0.09534009822885586, '1'),
#  ('Milos Raonic',
#   'John Isner'): Text(-0.6250870856745667, -0.34490841066837175, '2'),
#  ('Milos Raonic',
#   'Roger Federer'): Text(0.00483700431666384, 0.018778367718900082, '2'),
#  ('Milos Raonic',
#   'Steve Johnson'): Text(-0.15292480821266824, -0.24263166800305955, '2'),
#  ('Milos Raonic',
#   'Juan Martin Del Potro'): Text(-0.5107577566827035, -0.3650677446534871, '2'),
#  ('Milos Raonic',
#   'Karen Khachanov'): Text(-0.8519574143216073, -0.20191761262091104, '1'),
#  ('Milos Raonic',
#   'Philipp Kohlschreiber'): Text(-0.47198978923111934, -0.36581962744652785, '1'),
#  ('Milos Raonic',
#   'Jo Wilfried Tsonga'): Text(-0.39486135824658897, -0.3583175186190143, '2'),
#  ('Milos Raonic',
#   'Ugo Humbert'): Text(-0.6973785196320444, -0.3169973436029183, '1'),
#  ('Milos Raonic',
#   'Sam Querrey'): Text(-0.12472054589897141, -0.21602230677749004, '3'),
#  ('Milos Raonic',
#   'John Millman'): Text(-0.18310612679524324, -0.2669752480598746, '1'),
#  ('Milos Raonic',
#   'Grigor Dimitrov'): Text(-0.9723130802489071, 0.2304425083716835, '1'),
#  ('Milos Raonic',
#   'Adrian Mannarino'): Text(-0.3569647473734493, -0.35010861791232395, '2'),
#  ('Milos Raonic',
#   'Mirza Basic'): Text(-0.587537291878335, -0.3545806054072591, '1'),
#  ('Milos Raonic',
#   'Marco Cecchinato'): Text(-0.6617742363463797, -0.3323555234416603, '2'),
#  ('Grigor Dimitrov',
#   'Denis Shapovalov'): Text(-0.9723130802489071, -0.03773014370030671, '2'),
#  ('Grigor Dimitrov',
#   'Christian Garin'): Text(-0.9604739586448254, -0.07465390991119562, '1'),
#  ('Grigor Dimitrov',
#   'Yoshihito Nishioka'): Text(0.00336730278514058, 0.019096842787160048, '2'),
#  ('Grigor Dimitrov',
#   'Roger Federer'): Text(-0.004105212336182107, -0.018951812084528757, '2'),
#  ('Grigor Dimitrov',
#   'Karen Khachanov'): Text(-0.8608996309744532, -0.23964779242433987, '1'),
#  ('Grigor Dimitrov',
#   'Philipp Kohlschreiber'): Text(-0.4809320058839653, -0.40354980724995665, '1'),
#  ('Grigor Dimitrov',
#   'Damir Dzumhur'): Text(-0.04381129356849417, -0.12804336986763926, '3'),
#  ('Grigor Dimitrov',
#   'Borna Coric'): Text(-0.22402552017905847, -0.32663710596440165, '1'),
#  ('Grigor Dimitrov',
#   'Marin Cilic'): Text(-0.44222211384560656, -0.4012952317544427, '2'),
#  ('Grigor Dimitrov',
#   'Ugo Humbert'): Text(-0.7063207362848904, -0.35472752340634717, '2'),
#  ('Grigor Dimitrov',
#   'Roberto Carballes Baena'): Text(-0.7406276052651037, -0.33665655736445316, '1'),
#  ('Grigor Dimitrov',
#   'John Millman'): Text(-0.1920483434480892, -0.30470542786330346, '2'),
#  ('Grigor Dimitrov',
#   'Novak Djokovic'): Text(-0.7734311556940725, -0.31598128557311794, '3'),
#  ('Grigor Dimitrov',
#   'Dusan Lajovic'): Text(-0.10760548934959713, -0.2250377104836877, '1'),
#  ('Grigor Dimitrov',
#   'Rafael Nadal'): Text(-0.8337484337244566, -0.26733069290913136, '3'),
#  ('Grigor Dimitrov',
#   'Daniil Medvedev'): Text(-0.9902516345721646, 0.07696849567133215, '1'),
#  ('Grigor Dimitrov',
#   'Kevin Anderson'): Text(-0.9872468154113446, 0.15440265005540504, '1'),
#  ('Grigor Dimitrov',
#   'Taylor Harry Fritz'): Text(-0.2925878640344236, -0.36275191793476197, '1'),
#  ('Grigor Dimitrov',
#   'Corentin Moutet'): Text(0.00786882438162173, 0.05760991842542702, '1'),
#  ('Grigor Dimitrov',
#   'Sam Querrey'): Text(-0.13366276255181736, -0.25375248658091887, '1'),
#  ('Grigor Dimitrov',
#   'Federico Delbonis'): Text(-0.32876067132426773, -0.3767179120826679, '1'),
#  ('Grigor Dimitrov',
#   'Matteo Berrettini'): Text(-0.2576058830437956, -0.34602473861204847, '2'),
#  ('Grigor Dimitrov',
#   'Adrian Mannarino'): Text(-0.36590696402629524, -0.38783879771575275, '1'),
#  ('Grigor Dimitrov',
#   'Steve Johnson'): Text(-0.1618670248655142, -0.2803618478064884, '1'),
#  ('Kevin Anderson',
#   'Daniil Medvedev'): Text(-0.9962431530817561, 0.03865881715848252, '2'),
#  ('Kevin Anderson',
#   'Denis Shapovalov'): Text(-0.9783045987584986, -0.07603982221315636, '1'),
#  ('Kevin Anderson',
#   'Novak Djokovic'): Text(-0.7794226742036641, -0.3542909640859676, '4'),
#  ('Kevin Anderson',
#   'Taylor Harry Fritz'): Text(-0.29857938254401517, -0.40106159644761163, '1'),
#  ('Kevin Anderson',
#   'Borna Coric'): Text(-0.23001703868865003, -0.3649467844772513, '2'),
#  ('Kevin Anderson',
#   'Diego Sebastian Schwartzman'): Text(-0.06853574730619477, -0.20030325806680577, '1'),
#  ('Kevin Anderson',
#   'Ugo Humbert'): Text(-0.712312254794482, -0.39303720191919683, '1'),
#  ('Kevin Anderson',
#   'Roger Federer'): Text(-0.010096730845773672, -0.0572614905973784, '3'),
#  ('Kevin Anderson',
#   'Juan Martin Del Potro'): Text(-0.525691491845141, -0.44110760296976564, '1'),
#  ('Kevin Anderson',
#   'Christian Garin'): Text(-0.966465477154417, -0.11296358842404527, '1'),
#  ('Kevin Anderson',
#   'Karen Khachanov'): Text(-0.8668911494840448, -0.27795747093718953, '1'),
#  ('Kevin Anderson',
#   'Philipp Kohlschreiber'): Text(-0.48692352439355685, -0.4418594857628063, '2'),
#  ('Kevin Anderson',
#   'Nikoloz Basilashvili'): Text(-0.9962431530817561, 0.07743419234984013, '3'),
#  ('Kevin Anderson',
#   'Sam Querrey'): Text(-0.13965428106140892, -0.29206216509376853, '1'),
#  ('Kevin Anderson',
#   'John Isner'): Text(-0.6400208208370042, -0.42094826898465026, '1'),
#  ('Kevin Anderson',
#   'Dusan Lajovic'): Text(-0.11359700785918869, -0.26334738899653737, '2'),
#  ('Kevin Anderson',
#   'Adrian Mannarino'): Text(-0.3718984825358868, -0.4261484762286024, '2'),
#  ('Nikoloz Basilashvili',
#   'Denis Shapovalov'): Text(-0.9813094179193187, -0.11469860140587163, '2'),
#  ('Nikoloz Basilashvili',
#   'Karen Khachanov'): Text(-0.8698959686448648, -0.3166162501299048, '1'),
#  ('Nikoloz Basilashvili',
#   'Philipp Kohlschreiber'): Text(-0.48992834355437687, -0.4805182649555216, '1'),
#  ('Nikoloz Basilashvili',
#   'Novak Djokovic'): Text(-0.7824274933644841, -0.3929497432786829, '2'),
#  ('Nikoloz Basilashvili',
#   'Dusan Lajovic'): Text(-0.11660182702000871, -0.30200616818925263, '3'),
#  ('Nikoloz Basilashvili',
#   'Rafael Nadal'): Text(-0.8427447713948681, -0.3442991506146963, '3'),
#  ('Nikoloz Basilashvili',
#   'Yoshihito Nishioka'): Text(-0.005629034885271, -0.05787161491840486, '1'),
#  ('Nikoloz Basilashvili',
#   'Borna Coric'): Text(-0.23302185784947005, -0.4036055636699666, '3'),
#  ('Nikoloz Basilashvili',
#   'John Millman'): Text(-0.20104468111850077, -0.3816738855688684, '2'),
#  ('Nikoloz Basilashvili',
#   'Sam Querrey'): Text(-0.14265910022222894, -0.3307209442864838, '1'),
#  ('Nikoloz Basilashvili',
#   'Federico Delbonis'): Text(-0.3377570089946793, -0.45368636978823285, '1'),
#  ('Nikoloz Basilashvili',
#   'Matteo Berrettini'): Text(-0.2666022207142072, -0.4229931963176134, '3'),
#  ('Nikoloz Basilashvili',
#   'Steve Johnson'): Text(-0.17086336253592577, -0.3573303055120533, '1'),
#  ('Nikoloz Basilashvili',
#   'Dominik Koepfer'): Text(-0.5672896685129674, -0.4760124816269304, '1'),
#  ('Nikoloz Basilashvili',
#   'Lorenzo Sonego'): Text(-0.0235000273435389, -0.1332752234527409, '1'),
#  ('Nikoloz Basilashvili',
#   'Jo Wilfried Tsonga'): Text(-0.4127999125698465, -0.47301615612800807, '2'),
#  ('Nikoloz Basilashvili',
#   'Juan Martin Del Potro'): Text(-0.528696311005961, -0.4797663821624809, '1'),
#  ('Nikoloz Basilashvili',
#   'Ugo Humbert'): Text(-0.715317073955302, -0.4316959811119121, '1'),
#  ('Nikoloz Basilashvili',
#   'Roberto Carballes Baena'): Text(-0.7496239429355154, -0.4136250150700181, '1'),
#  ('Nikoloz Basilashvili',
#   'Albert Ramos'): Text(-0.9374030867681523, -0.22216860737400562, '1'),
#  ('Daniil Medvedev',
#   'Rafael Nadal'): Text(-0.8427447713948681, -0.3830745258060539, '4'),
#  ('Daniil Medvedev',
#   'Novak Djokovic'): Text(-0.7824274933644841, -0.43172511847004047, '5'),
#  ('Daniil Medvedev',
#   'Dusan Lajovic'): Text(-0.11660182702000871, -0.34078154338061023, '2'),
#  ('Daniil Medvedev',
#   'Karen Khachanov'): Text(-0.8698959686448648, -0.3553916253212624, '2'),
#  ('Daniil Medvedev',
#   'Borna Coric'): Text(-0.23302185784947005, -0.4423809388613242, '5'),
#  ('Daniil Medvedev',
#   'Denis Shapovalov'): Text(-0.9813094179193187, -0.15347397659722922, '2'),
#  ('Daniil Medvedev',
#   'Ugo Humbert'): Text(-0.715317073955302, -0.4704713563032697, '1'),
#  ('Daniil Medvedev',
#   'Roger Federer'): Text(-0.013101550006593687, -0.13469564498145128, '3'),
#  ('Daniil Medvedev',
#   'Adrian Mannarino'): Text(-0.3749033016967068, -0.5035826306126753, '2'),
#  ('Daniil Medvedev',
#   'Steve Johnson'): Text(-0.17086336253592577, -0.3961056807034109, '3'),
#  ('Daniil Medvedev',
#   'Christian Garin'): Text(-0.969470296315237, -0.19039774280811814, '1'),
#  ('Daniil Medvedev',
#   'Diego Sebastian Schwartzman'): Text(-0.07154056646701479, -0.27773741245087863, '5'),
#  ('Daniil Medvedev',
#   'Philipp Kohlschreiber'): Text(-0.48992834355437687, -0.5192936401468792, '1'),
#  ('Daniil Medvedev',
#   'Casper Ruud'): Text(-0.9548054675082478, -0.22629304577248766, '1'),
#  ('Daniil Medvedev',
#   'Dominik Koepfer'): Text(-0.5672896685129674, -0.514787856818288, '1'),
#  ('Daniil Medvedev',
#   'Jo Wilfried Tsonga'): Text(-0.4127999125698465, -0.5117915313193657, '2'),
#  ('Daniil Medvedev',
#   'Federico Delbonis'): Text(-0.3377570089946793, -0.49246174497959044, '1'),
#  ('Daniil Medvedev',
#   'Marin Cilic'): Text(-0.45121845151601814, -0.5170390646513653, '1'),
#  ('Daniil Medvedev',
#   'Henri Laaksonen'): Text(-0.09284791571514978, -0.3101336694401117, '1'),
#  ('Daniil Medvedev',
#   'John Isner'): Text(-0.6430256399978242, -0.4983824233687231, '1'),
#  ('Daniil Medvedev',
#   'Matteo Berrettini'): Text(-0.2666022207142072, -0.461768571508971, '1'),
#  ('Daniil Medvedev',
#   'Albert Ramos'): Text(-0.9374030867681523, -0.2609439825653632, '1'),
#  ('Daniil Medvedev',
#   'Mirza Basic'): Text(-0.6054758462015926, -0.5080546181076105, '1'),
#  ('Horacio Zeballos',
#   'Yoshihito Nishioka'): Text(-0.0026242157244509845, -0.13530576743983258, '1'),
#  ('Horacio Zeballos',
#   'Novak Djokovic'): Text(-0.7794226742036641, -0.4703838958001106, '1'),
#  ('Horacio Zeballos',
#   'Dusan Lajovic'): Text(-0.11359700785918869, -0.37944032071068035, '2'),
#  ('Horacio Zeballos',
#   'John Isner'): Text(-0.6400208208370042, -0.5370412006987932, '1'),
#  ...}

# %%
from collections import Counter
from operator import itemgetter
def plot_deg_frequency(G, weighted=False, xscale = "log", yscale = "log"):

    if weighted:
        degrees = G.degree(weight="weight")
    else:
        degrees = G.degree()
    _, deg_list = zip(*degrees)
    deg_counts = Counter(deg_list)  #broji koliko ima odigranih meceva?????????????????      
    print(deg_counts)
    x, y = zip(*deg_counts.items())                                                      

    plt.figure(1)   

    # prep axes   
    if weighted:
        plt.xlabel('weighted degree')  
    else:
        plt.xlabel('degree')                                                                                                             
    plt.xscale(xscale)                                                                                                                
    plt.xlim(1, max(x))  

    plt.ylabel('frequency')                                                                                                          
    plt.yscale(yscale)                                                                                                                
    plt.ylim(1, max(y))                                                                                                             
                                                                                                                                                                                                    
    plt.scatter(x, y, marker='.')                                                                                                    
    plt.show()

# %%
 plot_deg_frequency(G)
# Out:
# Counter({1: 159, 2: 70, 3: 43, 5: 25, 6: 25, 4: 22, 7: 14, 8: 10, 9: 10, 13: 7, 10: 7, 80: 6, 23: 6, 22: 6, 20: 6, 48: 5, 52: 5, 29: 5, 35: 5, 71: 5, 14: 4, 16: 4, 41: 4, 18: 4, 19: 4, 17: 4, 74: 4, 66: 4, 84: 3, 75: 3, 30: 3, 64: 3, 27: 3, 15: 3, 67: 3, 65: 3, 11: 3, 86: 3, 83: 3, 90: 3, 12: 3, 93: 2, 56: 2, 63: 2, 36: 2, 49: 2, 57: 2, 54: 2, 21: 2, 38: 2, 60: 2, 55: 2, 42: 2, 78: 2, 81: 2, 89: 2, 32: 2, 79: 2, 92: 2, 61: 2, 46: 2, 28: 2, 25: 2, 82: 2, 94: 1, 70: 1, 68: 1, 85: 1, 53: 1, 73: 1, 26: 1, 40: 1, 91: 1, 37: 1, 95: 1, 44: 1, 45: 1, 50: 1, 96: 1, 47: 1, 99: 1, 97: 1, 103: 1, 77: 1, 62: 1, 88: 1, 34: 1})

# %%
plot_deg_frequency(G, weighted = True)
# Out:
# Counter({1: 159, 2: 70, 3: 41, 6: 26, 4: 24, 5: 23, 7: 12, 10: 11, 8: 10, 9: 9, 23: 7, 21: 6, 24: 5, 14: 5, 13: 5, 126: 4, 38: 4, 16: 4, 50: 4, 17: 4, 31: 4, 18: 4, 61: 3, 131: 3, 74: 3, 20: 3, 89: 3, 29: 3, 55: 3, 36: 3, 11: 3, 114: 3, 19: 3, 73: 3, 62: 2, 88: 2, 104: 2, 15: 2, 41: 2, 25: 2, 102: 2, 101: 2, 84: 2, 83: 2, 40: 2, 32: 2, 66: 2, 71: 2, 151: 2, 118: 2, 183: 2, 60: 2, 12: 2, 49: 2, 39: 2, 87: 2, 142: 1, 68: 1, 72: 1, 109: 1, 43: 1, 22: 1, 180: 1, 134: 1, 47: 1, 138: 1, 100: 1, 96: 1, 91: 1, 65: 1, 98: 1, 127: 1, 124: 1, 119: 1, 128: 1, 107: 1, 44: 1, 33: 1, 135: 1, 80: 1, 45: 1, 116: 1, 176: 1, 94: 1, 108: 1, 115: 1, 63: 1, 139: 1, 59: 1, 196: 1, 161: 1, 158: 1, 122: 1, 26: 1, 111: 1, 46: 1, 165: 1, 95: 1, 58: 1, 28: 1, 85: 1, 110: 1, 120: 1, 146: 1, 112: 1, 30: 1, 136: 1, 141: 1, 52: 1, 106: 1, 140: 1, 121: 1, 56: 1, 42: 1, 93: 1, 129: 1})

# %%
#slucajno generisana mreza Gnm ima normalnu distribuciju!
n = G.number_of_nodes()
m = G.number_of_edges()
Gnm = nx.gnm_random_graph(n, m) 

plot_deg_frequency(Gnm, xscale = 'linear', yscale = 'linear')
plot_deg_frequency(Gnm, xscale = 'log', yscale = 'log')
# Out:
# Counter({18: 53, 16: 52, 19: 52, 17: 50, 22: 50, 14: 43, 21: 41, 15: 40, 20: 38, 13: 29, 24: 20, 23: 20, 12: 18, 26: 15, 25: 14, 11: 13, 10: 9, 28: 7, 27: 6, 29: 3, 9: 3, 30: 2, 8: 1, 34: 1, 33: 1})
# Counter({18: 53, 16: 52, 19: 52, 17: 50, 22: 50, 14: 43, 21: 41, 15: 40, 20: 38, 13: 29, 24: 20, 23: 20, 12: 18, 26: 15, 25: 14, 11: 13, 10: 9, 28: 7, 27: 6, 29: 3, 9: 3, 30: 2, 8: 1, 34: 1, 33: 1})

# %%
#Kako bi se ponašala Erdos-Renyi mreža sa koja ima isti broj čvorova n, a verovatnoća formiranja grane je takva da je očekivani broj grana u mreži m?
p = ( 2*float(m) ) / ( n* (n-1) )
print(p)

er_mreza = nx.erdos_renyi_graph(n,p)

delta_m = m - er_mreza.number_of_edges()
print(f"Broj čvorova originalne mreže minus broj čvorova u ER mreži iznosi {delta_m}, što je odstupanje od {abs(float(delta_m)) * 100 / m}%")

plot_deg_frequency(er_mreza, xscale = 'linear', yscale = 'linear')
plot_deg_frequency(er_mreza, xscale = 'log', yscale = 'log')
#Šta nam informacije o raspodeli stepena čvora govore o ovoj mreži?

# Da je mreža bila sa slučajnim vezivanjem, očekivali bismo da raspodela bude slična normalnoj raspodeli! Sto i lici!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Out:
# 0.03163392486200962
# Broj čvorova originalne mreže minus broj čvorova u ER mreži iznosi 114, što je odstupanje od 2.1388367729831144%
# Counter({16: 67, 17: 60, 18: 58, 19: 55, 15: 44, 20: 42, 22: 36, 21: 35, 14: 34, 13: 31, 23: 21, 24: 20, 12: 19, 26: 12, 25: 12, 11: 9, 10: 8, 9: 5, 27: 4, 8: 3, 29: 2, 33: 1, 30: 1, 31: 1, 34: 1})
# Counter({16: 67, 17: 60, 18: 58, 19: 55, 15: 44, 20: 42, 22: 36, 21: 35, 14: 34, 13: 31, 23: 21, 24: 20, 12: 19, 26: 12, 25: 12, 11: 9, 10: 8, 9: 5, 27: 4, 8: 3, 29: 2, 33: 1, 30: 1, 31: 1, 34: 1})

# %%
#Asortativnost (eng. assortativity) meri stepen tendencije čvorova mreže da se vezuju sa sličnim čvorovima. 
#U ovoj analizi ćemo prvo sprovesti analizu asortativnosti na osnovu stepena čvora, jer nas interesuje da li se međusobno vezuju čvorovi koji su sličnog stepena, 
#ili habovi (čvorovi velikog stepena) teže da se slabo međusobno vezuju, a mnogo vezuju sa čvorovima malog stepena.
#Uvodi se koeficijent asortativnosti r, koji je u opsegu od -1 do 1. 
#Mreža sa r = 1 iskazuje savršeno asortativno mešanje (perfect assortative mixing pattern), kad je r = 0 mreža je neasortativna ili neutralna, dok je u slučaju r = −1 mreža potpuno disasortativna.
# asortativnost na osnovu netežinskog stepena čvora
r1 = nx.degree_assortativity_coefficient(G)
print(f"Koeficijent asortativnosti na osnovu netežinskog stepena čvora: {r1}")

# asortativnost na osnovu težinskog stepena čvora
r2 = nx.degree_assortativity_coefficient(G, weight='weight')
print(f"Koeficijent asortativnosti na osnovu težinskog stepena čvora: {r2}")
# Out:
# Koeficijent asortativnosti na osnovu netežinskog stepena čvora: 0.16919387110544537
# Koeficijent asortativnosti na osnovu težinskog stepena čvora: 0.14652712553286887

# %%
#Kao što vidimo, mreža je neutralna tj. neasortativna, odnosno, čvorovi sličnog stepena uglavnom se ne vezuju međusobno.

# %%
#ANALIZA KOMUNA
#Stepen klasterisanja može se proceniti na osnovu koeficijenta klasterisanja.
id_igraca, clustering_coef = zip(*nx.clustering(G, weight = "weight").items())

nenula = [(id_ig, cc)  for id_ig, cc in zip(id_igraca, clustering_coef) if cc > 0]

df = pd.DataFrame(nenula, columns = ["id", "cc"])
df.sort_values('cc', inplace = True)

max_lokalni_stepen_klasterisanja = max(clustering_coef)

prosecni_stepen_klasterisanja = nx.average_clustering(G)

print(f"Max lokalni cc: {max_lokalni_stepen_klasterisanja}")
print(f"Prosečan cc: {prosecni_stepen_klasterisanja}")
print("Lokalni stepeni klasterisanja koji nisu nula:")
print(df)
# Out:
# Max lokalni cc: 0.16508715292071477
# Prosečan cc: 0.1866939496703153
# Lokalni stepeni klasterisanja koji nisu nula:
#                                      id        cc
# 166  Juan Pablo Varillas Patino Samudio  0.003472
# 211                      Roberto Quiroz  0.007500
# 213                       Benjamin Lock  0.008333
# 52                     Altug Celikbilek  0.008333
# 90                          Tatsuma Ito  0.008333
# ..                                  ...       ...
# 223                    Andrey Kuznetsov  0.157490
# 60                  Francisco Cerundolo  0.157490
# 74                           Luca Vanni  0.157490
# 202                    Thiemo De Bakker  0.160305
# 119                Michail Pervolarakis  0.165087
#
# [308 rows x 2 columns]

# %%
# možemo iskoristiti networkx.draw_network da predstavimo egomrežu tog čvora
ego_mreza = nx.ego_graph(G, 'Michail Pervolarakis')
print(f"Čvorovi ego mreže igrača Michail Pervolarakis su {ego_mreza.nodes}")
plt.figure(figsize=(15,10))
tezine_grana = nx.get_edge_attributes(ego_mreza,'weight')
pos = nx.circular_layout(ego_mreza)
#pos = nx.spring_layout(ego_mreza)
#print(pos)
nx.draw_networkx(ego_mreza, pos)
nx.draw_networkx_edge_labels(ego_mreza, pos, edge_labels = tezine_grana)
# Out:
# Čvorovi ego mreže igrača Michail Pervolarakis su ['Jan Lennard Struff', 'John Millman', 'Felix Auger Aliassime', 'Michail Pervolarakis']
# {('Jan Lennard Struff',
#   'Felix Auger Aliassime'): Text(7.946626690014114e-09, -2.1855693665697605e-08, '2'),
#  ('Jan Lennard Struff',
#   'John Millman'): Text(0.4999999751630862, 0.5000000109278468, '3'),
#  ('Jan Lennard Struff',
#   'Michail Pervolarakis'): Text(0.50000000298122, -0.49999996721645945, '1'),
#  ('John Millman',
#   'Felix Auger Aliassime'): Text(-0.50000000298122, 0.4999999672164595, '2'),
#  ('John Millman',
#   'Michail Pervolarakis'): Text(-7.946626738379675e-09, 2.1855693699279755e-08, '1'),
#  ('Felix Auger Aliassime',
#   'Michail Pervolarakis'): Text(-0.49999997516308625, -0.5000000109278468, '1')}

# %%
# možemo iskoristiti networkx.draw_network da predstavimo egomrežu tog čvora
ego_mreza = nx.ego_graph(G, 'Francisco Cerundolo')
print(f"Čvorovi ego mreže igrača Francisco Cerundolo su {ego_mreza.nodes}")
plt.figure(figsize=(15,10))
tezine_grana = nx.get_edge_attributes(ego_mreza,'weight')
pos = nx.circular_layout(ego_mreza)
#pos = nx.spring_layout(ego_mreza)
#print(pos)
nx.draw_networkx(ego_mreza, pos)
nx.draw_networkx_edge_labels(ego_mreza, pos, edge_labels = tezine_grana)
# Out:
# Čvorovi ego mreže igrača Francisco Cerundolo su ['Francisco Cerundolo', 'Guido Pella', 'Laslo Djere']
# {('Francisco Cerundolo',
#   'Guido Pella'): Text(0.24999996274709668, 0.43301271829021687, '1'),
#  ('Francisco Cerundolo',
#   'Laslo Djere'): Text(0.2500000372529033, -0.43301270835610933, '1'),
#  ('Guido Pella', 'Laslo Djere'): Text(-0.5, -9.934107536579972e-09, '2')}

# %%
# možemo iskoristiti networkx.draw_network da predstavimo egomrežu tog čvora
ego_mreza = nx.ego_graph(G, 'Rafael Nadal')
print(f"Čvorovi ego mreže igrača Rafael Nadal su {ego_mreza.nodes}")
plt.figure(figsize=(15,10))
tezine_grana = nx.get_edge_attributes(ego_mreza,'weight')
pos = nx.circular_layout(ego_mreza)
#pos = nx.spring_layout(ego_mreza)
#print(pos)
nx.draw_networkx(ego_mreza, pos)
nx.draw_networkx_edge_labels(ego_mreza, pos, edge_labels = tezine_grana)
# Out:
# Čvorovi ego mreže igrača Rafael Nadal su ['Dudi Sela', 'Nick Kyrgios', 'John Millman', 'Thanasi Kokkinakis', 'David Ferrer', 'Martin Klizan', 'Denis Shapovalov', 'Fernando Verdasco', 'Rafael Nadal', 'Borna Gojo', 'Mackenzie Mcdonald', 'Leonardo Mayer', 'Roger Federer', 'Alex De Minaur', 'Egor Gerasimov', 'Taylor Harry Fritz', 'Benoit Paire', 'Filip Krajinovic', 'Felix Auger Aliassime', 'Yannick Hanfmann', 'Matthew Ebden', 'Daniel Evans', 'Jannik Sinner', 'Feliciano Lopez', 'Yuichi Sugita', 'Kei Nishikori', 'Philipp Kohlschreiber', 'Guillermo Garcia Lopez', 'Grigor Dimitrov', 'Matteo Berrettini', 'Jan Lennard Struff', 'Jeremy Chardy', 'Richard Gasquet', 'Jo Wilfried Tsonga', 'Pablo Cuevas', 'Yoshihito Nishioka', 'Tomas Berdych', 'Stefanos Tsitsipas', 'Juan Ignacio Londero', 'Marin Cilic', 'Adrian Mannarino', 'Novak Djokovic', 'Gael Monfils', 'Andrey Rublev', 'Victor Estrella', 'Jiri Vesely', 'Roberto Carballes Baena', 'Stefano Travaglia', 'Pablo Andujar', 'Stanislas Wawrinka', 'Francis Tiafoe', 'Maximilian Marterer', 'Nikoloz Basilashvili', 'Miomir Kecmanovic', 'Mischa Zverev', 'Daniil Medvedev', 'Juan Martin Del Potro', 'Jared Donaldson', 'Simone Bolelli', 'Federico Delbonis', 'Dominic Thiem', 'Hyeon Chung', 'Damir Dzumhur', 'Vasek Pospisil', 'Jordan Thompson', 'Roberto Bautista Agut', 'Dusan Lajovic', 'Soon Woo Kwon', 'Mikhail Kukushkin', 'Alexander Zverev', 'Fabio Fognini', 'Diego Sebastian Schwartzman', 'Sam Querrey', 'Aljaz Bedene', 'Hugo Dellien', 'Guido Pella', 'David Goffin', 'Pablo Carreno Busta', 'Sebastian Korda', 'James Duckworth', 'Karen Khachanov', 'Yannick Maden', 'Joao Sousa']
# {('Dudi Sela',
#   'Nikoloz Basilashvili'): Text(0.1498078970994594, -0.3568830229749309, '1'),
#  ('Dudi Sela',
#   'Rafael Nadal'): Text(0.911078005705851, 0.2846311316457463, '1'),
#  ('Dudi Sela',
#   'Fernando Verdasco'): Text(0.9314270017038262, 0.2527266129254781, '1'),
#  ('Dudi Sela',
#   'Francis Tiafoe'): Text(0.09998726517585782, -0.2999830281563295, '1'),
#  ('Nick Kyrgios',
#   'Rafael Nadal'): Text(0.9096460339122387, 0.32244550307104414, '3'),
#  ('Nick Kyrgios',
#   'Daniil Medvedev'): Text(0.23772230467233973, -0.38875274003310434, '2'),
#  ('Nick Kyrgios',
#   'Jan Lennard Struff'): Text(0.17636948524495966, 0.4201598977572656, '3'),
#  ('Nick Kyrgios',
#   'Yoshihito Nishioka'): Text(0.05788650766234116, 0.27403419317595795, '2'),
#  ('Nick Kyrgios',
#   'Stefanos Tsitsipas'): Text(0.027299937049815426, 0.2048664150285694, '2'),
#  ('Nick Kyrgios',
#   'Karen Khachanov'): Text(0.9857293962913501, -0.07476359134768196, '2'),
#  ('Nick Kyrgios',
#   'Alexander Zverev'): Text(0.743085070510491, -0.3983179742521441, '3'),
#  ('Nick Kyrgios',
#   'Jo Wilfried Tsonga'): Text(0.098555323184568, 0.33779742444681793, '1'),
#  ('Nick Kyrgios',
#   'Roberto Carballes Baena'): Text(0.027299966852137925, -0.12923775162091178, '1'),
#  ('Nick Kyrgios',
#   'John Millman'): Text(0.9928483068683023, 0.1132265159780069, '1'),
#  ('Nick Kyrgios',
#   'Grigor Dimitrov'): Text(0.23772230467233973, 0.46438150774889064, '2'),
#  ('Nick Kyrgios',
#   'Dusan Lajovic'): Text(0.63860867786153, -0.44217376073513026, '2'),
#  ('Nick Kyrgios',
#   'Roberto Bautista Agut'): Text(0.6019068420361707, -0.45139018857167634, '1'),
#  ('Nick Kyrgios',
#   'Marin Cilic'): Text(0.007495459286165407, 0.13187677959370772, '1'),
#  ('Nick Kyrgios',
#   'Felix Auger Aliassime'): Text(0.6019067600797838, 0.5270189264851401, '1'),
#  ('Nick Kyrgios',
#   'Andrey Rublev'): Text(0.0017880463072708075, -0.01883943260102002, '2'),
#  ('Nick Kyrgios',
#   'Stanislas Wawrinka'): Text(0.07701357863565617, -0.2310570884054156, '2'),
#  ('Nick Kyrgios',
#   'Jeremy Chardy'): Text(0.14837595510816953, 0.39469741926541935, '1'),
#  ('Nick Kyrgios',
#   'Matteo Berrettini'): Text(0.20620855400463967, 0.4434323227781676, '1'),
#  ('Nick Kyrgios',
#   'Roger Federer'): Text(0.806067257414536, 0.4320785319768503, '2'),
#  ('Nick Kyrgios',
#   'Philipp Kohlschreiber'): Text(0.3050429050691011, 0.4988436915880917, '1'),
#  ('Nick Kyrgios',
#   'Richard Gasquet'): Text(0.12238827028697563, 0.36719073986892464, '1'),
#  ('Nick Kyrgios',
#   'Kei Nishikori'): Text(0.34046420215203105, 0.5121593692793234, '1'),
#  ('Nick Kyrgios',
#   'Juan Martin Del Potro'): Text(0.27072995635979896, -0.40725846238469937, '1'),
#  ('Nick Kyrgios',
#   'Feliciano Lopez'): Text(0.41381554092444656, 0.5305790225235498, '2'),
#  ('Nick Kyrgios',
#   'Matthew Ebden'): Text(0.5269406606940168, 0.5370087245904586, '1'),
#  ('Nick Kyrgios',
#   'Fabio Fognini'): Text(0.7753688088833601, -0.3785764687959282, '1'),
#  ('Nick Kyrgios',
#   'Jordan Thompson'): Text(0.5646128564145569, -0.4578045126401771, '1'),
#  ('Nick Kyrgios',
#   'Maximilian Marterer'): Text(0.12238824048465313, -0.29156197215313834, '1'),
#  ('John Millman',
#   'Jan Lennard Struff'): Text(0.17208173570048657, 0.4577576733532428, '3'),
#  ('John Millman',
#   'Roger Federer'): Text(0.8017795078700629, 0.4696763075728275, '3'),
#  ('John Millman',
#   'Karen Khachanov'): Text(0.9814416467468771, -0.03716581575170477, '1'),
#  ('John Millman',
#   'Damir Dzumhur'): Text(0.4848182527245294, -0.42449833108827495, '2'),
#  ('John Millman',
#   'Nikoloz Basilashvili'): Text(0.144088175761374, -0.28147087595365594, '2'),
#  ('John Millman',
#   'Federico Delbonis'): Text(0.3725033305124333, -0.40953154512611745, '3'),
#  ('John Millman',
#   'Novak Djokovic'): Text(-0.005361590464174726, 0.09433289218473886, '3'),
#  ('John Millman',
#   'Roberto Bautista Agut'): Text(0.5976190924916976, -0.41379241297569913, '2'),
#  ('John Millman',
#   'Dusan Lajovic'): Text(0.6343209283170569, -0.40457598513915305, '1'),
#  ('John Millman',
#   'Rafael Nadal'): Text(0.9053582843677657, 0.36004327866702135, '1'),
#  ('John Millman',
#   'Benoit Paire'): Text(0.6702207761934671, 0.5434345225531202, '2'),
#  ('John Millman',
#   'Yoshihito Nishioka'): Text(0.05359875811786807, 0.3116319687719351, '1'),
#  ('John Millman',
#   'Grigor Dimitrov'): Text(0.23343455512786665, 0.5019792833448679, '2'),
#  ('John Millman',
#   'Fabio Fognini'): Text(0.771081059338887, -0.340978693199951, '2'),
#  ('John Millman',
#   'Taylor Harry Fritz'): Text(0.705112828732351, 0.5287879625461828, '1'),
#  ('John Millman',
#   'Marin Cilic'): Text(0.0032077097416923217, 0.1694745551896849, '1'),
#  ('John Millman',
#   'Dominic Thiem'): Text(0.40952788078694097, -0.4173525388164314, '1'),
#  ('John Millman',
#   'Diego Sebastian Schwartzman'): Text(0.8017795078700629, -0.3188519886650868, '1'),
#  ('John Millman',
#   'Guido Pella'): Text(0.905358254565443, -0.20921898956160315, '2'),
#  ('John Millman',
#   'Stefanos Tsitsipas'): Text(0.02301218750534234, 0.24246419062454658, '1'),
#  ('John Millman',
#   'Denis Shapovalov'): Text(0.9435850677823443, 0.2947866977193684, '1'),
#  ('John Millman',
#   'Alex De Minaur'): Text(0.7710811487458545, 0.49180292270072423, '1'),
#  ('John Millman',
#   'Felix Auger Aliassime'): Text(0.5976190105353107, 0.5646167020811174, '2'),
#  ('John Millman',
#   'Andrey Rublev'): Text(-0.0024997032372022776, 0.01875834299495717, '1'),
#  ('John Millman',
#   'Miomir Kecmanovic'): Text(0.17208179530513157, -0.30693344385246957, '2'),
#  ('John Millman',
#   'Fernando Verdasco'): Text(0.9257072803657409, 0.3281387599467531, '3'),
#  ('John Millman',
#   'Pablo Carreno Busta'): Text(0.9435850677823443, -0.14396246821859515, '2'),
#  ('John Millman',
#   'Sam Querrey'): Text(0.8307164603277877, -0.2944671621546976, '1'),
#  ('John Millman',
#   'Vasek Pospisil'): Text(0.5226528198799311, -0.42378221108101755, '2'),
#  ('John Millman',
#   'Alexander Zverev'): Text(0.7387973209660179, -0.3607201986561669, '2'),
#  ('John Millman',
#   'Jordan Thompson'): Text(0.5603251068700839, -0.42020673704419986, '1'),
#  ('John Millman',
#   'Francis Tiafoe'): Text(0.09426754383777242, -0.2245708811350545, '3'),
#  ('John Millman',
#   'Kei Nishikori'): Text(0.33617645260755796, 0.5497571448753006, '1'),
#  ('John Millman',
#   'Mischa Zverev'): Text(0.20192077465784408, -0.33020580926872656, '1'),
#  ('John Millman',
#   'Guillermo Garcia Lopez'): Text(0.2664423409257771, 0.5204850354987853, '1'),
#  ('John Millman',
#   'Adrian Mannarino'): Text(-0.0024997032372022776, 0.13206597591278352, '3'),
#  ('John Millman',
#   'Joao Sousa'): Text(0.9928483068683023, 0.03759775450095976, '1'),
#  ('John Millman',
#   'Feliciano Lopez'): Text(0.40952779137997347, 0.568176798119527, '1'),
#  ('John Millman',
#   'Pablo Andujar'): Text(0.05359875811786807, -0.16080764986419444, '1'),
#  ('John Millman',
#   'Aljaz Bedene'): Text(0.8577265138222083, -0.26796350972412963, '1'),
#  ('John Millman',
#   'Hugo Dellien'): Text(0.8826547558809905, -0.23949305302043536, '1'),
#  ('John Millman',
#   'Stefano Travaglia'): Text(0.036995824650677855, -0.12680294657646884, '1'),
#  ('John Millman',
#   'Leonardo Mayer'): Text(0.8307165497347553, 0.4452913618531482, '1'),
#  ('John Millman',
#   'Yannick Maden'): Text(0.9885605871261517, 1.0929014350458122e-07, '1'),
#  ('John Millman',
#   'Yuichi Sugita'): Text(0.3725033603147558, 0.5603558342315357, '1'),
#  ('John Millman',
#   'Mikhail Kukushkin'): Text(0.7051127989300285, -0.37796370324308703, '1'),
#  ('Thanasi Kokkinakis',
#   'Roger Federer'): Text(0.7946605972931108, 0.5068421283065471, '1'),
#  ('Thanasi Kokkinakis',
#   'Rafael Nadal'): Text(0.8982393737908134, 0.39720909940074084, '1'),
#  ('Thanasi Kokkinakis',
#   'Daniil Medvedev'): Text(0.22631564455091452, -0.31398914370340764, '1'),
#  ('Thanasi Kokkinakis',
#   'Karen Khachanov'): Text(0.9743227361699249, 4.982014759069564e-09, '1'),
#  ('Thanasi Kokkinakis',
#   'Taylor Harry Fritz'): Text(0.6979939181553989, 0.5659537832799023, '1'),
#  ('Thanasi Kokkinakis',
#   'Fernando Verdasco'): Text(0.9185883697887887, 0.3653045806804726, '1'),
#  ('Thanasi Kokkinakis',
#   'Feliciano Lopez'): Text(0.40240888080302134, 0.6053426188532466, '1'),
#  ('Thanasi Kokkinakis',
#   'Jo Wilfried Tsonga'): Text(0.08714866306314278, 0.41256102077651463, '1'),
#  ('David Ferrer',
#   'Philipp Kohlschreiber'): Text(0.2837269131130968, 0.6101282832502417, '1'),
#  ('David Ferrer',
#   'Roberto Bautista Agut'): Text(0.5805908500801664, -0.34010559690952635, '1'),
#  ('David Ferrer',
#   'Alexander Zverev'): Text(0.7217690785544867, -0.2870333825899941, '6'),
#  ('David Ferrer',
#   'Sam Querrey'): Text(0.8136882179162566, -0.22078034608852473, '1'),
#  ('David Ferrer',
#   'Matteo Berrettini'): Text(0.18489256204863536, 0.5547169144403176, '1'),
#  ('David Ferrer',
#   'Joao Sousa'): Text(0.975820064456771, 0.11128457056713259, '1'),
#  ('David Ferrer',
#   'Andrey Rublev'): Text(-0.019527945648733502, 0.09244515906113, '2'),
#  ('David Ferrer',
#   'Mischa Zverev'): Text(0.18489253224631286, -0.2565189932025538, '1'),
#  ('David Ferrer',
#   'Rafael Nadal'): Text(0.8883300419562343, 0.4337300947331941, '2'),
#  ('David Ferrer',
#   'Karen Khachanov'): Text(0.9644134043353458, 0.03652100031446806, '2'),
#  ('David Ferrer',
#   'Benoit Paire'): Text(0.6531925337819359, 0.6171213386192931, '1'),
#  ('David Ferrer',
#   'Mikhail Kukushkin'): Text(0.6880845565184973, -0.30427688717691426, '1'),
#  ('David Ferrer',
#   'Pablo Carreno Busta'): Text(0.926556825370813, -0.07027565215242232, '1'),
#  ('David Ferrer',
#   'Francis Tiafoe'): Text(0.07723930142624119, -0.15088406506888166, '1'),
#  ('David Ferrer',
#   'Juan Martin Del Potro'): Text(0.24941396440379465, -0.2959738707225493, '3'),
#  ('David Ferrer',
#   'Hyeon Chung'): Text(0.43000940398776577, -0.3486641682792948, '1'),
#  ('Martin Klizan',
#   'Denis Shapovalov'): Text(0.9139138159006395, 0.404140471412806, '2'),
#  ('Martin Klizan',
#   'Dominic Thiem'): Text(0.3798566289052362, -0.30799876512299373, '3'),
#  ('Martin Klizan',
#   'Damir Dzumhur'): Text(0.4551470008428246, -0.3151445573948373, '1'),
#  ('Martin Klizan',
#   'Federico Delbonis'): Text(0.3428320786307285, -0.3001777714326798, '3'),
#  ('Martin Klizan',
#   'Dusan Lajovic'): Text(0.6046496764353522, -0.2952222114457154, '1'),
#  ('Martin Klizan',
#   'Feliciano Lopez'): Text(0.3798565394982687, 0.6775305718129647, '2'),
#  ('Martin Klizan',
#   'Novak Djokovic'): Text(-0.0350328423458795, 0.20368666587817652, '1'),
#  ('Martin Klizan',
#   'Stanislas Wawrinka'): Text(0.043054577209478306, -0.08410553911600077, '2'),
#  ('Martin Klizan',
#   'Fabio Fognini'): Text(0.7414098074571822, -0.23162491950651337, '1'),
#  ('Martin Klizan',
#   'Felix Auger Aliassime'): Text(0.567947758653606, 0.673970475774555, '1'),
#  ('Martin Klizan',
#   'Mischa Zverev'): Text(0.1722495227761393, -0.22085203557528893, '1'),
#  ('Martin Klizan',
#   'Rafael Nadal'): Text(0.8756870324860608, 0.469397052360459, '1'),
#  ('Martin Klizan',
#   'Daniil Medvedev'): Text(0.20376330324616188, -0.2418011907436895, '2'),
#  ('Martin Klizan',
#   'Karen Khachanov'): Text(0.9517703948651723, 0.07218795794173288, '1'),
#  ('Martin Klizan',
#   'Gael Monfils'): Text(-0.0350328423458795, 0.16584520227908467, '1'),
#  ('Martin Klizan',
#   'Marin Cilic'): Text(-0.026463542140012453, 0.2788283288831226, '2'),
#  ('Martin Klizan',
#   'Jeremy Chardy'): Text(0.11441695368199167, 0.5416489685548342, '1'),
#  ('Martin Klizan',
#   'Filip Krajinovic'): Text(0.6046497211388359, 0.664754047938009, '1'),
#  ('Martin Klizan',
#   'Alexander Zverev'): Text(0.7091260690843131, -0.25136642496272926, '1'),
#  ('Martin Klizan',
#   'Adrian Mannarino'): Text(-0.03217095511890705, 0.2414197496062212, '1'),
#  ('Martin Klizan',
#   'Roberto Carballes Baena'): Text(-0.006659034574039935, 0.017713797668503062, '1'),
#  ('Martin Klizan',
#   'Jo Wilfried Tsonga'): Text(0.06459632175839014, 0.48474897373623277, '1'),
#  ('Martin Klizan',
#   'Hyeon Chung'): Text(0.4173663945175922, -0.31299721065202996, '1'),
#  ('Martin Klizan',
#   'Mikhail Kukushkin'): Text(0.6754415470483238, -0.2686099295496494, '1'),
#  ('Denis Shapovalov',
#   'Rafael Nadal'): Text(0.8603827948262807, 0.5040056848124056, '3'),
#  ('Denis Shapovalov',
#   'Daniil Medvedev'): Text(0.1884590655863817, -0.20719255829174288, '2'),
#  ('Denis Shapovalov',
#   'Novak Djokovic'): Text(-0.05033708000565967, 0.23829529833012314, '5'),
#  ('Denis Shapovalov',
#   'David Goffin'): Text(0.8807318206265784, -0.033352034893628146, '2'),
#  ('Denis Shapovalov',
#   'Benoit Paire'): Text(0.6252452866519821, 0.6873969286985044, '3'),
#  ('Denis Shapovalov',
#   'Gael Monfils'): Text(-0.05033708000565967, 0.2004538347310313, '2'),
#  ('Denis Shapovalov',
#   'Yoshihito Nishioka'): Text(0.008623268576383125, 0.4555943749173194, '1'),
#  ('Denis Shapovalov',
#   'Nikoloz Basilashvili'): Text(0.09911268621988906, -0.13750846980827164, '2'),
#  ('Denis Shapovalov',
#   'Grigor Dimitrov'): Text(0.1884590655863817, 0.6459416894902521, '2'),
#  ('Denis Shapovalov',
#   'Marin Cilic'): Text(-0.041767779799792626, 0.31343696133506915, '4'),
#  ('Denis Shapovalov',
#   'Dominic Thiem'): Text(0.364552391245456, -0.2733901326710471, '2'),
#  ('Denis Shapovalov',
#   'Diego Sebastian Schwartzman'): Text(0.756804018328578, -0.17488958251970255, '1'),
#  ('Denis Shapovalov',
#   'Stefanos Tsitsipas'): Text(-0.021963302036142607, 0.38642659676993085, '4'),
#  ('Denis Shapovalov',
#   'Jan Lennard Struff'): Text(0.12710624615900162, 0.601720079498627, '5'),
#  ('Denis Shapovalov',
#   'Alex De Minaur'): Text(0.7261056592043695, 0.6357653288461085, '2'),
#  ('Denis Shapovalov',
#   'Felix Auger Aliassime'): Text(0.5526435209938259, 0.7085791082265016, '3'),
#  ('Denis Shapovalov',
#   'Andrey Rublev'): Text(-0.047475192778687225, 0.16272074914034146, '3'),
#  ('Denis Shapovalov',
#   'Stanislas Wawrinka'): Text(0.027750339549698133, -0.04949690666405415, '3'),
#  ('Denis Shapovalov',
#   'Mikhail Kukushkin'): Text(0.6601373093885436, -0.2340012970977028, '1'),
#  ('Denis Shapovalov',
#   'Pablo Carreno Busta'): Text(0.8986095782408593, -6.207321087692286e-08, '4'),
#  ('Denis Shapovalov',
#   'Pablo Cuevas'): Text(0.027750369352020632, 0.4882460378625634, '1'),
#  ('Denis Shapovalov',
#   'Vasek Pospisil'): Text(0.47767733033844617, -0.2798198049356333, '2'),
#  ('Denis Shapovalov',
#   'Alexander Zverev'): Text(0.693821831424533, -0.21675779251078264, '3'),
#  ('Denis Shapovalov',
#   'Roger Federer'): Text(0.756804018328578, 0.6136387137182118, '1'),
#  ('Denis Shapovalov',
#   'Richard Gasquet'): Text(0.0731250312010176, 0.5487509216102862, '1'),
#  ('Denis Shapovalov',
#   'Roberto Carballes Baena'): Text(-0.021963272233820108, 0.05232243012044968, '1'),
#  ('Denis Shapovalov',
#   'Francis Tiafoe'): Text(0.04929205429628747, -0.08060847498967022, '4'),
#  ('Denis Shapovalov',
#   'Maximilian Marterer'): Text(0.0731250013986951, -0.11000179041177688, '1'),
#  ('Denis Shapovalov',
#   'Kei Nishikori'): Text(0.291200963066073, 0.6937195510206848, '2'),
#  ('Denis Shapovalov',
#   'Mischa Zverev'): Text(0.15694528511635913, -0.1862434031233423, '1'),
#  ('Denis Shapovalov',
#   'Joao Sousa'): Text(0.9478728173268174, 0.18156016064634403, '2'),
#  ('Denis Shapovalov',
#   'Jo Wilfried Tsonga'): Text(0.04929208409860997, 0.5193576061881794, '1'),
#  ('Denis Shapovalov',
#   'Juan Martin Del Potro'): Text(0.22146671727384093, -0.2256982806433379, '2'),
#  ('Denis Shapovalov',
#   'Karen Khachanov'): Text(0.9364661572053921, 0.1067965903936795, '1'),
#  ('Denis Shapovalov',
#   'Damir Dzumhur'): Text(0.43984276318304444, -0.2805359249428907, '1'),
#  ('Denis Shapovalov',
#   'Filip Krajinovic'): Text(0.5893454834790557, 0.6993626803899555, '1'),
#  ('Denis Shapovalov',
#   'Taylor Harry Fritz'): Text(0.6601373391908661, 0.672750368691567, '3'),
#  ('Denis Shapovalov',
#   'Jeremy Chardy'): Text(0.0991127160222115, 0.5762576010067808, '2'),
#  ('Denis Shapovalov',
#   'Sam Querrey'): Text(0.7857409707863028, -0.1505047560093133, '1'),
#  ('Denis Shapovalov',
#   'Matteo Berrettini'): Text(0.15694531491868163, 0.624992504519529, '2'),
#  ('Denis Shapovalov',
#   'Miomir Kecmanovic'): Text(0.12710630576364662, -0.16297103770708532, '2'),
#  ('Denis Shapovalov',
#   'Tomas Berdych'): Text(-0.007979635088484593, 0.4215896716295938, '2'),
#  ('Denis Shapovalov',
#   'Fabio Fognini'): Text(0.7261055697974022, -0.19701628705456675, '2'),
#  ('Denis Shapovalov',
#   'Guido Pella'): Text(0.8603827650239582, -0.06525658341621887, '1'),
#  ('Denis Shapovalov',
#   'Pablo Andujar'): Text(0.008623268576383125, -0.01684524371881016, '1'),
#  ('Denis Shapovalov',
#   'Jared Donaldson'): Text(0.25577963618082056, -0.24165474213094396, '2'),
#  ('Denis Shapovalov',
#   'Soon Woo Kwon'): Text(0.6252453760589496, -0.24864779749999533, '1'),
#  ('Denis Shapovalov',
#   'Egor Gerasimov'): Text(0.6938218016222104, 0.6555068939069694, '1'),
#  ('Denis Shapovalov',
#   'Sebastian Korda'): Text(0.913913845702962, 0.03460867468686449, '1'),
#  ('Denis Shapovalov',
#   'Yuichi Sugita'): Text(0.32752787077327083, 0.7043182403769199, '1'),
#  ('Denis Shapovalov',
#   'Daniel Evans'): Text(0.4398427352433671, 0.7192850263390774, '1'),
#  ('Denis Shapovalov',
#   'Hyeon Chung'): Text(0.40206215685781205, -0.27838857820008334, '1'),
#  ('Fernando Verdasco',
#   'Daniil Medvedev'): Text(0.1705812781697783, -0.17384049606435814, '3'),
#  ('Fernando Verdasco',
#   'Gael Monfils'): Text(-0.06821486742226307, 0.23380589695841603, '2'),
#  ('Fernando Verdasco',
#   'Yoshihito Nishioka'): Text(-0.009254518840220272, 0.48894643714470415, '2'),
#  ('Fernando Verdasco',
#   'Dominic Thiem'): Text(0.3466746038288526, -0.24003807044366238, '3'),
#  ('Fernando Verdasco',
#   'Karen Khachanov'): Text(0.9185883697887887, 0.14014865262106424, '2'),
#  ('Fernando Verdasco',
#   'Roberto Bautista Agut'): Text(0.5347658155336092, -0.23647794460293015, '1'),
#  ('Fernando Verdasco',
#   'Filip Krajinovic'): Text(0.5714676960624523, 0.7327147426173403, '2'),
#  ('Fernando Verdasco',
#   'Pablo Carreno Busta'): Text(0.8807317908242559, 0.03335200015417386, '2'),
#  ('Fernando Verdasco',
#   'Nikoloz Basilashvili'): Text(0.08123489880328566, -0.1041564075808869, '3'),
#  ('Fernando Verdasco',
#   'Jeremy Chardy'): Text(0.0812349286056081, 0.6096096632341655, '2'),
#  ('Fernando Verdasco',
#   'Juan Ignacio Londero'): Text(-0.05112535143567998, 0.3836588252774009, '1'),
#  ('Fernando Verdasco',
#   'Grigor Dimitrov'): Text(0.1705812781697783, 0.6792937517176368, '4'),
#  ('Fernando Verdasco',
#   'Dusan Lajovic'): Text(0.5714676513589686, -0.22726151676638406, '1'),
#  ('Fernando Verdasco',
#   'Novak Djokovic'): Text(-0.06821486742226307, 0.2716473605575079, '1'),
#  ('Fernando Verdasco',
#   'Rafael Nadal'): Text(0.8425050074096773, 0.5373577470397903, '1'),
#  ('Fernando Verdasco',
#   'David Goffin'): Text(0.862854033209975, 2.7333756591474412e-08, '1'),
#  ('Fernando Verdasco',
#   'Benoit Paire'): Text(0.6073674992353787, 0.7207489909258893, '1'),
#  ('Fernando Verdasco',
#   'Fabio Fognini'): Text(0.7082277823807988, -0.16366422482718201, '2'),
#  ('Fernando Verdasco',
#   'Taylor Harry Fritz'): Text(0.6422595517742627, 0.7061024309189518, '2'),
#  ('Fernando Verdasco',
#   'Marin Cilic'): Text(-0.05964556721639602, 0.3467890235624539, '3'),
#  ('Fernando Verdasco',
#   'Diego Sebastian Schwartzman'): Text(0.7389262309119746, -0.1415375202923178, '3'),
#  ('Fernando Verdasco',
#   'Guido Pella'): Text(0.8425049776073548, -0.031904521188834134, '2'),
#  ('Fernando Verdasco',
#   'Stefanos Tsitsipas'): Text(-0.039841089452746004, 0.4197786589973156, '1'),
#  ('Fernando Verdasco',
#   'Alex De Minaur'): Text(0.7082278717877661, 0.6691173910734932, '1'),
#  ('Fernando Verdasco',
#   'Andrey Rublev'): Text(-0.06535298019529062, 0.1960728113677262, '1'),
#  ('Fernando Verdasco',
#   'Sam Querrey'): Text(0.7678631833696994, -0.11715269378192855, '1'),
#  ('Fernando Verdasco',
#   'Alexander Zverev'): Text(0.6759440440079296, -0.1834057302833979, '3'),
#  ('Fernando Verdasco',
#   'Matteo Berrettini'): Text(0.13906752750207824, 0.6583445667469138, '1'),
#  ('Fernando Verdasco',
#   'Roger Federer'): Text(0.7389262309119746, 0.6469907759455965, '1'),
#  ('Fernando Verdasco',
#   'Philipp Kohlschreiber'): Text(0.23790187856653966, 0.7137559355568379, '1'),
#  ('Fernando Verdasco',
#   'Pablo Andujar'): Text(-0.009254518840220272, 0.016506818508574578, '2'),
#  ('Fernando Verdasco',
#   'Adrian Mannarino'): Text(-0.06535298019529062, 0.30938044428555256, '1'),
#  ('Fernando Verdasco',
#   'Jiri Vesely'): Text(-0.05112532163335748, 0.12179432606774912, '1'),
#  ('Fernando Verdasco',
#   'Francis Tiafoe'): Text(0.03141426687968407, -0.04725641276228548, '1'),
#  ('Fernando Verdasco',
#   'Maximilian Marterer'): Text(0.0552472139820917, -0.07664972818439214, '1'),
#  ('Fernando Verdasco',
#   'Damir Dzumhur'): Text(0.42196497576644104, -0.24718386271550596, '1'),
#  ('Fernando Verdasco',
#   'Tomas Berdych'): Text(-0.02585742250508799, 0.45494173385697856, '1'),
#  ('Fernando Verdasco',
#   'Leonardo Mayer'): Text(0.7678632727766669, 0.6226058302259172, '2'),
#  ('Fernando Verdasco',
#   'Hyeon Chung'): Text(0.38418436944120865, -0.2450365159726986, '1'),
#  ('Fernando Verdasco',
#   'Juan Martin Del Potro'): Text(0.20358892985723753, -0.19234621841595317, '1'),
#  ('Fernando Verdasco',
#   'Feliciano Lopez'): Text(0.3466745144218851, 0.7454912664922961, '2'),
#  ('Fernando Verdasco',
#   'Miomir Kecmanovic'): Text(0.10922851834704322, -0.12961897547970058, '1'),
#  ('Fernando Verdasco',
#   'Guillermo Garcia Lopez'): Text(0.20358906396768875, 0.6977995038715543, '1'),
#  ('Fernando Verdasco',
#   'Matthew Ebden'): Text(0.4597996341914554, 0.7519209685592048, '2'),
#  ('Fernando Verdasco',
#   'Pablo Cuevas'): Text(0.009872581935417235, 0.5215981000899481, '1'),
#  ('Fernando Verdasco',
#   'Egor Gerasimov'): Text(0.675944014205607, 0.6888589561343541, '1'),
#  ('Fernando Verdasco',
#   'James Duckworth'): Text(0.9086790081518872, 0.10362757533222408, '1'),
#  ('Fernando Verdasco',
#   'Daniel Evans'): Text(0.4219649478267637, 0.7526370885664622, '1'),
#  ('Rafael Nadal',
#   'Novak Djokovic'): Text(-0.08856386342023831, 0.3035518792777761, '6'),
#  ('Rafael Nadal',
#   'Daniil Medvedev'): Text(0.15023228217180307, -0.14193597734408991, '4'),
#  ('Rafael Nadal',
#   'David Goffin'): Text(0.8425050372119998, 0.03190454605402482, '3'),
#  ('Rafael Nadal',
#   'Fabio Fognini'): Text(0.6878787863828235, -0.1317597061069138, '3'),
#  ('Rafael Nadal',
#   'Marin Cilic'): Text(-0.07999456321437126, 0.3786935422827221, '3'),
#  ('Rafael Nadal',
#   'Dominic Thiem'): Text(0.3263256078308774, -0.20813355172339415, '8'),
#  ('Rafael Nadal',
#   'Diego Sebastian Schwartzman'): Text(0.7185772349139994, -0.10963300157204958, '8'),
#  ('Rafael Nadal',
#   'Stefanos Tsitsipas'): Text(-0.06019008545072124, 0.4516831777175838, '7'),
#  ('Rafael Nadal',
#   'Alexander Zverev'): Text(0.6555950480099544, -0.15150121156312968, '4'),
#  ('Rafael Nadal',
#   'Roger Federer'): Text(0.7185772349139994, 0.6788952946658647, '3'),
#  ('Rafael Nadal',
#   'Juan Martin Del Potro'): Text(0.1832399338592623, -0.16044169969568495, '3'),
#  ('Rafael Nadal',
#   'Gael Monfils'): Text(-0.08856386342023831, 0.26571041567868425, '2'),
#  ('Rafael Nadal',
#   'Jan Lennard Struff'): Text(0.08887946274442299, 0.66697666044628, '1'),
#  ('Rafael Nadal',
#   'Yoshihito Nishioka'): Text(-0.02960351483819551, 0.5208509558649723, '1'),
#  ('Rafael Nadal',
#   'Karen Khachanov'): Text(0.8982393737908134, 0.17205317134133247, '5'),
#  ('Rafael Nadal',
#   'Philipp Kohlschreiber'): Text(0.21755288256856442, 0.7456604542771061, '1'),
#  ('Rafael Nadal',
#   'Roberto Bautista Agut'): Text(0.514416819535634, -0.20457342588266192, '1'),
#  ('Rafael Nadal',
#   'Damir Dzumhur'): Text(0.4016159797684658, -0.21527934399523774, '2'),
#  ('Rafael Nadal',
#   'Filip Krajinovic'): Text(0.551118700064477, 0.7646192613376085, '1'),
#  ('Rafael Nadal',
#   'Pablo Carreno Busta'): Text(0.8603827948262807, 0.06525651887444209, '3'),
#  ('Rafael Nadal',
#   'Nikoloz Basilashvili'): Text(0.06088590280531042, -0.07225188886061867, '3'),
#  ('Rafael Nadal',
#   'Kei Nishikori'): Text(0.2529741796514944, 0.7589761319683379, '2'),
#  ('Rafael Nadal',
#   'Jo Wilfried Tsonga'): Text(0.011065300684031332, 0.5846141871358324, '2'),
#  ('Rafael Nadal',
#   'Federico Delbonis'): Text(0.2893010575563697, -0.20031255803308023, '1'),
#  ('Rafael Nadal',
#   'Taylor Harry Fritz'): Text(0.6219105557762875, 0.73800694963922, '1'),
#  ('Rafael Nadal',
#   'Jeremy Chardy'): Text(0.060885932607632864, 0.6415141819544338, '1'),
#  ('Rafael Nadal',
#   'Sam Querrey'): Text(0.7475141873717241, -0.08524817506166033, '1'),
#  ('Rafael Nadal',
#   'Roberto Carballes Baena'): Text(-0.060190055648398744, 0.11757901106810265, '1'),
#  ('Rafael Nadal',
#   'Juan Ignacio Londero'): Text(-0.07147434743365522, 0.41556334399766914, '1'),
#  ('Rafael Nadal',
#   'Grigor Dimitrov'): Text(0.15023228217180307, 0.7111982704379051, '3'),
#  ('Rafael Nadal',
#   'Matteo Berrettini'): Text(0.118718531504103, 0.690249085467182, '1'),
#  ('Rafael Nadal',
#   'Benoit Paire'): Text(0.5870185032374035, 0.7526535096461575, '1'),
#  ('Rafael Nadal',
#   'Dusan Lajovic'): Text(0.5511186553609934, -0.19535699804611584, '1'),
#  ('Rafael Nadal',
#   'Adrian Mannarino'): Text(-0.08570197619326586, 0.3412849630058208, '1'),
#  ('Rafael Nadal',
#   'Richard Gasquet'): Text(0.03489824778643896, 0.614007502557939, '1'),
#  ('Rafael Nadal',
#   'Joao Sousa'): Text(0.9096460339122387, 0.246816741593997, '1'),
#  ('Rafael Nadal',
#   'Feliciano Lopez'): Text(0.3263255184239099, 0.7773957852125644, '1'),
#  ('Rafael Nadal',
#   'Miomir Kecmanovic'): Text(0.08887952234906799, -0.09771445675943236, '1'),
#  ('Rafael Nadal',
#   'Tomas Berdych'): Text(-0.04620641850306323, 0.4868462525772468, '1'),
#  ('Rafael Nadal',
#   'Stanislas Wawrinka'): Text(-0.010476443864880502, 0.015759674283598812, '3'),
#  ('Rafael Nadal',
#   'Guillermo Garcia Lopez'): Text(0.1832400679697135, 0.7297040225918225, '1'),
#  ('Rafael Nadal',
#   'Matthew Ebden'): Text(0.4394506381934802, 0.783825487279473, '1'),
#  ('Rafael Nadal',
#   'Guido Pella'): Text(0.8221559816093795, -2.468565907243203e-09, '3'),
#  ('Rafael Nadal',
#   'Francis Tiafoe'): Text(0.011065270881708833, -0.015351894042017256, '2'),
#  ('Rafael Nadal',
#   'Pablo Andujar'): Text(-0.02960351483819551, 0.048411337228842805, '1'),
#  ('Rafael Nadal',
#   'Felix Auger Aliassime'): Text(0.5144167375792472, 0.7738356891741546, '1'),
#  ('Rafael Nadal',
#   'Jiri Vesely'): Text(-0.07147431763133272, 0.15369884478801735, '1'),
#  ('Rafael Nadal',
#   'Jared Donaldson'): Text(0.21755285276624192, -0.176398161183291, '1'),
#  ('Rafael Nadal',
#   'Andrey Rublev'): Text(-0.08570197619326586, 0.22797733008799442, '1'),
#  ('Rafael Nadal',
#   'Mackenzie Mcdonald'): Text(0.7745242408661448, 0.6280067859225851, '1'),
#  ('Rafael Nadal',
#   'Pablo Cuevas'): Text(-0.010476414062558004, 0.5535026188102163, '1'),
#  ('Rafael Nadal',
#   'Aljaz Bedene'): Text(0.7745242408661448, -0.058744522631092366, '1'),
#  ('Rafael Nadal',
#   'Vasek Pospisil'): Text(0.43945054692386754, -0.21456322398798033, '1'),
#  ('Rafael Nadal',
#   'Alex De Minaur'): Text(0.6878788757897909, 0.7010219097937614, '3'),
#  ('Rafael Nadal',
#   'Hugo Dellien'): Text(0.799452482924927, -0.03027406592739812, '1'),
#  ('Rafael Nadal',
#   'Soon Woo Kwon'): Text(0.587018592644371, -0.18339121655234236, '1'),
#  ('Rafael Nadal',
#   'Egor Gerasimov'): Text(0.6555950182076318, 0.7207634748546223, '1'),
#  ('Rafael Nadal',
#   'Stefano Travaglia'): Text(-0.04620644830538573, 0.0824160405165684, '1'),
#  ('Rafael Nadal',
#   'Sebastian Korda'): Text(0.8756870622883833, 0.09986525563451745, '1'),
#  ('Rafael Nadal',
#   'Jannik Sinner'): Text(0.3638354628502009, 0.782394260543923, '1'),
#  ('Rafael Nadal',
#   'Jordan Thompson'): Text(0.4771228339140203, -0.21098774995116265, '1'),
#  ('Rafael Nadal',
#   'James Duckworth'): Text(0.8883300121539119, 0.1355320940524923, '1'),
#  ('Rafael Nadal',
#   'Mischa Zverev'): Text(0.1187185017017805, -0.12098682217568935, '1'),
#  ('Rafael Nadal',
#   'Leonardo Mayer'): Text(0.7475142767786916, 0.6545103489461854, '2'),
#  ('Rafael Nadal',
#   'Yannick Hanfmann'): Text(0.4771228041116978, 0.7802500132426553, '1'),
#  ('Rafael Nadal',
#   'Yannick Maden'): Text(0.905358314170088, 0.20921909638318076, '1'),
#  ('Rafael Nadal',
#   'Yuichi Sugita'): Text(0.2893010873586922, 0.7695748213245729, '1'),
#  ('Rafael Nadal',
#   'Daniel Evans'): Text(0.40161595182878845, 0.7845416072867304, '2'),
#  ('Rafael Nadal',
#   'Hyeon Chung'): Text(0.3638353734432334, -0.21313199725243037, '1'),
#  ('Rafael Nadal',
#   'Borna Gojo'): Text(0.799452423320282, 0.5995363888235358, '1'),
#  ('Rafael Nadal',
#   'Victor Estrella'): Text(-0.07999456321437126, 0.19056875081109304, '1'),
#  ('Rafael Nadal',
#   'Simone Bolelli'): Text(0.2529742690584619, -0.1897138984791677, '1'),
#  ('Rafael Nadal',
#   'Maximilian Marterer'): Text(0.034898217984116464, -0.044745209464123914, '1'),
#  ('Rafael Nadal',
#   'Mikhail Kukushkin'): Text(0.621910525973965, -0.16874471615004982, '1'),
#  ('Borna Gojo',
#   'Andrey Rublev'): Text(-0.10840556428468595, 0.25825145315147163, '1'),
#  ('Mackenzie Mcdonald',
#   'Taylor Harry Fritz'): Text(0.5742787852307303, 0.7967514698017464, '1'),
#  ('Mackenzie Mcdonald',
#   'Juan Martin Del Potro'): Text(0.13560816331370507, -0.10169717953315849, '1'),
#  ('Mackenzie Mcdonald',
#   'Joao Sousa'): Text(0.8620142633666814, 0.30556126175652343, '1'),
#  ('Mackenzie Mcdonald',
#   'Guillermo Garcia Lopez'): Text(0.13560829742415628, 0.7884485427543491, '1'),
#  ('Mackenzie Mcdonald',
#   'Guido Pella'): Text(0.7745242110638223, 0.05874451769396055, '1'),
#  ('Mackenzie Mcdonald',
#   'Francis Tiafoe'): Text(-0.036566499663848395, 0.0433926261205092, '2'),
#  ('Mackenzie Mcdonald',
#   'Andrey Rublev'): Text(-0.1333337467388231, 0.2867218502505209, '1'),
#  ('Mackenzie Mcdonald',
#   'Roberto Bautista Agut'): Text(0.46678504899007683, -0.14582890572013546, '1'),
#  ('Mackenzie Mcdonald',
#   'Daniil Medvedev'): Text(0.10260051162624584, -0.08319145718156346, '2'),
#  ('Mackenzie Mcdonald',
#   'Daniel Evans'): Text(0.3539841812832312, 0.8432861274492569, '1'),
#  ('Mackenzie Mcdonald',
#   'Benoit Paire'): Text(0.5393867326918462, 0.8113980298086839, '1'),
#  ('Mackenzie Mcdonald',
#   'Yoshihito Nishioka'): Text(-0.07723528538375274, 0.5795954760274988, '2'),
#  ('Mackenzie Mcdonald',
#   'Grigor Dimitrov'): Text(0.10260051162624584, 0.7699427906004315, '1'),
#  ('Mackenzie Mcdonald',
#   'Marin Cilic'): Text(-0.1276263337599285, 0.43743806244524863, '1'),
#  ('Mackenzie Mcdonald',
#   'Stefanos Tsitsipas'): Text(-0.10782185599627847, 0.5104276978801103, '1'),
#  ('Mackenzie Mcdonald',
#   'Alex De Minaur'): Text(0.6402471052442338, 0.7597664299562878, '1'),
#  ('Mackenzie Mcdonald',
#   'Jeremy Chardy'): Text(0.013254162062075636, 0.7002587021169602, '1'),
#  ('Mackenzie Mcdonald',
#   'Alexander Zverev'): Text(0.607963277464397, -0.09275669140060322, '1'),
#  ('Mackenzie Mcdonald',
#   'Matteo Berrettini'): Text(0.07108676095854577, 0.7489936056297084, '1'),
#  ('Mackenzie Mcdonald',
#   'Adrian Mannarino'): Text(-0.1333337467388231, 0.40002948316834724, '1'),
#  ('Leonardo Mayer',
#   'Gael Monfils'): Text(-0.1632055980532487, 0.3509584988648112, '3'),
#  ('Leonardo Mayer',
#   'Diego Sebastian Schwartzman'): Text(0.643935500280989, -0.02438491838592266, '2'),
#  ('Leonardo Mayer',
#   'Matteo Berrettini'): Text(0.044076796871092616, 0.775497168653309, '3'),
#  ('Leonardo Mayer',
#   'Dusan Lajovic'): Text(0.476476920727983, -0.11010891485998892, '2'),
#  ('Leonardo Mayer',
#   'Fabio Fognini'): Text(0.6132370517498131, -0.046511622920786866, '3'),
#  ('Leonardo Mayer',
#   'Guido Pella'): Text(0.7475142469763691, 0.08524808071756101, '2'),
#  ('Leonardo Mayer',
#   'Pablo Andujar'): Text(-0.10424524947120589, 0.13365942041496973, '2'),
#  ('Leonardo Mayer',
#   'Jiri Vesely'): Text(-0.1461160522643431, 0.23894692797414427, '2'),
#  ('Leonardo Mayer',
#   'Mischa Zverev'): Text(0.04407676706877012, -0.035738738989562424, '2'),
#  ('Leonardo Mayer',
#   'Karen Khachanov'): Text(0.823597639157803, 0.2573012545274594, '1'),
#  ('Leonardo Mayer',
#   'David Goffin'): Text(0.7678633025789894, 0.11715262924015174, '1'),
#  ('Leonardo Mayer',
#   'Benoit Paire'): Text(0.5123767686043931, 0.8379015928322844, '1'),
#  ('Leonardo Mayer',
#   'Nikoloz Basilashvili'): Text(-0.01375583182769996, 0.012996194325508248, '1'),
#  ('Leonardo Mayer',
#   'Stefanos Tsitsipas'): Text(-0.13483182008373162, 0.5369312609037107, '1'),
#  ('Leonardo Mayer',
#   'Jan Lennard Struff'): Text(0.014237728111412606, 0.752224743632407, '1'),
#  ('Leonardo Mayer',
#   'Miomir Kecmanovic'): Text(0.014237787716057604, -0.012466373573305434, '1'),
#  ('Leonardo Mayer',
#   'Pablo Cuevas'): Text(-0.08511814869556839, 0.6387507019963432, '1'),
#  ('Leonardo Mayer',
#   'Vasek Pospisil'): Text(0.36480881229085715, -0.1293151408018534, '1'),
#  ('Leonardo Mayer',
#   'Federico Delbonis'): Text(0.21465932292335932, -0.11506447484695331, '1'),
#  ('Leonardo Mayer',
#   'Alexander Zverev'): Text(0.580953313376944, -0.06625312837700276, '1'),
#  ('Leonardo Mayer',
#   'Roger Federer'): Text(0.643935500280989, 0.7641433778519917, '2'),
#  ('Leonardo Mayer',
#   'Richard Gasquet'): Text(-0.03974348684657142, 0.699255585744066, '1'),
#  ('Leonardo Mayer',
#   'Francis Tiafoe'): Text(-0.06357646375130155, 0.06989618914410967, '1'),
#  ('Leonardo Mayer',
#   'Joao Sousa'): Text(0.8350042992792284, 0.3320648247801239, '1'),
#  ('Leonardo Mayer',
#   'Juan Martin Del Potro'): Text(0.10859819922625191, -0.07519361650955803, '1'),
#  ('Leonardo Mayer',
#   'Yuichi Sugita'): Text(0.21465935272568182, 0.8548229045106999, '1'),
#  ('Leonardo Mayer',
#   'Victor Estrella'): Text(-0.15463629784738164, 0.27581683399721996, '1'),
#  ('Roger Federer',
#   'Daniil Medvedev'): Text(0.04665350567410037, -0.03230294843828374, '3'),
#  ('Roger Federer',
#   'Gael Monfils'): Text(-0.192142639917941, 0.3753434445844904, '1'),
#  ('Roger Federer',
#   'Jan Lennard Struff'): Text(-0.014699313753279708, 0.7766096893520862, '3'),
#  ('Roger Federer',
#   'Yoshihito Nishioka'): Text(-0.1331822913358982, 0.6304839847707786, '1'),
#  ('Roger Federer',
#   'Novak Djokovic'): Text(-0.192142639917941, 0.4131849081835823, '5'),
#  ('Roger Federer',
#   'Grigor Dimitrov'): Text(0.04665350567410037, 0.8208312993437112, '2'),
#  ('Roger Federer',
#   'Dominic Thiem'): Text(0.2227468313331747, -0.09850052281758798, '4'),
#  ('Roger Federer',
#   'Stefanos Tsitsipas'): Text(-0.16376886194842394, 0.56131620662339, '5'),
#  ('Roger Federer',
#   'Andrey Rublev'): Text(-0.18928075269096856, 0.3376103589938006, '1'),
#  ('Roger Federer',
#   'Alexander Zverev'): Text(0.5520162715122516, -0.041868182657323505, '2'),
#  ('Roger Federer',
#   'Kei Nishikori'): Text(0.14939540315379168, 0.868609160874144, '4'),
#  ('Roger Federer',
#   'Juan Martin Del Potro'): Text(0.0796611573615596, -0.050808670789878774, '1'),
#  ('Roger Federer',
#   'Philipp Kohlschreiber'): Text(0.11397410607086172, 0.8552934831829123, '2'),
#  ('Roger Federer',
#   'Roberto Bautista Agut'): Text(0.41083804303793137, -0.09494039697685575, '2'),
#  ('Roger Federer',
#   'Damir Dzumhur'): Text(0.2980372032707631, -0.10564631508943156, '1'),
#  ('Roger Federer',
#   'Filip Krajinovic'): Text(0.4475399235667744, 0.8742522902434147, '4'),
#  ('Roger Federer',
#   'Jo Wilfried Tsonga'): Text(-0.09251347581367136, 0.6942472160416385, '1'),
#  ('Roger Federer',
#   'Federico Delbonis'): Text(0.185722281058667, -0.09067952912727406, '1'),
#  ('Roger Federer',
#   'Taylor Harry Fritz'): Text(0.5183317792785848, 0.8476399785450262, '1'),
#  ('Roger Federer',
#   'Marin Cilic'): Text(-0.18357333971207396, 0.4883265711885283, '1'),
#  ('Roger Federer',
#   'Jeremy Chardy'): Text(-0.04269284389006983, 0.7511472108602399, '1'),
#  ('Roger Federer',
#   'David Goffin'): Text(0.738926260714297, 0.141537574959831, '4'),
#  ('Roger Federer',
#   'Juan Ignacio Londero'): Text(-0.1750531239313579, 0.5251963729034753, '1'),
#  ('Roger Federer',
#   'Matteo Berrettini'): Text(0.015139755006400302, 0.7998821143729882, '2'),
#  ('Roger Federer',
#   'Benoit Paire'): Text(0.4834397267397008, 0.8622865385519636, '2'),
#  ('Roger Federer',
#   'Dusan Lajovic'): Text(0.4475398788632906, -0.08572396914030966, '1'),
#  ('Roger Federer',
#   'Adrian Mannarino'): Text(-0.18928075269096856, 0.45091799191162696, '1'),
#  ('Roger Federer',
#   'Richard Gasquet'): Text(-0.06868052871126373, 0.7236405314637453, '2'),
#  ('Roger Federer',
#   'Joao Sousa'): Text(0.806067257414536, 0.3564497704998032, '1'),
#  ('Roger Federer',
#   'Tomas Berdych'): Text(-0.14978519500076592, 0.596479281483053, '1'),
#  ('Roger Federer',
#   'Stanislas Wawrinka'): Text(-0.1140552203625832, 0.12539270318940499, '4'),
#  ('Roger Federer',
#   'Matthew Ebden'): Text(0.3358718616957775, 0.8934585161852792, '1'),
#  ('Roger Federer',
#   'Fabio Fognini'): Text(0.5843000098851208, -0.022126677201107614, '1'),
#  ('Roger Federer',
#   'Guido Pella'): Text(0.7185772051116768, 0.10963302643724027, '1'),
#  ('Roger Federer',
#   'Aljaz Bedene'): Text(0.670945464368442, 0.05088850627471381, '2'),
#  ('Roger Federer',
#   'Alex De Minaur'): Text(0.5843000992920883, 0.8106549386995676, '1'),
#  ('Roger Federer',
#   'Mischa Zverev'): Text(0.015139725204077803, -0.011353793269883172, '1'),
#  ('Roger Federer',
#   'Daniel Evans'): Text(0.29803717533108576, 0.8941746361925366, '2'),
#  ('Roger Federer',
#   'Hyeon Chung'): Text(0.2602565969455307, -0.1034989683466242, '2'),
#  ('Alex De Minaur',
#   'Jan Lennard Struff'): Text(-0.04539767287748808, 0.7987363044799829, '3'),
#  ('Alex De Minaur',
#   'Karen Khachanov'): Text(0.7639622381689024, 0.30381281537503535, '1'),
#  ('Alex De Minaur',
#   'Roberto Bautista Agut'): Text(0.380139683913723, -0.07281378184895904, '2'),
#  ('Alex De Minaur',
#   'Damir Dzumhur'): Text(0.26733884414655473, -0.08351969996153485, '2'),
#  ('Alex De Minaur',
#   'Alexander Zverev'): Text(0.5213179123880433, -0.019741567529426796, '5'),
#  ('Alex De Minaur',
#   'Kei Nishikori'): Text(0.11869704402958331, 0.8907357760020407, '1'),
#  ('Alex De Minaur',
#   'Taylor Harry Fritz'): Text(0.4876334201543764, 0.8697665936729229, '3'),
#  ('Alex De Minaur',
#   'David Goffin'): Text(0.7082279015900887, 0.1636641900877277, '1'),
#  ('Alex De Minaur',
#   'Benoit Paire'): Text(0.45274136761549244, 0.8844131536798603, '2'),
#  ('Alex De Minaur',
#   'Dusan Lajovic'): Text(0.41684151973908223, -0.06359735401241295, '1'),
#  ('Alex De Minaur',
#   'Adrian Mannarino'): Text(-0.21997911181517693, 0.47304460703952367, '1'),
#  ('Alex De Minaur',
#   'Richard Gasquet'): Text(-0.09937888783547211, 0.745767146591642, '2'),
#  ('Alex De Minaur',
#   'Feliciano Lopez'): Text(0.19204838280199882, 0.9091554292462671, '3'),
#  ('Alex De Minaur',
#   'Francis Tiafoe'): Text(-0.12321186474020224, 0.11640774999168563, '1'),
#  ('Alex De Minaur',
#   'Andrey Rublev'): Text(-0.21997911181517693, 0.3597369741216973, '2'),
#  ('Alex De Minaur',
#   'Vasek Pospisil'): Text(0.30517341130195647, -0.08280357995427745, '3'),
#  ('Alex De Minaur',
#   'Daniil Medvedev'): Text(0.015955146549891996, -0.010176333310387031, '3'),
#  ('Alex De Minaur',
#   'Daniel Evans'): Text(0.2673388162068774, 0.9163012513204333, '2'),
#  ('Alex De Minaur',
#   'Yoshihito Nishioka'): Text(-0.16388065046010658, 0.6526105998986753, '2'),
#  ('Alex De Minaur',
#   'Grigor Dimitrov'): Text(0.015955146549891996, 0.842957914471608, '1'),
#  ('Alex De Minaur',
#   'Marin Cilic'): Text(-0.21427169883628233, 0.510453186316425, '1'),
#  ('Alex De Minaur',
#   'Dominic Thiem'): Text(0.19204847220896631, -0.07637390768969127, '2'),
#  ('Alex De Minaur',
#   'Stefanos Tsitsipas'): Text(-0.1944672210726323, 0.5834428217512867, '3'),
#  ('Alex De Minaur',
#   'Miomir Kecmanovic'): Text(-0.045397613272843085, 0.03404518727427053, '1'),
#  ('Alex De Minaur',
#   'Aljaz Bedene'): Text(0.6402471052442338, 0.07301512140261052, '1'),
#  ('Alex De Minaur',
#   'Mikhail Kukushkin'): Text(0.4876333903520539, -0.03698507211634694, '1'),
#  ('Alex De Minaur',
#   'Pablo Carreno Busta'): Text(0.7261056592043695, 0.19701616290814497, '1'),
#  ('Alex De Minaur',
#   'Jordan Thompson'): Text(0.3428456982921092, -0.07922810591745977, '3'),
#  ('Alex De Minaur',
#   'Jannik Sinner'): Text(0.22955832722828984, 0.9141539045776259, '1'),
#  ('Alex De Minaur',
#   'Philipp Kohlschreiber'): Text(0.08327574694665335, 0.877420098310809, '1'),
#  ('Alex De Minaur',
#   'Jo Wilfried Tsonga'): Text(-0.12321183493787974, 0.7163738311695352, '1'),
#  ('Alex De Minaur',
#   'Tomas Berdych'): Text(-0.1804835541249743, 0.6186058966109497, '1'),
#  ('Alex De Minaur',
#   'Juan Martin Del Potro'): Text(0.048962798237351224, -0.028682055661982064, '1'),
#  ('Alex De Minaur',
#   'Hugo Dellien'): Text(0.6651753473030159, 0.10148557810630476, '1'),
#  ('Alex De Minaur',
#   'Stefano Travaglia'): Text(-0.1804835839272968, 0.21417568455027128, '1'),
#  ('Alex De Minaur',
#   'Yuichi Sugita'): Text(0.15502395173678113, 0.9013344653582758, '1'),
#  ('Alex De Minaur',
#   'Hyeon Chung'): Text(0.22955823782132234, -0.08137235321872749, '1'),
#  ('Egor Gerasimov',
#   'Philipp Kohlschreiber'): Text(0.050991889364494225, 0.8971616633716699, '1'),
#  ('Egor Gerasimov',
#   'Damir Dzumhur'): Text(0.23505498656439558, -0.06377813490067397, '1'),
#  ('Egor Gerasimov',
#   'David Goffin'): Text(0.6759440440079296, 0.1834057551485886, '1'),
#  ('Egor Gerasimov',
#   'Sam Querrey'): Text(0.580953194167654, 0.06625303403290345, '1'),
#  ('Egor Gerasimov',
#   'Matteo Berrettini'): Text(-0.0478424616999672, 0.8417502945617458, '1'),
#  ('Egor Gerasimov',
#   'Benoit Paire'): Text(0.4204575100333333, 0.9041547187407213, '1'),
#  ('Egor Gerasimov',
#   'Dusan Lajovic'): Text(0.3845576621569231, -0.043855788951552066, '1'),
#  ('Egor Gerasimov',
#   'Adrian Mannarino'): Text(-0.25226296939733606, 0.49278617210038456, '3'),
#  ('Egor Gerasimov',
#   'Joao Sousa'): Text(0.7430850407081685, 0.3983179506885608, '1'),
#  ('Egor Gerasimov',
#   'Jiri Vesely'): Text(-0.2380353108354029, 0.3052000538825811, '2'),
#  ('Egor Gerasimov',
#   'Soon Woo Kwon'): Text(0.4204575994403008, -0.03189000745777859, '1'),
#  ('Egor Gerasimov',
#   'Daniil Medvedev'): Text(-0.01632871103226713, 0.009565231750473857, '1'),
#  ('Egor Gerasimov',
#   'Diego Sebastian Schwartzman'): Text(0.5520162417099291, 0.04186820752251419, '1'),
#  ('Egor Gerasimov',
#   'Stefanos Tsitsipas'): Text(-0.22675107865479144, 0.6031843868121476, '1'),
#  ('Egor Gerasimov',
#   'Jan Lennard Struff'): Text(-0.07768153045964721, 0.8184778695408438, '1'),
#  ('Egor Gerasimov',
#   'Felix Auger Aliassime'): Text(0.34785574437517697, 0.9253368982687183, '2'),
#  ('Egor Gerasimov',
#   'Andrey Rublev'): Text(-0.25226296939733606, 0.3794785391825582, '1'),
#  ('Egor Gerasimov',
#   'Alexander Zverev'): Text(0.48903405480588413, -2.468565907243203e-09, '1'),
#  ('Egor Gerasimov',
#   'Jordan Thompson'): Text(0.3105618407099501, -0.05948654085659888, '1'),
#  ('Egor Gerasimov',
#   'Francis Tiafoe'): Text(-0.15549572232236136, 0.13614931505254652, '1'),
#  ('Egor Gerasimov',
#   'Juan Martin Del Potro'): Text(0.016678940655192098, -0.008940490601121176, '1'),
#  ('Egor Gerasimov',
#   'James Duckworth'): Text(0.7217690189498417, 0.2870333031470561, '1'),
#  ('Taylor Harry Fritz',
#   'Gael Monfils'): Text(-0.2888093190556529, 0.43445509955784567, '1'),
#  ('Taylor Harry Fritz',
#   'Diego Sebastian Schwartzman'): Text(0.5183317792785848, 0.059111682307111835, '2'),
#  ('Taylor Harry Fritz',
#   'Roberto Bautista Agut'): Text(0.3141713639002195, -0.0358287420035005, '3'),
#  ('Taylor Harry Fritz',
#   'Alexander Zverev'): Text(0.45534959237453976, 0.017243472316031738, '2'),
#  ('Taylor Harry Fritz',
#   'Jo Wilfried Tsonga'): Text(-0.1891801549513832, 0.7533588710149938, '1'),
#  ('Taylor Harry Fritz',
#   'Novak Djokovic'): Text(-0.2888093190556529, 0.4722965631569375, '2'),
#  ('Taylor Harry Fritz',
#   'Dusan Lajovic'): Text(0.3508731997255788, -0.02661231416695442, '1'),
#  ('Taylor Harry Fritz',
#   'Karen Khachanov'): Text(0.6979939181553989, 0.3407978552204939, '2'),
#  ('Taylor Harry Fritz',
#   'David Goffin'): Text(0.6422595815765852, 0.20064922993318624, '1'),
#  ('Taylor Harry Fritz',
#   'Benoit Paire'): Text(0.38677304760198894, 0.9213981935253188, '2'),
#  ('Taylor Harry Fritz',
#   'Yoshihito Nishioka'): Text(-0.22984897047361005, 0.6895956397441338, '2'),
#  ('Taylor Harry Fritz',
#   'Fabio Fognini'): Text(0.4876333307474089, 0.03698497777224763, '2'),
#  ('Taylor Harry Fritz',
#   'Stefano Travaglia'): Text(-0.24645190394080027, 0.2511607243957298, '2'),
#  ('Taylor Harry Fritz',
#   'Dominic Thiem'): Text(0.1260801521954628, -0.03938886784423273, '2'),
#  ('Taylor Harry Fritz',
#   'Stefanos Tsitsipas'): Text(-0.26043554108613576, 0.6204278615967452, '1'),
#  ('Taylor Harry Fritz',
#   'Jan Lennard Struff'): Text(-0.11136599289099156, 0.8357213443254414, '1'),
#  ('Taylor Harry Fritz',
#   'Andrey Rublev'): Text(-0.28594743182868043, 0.39672201396715584, '2'),
#  ('Taylor Harry Fritz',
#   'Stanislas Wawrinka'): Text(-0.21072189950029505, 0.18450435816276023, '1'),
#  ('Taylor Harry Fritz',
#   'Aljaz Bedene'): Text(0.5742787852307303, 0.11000016124806905, '1'),
#  ('Taylor Harry Fritz',
#   'Filip Krajinovic'): Text(0.35087324442906254, 0.9333639452167699, '1'),
#  ('Taylor Harry Fritz',
#   'Pablo Cuevas'): Text(-0.21072186969797255, 0.7222473026893778, '1'),
#  ('Taylor Harry Fritz',
#   'Sam Querrey'): Text(0.5472687317363096, 0.08349650881750109, '4'),
#  ('Taylor Harry Fritz',
#   'Feliciano Lopez'): Text(0.12608006278849535, 0.9461404690917257, '1'),
#  ('Taylor Harry Fritz',
#   'Richard Gasquet'): Text(-0.16534720784897558, 0.7827521864371005, '2'),
#  ('Taylor Harry Fritz',
#   'Maximilian Marterer'): Text(-0.16534723765129808, 0.1239994744150375, '1'),
#  ('Taylor Harry Fritz',
#   'Kei Nishikori'): Text(0.052728724016079837, 0.9277208158474992, '2'),
#  ('Taylor Harry Fritz',
#   'Hyeon Chung'): Text(0.1635899178078189, -0.044387313373268955, '2'),
#  ('Taylor Harry Fritz',
#   'Jared Donaldson'): Text(0.01730739713082738, -0.0076534773041295745, '1'),
#  ('Taylor Harry Fritz',
#   'Grigor Dimitrov'): Text(-0.05001317346361148, 0.8799429543170665, '1'),
#  ('Taylor Harry Fritz',
#   'Matteo Berrettini'): Text(-0.08152692413131155, 0.8589937693463434, '1'),
#  ('Taylor Harry Fritz',
#   'Miomir Kecmanovic'): Text(-0.11136593328634656, 0.07103022711972906, '1'),
#  ('Taylor Harry Fritz',
#   'Tomas Berdych'): Text(-0.24645187413847777, 0.6555909364564082, '1'),
#  ('Taylor Harry Fritz',
#   'Matthew Ebden'): Text(0.23920518255806564, 0.9525701711586344, '1'),
#  ('Taylor Harry Fritz',
#   'Guido Pella'): Text(0.621910525973965, 0.1687446814105955, '2'),
#  ('Taylor Harry Fritz',
#   'Francis Tiafoe'): Text(-0.1891801847537057, 0.15339278983714416, '1'),
#  ('Taylor Harry Fritz',
#   'Jiri Vesely'): Text(-0.27171977326674723, 0.32244352866717874, '1'),
#  ('Taylor Harry Fritz',
#   'Mischa Zverev'): Text(-0.08152695393363404, 0.04775786170347207, '1'),
#  ('Taylor Harry Fritz',
#   'Mikhail Kukushkin'): Text(0.42166507033855044, -3.227088840596082e-08, '1'),
#  ('Benoit Paire',
#   'Yoshihito Nishioka'): Text(-0.264741023012494, 0.7042421997510713, '1'),
#  ('Benoit Paire',
#   'Diego Sebastian Schwartzman'): Text(0.4834397267397008, 0.07375824231404932, '2'),
#  ('Benoit Paire',
#   'Damir Dzumhur'): Text(0.16647847159416723, -0.03188810010913884, '1'),
#  ('Benoit Paire',
# ...
#  ('Jan Lennard Struff',
#   'Yoshihito Nishioka'): Text(-0.7628800635054745, 0.6185653505511939, '2'),
#  ('Jan Lennard Struff',
#   'Nikoloz Basilashvili'): Text(-0.6723906458619686, 0.025462505825602777, '3'),
#  ('Jan Lennard Struff',
#   'Marin Cilic'): Text(-0.8132711118816502, 0.47640793696894357, '3'),
#  ('Jan Lennard Struff',
#   'Dominic Thiem'): Text(-0.40695094083640165, -0.1104191570371727, '1'),
#  ('Jan Lennard Struff',
#   'Stefanos Tsitsipas'): Text(-0.7934666341180003, 0.5493975724038053, '5'),
#  ('Jan Lennard Struff',
#   'Jeremy Chardy'): Text(-0.6723906160596462, 0.7392285766406552, '2'),
#  ('Jan Lennard Struff',
#   'Mikhail Kukushkin'): Text(-0.11136602269331405, -0.07103032146382837, '1'),
#  ('Jan Lennard Struff',
#   'Pablo Carreno Busta'): Text(0.12710624615900162, 0.16297091356066354, '3'),
#  ('Jan Lennard Struff',
#   'Vasek Pospisil'): Text(-0.2938260017434115, -0.11684882930175888, '1'),
#  ('Jan Lennard Struff',
#   'Alexander Zverev'): Text(-0.07768150065732471, -0.05378681687690823, '3'),
#  ('Jan Lennard Struff',
#   'Jordan Thompson'): Text(-0.25615371475325877, -0.1132733552649412, '1'),
#  ('Jan Lennard Struff',
#   'Richard Gasquet'): Text(-0.6983783008808401, 0.7117218972441606, '1'),
#  ('Jan Lennard Struff',
#   'Francis Tiafoe'): Text(-0.7222112777855703, 0.0823625006442042, '2'),
#  ('Jan Lennard Struff',
#   'Damir Dzumhur'): Text(-0.33166056889881323, -0.11756494930901629, '1'),
#  ('Jan Lennard Struff',
#   'Jo Wilfried Tsonga'): Text(-0.7222112479832477, 0.6823285818220538, '2'),
#  ('Jan Lennard Struff',
#   'Diego Sebastian Schwartzman'): Text(-0.014699313753279708, -0.011918606885828131, '1'),
#  ('Jan Lennard Struff',
#   'Miomir Kecmanovic'): Text(-0.644397026318211, -6.207321090467843e-08, '2'),
#  ('Jan Lennard Struff',
#   'Tomas Berdych'): Text(-0.7794829671703423, 0.5845606472634682, '1'),
#  ('Jan Lennard Struff',
#   'Fabio Fognini'): Text(-0.04539776228445558, -0.03404531142069234, '1'),
#  ('Jan Lennard Struff',
#   'Andrey Rublev'): Text(-0.8189785248605449, 0.3256917247742159, '1'),
#  ('Jan Lennard Struff',
#   'Hugo Dellien'): Text(0.0661759342576479, 0.06744032875882333, '1'),
#  ('Jan Lennard Struff',
#   'Soon Woo Kwon'): Text(-0.14625795602290806, -0.08567682186612091, '1'),
#  ('Jan Lennard Struff',
#   'Stefano Travaglia'): Text(-0.7794829969726648, 0.18013043520278985, '1'),
#  ('Jan Lennard Struff',
#   'Yannick Maden'): Text(0.17208176550280907, 0.3069334910694022, '1'),
#  ('Jeremy Chardy',
#   'Daniil Medvedev'): Text(-0.6110377966322661, -0.0696840611497147, '3'),
#  ('Jeremy Chardy',
#   'Diego Sebastian Schwartzman'): Text(-0.04269284389006983, -0.03738108537767437, '1'),
#  ('Jeremy Chardy',
#   'Stefanos Tsitsipas'): Text(-0.8214601642547904, 0.523935093911959, '3'),
#  ('Jeremy Chardy',
#   'Damir Dzumhur'): Text(-0.35965409903560336, -0.14302742780086253, '1'),
#  ('Jeremy Chardy',
#   'Pablo Carreno Busta'): Text(0.0991127160222115, 0.1375084350688173, '3'),
#  ('Jeremy Chardy',
#   'Nikoloz Basilashvili'): Text(-0.7003841759987588, 2.733375653596326e-08, '2'),
#  ('Jeremy Chardy',
#   'Novak Djokovic'): Text(-0.8498339422243075, 0.3758037954721513, '3'),
#  ('Jeremy Chardy',
#   'Karen Khachanov'): Text(0.13696929498674432, 0.24430508753570768, '1'),
#  ('Jeremy Chardy',
#   'David Goffin'): Text(0.0812349584079306, 0.10415646224840003, '2'),
#  ('Jeremy Chardy',
#   'Fabio Fognini'): Text(-0.0733912924212457, -0.05950778991253858, '2'),
#  ('Jeremy Chardy',
#   'Marin Cilic'): Text(-0.8412646420184404, 0.4509454584770973, '1'),
#  ('Jeremy Chardy',
#   'Andrey Rublev'): Text(-0.846972054997335, 0.30022924628236963, '3'),
#  ('Jeremy Chardy',
#   'Stanislas Wawrinka'): Text(-0.7717465226689497, 0.08801159047797402, '2'),
#  ('Jeremy Chardy',
#   'Mikhail Kukushkin'): Text(-0.13935955283010418, -0.09649279995567461, '2'),
#  ('Jeremy Chardy',
#   'Alexander Zverev'): Text(-0.10567503079411483, -0.07924929536875447, '2'),
#  ('Jeremy Chardy',
#   'Richard Gasquet'): Text(-0.7263718310176301, 0.6862594187523143, '5'),
#  ('Jeremy Chardy',
#   'Francis Tiafoe'): Text(-0.7502048079223603, 0.056900022152357954, '2'),
#  ('Jeremy Chardy',
#   'Jo Wilfried Tsonga'): Text(-0.7502047781200378, 0.6568661033302076, '1'),
#  ('Jeremy Chardy',
#   'Juan Martin Del Potro'): Text(-0.5780301449448069, -0.08818978350130974, '1'),
#  ('Jeremy Chardy',
#   'Sam Querrey'): Text(-0.013755891432345013, -0.012996258867285115, '1'),
#  ('Jeremy Chardy',
#   'Dusan Lajovic'): Text(-0.21015142344307583, -0.12310508185174063, '2'),
#  ('Jeremy Chardy',
#   'Adrian Mannarino'): Text(-0.846972054997335, 0.413536879200196, '2'),
#  ('Jeremy Chardy',
#   'Miomir Kecmanovic'): Text(-0.6723905564550012, -0.025462540565057146, '1'),
#  ('Jeremy Chardy',
#   'Tomas Berdych'): Text(-0.8074764973071324, 0.559098168771622, '1'),
#  ('Jeremy Chardy',
#   'Stefano Travaglia'): Text(-0.8074765271094548, 0.1546679567109436, '1'),
#  ('Jeremy Chardy',
#   'Maximilian Marterer'): Text(-0.7263718608199528, 0.027506706730251296, '1'),
#  ('Richard Gasquet',
#   'Daniil Medvedev'): Text(-0.6370254814534599, -0.09719074054620941, '2'),
#  ('Richard Gasquet',
#   'Diego Sebastian Schwartzman'): Text(-0.06868052871126373, -0.06488776477416908, '3'),
#  ('Richard Gasquet',
#   'Stefanos Tsitsipas'): Text(-0.8474478490759842, 0.4964284145154643, '2'),
#  ('Richard Gasquet',
#   'Roberto Bautista Agut'): Text(-0.272840944089629, -0.1598281890847814, '6'),
#  ('Richard Gasquet',
#   'Damir Dzumhur'): Text(-0.38564178385679726, -0.17053410719735723, '1'),
#  ('Richard Gasquet',
#   'Federico Delbonis'): Text(-0.49795670606889336, -0.15556732123519973, '1'),
#  ('Richard Gasquet',
#   'David Goffin'): Text(0.0552472735867367, 0.07664978285190532, '3'),
#  ('Richard Gasquet',
#   'Roberto Carballes Baena'): Text(-0.8474478192736619, 0.16232424786598315, '1'),
#  ('Richard Gasquet',
#   'Juan Ignacio Londero'): Text(-0.8587321110589183, 0.4603085807955496, '3'),
#  ('Richard Gasquet',
#   'Novak Djokovic'): Text(-0.8758216270455014, 0.3482971160756566, '1'),
#  ('Richard Gasquet',
#   'Dusan Lajovic'): Text(-0.23613910826426973, -0.15061176124823533, '1'),
#  ('Richard Gasquet',
#   'Gael Monfils'): Text(-0.8758216270455014, 0.31045565247656476, '2'),
#  ('Richard Gasquet',
#   'Fabio Fognini'): Text(-0.0993789772424396, -0.08701446930903328, '1'),
#  ('Richard Gasquet',
#   'Dominic Thiem'): Text(-0.4609321557943857, -0.16338831492551364, '1'),
#  ('Richard Gasquet',
#   'Pablo Carreno Busta'): Text(0.0731250312010176, 0.1100017556723226, '1'),
#  ('Richard Gasquet',
#   'Vasek Pospisil'): Text(-0.3478072167013955, -0.16981798719009983, '2'),
#  ('Richard Gasquet',
#   'Alexander Zverev'): Text(-0.13166271561530873, -0.10675597476524917, '1'),
#  ('Richard Gasquet',
#   'Jordan Thompson'): Text(-0.3101349297112428, -0.16624251315328215, '1'),
#  ('Richard Gasquet',
#   'Soon Woo Kwon'): Text(-0.20023917098089208, -0.13864597975446186, '1'),
#  ('Richard Gasquet',
#   'Juan Martin Del Potro'): Text(-0.6040178297660008, -0.11569646289780444, '1'),
#  ('Richard Gasquet',
#   'Tomas Berdych'): Text(-0.8334641821283263, 0.5315914893751273, '1'),
#  ('Richard Gasquet',
#   'Jiri Vesely'): Text(-0.8587320812565957, 0.19844408158589785, '1'),
#  ('Richard Gasquet',
#   'Aljaz Bedene'): Text(-0.012733522759118265, -0.01399928583321186, '1'),
#  ('Richard Gasquet',
#   'Mischa Zverev'): Text(-0.6685392619234826, -0.07624158537780884, '2'),
#  ('Richard Gasquet',
#   'Victor Estrella'): Text(-0.8672523268396344, 0.23531398760897354, '1'),
#  ('Richard Gasquet',
#   'Mikhail Kukushkin'): Text(-0.16534723765129808, -0.12399947935216932, '1'),
#  ('Jo Wilfried Tsonga',
#   'Karen Khachanov'): Text(0.08714866306314278, 0.18740509271710626, '1'),
#  ('Jo Wilfried Tsonga',
#   'Nikoloz Basilashvili'): Text(-0.7502048079223602, -0.05689996748484488, '2'),
#  ('Jo Wilfried Tsonga',
#   'Novak Djokovic'): Text(-0.899654574147909, 0.3189038006535499, '1'),
#  ('Jo Wilfried Tsonga',
#   'Daniil Medvedev'): Text(-0.6608584285558676, -0.12658405596831612, '2'),
#  ('Jo Wilfried Tsonga',
#   'Gael Monfils'): Text(-0.899654574147909, 0.28106233705445804, '1'),
#  ('Jo Wilfried Tsonga',
#   'Fabio Fognini'): Text(-0.12321192434484723, -0.11640778473114, '1'),
#  ('Jo Wilfried Tsonga',
#   'Marin Cilic'): Text(-0.891085273942042, 0.3940454636584959, '1'),
#  ('Jo Wilfried Tsonga',
#   'Dominic Thiem'): Text(-0.4847651028967933, -0.19278163034762036, '1'),
#  ('Jo Wilfried Tsonga',
#   'Andrey Rublev'): Text(-0.8967926869209366, 0.24332925146376821, '3'),
#  ('Jo Wilfried Tsonga',
#   'Miomir Kecmanovic'): Text(-0.7222111883786027, -0.08236253538365856, '1'),
#  ('Jo Wilfried Tsonga',
#   'Sam Querrey'): Text(-0.06357652335594655, -0.06989625368588653, '1'),
#  ('Jo Wilfried Tsonga',
#   'Dusan Lajovic'): Text(-0.25997205536667733, -0.18000507667034205, '1'),
#  ('Jo Wilfried Tsonga',
#   'Guido Pella'): Text(0.011065270881708833, 0.015351918907207884, '1'),
#  ('Jo Wilfried Tsonga',
#   'Pablo Andujar'): Text(-0.8406942255658663, 0.0637632586046166, '1'),
#  ('Jo Wilfried Tsonga',
#   'Aljaz Bedene'): Text(-0.036566469861525897, -0.043392601255318575, '1'),
#  ('Jo Wilfried Tsonga',
#   'Mischa Zverev'): Text(-0.6923722090258901, -0.10563490079991555, '1'),
#  ('Pablo Cuevas',
#   'Diego Sebastian Schwartzman'): Text(-0.1140551905602607, -0.1253926485218918, '2'),
#  ('Pablo Cuevas',
#   'Dominic Thiem'): Text(-0.5063068176433827, -0.22389319867323637, '4'),
#  ('Pablo Cuevas',
#   'Damir Dzumhur'): Text(-0.4310164457057942, -0.23103899094507996, '1'),
#  ('Pablo Cuevas',
#   'Federico Delbonis'): Text(-0.5433313679178904, -0.21607220498292246, '2'),
#  ('Pablo Cuevas',
#   'Marin Cilic'): Text(-0.9126269886886313, 0.3629338953328799, '1'),
#  ('Pablo Cuevas',
#   'Juan Ignacio Londero'): Text(-0.9041067729079153, 0.3998036970478269, '1'),
#  ('Pablo Cuevas',
#   'Dusan Lajovic'): Text(-0.2815137701132667, -0.21111664499595806, '2'),
#  ('Pablo Cuevas',
#   'Joao Sousa'): Text(0.07701360843797866, 0.23105709464415478, '1'),
#  ('Pablo Cuevas',
#   'Francis Tiafoe'): Text(-0.8215671545925511, -0.031111540991859477, '1'),
#  ('Pablo Cuevas',
#   'Karen Khachanov'): Text(0.06560694831655345, 0.15629352439149025, '2'),
#  ('Pablo Cuevas',
#   'Gael Monfils'): Text(-0.9211962888944983, 0.24995076872884203, '1'),
#  ('Pablo Cuevas',
#   'Yoshihito Nishioka'): Text(-0.8622359403124555, 0.5050913089151301, '1'),
#  ('Pablo Cuevas',
#   'Nikoloz Basilashvili'): Text(-0.7717465226689496, -0.0880115358104609, '2'),
#  ('Pablo Cuevas',
#   'Fabio Fognini'): Text(-0.14475363909143657, -0.147519353056756, '1'),
#  ('Pablo Cuevas',
#   'Guido Pella'): Text(-0.010476443864880502, -0.015759649418408128, '1'),
#  ('Pablo Cuevas',
#   'Stefanos Tsitsipas'): Text(-0.8928225109249812, 0.4359235307677416, '3'),
#  ('Pablo Cuevas',
#   'Stanislas Wawrinka'): Text(-0.8431088693391405, 2.7333756591474412e-08, '1'),
#  ('Pablo Cuevas',
#   'Adrian Mannarino'): Text(-0.9183344016675259, 0.32552531605597856, '1'),
#  ('Pablo Cuevas',
#   'Jiri Vesely'): Text(-0.9041067431055927, 0.13793919783817513, '1'),
#  ('Pablo Cuevas',
#   'Simone Bolelli'): Text(-0.5796581564157981, -0.20547354542900992, '1'),
#  ('Pablo Cuevas',
#   'Hyeon Chung'): Text(-0.4687970520310266, -0.2288916442022726, '1'),
#  ('Pablo Cuevas',
#   'Aljaz Bedene'): Text(-0.05810818460811523, -0.07450416958093459, '2'),
#  ('Pablo Cuevas',
#   'Hugo Dellien'): Text(-0.0331799425493331, -0.04603371287724034, '1'),
#  ('Pablo Cuevas',
#   'Yannick Maden'): Text(0.07272588869582808, 0.19345944943333854, '1'),
#  ('Yoshihito Nishioka',
#   'Gael Monfils'): Text(-0.9403233896701358, 0.21729910578359807, '1'),
#  ('Yoshihito Nishioka',
#   'Novak Djokovic'): Text(-0.9403233896701358, 0.2551405693826899, '2'),
#  ('Yoshihito Nishioka',
#   'Karen Khachanov'): Text(0.04647984754091594, 0.12364186144624628, '1'),
#  ('Yoshihito Nishioka',
#   'David Goffin'): Text(-0.009254489037897773, -0.016506763841061367, '2'),
#  ('Yoshihito Nishioka',
#   'Fabio Fognini'): Text(-0.16388073986707408, -0.18017101600199997, '1'),
#  ('Yoshihito Nishioka',
#   'Marin Cilic'): Text(-0.9317540894642689, 0.330282232387636, '1'),
#  ('Yoshihito Nishioka',
#   'Diego Sebastian Schwartzman'): Text(-0.1331822913358982, -0.15804431146713577, '3'),
#  ('Yoshihito Nishioka',
#   'Guido Pella'): Text(-0.02960354464051801, -0.04841131236365209, '1'),
#  ('Yoshihito Nishioka',
#   'Miomir Kecmanovic'): Text(-0.7628800039008296, -0.14612576665451854, '2'),
#  ('Yoshihito Nishioka',
#   'Pablo Carreno Busta'): Text(0.008623268576383125, 0.016845208979355902, '1'),
#  ('Yoshihito Nishioka',
#   'Adrian Mannarino'): Text(-0.9374615024431634, 0.2928736531107346, '1'),
#  ('Yoshihito Nishioka',
#   'Francis Tiafoe'): Text(-0.8406942553681886, -0.06376320393710344, '1'),
#  ('Yoshihito Nishioka',
#   'Tomas Berdych'): Text(-0.8979659447529608, 0.43843494268216066, '1'),
#  ('Yoshihito Nishioka',
#   'Juan Martin Del Potro'): Text(-0.6685195923906353, -0.20885300959077113, '2'),
#  ('Yoshihito Nishioka',
#   'Roberto Bautista Agut'): Text(-0.3373427067142635, -0.2529847357777481, '1'),
#  ('Yoshihito Nishioka',
#   'Nikoloz Basilashvili'): Text(-0.7908736234445871, -0.12066319875570486, '1'),
#  ('Yoshihito Nishioka',
#   'Joao Sousa'): Text(0.05788650766234116, 0.1984054316989108, '1'),
#  ('Yoshihito Nishioka',
#   'Pablo Andujar'): Text(-0.881363041088093, 2.7333756619229987e-08, '1'),
#  ('Yoshihito Nishioka',
#   'Andrey Rublev'): Text(-0.9374615024431634, 0.17956602019290824, '1'),
#  ('Yoshihito Nishioka',
#   'Jordan Thompson'): Text(-0.37463669233587726, -0.25939905984624884, '1'),
#  ('Tomas Berdych',
#   'Diego Sebastian Schwartzman'): Text(-0.14978519500076592, -0.19204901475486133, '1'),
#  ('Tomas Berdych',
#   'Damir Dzumhur'): Text(-0.46674645014629945, -0.2976953571780495, '1'),
#  ('Tomas Berdych',
#   'Juan Martin Del Potro'): Text(-0.6851224960555029, -0.2428577128784967, '1'),
#  ('Tomas Berdych',
#   'Roberto Bautista Agut'): Text(-0.3539456103791312, -0.2869894390654737, '1'),
#  ('Tomas Berdych',
#   'Karen Khachanov'): Text(0.029876943876048223, 0.08963715815852072, '1'),
#  ('Tomas Berdych',
#   'David Goffin'): Text(-0.02585739270276549, -0.05051146712878693, '1'),
#  ('Tomas Berdych',
#   'Francis Tiafoe'): Text(-0.8572971590330565, -0.097767907224829, '1'),
#  ('Tomas Berdych',
#   'Hyeon Chung'): Text(-0.5045270564715318, -0.29554801043524215, '1'),
#  ('Tomas Berdych',
#   'Fabio Fognini'): Text(-0.1804836435319418, -0.21417571928972554, '1'),
#  ('Tomas Berdych',
#   'Stefano Travaglia'): Text(-0.914568878220151, 2.7333756646985563e-08, '1'),
#  ('Tomas Berdych',
#   'Mischa Zverev'): Text(-0.7496439282129848, -0.2034028353585011, '1'),
#  ('Tomas Berdych',
#   'Maximilian Marterer'): Text(-0.8334642119306488, -0.12716122264693566, '1'),
#  ('Stefanos Tsitsipas',
#   'Daniil Medvedev'): Text(-0.7321138146906202, -0.25951506538656466, '6'),
#  ('Stefanos Tsitsipas',
#   'Gael Monfils'): Text(-0.9709099602826616, 0.1481313276362095, '3'),
#  ('Stefanos Tsitsipas',
#   'Diego Sebastian Schwartzman'): Text(-0.16376886194842394, -0.22721208961452433, '1'),
#  ('Stefanos Tsitsipas',
#   'Dominic Thiem'): Text(-0.5560204890315459, -0.3257126397658689, '8'),
#  ('Stefanos Tsitsipas',
#   'Novak Djokovic'): Text(-0.9709099602826616, 0.18597279123530136, '6'),
#  ('Stefanos Tsitsipas',
#   'David Goffin'): Text(-0.039841059650423505, -0.08567454198844993, '5'),
#  ('Stefanos Tsitsipas',
#   'Andrey Rublev'): Text(-0.9680480730556891, 0.11039824204551967, '5'),
#  ('Stefanos Tsitsipas',
#   'Stanislas Wawrinka'): Text(-0.8928225407273038, -0.10181941375887593, '1'),
#  ('Stefanos Tsitsipas',
#   'Aljaz Bedene'): Text(-0.10782185599627847, -0.1763236106735671, '2'),
#  ('Stefanos Tsitsipas',
#   'Alexander Zverev'): Text(-0.22675104885246894, -0.2690802996056044, '6'),
#  ('Stefanos Tsitsipas',
#   'Adrian Mannarino'): Text(-0.9680480730556891, 0.22370587496334604, '2'),
#  ('Stefanos Tsitsipas',
#   'Damir Dzumhur'): Text(-0.48073011709395747, -0.3328584320377125, '3'),
#  ('Stefanos Tsitsipas',
#   'Joao Sousa'): Text(0.027299937049815426, 0.12923765355152225, '1'),
#  ('Stefanos Tsitsipas',
#   'Juan Martin Del Potro'): Text(-0.699106163003161, -0.2780207877381597, '1'),
#  ('Stefanos Tsitsipas',
#   'Karen Khachanov'): Text(0.01589327692839021, 0.05447408329885772, '1'),
#  ('Stefanos Tsitsipas',
#   'Roberto Bautista Agut'): Text(-0.3679292773267892, -0.32215251392513666, '1'),
#  ...}

# %%
# možemo iskoristiti networkx.draw_network da predstavimo egomrežu tog čvora
ego_mreza = nx.ego_graph(G, 'Roger Federer')
print(f"Čvorovi ego mreže igrača Roger Federer su {ego_mreza.nodes}")
plt.figure(figsize=(15,10))
tezine_grana = nx.get_edge_attributes(ego_mreza,'weight')
pos = nx.circular_layout(ego_mreza)
#pos = nx.spring_layout(ego_mreza)
#print(pos)
nx.draw_networkx(ego_mreza, pos)
nx.draw_networkx_edge_labels(ego_mreza, pos, edge_labels = tezine_grana)
# Out:
# Čvorovi ego mreže igrača Roger Federer su ['Oscar Otte', 'Mischa Zverev', 'Milos Raonic', 'Grigor Dimitrov', 'Daniil Medvedev', 'Alexander Zverev', 'Fabio Fognini', 'Nick Kyrgios', 'Casper Ruud', 'Jan Lennard Struff', 'John Millman', 'Matteo Berrettini', 'Jeremy Chardy', 'Richard Gasquet', 'Thanasi Kokkinakis', 'Andreas Seppi', 'Juan Martin Del Potro', 'Denis Shapovalov', 'Jo Wilfried Tsonga', 'Hubert Hurkacz', 'Gilles Simon', 'Robin Haase', 'John Isner', 'Lukas Lacko', 'Steve Johnson', 'Fernando Verdasco', 'Yoshihito Nishioka', 'Rafael Nadal', 'Borna Coric', 'Federico Delbonis', 'Aljaz Bedene', 'Lucas Pouille', 'Guido Pella', 'Dominic Thiem', 'Hyeon Chung', 'Tomas Berdych', 'Leonardo Mayer', 'Marton Fucsovics', 'Roger Federer', 'Kevin Anderson', 'David Goffin', 'Stefanos Tsitsipas', 'Juan Ignacio Londero', 'Denis Istomin', 'Alex De Minaur', 'Radu Albot', 'Tennys Sandgren', 'Damir Dzumhur', 'Taylor Harry Fritz', 'Benoit Paire', 'Ruben Bemelmans', 'Lorenzo Sonego', 'Marin Cilic', 'Albert Ramos', 'Adrian Mannarino', 'Novak Djokovic', 'Roberto Bautista Agut', 'Filip Krajinovic', 'Gael Monfils', 'Jay Clarke', 'Andrey Rublev', 'Dusan Lajovic', 'Joao Sousa', 'Lloyd George Muirhead Harris', 'Sumit Nagal', 'Marius Copil', 'Matthew Ebden', 'Pierre Hugues Herbert', 'Daniel Evans', 'Peter Gojowczyk', 'Stanislas Wawrinka', 'Denis Kudla', 'Kei Nishikori', 'Philipp Kohlschreiber', 'Kyle Edmund']
# {('Oscar Otte',
#   'Jan Lennard Struff'): Text(0.8644843105573803, 0.3422735712077443, '1'),
#  ('Oscar Otte',
#   'Tennys Sandgren'): Text(0.12150249149149156, -0.32671030348708363, '1'),
#  ('Oscar Otte',
#   'Matteo Berrettini'): Text(0.8022995597104667, 0.39826495244627047, '1'),
#  ('Oscar Otte',
#   'Roger Federer'): Text(0.0004385739800069066, -0.020937791254781866, '1'),
#  ('Oscar Otte',
#   'Lorenzo Sonego'): Text(0.28711028611311457, -0.45241348890607475, '1'),
#  ('Oscar Otte',
#   'Radu Albot'): Text(0.09549153122915638, -0.2938926716257877, '1'),
#  ('Mischa Zverev',
#   'Denis Shapovalov'): Text(0.5712879760035414, 0.5364750772984453, '1'),
#  ('Mischa Zverev',
#   'Damir Dzumhur'): Text(0.1484147633870893, -0.315397423899097, '1'),
#  ('Mischa Zverev',
#   'Lucas Pouille'): Text(0.07056430261487062, 0.3008524335820688, '1'),
#  ('Mischa Zverev',
#   'John Millman'): Text(0.8328117137211011, 0.41341136435611114, '1'),
#  ('Mischa Zverev',
#   'Steve Johnson'): Text(0.2853567472714144, 0.49425242856630325, '1'),
#  ('Mischa Zverev',
#   'Lukas Lacko'): Text(0.32396039569876567, 0.5104799122669282, '1'),
#  ('Mischa Zverev',
#   'Rafael Nadal'): Text(0.17953443773777117, 0.4270955476741354, '1'),
#  ('Mischa Zverev',
#   'Benoit Paire'): Text(0.21288961408635865, -0.36873565339503156, '3'),
#  ('Mischa Zverev',
#   'Kevin Anderson'): Text(0.002189072984832563, -0.020827634420987368, '1'),
#  ('Mischa Zverev',
#   'Grigor Dimitrov'): Text(0.9825380147028193, 0.16618388260135428, '1'),
#  ('Mischa Zverev',
#   'Taylor Harry Fritz'): Text(0.1795345271447381, -0.34341774613773957, '1'),
#  ('Mischa Zverev',
#   'Hubert Hurkacz'): Text(0.48777523697612674, 0.5417292565219293, '1'),
#  ('Mischa Zverev',
#   'Guido Pella'): Text(0.050390544407137805, 0.2641565361131494, '1'),
#  ('Mischa Zverev',
#   'Pierre Hugues Herbert'): Text(0.8900931778872689, -0.2687349444002676, '1'),
#  ('Mischa Zverev',
#   'Filip Krajinovic'): Text(0.5296417116352258, -0.4571744322449439, '1'),
#  ('Mischa Zverev',
#   'John Isner'): Text(0.3637865502879477, 0.5234202296203909, '2'),
#  ('Mischa Zverev',
#   'Federico Delbonis'): Text(0.11974886324282458, 0.3685491835426675, '1'),
#  ('Mischa Zverev',
#   'Alexander Zverev'): Text(0.9550191463391653, 0.245207251020519, '1'),
#  ('Mischa Zverev',
#   'Roger Federer'): Text(-0.001314994664015523, 0.020901130226030035, '1'),
#  ('Mischa Zverev',
#   'Philipp Kohlschreiber'): Text(0.9912444353366747, -0.04154554578098131, '1'),
#  ('Mischa Zverev',
#   'Juan Ignacio Londero'): Text(0.03335818938820706, -0.1422233411866172, '1'),
#  ('Mischa Zverev',
#   'Richard Gasquet'): Text(0.7298944451581133, 0.4849407227665725, '2'),
#  ('Mischa Zverev',
#   'Ruben Bemelmans'): Text(0.24824647831326166, -0.3911737920509768, '1'),
#  ('Mischa Zverev',
#   'Jo Wilfried Tsonga'): Text(0.5296416818329035, 0.5408522933859843, '1'),
#  ('Mischa Zverev',
#   'Tomas Berdych'): Text(0.009172621366632772, 0.14579473555979225, '1'),
#  ('Mischa Zverev',
#   'Leonardo Mayer'): Text(0.002189072984832563, 0.10450553281493064, '2'),
#  ('Mischa Zverev',
#   'Hyeon Chung'): Text(0.019586715068171612, 0.18635487664369393, '1'),
#  ('Mischa Zverev',
#   'Juan Martin Del Potro'): Text(0.6124218713963269, 0.5286283940582465, '1'),
#  ('Milos Raonic',
#   'Denis Shapovalov'): Text(0.566039548628261, 0.5780205278610069, '2'),
#  ('Milos Raonic',
#   'Jan Lennard Struff'): Text(0.8574823145380774, 0.4256579432511178, '2'),
#  ('Milos Raonic',
#   'Novak Djokovic'): Text(0.4407338367817602, -0.4138765753289296, '3'),
#  ('Milos Raonic',
#   'Dusan Lajovic'): Text(0.686755732643171, -0.3775472166219549, '2'),
#  ('Milos Raonic',
#   'Daniil Medvedev'): Text(0.9651861787888525, 0.24781769603525744, '3'),
#  ('Milos Raonic',
#   'Borna Coric'): Text(0.14316636581413122, 0.440620735602699, '1'),
#  ('Milos Raonic',
#   'Marin Cilic'): Text(0.31871199812580764, -0.38525663036564856, '2'),
#  ('Milos Raonic',
#   'Dominic Thiem'): Text(0.028109762012926698, 0.26744668269254146, '2'),
#  ('Milos Raonic',
#   'Guido Pella'): Text(0.04514211703185744, 0.30570198667571097, '1'),
#  ('Milos Raonic',
#   'Alex De Minaur'): Text(0.06531584543726798, -0.17562909207614458, '1'),
#  ('Milos Raonic',
#   'Stanislas Wawrinka'): Text(0.9497707785685294, -0.1199838648111113, '3'),
#  ('Milos Raonic',
#   'Aljaz Bedene'): Text(0.08848947560520903, 0.37727697244161085, '4'),
#  ('Milos Raonic',
#   'John Isner'): Text(0.3585381229126674, 0.5649656801829525, '2'),
#  ('Milos Raonic',
#   'Kyle Edmund'): Text(0.9912444353366747, 0.04154545220168929, '1'),
#  ('Milos Raonic',
#   'Peter Gojowczyk'): Text(0.9311513306779338, -0.15749247160910096, '1'),
#  ('Milos Raonic',
#   'Roger Federer'): Text(-0.006563422039295885, 0.06244658078859158, '2'),
#  ('Milos Raonic',
#   'Steve Johnson'): Text(0.28010831989613405, 0.5357978791288648, '2'),
#  ('Milos Raonic',
#   'Lucas Pouille'): Text(0.06531587523959026, 0.3423978841446304, '3'),
#  ('Milos Raonic',
#   'Hyeon Chung'): Text(0.01433828769289125, 0.22790032720625547, '1'),
#  ('Milos Raonic',
#   'Juan Martin Del Potro'): Text(0.6071734440210464, 0.570173844620808, '2'),
#  ('Milos Raonic',
#   'Lukas Lacko'): Text(0.31871196832348536, 0.5520253628294898, '1'),
#  ('Milos Raonic',
#   'Stefanos Tsitsipas'): Text(0.014338257890568917, -0.061131535137769685, '2'),
#  ('Milos Raonic',
#   'Philipp Kohlschreiber'): Text(0.9859960079613944, -9.521841976001255e-08, '1'),
#  ('Milos Raonic',
#   'Filip Krajinovic'): Text(0.5243932842599455, -0.4156289816823823, '1'),
#  ('Milos Raonic',
#   'Alexander Zverev'): Text(0.9497707189638849, 0.2867527015830805, '1'),
#  ('Milos Raonic',
#   'Marton Fucsovics'): Text(-0.006563422039295885, 0.10432221314253935, '2'),
#  ('Milos Raonic',
#   'Jo Wilfried Tsonga'): Text(0.5243932544576232, 0.5823977439485458, '2'),
#  ('Milos Raonic',
#   'Jeremy Chardy'): Text(0.7609113760026724, 0.5055483431823216, '1'),
#  ('Milos Raonic',
#   'David Goffin'): Text(0.0039242237936747415, -0.02057151326315719, '1'),
#  ('Milos Raonic',
#   'John Millman'): Text(0.8275632863458207, 0.4549568149186727, '1'),
#  ('Milos Raonic',
#   'Grigor Dimitrov'): Text(0.9772895873275389, 0.20772933316391584, '1'),
#  ('Milos Raonic',
#   'Adrian Mannarino'): Text(0.3993073198369099, -0.4077592314447247, '2'),
#  ('Milos Raonic',
#   'Joao Sousa'): Text(0.7246460475851553, -0.3597173812606483, '1'),
#  ('Milos Raonic',
#   'Nick Kyrgios'): Text(0.9094586375096316, 0.3600801384059167, '1'),
#  ('Milos Raonic',
#   'Gilles Simon'): Text(0.44073375110008356, 0.5806453375950931, '1'),
#  ('Milos Raonic',
#   'Tomas Berdych'): Text(0.003924193991352409, 0.1873401861223538, '1'),
#  ('Milos Raonic',
#   'Robin Haase'): Text(0.3993073496392322, 0.5745279937108883, '1'),
#  ('Milos Raonic',
#   'Pierre Hugues Herbert'): Text(0.8848447505119886, -0.22718949383770604, '2'),
#  ('Milos Raonic',
#   'Denis Istomin'): Text(0.04514211703185744, -0.13893319460722514, '1'),
#  ('Milos Raonic',
#   'Leonardo Mayer'): Text(-0.0030593543904477993, 0.14605098337749217, '1'),
#  ('Milos Raonic',
#   'Daniel Evans'): Text(0.9094585481026648, -0.19331149534904235, '1'),
#  ('Grigor Dimitrov',
#   'Denis Shapovalov'): Text(0.5573331279944055, 0.6189811078484675, '2'),
#  ('Grigor Dimitrov',
#   'Jan Lennard Struff'): Text(0.848775893904222, 0.4666185232385784, '2'),
#  ('Grigor Dimitrov',
#   'Yoshihito Nishioka'): Text(0.19893479587954505, 0.5349195748884163, '2'),
#  ('Grigor Dimitrov',
#   'Roger Federer'): Text(-0.015269842673151401, 0.1034071607760522, '2'),
#  ('Grigor Dimitrov',
#   'Dominic Thiem'): Text(0.01940334137907118, 0.30840726268000207, '1'),
#  ('Grigor Dimitrov',
#   'Stefanos Tsitsipas'): Text(0.005631837256713401, -0.02017095515030906, '2'),
#  ('Grigor Dimitrov',
#   'Philipp Kohlschreiber'): Text(0.9772895873275389, 0.040960484769040864, '1'),
#  ('Grigor Dimitrov',
#   'Roberto Bautista Agut'): Text(0.4738202967660562, -0.3755453648308667, '1'),
#  ('Grigor Dimitrov',
#   'Tennys Sandgren'): Text(0.10579407483833325, -0.20236535145624956, '1'),
#  ('Grigor Dimitrov',
#   'Damir Dzumhur'): Text(0.13445991537795343, -0.23289139334907483, '3'),
#  ('Grigor Dimitrov',
#   'Kyle Edmund'): Text(0.9825380147028193, 0.08250603218914991, '2'),
#  ('Grigor Dimitrov',
#   'Filip Krajinovic'): Text(0.51568686362609, -0.3746684016949217, '1'),
#  ('Grigor Dimitrov',
#   'Borna Coric'): Text(0.1344599451802757, 0.4815813155901596, '1'),
#  ('Grigor Dimitrov',
#   'Marin Cilic'): Text(0.3100055774919521, -0.34429605037818795, '2'),
#  ('Grigor Dimitrov',
#   'David Goffin'): Text(-0.004782196840180775, 0.020389066724303434, '4'),
#  ('Grigor Dimitrov',
#   'Juan Ignacio Londero'): Text(0.01940334137907118, -0.05971731063659502, '1'),
#  ('Grigor Dimitrov',
#   'John Millman'): Text(0.8188568657119651, 0.4959173949061333, '2'),
#  ('Grigor Dimitrov',
#   'Novak Djokovic'): Text(0.4320274161479047, -0.37291599534146896, '3'),
#  ('Grigor Dimitrov',
#   'Dusan Lajovic'): Text(0.6780493120093155, -0.3365866366344943, '1'),
#  ('Grigor Dimitrov',
#   'Rafael Nadal'): Text(0.1655795897286353, 0.5096015782241575, '3'),
#  ('Grigor Dimitrov',
#   'Daniil Medvedev'): Text(0.956479758154997, 0.28877827602271805, '1'),
#  ('Grigor Dimitrov',
#   'Daniel Evans'): Text(0.9007521274688093, -0.15235091536158174, '3'),
#  ('Grigor Dimitrov',
#   'Nick Kyrgios'): Text(0.9007522168757762, 0.4010407183933773, '2'),
#  ('Grigor Dimitrov',
#   'Kevin Anderson'): Text(-0.011765775024303315, 0.06167839612903481, '1'),
#  ('Grigor Dimitrov',
#   'Taylor Harry Fritz'): Text(0.16557967913560223, -0.26091171558771736, '1'),
#  ('Grigor Dimitrov',
#   'Guido Pella'): Text(0.03643569639800193, 0.3466625666631716, '1'),
#  ('Grigor Dimitrov',
#   'Andrey Rublev'): Text(0.6388001452809866, -0.35118327765432056, '3'),
#  ('Grigor Dimitrov',
#   'Stanislas Wawrinka'): Text(0.9410643579346739, -0.07902328482365067, '6'),
#  ('Grigor Dimitrov',
#   'Fernando Verdasco'): Text(0.23429155579832006, 0.5573576539397171, '4'),
#  ('Grigor Dimitrov',
#   'Marton Fucsovics'): Text(-0.015269842673151401, 0.14528279312999998, '2'),
#  ('Grigor Dimitrov',
#   'Jeremy Chardy'): Text(0.7522049553688168, 0.5465089231697822, '1'),
#  ('Grigor Dimitrov',
#   'Federico Delbonis'): Text(0.1057940152336887, 0.4510552140926897, '1'),
#  ('Grigor Dimitrov',
#   'Matteo Berrettini'): Text(0.7865911430573084, 0.5226099044771045, '2'),
#  ('Grigor Dimitrov',
#   'Kei Nishikori'): Text(0.9685831666936834, 5.379319174825259e-08, '2'),
#  ('Grigor Dimitrov',
#   'Adrian Mannarino'): Text(0.3906008992030544, -0.3667986514572641, '1'),
#  ('Grigor Dimitrov',
#   'Steve Johnson'): Text(0.27140189926227853, 0.5767584591163254, '1'),
#  ('Grigor Dimitrov',
#   'Gilles Simon'): Text(0.43202733046622804, 0.6216059175825537, '1'),
#  ('Grigor Dimitrov',
#   'Andreas Seppi'): Text(0.6388000707751809, 0.5998732296977276, '1'),
#  ('Grigor Dimitrov',
#   'Pierre Hugues Herbert'): Text(0.8761383298781331, -0.18622891385024543, '1'),
#  ('Grigor Dimitrov',
#   'Alex De Minaur'): Text(0.05660942480341247, -0.13466851208868397, '1'),
#  ('Grigor Dimitrov',
#   'Radu Albot'): Text(0.07978311457599807, -0.16954771959495363, '1'),
#  ('Daniil Medvedev',
#   'Rafael Nadal'): Text(0.15347618118994888, 0.5496899410954992, '4'),
#  ('Daniil Medvedev',
#   'Novak Djokovic'): Text(0.4199240076092183, -0.33282763247012737, '5'),
#  ('Daniil Medvedev',
#   'Roberto Bautista Agut'): Text(0.4617168882273698, -0.3354570019595251, '1'),
#  ('Daniil Medvedev',
#   'Dusan Lajovic'): Text(0.6659459034706291, -0.2964982737631527, '2'),
#  ('Daniil Medvedev',
#   'Nick Kyrgios'): Text(0.8886488083370898, 0.4411290812647189, '2'),
#  ('Daniil Medvedev',
#   'David Goffin'): Text(-0.016885605378867186, 0.06047742959564503, '3'),
#  ('Daniil Medvedev',
#   'Kevin Anderson'): Text(-0.023869183562989726, 0.1017667590003764, '2'),
#  ('Daniil Medvedev',
#   'Gilles Simon'): Text(0.41992392192754163, 0.6616942804538952, '2'),
#  ('Daniil Medvedev',
#   'Gael Monfils'): Text(0.5452298014121054, -0.33020282273604123, '2'),
#  ('Daniil Medvedev',
#   'Borna Coric'): Text(0.1223565366415893, 0.5216696784615011, '5'),
#  ('Daniil Medvedev',
#   'Dominic Thiem'): Text(0.007299932840384771, 0.34849562555134367, '5'),
#  ('Daniil Medvedev',
#   'Guido Pella'): Text(0.024332287859315516, 0.3867509295345132, '1'),
#  ('Daniil Medvedev',
#   'Stefanos Tsitsipas'): Text(-0.00647157128197301, 0.019917407721032537, '6'),
#  ('Daniil Medvedev',
#   'Denis Shapovalov'): Text(0.5452297194557191, 0.6590694707198091, '2'),
#  ('Daniil Medvedev',
#   'Stanislas Wawrinka'): Text(0.9289609493959875, -0.038934921952309076, '2'),
#  ('Daniil Medvedev',
#   'Fernando Verdasco'): Text(0.22218814725963365, 0.5974460168110587, '3'),
#  ('Daniil Medvedev',
#   'Marton Fucsovics'): Text(-0.027373251211837812, 0.18537115600134157, '3'),
#  ('Daniil Medvedev',
#   'Pierre Hugues Herbert'): Text(0.8640349213394467, -0.14614055097890383, '2'),
#  ('Daniil Medvedev',
#   'Jeremy Chardy'): Text(0.7401015468301304, 0.5865972860411238, '3'),
#  ('Daniil Medvedev',
#   'Filip Krajinovic'): Text(0.5035834550874035, -0.3345800388235801, '1'),
#  ('Daniil Medvedev',
#   'Kyle Edmund'): Text(0.9704346061641329, 0.12259439506049151, '3'),
#  ('Daniil Medvedev',
#   'Andreas Seppi'): Text(0.6266966622364945, 0.6399615925690691, '2'),
#  ('Daniil Medvedev',
#   'Alexander Zverev'): Text(0.928960889791343, 0.3678016444418828, '6'),
#  ('Daniil Medvedev',
#   'Roger Federer'): Text(-0.027373251211837812, 0.14349552364739382, '3'),
#  ('Daniil Medvedev',
#   'Richard Gasquet'): Text(0.7038361886102911, 0.6075351161879363, '2'),
#  ('Daniil Medvedev',
#   'Adrian Mannarino'): Text(0.378497490664368, -0.3267102885859225, '2'),
#  ('Daniil Medvedev',
#   'Steve Johnson'): Text(0.2592984907235921, 0.616846821987667, '3'),
#  ('Daniil Medvedev',
#   'Kei Nishikori'): Text(0.956479758154997, 0.04008841666453335, '4'),
#  ('Daniil Medvedev',
#   'Robin Haase'): Text(0.3784975204666903, 0.6555769365696904, '2'),
#  ('Daniil Medvedev',
#   'Joao Sousa'): Text(0.7038362184126133, -0.2786684384018461, '3'),
#  ('Daniil Medvedev',
#   'Lucas Pouille'): Text(0.04450604606704833, 0.4234468270034326, '3'),
#  ('Daniil Medvedev',
#   'Hyeon Chung'): Text(-0.006471541479650678, 0.3089492700650577, '1'),
#  ('Daniil Medvedev',
#   'Jan Lennard Struff'): Text(0.8366724853655356, 0.50670688610992, '1'),
#  ('Daniil Medvedev',
#   'Philipp Kohlschreiber'): Text(0.9651861787888525, 0.08104884764038246, '1'),
#  ('Daniil Medvedev',
#   'Casper Ruud'): Text(0.8640348915371243, 0.47500719896267174, '1'),
#  ('Daniil Medvedev',
#   'Jo Wilfried Tsonga'): Text(0.5035834252850813, 0.6634466868073481, '2'),
#  ('Daniil Medvedev',
#   'Federico Delbonis'): Text(0.09369060669500229, 0.4911435769640313, '1'),
#  ('Daniil Medvedev',
#   'Marin Cilic'): Text(0.2979021689532657, -0.30420768750684635, '1'),
#  ('Daniil Medvedev',
#   'John Isner'): Text(0.3377282937401255, 0.6460146230417547, '1'),
#  ('Daniil Medvedev',
#   'Matteo Berrettini'): Text(0.774487734518622, 0.5626982673484462, '1'),
#  ('Daniil Medvedev',
#   'Benoit Paire'): Text(0.18683135753853636, -0.24614125997366776, '1'),
#  ('Daniil Medvedev',
#   'Albert Ramos'): Text(0.3377283682459312, -0.31714797505798675, '1'),
#  ('Daniil Medvedev',
#   'Fabio Fognini'): Text(0.9103415015053917, 0.40531017673406666, '3'),
#  ('Daniil Medvedev',
#   'Peter Gojowczyk'): Text(0.9103415015053917, -0.07644352875029875, '1'),
#  ('Daniil Medvedev',
#   'Andrey Rublev'): Text(0.6266967367423002, -0.31109491478297896, '3'),
#  ('Daniil Medvedev',
#   'Lloyd George Muirhead Harris'): Text(0.7401014872254859, -0.2577306976620005, '1'),
#  ('Daniil Medvedev',
#   'Aljaz Bedene'): Text(0.0676796464326671, 0.45832591530041306, '1'),
#  ('Daniil Medvedev',
#   'Alex De Minaur'): Text(0.044506016264726056, -0.09458014921734237, '3'),
#  ('Daniil Medvedev',
#   'Thanasi Kokkinakis'): Text(0.665945992877596, 0.6253648919445983, '1'),
#  ('Daniil Medvedev',
#   'Radu Albot'): Text(0.06767970603731166, -0.12945935672361203, '1'),
#  ('Alexander Zverev',
#   'Rafael Nadal'): Text(0.13806072136498126, 0.5886249466433222, '4'),
#  ('Alexander Zverev',
#   'Denis Shapovalov'): Text(0.5298142596307515, 0.6980044762676323, '3'),
#  ('Alexander Zverev',
#   'Kevin Anderson'): Text(-0.03928464338795734, 0.14070176454819952, '1'),
#  ('Alexander Zverev',
#   'Jan Lennard Struff'): Text(0.821257025540568, 0.5456418916577431, '3'),
#  ('Alexander Zverev',
#   'Roger Federer'): Text(-0.04278871103680543, 0.18243052919521693, '2'),
#  ('Alexander Zverev',
#   'Dominic Thiem'): Text(-0.008115526984582844, 0.38743063109916676, '5'),
#  ('Alexander Zverev',
#   'Stefanos Tsitsipas'): Text(-0.021887031106940624, 0.05885241326885565, '6'),
#  ('Alexander Zverev',
#   'Philipp Kohlschreiber'): Text(0.9497707189638849, 0.11998385318820558, '2'),
#  ('Alexander Zverev',
#   'Roberto Bautista Agut'): Text(0.44630142840240217, -0.29652199641170196, '2'),
#  ('Alexander Zverev',
#   'Damir Dzumhur'): Text(0.1069410470142994, -0.1538680249299101, '1'),
#  ('Alexander Zverev',
#   'Kyle Edmund'): Text(0.9550191463391653, 0.1615294006083146, '2'),
#  ('Alexander Zverev',
#   'Filip Krajinovic'): Text(0.4881679952624359, -0.295645033275757, '1'),
#  ('Alexander Zverev',
#   'Borna Coric'): Text(0.10694107681662168, 0.5606046840093243, '3'),
#  ('Alexander Zverev',
#   'Novak Djokovic'): Text(0.40450854778425066, -0.2938926269223042, '5'),
#  ('Alexander Zverev',
#   'Nick Kyrgios'): Text(0.8732333485121222, 0.480064086812542, '3'),
#  ('Alexander Zverev',
#   'David Goffin'): Text(-0.0323010652038348, 0.09941243514346815, '2'),
#  ('Alexander Zverev',
#   'Fabio Fognini'): Text(0.8949260416804241, 0.4442451822818898, '2'),
#  ('Alexander Zverev',
#   'Taylor Harry Fritz'): Text(0.1380608107719482, -0.18188834716855265, '2'),
#  ('Alexander Zverev',
#   'Alex De Minaur'): Text(0.02909055643975844, -0.055645143669519254, '5'),
#  ('Alexander Zverev',
#   'John Isner'): Text(0.32231283391515786, 0.6849496285895779, '3'),
#  ('Alexander Zverev',
#   'Andreas Seppi'): Text(0.6112812024115268, 0.6788965981168923, '1'),
#  ('Alexander Zverev',
#   'Matteo Berrettini'): Text(0.7590722746936543, 0.6016332728962692, '3'),
#  ('Alexander Zverev',
#   'Kei Nishikori'): Text(0.9410642983300294, 0.07902342221235646, '2'),
#  ('Alexander Zverev',
#   'Robin Haase'): Text(0.36308206064172266, 0.6945119421175135, '3'),
#  ('Alexander Zverev',
#   'Joao Sousa'): Text(0.6884207585876457, -0.23973343285402296, '1'),
#  ('Alexander Zverev',
#   'Hyeon Chung'): Text(-0.021887001304618292, 0.3478842756128808, '2'),
#  ('Alexander Zverev',
#   'Marius Copil'): Text(0.791338086755278, -0.1682040446412392, '1'),
#  ('Alexander Zverev',
#   'Juan Martin Del Potro'): Text(0.5709481550235369, 0.6901577930274334, '1'),
#  ('Alexander Zverev',
#   'Federico Delbonis'): Text(0.07827514687003467, 0.5300785825118545, '2'),
#  ('Alexander Zverev',
#   'Marin Cilic'): Text(0.2824867091282981, -0.2652726819590232, '2'),
#  ('Alexander Zverev',
#   'Jeremy Chardy'): Text(0.7246860870051628, 0.625532291588947, '2'),
#  ('Alexander Zverev',
#   'Hubert Hurkacz'): Text(0.44630152060333683, 0.7032586554911162, '1'),
#  ('Alexander Zverev',
#   'Juan Ignacio Londero'): Text(-0.008115526984582844, 0.01930605778256969, '1'),
#  ('Alexander Zverev',
#   'John Millman'): Text(0.7913379973483111, 0.574940763325298, '2'),
#  ('Alexander Zverev',
#   'Dusan Lajovic'): Text(0.6505304436456615, -0.2575632682153296, '2'),
#  ('Alexander Zverev',
#   'Fernando Verdasco'): Text(0.20677268743466604, 0.6363810223588818, '3'),
#  ('Alexander Zverev',
#   'Adrian Mannarino'): Text(0.3630820308394004, -0.2877752830380994, '3'),
#  ('Alexander Zverev',
#   'Steve Johnson'): Text(0.2438830308986245, 0.6557818275354901, '1'),
#  ('Alexander Zverev',
#   'Richard Gasquet'): Text(0.6884207287853235, 0.6464701217357595, '1'),
#  ('Alexander Zverev',
#   'Stanislas Wawrinka'): Text(0.9135454895710199, 8.359551403880339e-08, '2'),
#  ('Alexander Zverev',
#   'Peter Gojowczyk'): Text(0.8949260416804241, -0.037508523202475635, '2'),
#  ('Alexander Zverev',
#   'Pierre Hugues Herbert'): Text(0.8486194615144791, -0.10720554543108071, '1'),
#  ('Alexander Zverev',
#   'Denis Istomin'): Text(0.008916828034347901, -0.018949246200599817, '1'),
#  ('Alexander Zverev',
#   'Andrey Rublev'): Text(0.6112812769173326, -0.2721599092351559, '2'),
#  ('Alexander Zverev',
#   'Lloyd George Muirhead Harris'): Text(0.7246860274005182, -0.2187956921141774, '1'),
#  ('Alexander Zverev',
#   'Aljaz Bedene'): Text(0.05226418660769949, 0.49726092084823614, '2'),
#  ('Alexander Zverev',
#   'Leonardo Mayer'): Text(-0.03928464338795734, 0.2660349317841175, '1'),
#  ('Alexander Zverev',
#   'Radu Albot'): Text(0.052264246212344045, -0.09052435117578891, '1'),
#  ('Fabio Fognini',
#   'Rafael Nadal'): Text(0.1194413330790301, 0.6261334789355062, '3'),
#  ('Fabio Fognini',
#   'Gael Monfils'): Text(0.5111949533011866, -0.25375928489603417, '1'),
#  ('Fabio Fognini',
#   'Yoshihito Nishioka'): Text(0.15279653922993985, 0.651451475599765, '1'),
#  ('Fabio Fognini',
#   'Dominic Thiem'): Text(-0.02673491527053401, 0.42493916339135074, '2'),
#  ('Fabio Fognini',
#   'Philipp Kohlschreiber'): Text(0.9311513306779338, 0.15749238548038952, '2'),
#  ('Fabio Fognini',
#   'Roberto Bautista Agut'): Text(0.42768204011645106, -0.2590134641195181, '2'),
#  ('Fabio Fognini',
#   'Tennys Sandgren'): Text(0.05965581818872806, -0.08583345074490092, '4'),
#  ('Fabio Fognini',
#   'Damir Dzumhur'): Text(0.08832165872834824, -0.11635949263772619, '1'),
#  ('Fabio Fognini',
#   'Kyle Edmund'): Text(0.9363997580532141, 0.19903793290049854, '2'),
#  ('Fabio Fognini',
#   'Borna Coric'): Text(0.08832168853067052, 0.5981132163015083, '1'),
#  ('Fabio Fognini',
#   'Marton Fucsovics'): Text(-0.06140809932275659, 0.26181469384134864, '4'),
#  ('Fabio Fognini',
#   'Jo Wilfried Tsonga'): Text(0.46954857717416243, 0.7398902246473551, '1'),
#  ('Fabio Fognini',
#   'Federico Delbonis'): Text(0.05965575858408351, 0.5675871148040383, '2'),
#  ('Fabio Fognini',
#   'Taylor Harry Fritz'): Text(0.11944142248599704, -0.14437981487636872, '2'),
#  ('Fabio Fognini',
#   'Jeremy Chardy'): Text(0.7060666987192117, 0.6630408238811308, '2'),
#  ('Fabio Fognini',
#   'Juan Martin Del Potro'): Text(0.5523287667375858, 0.7276663253196173, '2'),
#  ('Fabio Fognini',
#   'John Millman'): Text(0.7727186090623599, 0.612449295617482, '2'),
#  ('Fabio Fognini',
#   'John Isner'): Text(0.30369344562920664, 0.7224581608817617, '1'),
#  ('Fabio Fognini',
#   'Dusan Lajovic'): Text(0.6319110553597104, -0.22005473592314564, '1'),
#  ('Fabio Fognini',
#   'Fernando Verdasco'): Text(0.18815329914871487, 0.6738895546510657, '2'),
#  ('Fabio Fognini',
#   'Adrian Mannarino'): Text(0.34446264255344916, -0.2502667507459154, '2'),
#  ('Fabio Fognini',
#   'Steve Johnson'): Text(0.22526364261267334, 0.6932903598276741, '1'),
#  ('Fabio Fognini',
#   'Richard Gasquet'): Text(0.6698013404993722, 0.6839786540279433, '1'),
#  ('Fabio Fognini',
#   'Gilles Simon'): Text(0.38588907381662285, 0.7381378182939023, '1'),
#  ('Fabio Fognini',
#   'Matthew Ebden'): Text(0.8026376074522945, -0.10139673008846731, '1'),
#  ('Fabio Fognini',
#   'Daniel Evans'): Text(0.8546138708192041, -0.0358190146502331, '1'),
#  ('Fabio Fognini',
#   'Nick Kyrgios'): Text(0.854613960226171, 0.517572619104726, '1'),
#  ('Fabio Fognini',
#   'Casper Ruud'): Text(0.8300000434262056, 0.5514507368026788, '2'),
#  ('Fabio Fognini',
#   'Marin Cilic'): Text(0.26386732084234693, -0.2277641496668393, '1'),
#  ('Fabio Fognini',
#   'Stefanos Tsitsipas'): Text(-0.04050641939289179, 0.09636094556103958, '2'),
#  ('Fabio Fognini',
#   'Jan Lennard Struff'): Text(0.8026376372546168, 0.583150423949927, '1'),
#  ('Fabio Fognini',
#   'Denis Shapovalov'): Text(0.5111948713448004, 0.7355130085598162, '2'),
#  ('Fabio Fognini',
#   'Aljaz Bedene'): Text(0.033644798321748326, 0.5347694531404201, '2'),
#  ('Fabio Fognini',
#   'Filip Krajinovic'): Text(0.46954860697648476, -0.2581365009835731, '1'),
#  ('Fabio Fognini',
#   'Peter Gojowczyk'): Text(0.876306653394473, 9.08970829160971e-09, '3'),
#  ('Fabio Fognini',
#   'Roger Federer'): Text(-0.06140809932275659, 0.21993906148740086, '1'),
#  ('Fabio Fognini',
#   'Radu Albot'): Text(0.03364485792639288, -0.05301581888360499, '3'),
#  ('Fabio Fognini',
#   'Tomas Berdych'): Text(-0.0509204832921083, 0.3448326668211631, '1'),
#  ('Fabio Fognini',
#   'Leonardo Mayer'): Text(-0.05790403167390851, 0.30354346407630145, '3'),
#  ('Fabio Fognini',
#   'Lucas Pouille'): Text(0.010471197956129552, 0.4998903648434396, '1'),
#  ('Fabio Fognini',
#   'Guido Pella'): Text(-0.009702560251603265, 0.4631944673745202, '1'),
#  ('Fabio Fognini',
#   'Andreas Seppi'): Text(0.5926618141255756, 0.7164051304090763, '1'),
#  ('Fabio Fognini',
#   'Andrey Rublev'): Text(0.5926618886313814, -0.23465137694297192, '3'),
#  ('Fabio Fognini',
#   'Lukas Lacko'): Text(0.2638672910400246, 0.709517843528299, '1'),
#  ('Fabio Fognini',
#   'Hyeon Chung'): Text(-0.04050638959056946, 0.38539280790506475, '1'),
#  ('Fabio Fognini',
#   'Ruben Bemelmans'): Text(0.1881533736545206, -0.192135860789606, '1'),
#  ('Nick Kyrgios',
#   'Rafael Nadal'): Text(0.09774863991072807, 0.6619523834661584, '3'),
#  ('Nick Kyrgios',
#   'Jan Lennard Struff'): Text(0.7809449440863148, 0.6189693284805793, '3'),
#  ('Nick Kyrgios',
#   'Yoshihito Nishioka'): Text(0.13110384606163783, 0.6872703801304172, '2'),
#  ('Nick Kyrgios',
#   'Stefanos Tsitsipas'): Text(-0.062199112561193814, 0.13217985009169178, '2'),
#  ('Nick Kyrgios',
#   'Kyle Edmund'): Text(0.914707064884912, 0.23485683743115077, '2'),
#  ('Nick Kyrgios',
#   'Borna Coric'): Text(0.06662899536236849, 0.6339321208321604, '2'),
#  ('Nick Kyrgios',
#   'Jo Wilfried Tsonga'): Text(0.4478558840058604, 0.7757091291780074, '1'),
#  ('Nick Kyrgios',
#   'Denis Kudla'): Text(0.8886488083370898, 0.11226239185572293, '1'),
#  ('Nick Kyrgios',
#   'John Millman'): Text(0.751025915894058, 0.6482682001481341, '1'),
#  ('Nick Kyrgios',
#   'John Isner'): Text(0.2820007524609046, 0.758277065412414, '1'),
#  ('Nick Kyrgios',
#   'Dusan Lajovic'): Text(0.6102183621914083, -0.18423583139249344, '2'),
#  ('Nick Kyrgios',
#   'Steve Johnson'): Text(0.20357094944437132, 0.7291092643583262, '1'),
#  ('Nick Kyrgios',
#   'Roberto Bautista Agut'): Text(0.40598934694814903, -0.22319455958886586, '1'),
#  ('Nick Kyrgios',
#   'Casper Ruud'): Text(0.8083073502579036, 0.5872696413333309, '1'),
#  ('Nick Kyrgios',
#   'Marin Cilic'): Text(0.2421746276740449, -0.1919452451361871, '1'),
#  ('Nick Kyrgios',
#   'Andrey Rublev'): Text(0.5709691954630793, -0.19883247241231972, '2'),
#  ('Nick Kyrgios',
#   'Stanislas Wawrinka'): Text(0.8732334081167668, 0.07332752041835017, '2'),
#  ('Nick Kyrgios',
#   'Jeremy Chardy'): Text(0.6843740055509097, 0.698859728411783, '1'),
#  ('Nick Kyrgios',
#   'Andreas Seppi'): Text(0.5709691209572736, 0.7522240349397284, '2'),
#  ('Nick Kyrgios',
#   'Matteo Berrettini'): Text(0.7187601932394012, 0.6749607097191054, '1'),
#  ('Nick Kyrgios',
#   'Roger Federer'): Text(-0.08310079249105862, 0.25575796601805306, '2'),
#  ('Nick Kyrgios',
#   'Philipp Kohlschreiber'): Text(0.9094586375096316, 0.1933112900110417, '1'),
#  ('Nick Kyrgios',
#   'Richard Gasquet'): Text(0.6481086473310702, 0.7197975585585956, '1'),
#  ('Nick Kyrgios',
#   'Kei Nishikori'): Text(0.9007522168757762, 0.15235085903519258, '1'),
#  ('Nick Kyrgios',
#   'Radu Albot'): Text(0.011952164758090855, -0.017196914352952786, '2'),
#  ('Nick Kyrgios',
#   'Juan Martin Del Potro'): Text(0.5306360735692838, 0.7634852298502695, '1'),
#  ('Nick Kyrgios',
#   'Gilles Simon'): Text(0.3641963806483208, 0.7739567228245545, '2'),
#  ('Nick Kyrgios',
#   'Matthew Ebden'): Text(0.7809449142839924, -0.0655778255578151, '1'),
#  ('Nick Kyrgios',
#   'Robin Haase'): Text(0.32276997918746947, 0.7678393789403497, '1'),
#  ('Nick Kyrgios',
#   'Pierre Hugues Herbert'): Text(0.8083073800602258, -0.033878108608244584, '1'),
#  ('Nick Kyrgios',
#   'Denis Istomin'): Text(-0.03139525341990529, 0.05437819062223631, '1'),
#  ('Nick Kyrgios',
#   'Lorenzo Sonego'): Text(0.20357091964204904, -0.17571773163323984, '2'),
#  ('Casper Ruud',
#   'Novak Djokovic'): Text(0.3395825495300321, -0.18668707240151527, '1'),
#  ('Casper Ruud',
#   'Roberto Bautista Agut'): Text(0.38137543014818365, -0.189316441890913, '1'),
#  ('Casper Ruud',
#   'Gael Monfils'): Text(0.46488834333291923, -0.18406226266742914, '1'),
#  ('Casper Ruud',
#   'Borna Coric'): Text(0.04201507856240311, 0.6678102385301132, '1'),
#  ('Casper Ruud',
#   'Dominic Thiem'): Text(-0.07304152523880142, 0.49463618561995576, '1'),
#  ('Casper Ruud',
#   'Guido Pella'): Text(-0.056009170219870674, 0.5328914896031253, '2'),
#  ('Casper Ruud',
#   'Jan Lennard Struff'): Text(0.7563310272863494, 0.6528474461785321, '1'),
#  ('Casper Ruud',
#   'Andrey Rublev'): Text(0.546355278663114, -0.16495435471436687, '2'),
#  ('Casper Ruud',
#   'Filip Krajinovic'): Text(0.42324199700821735, -0.18843947875496803, '1'),
#  ('Casper Ruud',
#   'Albert Ramos'): Text(0.257386910166745, -0.17100741498937466, '3'),
#  ('Casper Ruud',
#   'John Isner'): Text(0.25738683566093923, 0.7921551831103668, '2'),
#  ('Casper Ruud',
#   'Matteo Berrettini'): Text(0.6941462764394357, 0.7088388274170583, '3'),
#  ('Casper Ruud',
#   'Roger Federer'): Text(-0.107714709291024, 0.2896360837160059, '1'),
#  ('Casper Ruud',
#   'Richard Gasquet'): Text(0.6234947305311048, 0.7536756762565484, '1'),
#  ('Casper Ruud',
#   'Adrian Mannarino'): Text(0.29815603258518175, -0.1805697285173104, '1'),
#  ('Casper Ruud',
#   'Steve Johnson'): Text(0.17895703264440593, 0.7629873820562791, '1'),
#  ('Casper Ruud',
#   'Robin Haase'): Text(0.2981560623875041, 0.8017174966383025, '2'),
#  ('Casper Ruud',
#   'Damir Dzumhur'): Text(0.04201504876008083, -0.04666247040912114, '1'),
#  ('Casper Ruud',
#   'Juan Martin Del Potro'): Text(0.5060221567693184, 0.7973633475482224, '1'),
#  ('Casper Ruud',
#   'Federico Delbonis'): Text(0.013349148615816098, 0.6372841370326434, '1'),
#  ('Casper Ruud',
#   'Marin Cilic'): Text(0.21756071087407952, -0.15806712743823426, '1'),
#  ('Casper Ruud',
#   'Juan Ignacio Londero'): Text(-0.07304152523880142, 0.12651161230335867, '1'),
#  ('Casper Ruud',
#   'Benoit Paire'): Text(0.10648989945935017, -0.10000069990505567, '1'),
#  ('Casper Ruud',
#   'Dusan Lajovic'): Text(0.585604445391443, -0.1503577136945406, '1'),
#  ('Casper Ruud',
#   'Joao Sousa'): Text(0.6234947603334271, -0.13252787833323398, '2'),
#  ('Casper Ruud',
#   'Marius Copil'): Text(0.7264120885010594, -0.06099849012045022, '1'),
#  ('Casper Ruud',
#   'Lloyd George Muirhead Harris'): Text(0.6597600291462997, -0.11159013759338843, '1'),
#  ('Casper Ruud',
#   'Lorenzo Sonego'): Text(0.17895700284208366, -0.141839613935287, '1'),
#  ('Casper Ruud',
#   'Daniel Evans'): Text(0.8083072608509367, 0.03387800757837195, '1'),
#  ('Jan Lennard Struff',
#   'Denis Shapovalov'): Text(0.43752585520494414, 0.8369097179356695, '5'),
#  ('Jan Lennard Struff',
#   'Novak Djokovic'): Text(0.3122201433584433, -0.15498738525426703, '4'),
#  ('Jan Lennard Struff',
#   'Roberto Bautista Agut'): Text(0.35401302397659484, -0.15761675474366477, '2'),
#  ('Jan Lennard Struff',
#   'Rafael Nadal'): Text(0.045772316939173885, 0.7275301883113594, '1'),
#  ('Jan Lennard Struff',
#   'Daniel Evans'): Text(0.7809448546793478, 0.0655776947256202, '1'),
#  ('Jan Lennard Struff',
#   'David Goffin'): Text(-0.12458946962964218, 0.23831767681150537, '3'),
#  ('Jan Lennard Struff',
#   'Gael Monfils'): Text(0.4375259371613304, -0.1523625755201809, '1'),
#  ('Jan Lennard Struff',
#   'Yoshihito Nishioka'): Text(0.07912752309008364, 0.7528481849756183, '2'),
#  ('Jan Lennard Struff',
#   'Borna Coric'): Text(0.014652672390814303, 0.6995099256773616, '2'),
#  ('Jan Lennard Struff',
#   'Marin Cilic'): Text(0.19019830470249072, -0.126367440290986, '3'),
#  ('Jan Lennard Struff',
#   'Dominic Thiem'): Text(-0.10040393141039022, 0.5263358727672041, '1'),
#  ('Jan Lennard Struff',
#   'Stefanos Tsitsipas'): Text(-0.114175435532748, 0.19775765493689287, '5'),
#  ('Jan Lennard Struff',
#   'Alex De Minaur'): Text(-0.06319784798604894, 0.08326009799851797, '3'),
#  ('Jan Lennard Struff',
#   'John Millman'): Text(0.6990495929225038, 0.7138460049933353, '3'),
#  ('Jan Lennard Struff',
#   'Marton Fucsovics'): Text(-0.1350771154626128, 0.3632114032172019, '1'),
#  ('Jan Lennard Struff',
#   'Pierre Hugues Herbert'): Text(0.7563310570886717, 0.03169969623695651, '1'),
#  ('Jan Lennard Struff',
#   'Jeremy Chardy'): Text(0.6323976825793555, 0.7644375332569842, '2'),
#  ('Jan Lennard Struff',
#   'John Isner'): Text(0.23002442948935045, 0.8238548702576151, '1'),
#  ('Jan Lennard Struff',
#   'Matteo Berrettini'): Text(0.666783870267847, 0.7405385145643064, '2'),
#  ('Jan Lennard Struff',
#   'Roger Federer'): Text(-0.1350771154626128, 0.32133577086325416, '3'),
#  ('Jan Lennard Struff',
#   'Richard Gasquet'): Text(0.596132324359516, 0.7853753634037967, '1'),
#  ('Jan Lennard Struff',
#   'Steve Johnson'): Text(0.15159462647281713, 0.7946870692035273, '1'),
#  ('Jan Lennard Struff',
#   'Kei Nishikori'): Text(0.848775893904222, 0.21792866388039367, '1'),
#  ('Jan Lennard Struff',
#   'Damir Dzumhur'): Text(0.014652642588492026, -0.014962783261872892, '1'),
#  ('Jan Lennard Struff',
#   'Jo Wilfried Tsonga'): Text(0.3958795610343062, 0.8412869340232084, '2'),
#  ('Jan Lennard Struff',
#   'Matthew Ebden'): Text(0.7289685913124382, -2.0712614012818875e-08, '1'),
#  ('Jan Lennard Struff',
#   'Lucas Pouille'): Text(-0.06319781818372666, 0.601287074219293, '1'),
#  ('Jan Lennard Struff',
#   'Taylor Harry Fritz'): Text(0.045772406346140826, -0.04298310550051543, '1'),
#  ('Jan Lennard Struff',
#   'Benoit Paire'): Text(0.07912749328776136, -0.06830101275780742, '1'),
#  ('Jan Lennard Struff',
#   'Tomas Berdych'): Text(-0.12458949943196451, 0.44622937619701636, '1'),
#  ('Jan Lennard Struff',
#   'Marius Copil'): Text(0.6990496823294706, -0.029298802973201976, '1'),
#  ('Jan Lennard Struff',
#   'Andrey Rublev'): Text(0.5189928724915251, -0.13325466756711862, '1'),
#  ('Jan Lennard Struff',
#   'Leonardo Mayer'): Text(-0.13157304781376472, 0.4049401734521547, '1'),
#  ('Jan Lennard Struff',
#   'Radu Albot'): Text(-0.040024158213463334, 0.04838089049224831, '2'),
#  ('John Millman',
#   'Roger Federer'): Text(-0.16499614365486964, 0.35063464253080906, '3'),
#  ('John Millman',
#   'Tennys Sandgren'): Text(-0.04393222614338499, 0.044862130298507275, '1'),
#  ('John Millman',
#   'Damir Dzumhur'): Text(-0.01526638560376481, 0.014336088405682013, '2'),
#  ('John Millman',
#   'Borna Coric'): Text(-0.015266355801442533, 0.7288087973449164, '1'),
#  ('John Millman',
#   'Marton Fucsovics'): Text(-0.16499614365486964, 0.3925102748847568, '1'),
#  ('John Millman',
#   'Lucas Pouille'): Text(-0.0931168463759835, 0.6305859458868479, '1'),
#  ('John Millman',
#   'Federico Delbonis'): Text(-0.04393228574802954, 0.6982826958474466, '3'),
#  ('John Millman',
#   'Hubert Hurkacz'): Text(0.3240940879852726, 0.8714627688267083, '1'),
#  ('John Millman',
#   'Novak Djokovic'): Text(0.28230111516618644, -0.12568851358671213, '3'),
#  ('John Millman',
#   'Roberto Bautista Agut'): Text(0.32409399578433795, -0.12831788307610986, '2'),
#  ('John Millman',
#   'Dusan Lajovic'): Text(0.5283230110275973, -0.08935915487973745, '1'),
#  ('John Millman',
#   'Rafael Nadal'): Text(0.01585328874691705, 0.7568290599789144, '1'),
#  ('John Millman',
#   'Benoit Paire'): Text(0.04920846509550453, -0.03900214109025252, '2'),
#  ('John Millman',
#   'Gilles Simon'): Text(0.2823010294845098, 0.8688333993373105, '2'),
#  ('John Millman',
#   'Yoshihito Nishioka'): Text(0.049208494897826804, 0.7821470566431732, '1'),
#  ('John Millman',
#   'Taylor Harry Fritz'): Text(0.01585337815388399, -0.013684233832960524, '1'),
#  ('John Millman',
#   'Marin Cilic'): Text(0.16027927651023388, -0.0970685686234311, '1'),
#  ('John Millman',
#   'Dominic Thiem'): Text(-0.13032295960264706, 0.5556347444347589, '1'),
#  ('John Millman',
#   'Guido Pella'): Text(-0.11329060458371631, 0.5938900484179284, '2'),
#  ('John Millman',
#   'Stefanos Tsitsipas'): Text(-0.14409446372500484, 0.22705652660444778, '1'),
#  ('John Millman',
#   'Denis Shapovalov'): Text(0.40760682701268725, 0.8662085896032243, '1'),
#  ('John Millman',
#   'Alex De Minaur'): Text(-0.09311687617830577, 0.11255896966607287, '1'),
#  ('John Millman',
#   'Andrey Rublev'): Text(0.48907384429926837, -0.10395579589956372, '1'),
#  ('John Millman',
#   'Fernando Verdasco'): Text(0.08456525481660182, 0.804585135694474, '3'),
#  ('John Millman',
#   'John Isner'): Text(0.20010540129709362, 0.85315374192517, '2'),
#  ('John Millman',
#   'Steve Johnson'): Text(0.1216755982805603, 0.8239859408710822, '2'),
#  ('John Millman',
#   'Kei Nishikori'): Text(0.8188568657119651, 0.24722753554794857, '1'),
#  ('John Millman',
#   'Adrian Mannarino'): Text(0.24087459822133614, -0.11957116970250725, '3'),
#  ('John Millman',
#   'Joao Sousa'): Text(0.5662133259695815, -0.07152931951843083, '1'),
#  ('John Millman',
#   'Peter Gojowczyk'): Text(0.7727186090623599, 0.1306955901331165, '2'),
#  ('John Millman',
#   'Robin Haase'): Text(0.24087462802365844, 0.8627160554531057, '1'),
#  ('John Millman',
#   'Lloyd George Muirhead Harris'): Text(0.602478594782454, -0.05059157877858528, '1'),
#  ('John Millman',
#   'Aljaz Bedene'): Text(-0.06994324601036472, 0.6654650341838283, '1'),
#  ('John Millman',
#   'Leonardo Mayer'): Text(-0.16149207600602156, 0.4342390451197097, '1'),
#  ('John Millman',
#   'Radu Albot'): Text(-0.06994318640572017, 0.07767976215980321, '1'),
#  ('Matteo Berrettini',
#   'Gael Monfils'): Text(0.3753411863144168, -0.09637119428165475, '1'),
#  ('Matteo Berrettini',
#   'Dominic Thiem'): Text(-0.16258868225730383, 0.5823272540057302, '4'),
#  ('Matteo Berrettini',
#   'Philipp Kohlschreiber'): Text(0.7952975636911639, 0.31488047609476894, '1'),
#  ('Matteo Berrettini',
#   'Roberto Bautista Agut'): Text(0.2918282731296812, -0.10162537350513862, '4'),
#  ('Matteo Berrettini',
#   'Kyle Edmund'): Text(0.8005459910664443, 0.356426023514878, '2'),
#  ('Matteo Berrettini',
#   'Filip Krajinovic'): Text(0.33369483998971494, -0.10074841036919363, '1'),
#  ('Matteo Berrettini',
#   'Lucas Pouille'): Text(-0.12538256903064027, 0.657278455457819, '1'),
#  ('Matteo Berrettini',
#   'Jeremy Chardy'): Text(0.5702129317324418, 0.8204289144955104, '1'),
#  ('Matteo Berrettini',
#   'Denis Kudla'): Text(0.774487734518622, 0.23383157793945017, '4'),
#  ('Matteo Berrettini',
#   'Novak Djokovic'): Text(0.2500353925115297, -0.09899600401574088, '1'),
#  ('Matteo Berrettini',
#   'Rafael Nadal'): Text(-0.01641243390773972, 0.7835215695498856, '1'),
#  ('Matteo Berrettini',
#   'David Goffin'): Text(-0.18677422047655579, 0.2943090580500315, '1'),
#  ('Matteo Berrettini',
#   'Gilles Simon'): Text(0.25003530682985303, 0.8955259089082818, '2'),
#  ('Matteo Berrettini',
#   'Taylor Harry Fritz'): Text(-0.01641234450077278, 0.013008275738010722, '1'),
#  ('Matteo Berrettini',
#   'Hubert Hurkacz'): Text(0.29182836533061585, 0.8981552783976796, '1'),
#  ('Matteo Berrettini',
#   'Stefanos Tsitsipas'): Text(-0.1763601863796616, 0.253749036175419, '1'),
#  ('Matteo Berrettini',
#   'Denis Shapovalov'): Text(0.3753411043580305, 0.8929010991741957, '2'),
#  ('Matteo Berrettini',
#   'Andrey Rublev'): Text(0.4568081216446116, -0.07726328632859247, '5'),
#  ('Matteo Berrettini',
#   'Aljaz Bedene'): Text(-0.1022089686650215, 0.6921575437547995, '3'),
#  ('Matteo Berrettini',
#   'Marton Fucsovics'): Text(-0.1972618663095264, 0.41920278445572806, '1'),
#  ('Matteo Berrettini',
#   'Andreas Seppi'): Text(0.45680804713880585, 0.8737932210234557, '2'),
#  ('Matteo Berrettini',
#   'Tennys Sandgren'): Text(-0.07619794879804176, 0.07155463986947852, '1'),
#  ('Matteo Berrettini',
#   'Peter Gojowczyk'): Text(0.7404528864077031, 0.15738809970408774, '1'),
#  ('Matteo Berrettini',
#   'Roger Federer'): Text(-0.1972618663095264, 0.3773271521017803, '2'),
#  ('Matteo Berrettini',
#   'Juan Ignacio Londero'): Text(-0.16258868225730383, 0.21420268068913306, '1'),
#  ('Matteo Berrettini',
#   'Adrian Mannarino'): Text(0.20860887556667937, -0.092878660131536, '1'),
#  ('Matteo Berrettini',
#   'Jo Wilfried Tsonga'): Text(0.3336948101873926, 0.8972783152617345, '1'),
#  ('Matteo Berrettini',
#   'Leonardo Mayer'): Text(-0.19375779866067833, 0.4609315546906809, '3'),
#  ('Matteo Berrettini',
#   'Hyeon Chung'): Text(-0.17636015657733928, 0.5427808985194442, '1'),
#  ('Matteo Berrettini',
#   'Matthew Ebden'): Text(0.6667838404655246, 0.05599136052591214, '1'),
#  ('Matteo Berrettini',
#   'Fernando Verdasco'): Text(0.05229953216194505, 0.8312776452654451, '1'),
#  ('Matteo Berrettini',
#   'Richard Gasquet'): Text(0.5339475735126025, 0.8413667446423228, '1'),
#  ('Matteo Berrettini',
#   'Denis Istomin'): Text(-0.14555632723837308, 0.17594737670596355, '2'),
#  ('Matteo Berrettini',
#   'Lloyd George Muirhead Harris'): Text(0.5702128721277973, -0.023899069207614032, '1'),
#  ('Matteo Berrettini',
#   'Radu Albot'): Text(-0.10220890906037694, 0.10437227173077446, '2'),
#  ('Jeremy Chardy',
#   'Stefanos Tsitsipas'): Text(-0.2107463740681531, 0.27764805486809674, '3'),
#  ('Jeremy Chardy',
#   'Damir Dzumhur'): Text(-0.08191829594691308, 0.06492761666933095, '1'),
#  ('Jeremy Chardy',
#   'Kyle Edmund'): Text(0.7661598033779528, 0.3803250422075557, '2'),
#  ('Jeremy Chardy',
#   'Novak Djokovic'): Text(0.21564920482303815, -0.07509698532306319, '3'),
#  ('Jeremy Chardy',
#   'Rafael Nadal'): Text(-0.05079862159623122, 0.8074205882425634, '1'),
#  ('Jeremy Chardy',
#   'David Goffin'): Text(-0.22116040816504728, 0.31820807674270923, '2'),
#  ('Jeremy Chardy',
#   'Kevin Anderson'): Text(-0.22814398634916983, 0.3594974061474406, '2'),
#  ('Jeremy Chardy',
#   'Borna Coric'): Text(-0.0819182661445908, 0.7794003256085653, '2'),
#  ('Jeremy Chardy',
#   'Marin Cilic'): Text(0.09362736616708561, -0.046477040359782174, '1'),
#  ('Jeremy Chardy',
#   'Denis Shapovalov'): Text(0.34095491666953903, 0.9168001178668733, '2'),
#  ('Jeremy Chardy',
#   'Andrey Rublev'): Text(0.42242193395612004, -0.053364267635914786, '3'),
#  ('Jeremy Chardy',
#   'Stanislas Wawrinka'): Text(0.7246861466098073, 0.2187957251947551, '2'),
#  ('Jeremy Chardy',
#   'Fernando Verdasco'): Text(0.017913344473453552, 0.8551766639581229, '2'),
#  ('Jeremy Chardy',
#   'Pierre Hugues Herbert'): Text(0.6597601185532667, 0.11159009616816035, '2'),
#  ('Jeremy Chardy',
#   'Albert Ramos'): Text(0.1334535654597511, -0.05941732791092258, '2'),
#  ('Jeremy Chardy',
#   'Andreas Seppi'): Text(0.4224218594503143, 0.8976922397161333, '1'),
#  ('Jeremy Chardy',
#   'Tennys Sandgren'): Text(-0.11058413648653326, 0.09545365856215621, '1'),
#  ('Jeremy Chardy',
#   'Roger Federer'): Text(-0.2316480539980179, 0.401226170794458, '1'),
#  ('Jeremy Chardy',
#   'Richard Gasquet'): Text(0.4995613858241109, 0.8652657633350005, '5'),
#  ('Jeremy Chardy',
#   'Kei Nishikori'): Text(0.7522049553688168, 0.2978190638115975, '1'),
#  ('Jeremy Chardy',
#   'Jo Wilfried Tsonga'): Text(0.2993086224989011, 0.9211773339544123, '1'),
#  ('Jeremy Chardy',
#   'Marius Copil'): Text(0.6024787437940655, 0.05059159695800186, '1'),
#  ('Jeremy Chardy',
#   'Juan Martin Del Potro'): Text(0.3820888120623244, 0.9089534346266744, '1'),
#  ('Jeremy Chardy',
#   'Hubert Hurkacz'): Text(0.25744217764212435, 0.9220542970903572, '1'),
#  ('Jeremy Chardy',
#   'Benoit Paire'): Text(-0.01744344524764374, 0.011589387173396415, '1'),
#  ('Jeremy Chardy',
#   'Dusan Lajovic'): Text(0.46167110068444905, -0.03876762661608851, '2'),
#  ('Jeremy Chardy',
#   'Adrian Mannarino'): Text(0.17422268787818787, -0.06897964143885832, '2'),
#  ('Jeremy Chardy',
#   'Gilles Simon'): Text(0.21564911914136153, 0.9194249276009594, '2'),
#  ('Jeremy Chardy',
#   'Tomas Berdych'): Text(-0.22116043796736962, 0.5261197761282201, '1'),
#  ('Jeremy Chardy',
#   'Matthew Ebden'): Text(0.6323976527770332, 0.07989037921858982, '1'),
#  ('Richard Gasquet',
#   'Denis Shapovalov'): Text(0.3046895584496996, 0.9377379480136858, '1'),
#  ('Richard Gasquet',
#   'Kevin Anderson'): Text(-0.2644093445690092, 0.3804352362942531, '1'),
#  ('Richard Gasquet',
#   'Stefanos Tsitsipas'): Text(-0.24701173228799253, 0.29858588501490924, '2'),
#  ('Richard Gasquet',
#   'Roberto Bautista Agut'): Text(0.2211767272213503, -0.05678852466564843, '6'),
#  ('Richard Gasquet',
#   'Damir Dzumhur'): Text(-0.1181836541667525, 0.08586544681614344, '1'),
#  ('Richard Gasquet',
#   'Kei Nishikori'): Text(0.7159395971489775, 0.31875689395841, '2'),
#  ('Richard Gasquet',
#   'Federico Delbonis'): Text(-0.14684955431101723, 0.769812054257908, '1'),
#  ('Richard Gasquet',
#   'Taylor Harry Fritz'): Text(-0.0870638904091037, 0.057845124577500906, '2'),
#  ('Richard Gasquet',
#   'Denis Kudla'): Text(0.7038361886102911, 0.2786684267789403, '1'),
#  ('Richard Gasquet',
#   'David Goffin'): Text(-0.2574257663848867, 0.33914590688952173, '3'),
#  ('Richard Gasquet',
#   'Juan Ignacio Londero'): Text(-0.23324022816563475, 0.25903952952862325, '3'),
#  ('Richard Gasquet',
#   'Benoit Paire'): Text(-0.05370880346748316, 0.03252721732020891, '5'),
#  ('Richard Gasquet',
#   'Novak Djokovic'): Text(0.17938384660319873, -0.054159155176250695, '1'),
#  ('Richard Gasquet',
#   'Dusan Lajovic'): Text(0.4254057424646096, -0.017829796469276016, '1'),
#  ('Richard Gasquet',
#   'Rafael Nadal'): Text(-0.08706397981607064, 0.8283584183893757, '1'),
#  ('Richard Gasquet',
#   'Gilles Simon'): Text(0.17938376092152214, 0.940362757747772, '3'),
#  ('Richard Gasquet',
#   'Gael Monfils'): Text(0.3046896404060859, -0.051534345442164564, '2'),
#  ('Richard Gasquet',
#   'Borna Coric'): Text(-0.11818362436443022, 0.8003381557553779, '1'),
#  ('Richard Gasquet',
#   'Dominic Thiem'): Text(-0.23324022816563475, 0.6271641028452204, '1'),
#  ('Richard Gasquet',
#   'Alex De Minaur'): Text(-0.19603414474129346, 0.1840883280765343, '2'),
#  ('Richard Gasquet',
#   'Pierre Hugues Herbert'): Text(0.6234947603334272, 0.13252792631497284, '2'),
#  ('Richard Gasquet',
#   'Albert Ramos'): Text(0.09718820723991167, -0.03847949776411008, '1'),
#  ('Richard Gasquet',
#   'Kyle Edmund'): Text(0.7298944451581133, 0.4012628723543682, '2'),
#  ('Richard Gasquet',
#   'Roger Federer'): Text(-0.26791341221785736, 0.4221640009412705, '2'),
#  ('Richard Gasquet',
#   'Philipp Kohlschreiber'): Text(0.724646017782833, 0.3597173249342591, '1'),
#  ('Richard Gasquet',
#   'Lorenzo Sonego'): Text(0.018758299915250326, -0.00931169671002241, '2'),
#  ('Richard Gasquet',
#   'Lucas Pouille'): Text(-0.1960341149389712, 0.7021153042973093, '2'),
#  ('Richard Gasquet',
#   'Juan Martin Del Potro'): Text(0.34582345384248503, 0.9298912647734869, '1'),
#  ('Richard Gasquet',
#   'Tomas Berdych'): Text(-0.25742579618720907, 0.5470576062750327, '1'),
#  ('Richard Gasquet',
#   'Andreas Seppi'): Text(0.3861565012304749, 0.9186300698629459, '1'),
#  ('Richard Gasquet',
#   'Peter Gojowczyk'): Text(0.6698013404993722, 0.20222494854357792, '1'),
#  ('Richard Gasquet',
#   'Robin Haase'): Text(0.13795735946067075, 0.9342454138635672, '1'),
#  ('Richard Gasquet',
#   'Lloyd George Muirhead Harris'): Text(0.49956132621946636, 0.020937779631876152, '1'),
#  ('Richard Gasquet',
#   'Aljaz Bedene'): Text(-0.17286051457335241, 0.7369943925942897, '1'),
#  ('Richard Gasquet',
#   'Leonardo Mayer'): Text(-0.2644093445690092, 0.505768403530171, '1'),
#  ('Richard Gasquet',
#   'Sumit Nagal'): Text(0.5339475437102802, 0.04483682812687617, '1'),
#  ('Thanasi Kokkinakis',
#   'Roger Federer'): Text(-0.3058036079505524, 0.4399937766979325, '1'),
#  ('Thanasi Kokkinakis',
#   'Lucas Pouille'): Text(-0.23392431067166622, 0.7199450800539713, '1'),
#  ('Thanasi Kokkinakis',
#   'Rafael Nadal'): Text(-0.12495417554876567, 0.8461881941460379, '1'),
#  ('Thanasi Kokkinakis',
#   'Taylor Harry Fritz'): Text(-0.12495408614179873, 0.07567490033416291, '1'),
#  ('Thanasi Kokkinakis',
# ...
#   'Stefanos Tsitsipas'): Text(-0.7973717397083346, 0.240740709922472, '7'),
#  ('Rafael Nadal',
#   'Roger Federer'): Text(-0.8182734196381996, 0.3643188258488333, '3'),
#  ('Rafael Nadal',
#   'Gael Monfils'): Text(-0.24567036701425626, -0.10937952053460176, '2'),
#  ('Rafael Nadal',
#   'Philipp Kohlschreiber'): Text(0.1742860103624908, 0.3018721498418219, '1'),
#  ('Rafael Nadal',
#   'Roberto Bautista Agut'): Text(-0.3291832801989919, -0.11463369975808563, '1'),
#  ('Rafael Nadal',
#   'Damir Dzumhur'): Text(-0.6685436615870947, 0.028020271723706247, '2'),
#  ('Rafael Nadal',
#   'Filip Krajinovic'): Text(-0.28731671333895814, -0.11375673662214064, '1'),
#  ('Rafael Nadal',
#   'Kei Nishikori'): Text(0.1655795897286353, 0.2609117188659728, '2'),
#  ('Rafael Nadal',
#   'Federico Delbonis'): Text(-0.6972095617313594, 0.7119668791654707, '1'),
#  ('Rafael Nadal',
#   'Taylor Harry Fritz'): Text(-0.6374238978294459, -5.0514936289491885e-08, '1'),
#  ('Rafael Nadal',
#   'Juan Ignacio Londero'): Text(-0.7836002355859769, 0.20119435443618605, '1'),
#  ('Rafael Nadal',
#   'Benoit Paire'): Text(-0.6040688108878254, -0.025317957772228283, '1'),
#  ('Rafael Nadal',
#   'Dusan Lajovic'): Text(-0.12495426495573256, -0.07567497156171321, '1'),
#  ('Rafael Nadal',
#   'Adrian Mannarino'): Text(-0.4124026777619937, -0.10588698638448302, '1'),
#  ('Rafael Nadal',
#   'Joao Sousa'): Text(-0.08706395001374836, -0.0578451362004066, '1'),
#  ('Rafael Nadal',
#   'Tomas Berdych'): Text(-0.8077858036075511, 0.4892124311825955, '1'),
#  ('Rafael Nadal',
#   'Stanislas Wawrinka'): Text(0.13806078096962582, 0.1818883802491304, '3'),
#  ('Rafael Nadal',
#   'Matthew Ebden'): Text(0.04577228713685155, 0.042983034272965126, '1'),
#  ('Rafael Nadal',
#   'Guido Pella'): Text(-0.7665678805670462, 0.6075742317359527, '3'),
#  ('Rafael Nadal',
#   'Andrey Rublev'): Text(-0.1642034316840615, -0.09027161258153948, '1'),
#  ('Rafael Nadal',
#   'Aljaz Bedene'): Text(-0.7232205219936946, 0.6791492175018525, '1'),
#  ('Rafael Nadal',
#   'Alex De Minaur'): Text(-0.7463941521616356, 0.1262431529840971, '3'),
#  ('Rafael Nadal',
#   'Leonardo Mayer'): Text(-0.8147693519893514, 0.4479232284377339, '2'),
#  ('Rafael Nadal',
#   'Daniel Evans'): Text(0.09774855050376119, 0.10856074971119933, '2'),
#  ('Rafael Nadal',
#   'Hyeon Chung'): Text(-0.7973717099060124, 0.5297725722664972, '1'),
#  ('Borna Coric',
#   'Kevin Anderson'): Text(-0.845888996537711, 0.29456979856781795, '2'),
#  ('Borna Coric',
#   'Roger Federer'): Text(-0.849393064186559, 0.33629856321483537, '5'),
#  ('Borna Coric',
#   'Dominic Thiem'): Text(-0.8147198801343365, 0.5412986651187852, '3'),
#  ('Borna Coric',
#   'Stefanos Tsitsipas'): Text(-0.8284913842566943, 0.21272044728847408, '2'),
#  ('Borna Coric',
#   'Philipp Kohlschreiber'): Text(0.14316636581413122, 0.273851887207824, '1'),
#  ('Borna Coric',
#   'Roberto Bautista Agut'): Text(-0.3603029247473515, -0.14265396239208356, '3'),
#  ('Borna Coric',
#   'Filip Krajinovic'): Text(-0.3184363578873177, -0.14177699925613857, '2'),
#  ('Borna Coric',
#   'Novak Djokovic'): Text(-0.402095805365503, -0.14002459290268582, '3'),
#  ('Borna Coric',
#   'David Goffin'): Text(-0.8389054183535885, 0.25328046916308655, '1'),
#  ('Borna Coric',
#   'Marin Cilic'): Text(-0.5241176440214556, -0.1114046479394048, '1'),
#  ('Borna Coric',
#   'Alex De Minaur'): Text(-0.7775137967099952, 0.09822289035009918, '1'),
#  ('Borna Coric',
#   'Andrey Rublev'): Text(-0.1953230762324211, -0.11829187521553741, '3'),
#  ('Borna Coric',
#   'Pierre Hugues Herbert'): Text(0.04201510836472544, 0.04666248858853772, '2'),
#  ('Borna Coric',
#   'Adrian Mannarino'): Text(-0.44352232231035327, -0.13390724901848094, '2'),
#  ('Borna Coric',
#   'Lucas Pouille'): Text(-0.7775137669076729, 0.6162498665708742, '3'),
#  ('Borna Coric',
#   'Marton Fucsovics'): Text(-0.849393064186559, 0.3781741955687831, '3'),
#  ('Borna Coric',
#   'Taylor Harry Fritz'): Text(-0.6685435423778054, -0.028020313148934217, '3'),
#  ('Borna Coric',
#   'Juan Ignacio Londero'): Text(-0.8147198801343365, 0.17317409180218812, '2'),
#  ('Borna Coric',
#   'Benoit Paire'): Text(-0.6351884554361849, -0.05333822040622621, '2'),
#  ('Borna Coric',
#   'Albert Ramos'): Text(-0.48429144472879004, -0.1243449354905452, '2'),
#  ('Borna Coric',
#   'Joao Sousa'): Text(-0.11818359456210795, -0.08586539883440453, '2'),
#  ('Borna Coric',
#   'Tomas Berdych'): Text(-0.8389054481559108, 0.46119216854859757, '1'),
#  ('Borna Coric',
#   'Stanislas Wawrinka'): Text(0.10694113642126624, 0.15386811761513247, '1'),
#  ('Borna Coric',
#   'Matthew Ebden'): Text(0.014652642588491971, 0.014962771638967198, '1'),
#  ('Borna Coric',
#   'Peter Gojowczyk'): Text(0.08832168853067052, 0.1163595108171428, '1'),
#  ('Borna Coric',
#   'Lloyd George Muirhead Harris'): Text(-0.08191832574923541, -0.06492765809455897, '1'),
#  ('Borna Coric',
#   'Lorenzo Sonego'): Text(-0.5627213520534514, -0.09517713443645753, '1'),
#  ('Borna Coric',
#   'Aljaz Bedene'): Text(-0.7543401665420542, 0.6511289548678546, '1'),
#  ('Borna Coric',
#   'Leonardo Mayer'): Text(-0.845888996537711, 0.419902965803736, '1'),
#  ('Federico Delbonis',
#   'Marton Fucsovics'): Text(-0.878058994133146, 0.34764809407131325, '1'),
#  ('Federico Delbonis',
#   'Novak Djokovic'): Text(-0.43076173531209, -0.1705506944001557, '1'),
#  ('Federico Delbonis',
#   'Daniel Evans'): Text(0.0379629760088146, 0.050014385579731535, '1'),
#  ('Federico Delbonis',
#   'Dominic Thiem'): Text(-0.8433858100809235, 0.5107725636213154, '1'),
#  ('Federico Delbonis',
#   'Aljaz Bedene'): Text(-0.7830060964886412, 0.6206028533703847, '1'),
#  ('Federico Delbonis',
#   'Pierre Hugues Herbert'): Text(0.01334917841813843, 0.01613638709106785, '1'),
#  ('Federico Delbonis',
#   'Albert Ramos'): Text(-0.512957374675377, -0.15487103698801508, '4'),
#  ('Federico Delbonis',
#   'Roger Federer'): Text(-0.878058994133146, 0.3057724617173655, '1'),
#  ('Federico Delbonis',
#   'Juan Ignacio Londero'): Text(-0.8433858100809235, 0.14264799030471825, '3'),
#  ('Federico Delbonis',
#   'Lorenzo Sonego'): Text(-0.5913872820000384, -0.1257032359339274, '2'),
#  ('Federico Delbonis',
#   'Radu Albot'): Text(-0.7830060368839966, 0.03281758134635965, '1'),
#  ('Federico Delbonis',
#   'Marius Copil'): Text(-0.04393219634106266, -0.044862112119090636, '1'),
#  ('Federico Delbonis',
#   'Denis Istomin'): Text(-0.8263534550619928, 0.10439268632154874, '1'),
#  ('Federico Delbonis',
#   'Joao Sousa'): Text(-0.14684952450869496, -0.1163915003318744, '2'),
#  ('Federico Delbonis',
#   'Peter Gojowczyk'): Text(0.05965575858408351, 0.08583340931967293, '1'),
#  ('Federico Delbonis',
#   'Leonardo Mayer'): Text(-0.874554926484298, 0.38937686430626606, '1'),
#  ('Aljaz Bedene',
#   'Kevin Anderson'): Text(-0.9005658867466332, 0.2312260354067298, '1'),
#  ('Aljaz Bedene',
#   'Stefanos Tsitsipas'): Text(-0.8831682744656164, 0.14937668412738594, '2'),
#  ('Aljaz Bedene',
#   'Taylor Harry Fritz'): Text(-0.7232204325867276, -0.09136407631002236, '1'),
#  ('Aljaz Bedene',
#   'Benoit Paire'): Text(-0.6898653456451072, -0.11668198356731435, '5'),
#  ('Aljaz Bedene',
#   'Albert Ramos'): Text(-0.5389683349377122, -0.18768869865163335, '1'),
#  ('Aljaz Bedene',
#   'Joao Sousa'): Text(-0.17286048477103014, -0.14920916199549267, '1'),
#  ('Aljaz Bedene',
#   'Guido Pella'): Text(-0.8523644153243279, 0.5162102059408666, '2'),
#  ('Aljaz Bedene',
#   'Marius Copil'): Text(-0.06994315660339784, -0.0776797737827089, '2'),
#  ('Aljaz Bedene',
#   'Lorenzo Sonego'): Text(-0.6173982422623736, -0.15852089759754567, '1'),
#  ('Aljaz Bedene',
#   'Dusan Lajovic'): Text(-0.21075079971301433, -0.16703899735679928, '1'),
#  ('Aljaz Bedene',
#   'Daniel Evans'): Text(0.011952015746479416, 0.017196723916113266, '1'),
#  ('Aljaz Bedene',
#   'Gael Monfils'): Text(-0.33146690177153804, -0.20074354632968783, '1'),
#  ('Aljaz Bedene',
#   'Dominic Thiem'): Text(-0.8693967703432587, 0.4779549019576971, '2'),
#  ('Aljaz Bedene',
#   'Stanislas Wawrinka'): Text(0.052264246212344045, 0.09052435445404433, '2'),
#  ('Aljaz Bedene',
#   'Roger Federer'): Text(-0.9040699543954813, 0.2729548000537472, '2'),
#  ('Aljaz Bedene',
#   'Adrian Mannarino'): Text(-0.49819921251927546, -0.19725101217956909, '1'),
#  ('Aljaz Bedene',
#   'Radu Albot'): Text(-0.8090169971463318, -8.031725862167605e-08, '2'),
#  ('Aljaz Bedene',
#   'Alex De Minaur'): Text(-0.8321906869189174, 0.03487912718901104, '1'),
#  ('Lucas Pouille',
#   'Philipp Kohlschreiber'): Text(0.06531587523959026, 0.1756290357497554, '2'),
#  ('Lucas Pouille',
#   'Roberto Bautista Agut'): Text(-0.43815341532189245, -0.24087681385015214, '2'),
#  ('Lucas Pouille',
#   'Filip Krajinovic'): Text(-0.3962868484618587, -0.23999985071420715, '3'),
#  ('Lucas Pouille',
#   'Novak Djokovic'): Text(-0.47994629594004395, -0.2382474443607544, '3'),
#  ('Lucas Pouille',
#   'Daniel Evans'): Text(-0.011221584619139358, -0.017682364380867177, '1'),
#  ('Lucas Pouille',
#   'Benoit Paire'): Text(-0.7130389460107258, -0.1515610718642948, '2'),
#  ('Lucas Pouille',
#   'Marin Cilic'): Text(-0.6019681345959965, -0.20962749939747338, '1'),
#  ('Lucas Pouille',
#   'Stefanos Tsitsipas'): Text(-0.9063418748312353, 0.1144975958304055, '1'),
#  ('Lucas Pouille',
#   'Andrey Rublev'): Text(-0.27317356680696203, -0.216514726673606, '2'),
#  ('Lucas Pouille',
#   'Stanislas Wawrinka'): Text(0.02909064584672527, 0.05564526615706389, '1'),
#  ('Lucas Pouille',
#   'Albert Ramos'): Text(-0.562141935303331, -0.2225677869486138, '1'),
#  ('Lucas Pouille',
#   'Kyle Edmund'): Text(0.07056430261487062, 0.2171745831698645, '1'),
#  ('Lucas Pouille',
#   'Tennys Sandgren'): Text(-0.8061796372496154, -0.067696800475535, '1'),
#  ('Lucas Pouille',
#   'Roger Federer'): Text(-0.9272435547611, 0.23807571175676678, '1'),
#  ('Lucas Pouille',
#   'Ruben Bemelmans'): Text(-0.6776820817838228, -0.1739992105202401, '1'),
#  ('Lucas Pouille',
#   'Joao Sousa'): Text(-0.1960340851366489, -0.1840882502924731, '1'),
#  ('Lucas Pouille',
#   'Denis Kudla'): Text(0.04450604606704833, 0.09458013759443665, '3'),
#  ('Lucas Pouille',
#   'Leonardo Mayer'): Text(-0.923739487112252, 0.32168011434566735, '1'),
#  ('Lucas Pouille',
#   'Pierre Hugues Herbert'): Text(-0.035835382209815525, -0.05156036286953086, '1'),
#  ('Lucas Pouille',
#   'Denis Istomin'): Text(-0.8755380156899467, 0.03669593636095003, '1'),
#  ('Lucas Pouille',
#   'Lorenzo Sonego'): Text(-0.6405718426279924, -0.19339998589452612, '1'),
#  ('Lucas Pouille',
#   'Jay Clarke'): Text(-0.31350671850308, -0.2277759513864694, '1'),
#  ('Guido Pella',
#   'Kevin Anderson'): Text(-0.9439132453199848, 0.15965104964082993, '1'),
#  ('Guido Pella',
#   'Marin Cilic'): Text(-0.6221418928037293, -0.24632339686639282, '3'),
#  ('Guido Pella',
#   'David Goffin'): Text(-0.9369296671358622, 0.11836172023609856, '3'),
#  ('Guido Pella',
#   'Benoit Paire'): Text(-0.7332127042184586, -0.18825696933321423, '1'),
#  ('Guido Pella',
#   'Albert Ramos'): Text(-0.5823156935110638, -0.2592636844175332, '2'),
#  ('Guido Pella',
#   'Dusan Lajovic'): Text(-0.25409815828636595, -0.23861398312269916, '1'),
#  ('Guido Pella',
#   'Joao Sousa'): Text(-0.21620784334438173, -0.22078414776139255, '4'),
#  ('Guido Pella',
#   'Roberto Bautista Agut'): Text(-0.45832717352962526, -0.2775727113190716, '2'),
#  ('Guido Pella',
#   'Taylor Harry Fritz'): Text(-0.7665677911600792, -0.16293906207592224, '2'),
#  ('Guido Pella',
#   'Dominic Thiem'): Text(-0.9127441289166103, 0.4063799161917972, '3'),
#  ('Guido Pella',
#   'Andrey Rublev'): Text(-0.29334732501469485, -0.25321062414252543, '1'),
#  ('Guido Pella',
#   'Stanislas Wawrinka'): Text(0.008916887638992455, 0.018949368688144452, '1'),
#  ('Guido Pella',
#   'Marton Fucsovics'): Text(-0.9474173129688328, 0.2432554466417951, '1'),
#  ('Guido Pella',
#   'Tennys Sandgren'): Text(-0.8263533954573482, -0.10439269794445444, '1'),
#  ('Guido Pella',
#   'Peter Gojowczyk'): Text(-0.009702560251603265, -0.018559238109845222, '3'),
#  ('Guido Pella',
#   'Roger Federer'): Text(-0.9474173129688328, 0.20137981428784735, '1'),
#  ('Guido Pella',
#   'Philipp Kohlschreiber'): Text(0.04514211703185744, 0.13893313828083598, '1'),
#  ('Guido Pella',
#   'Juan Ignacio Londero'): Text(-0.9127441289166103, 0.038255342875200105, '2'),
#  ('Guido Pella',
#   'Damir Dzumhur'): Text(-0.797687554917728, -0.1349187398372797, '1'),
#  ('Guido Pella',
#   'Leonardo Mayer'): Text(-0.9439132453199848, 0.2849842168767479, '2'),
#  ('Guido Pella',
#   'Marius Copil'): Text(-0.11329051517674943, -0.14925475954860878, '1'),
#  ('Guido Pella',
#   'Radu Albot'): Text(-0.8523643557196834, -0.0715750660831585, '1'),
#  ('Dominic Thiem',
#   'Gael Monfils'): Text(-0.39184661536382037, -0.3105738360787572, '5'),
#  ('Dominic Thiem',
#   'Kevin Anderson'): Text(-0.9609456003389155, 0.12139574565766043, '3'),
#  ('Dominic Thiem',
#   'Roger Federer'): Text(-0.9644496679877637, 0.16312451030467784, '4'),
#  ('Dominic Thiem',
#   'Novak Djokovic'): Text(-0.5171524091667076, -0.31319864581284335, '6'),
#  ('Dominic Thiem',
#   'Dusan Lajovic'): Text(-0.2711305133052967, -0.27686928710586867, '3'),
#  ('Dominic Thiem',
#   'Stefanos Tsitsipas'): Text(-0.9435479880578987, 0.03954639437831656, '8'),
#  ('Dominic Thiem',
#   'Andrey Rublev'): Text(-0.3103796800336256, -0.29146592812569494, '4'),
#  ('Dominic Thiem',
#   'Pierre Hugues Herbert'): Text(-0.07304149543647909, -0.1265115643216198, '1'),
#  ('Dominic Thiem',
#   'Filip Krajinovic'): Text(-0.43349296168852225, -0.3149510521662961, '1'),
#  ('Dominic Thiem',
#   'Tennys Sandgren'): Text(-0.843385750476279, -0.14264800192762395, '1'),
#  ('Dominic Thiem',
#   'Kei Nishikori'): Text(0.01940334137907118, 0.05971740332181737, '3'),
#  ('Dominic Thiem',
#   'Matthew Ebden'): Text(-0.10040396121271256, -0.15821128127119033, '1'),
#  ('Dominic Thiem',
#   'Roberto Bautista Agut'): Text(-0.475359528548556, -0.3158280153022411, '1'),
#  ('Dominic Thiem',
#   'Marton Fucsovics'): Text(-0.9644496679877637, 0.2050001426586256, '1'),
#  ('Dominic Thiem',
#   'Taylor Harry Fritz'): Text(-0.78360014617901, -0.20119436605909174, '2'),
#  ('Dominic Thiem',
#   'Marin Cilic'): Text(-0.6391742478226601, -0.2845787008495623, '3'),
#  ('Dominic Thiem',
#   'Denis Kudla'): Text(0.007299932840384771, 0.019628936142347703, '1'),
#  ('Dominic Thiem',
#   'Benoit Paire'): Text(-0.7502450592373895, -0.22651227331638374, '1'),
#  ('Dominic Thiem',
#   'Albert Ramos'): Text(-0.5993480485299946, -0.29751898840070273, '1'),
#  ('Dominic Thiem',
#   'Adrian Mannarino'): Text(-0.5585789261115578, -0.3070813019286385, '2'),
#  ('Dominic Thiem',
#   'Lorenzo Sonego'): Text(-0.677777955854656, -0.26835118734661506, '1'),
#  ('Dominic Thiem',
#   'Alex De Minaur'): Text(-0.8925704005111997, -0.07495116256005835, '2'),
#  ('Dominic Thiem',
#   'Ruben Bemelmans'): Text(-0.7148881950104864, -0.24895041197232903, '1'),
#  ('Dominic Thiem',
#   'Sumit Nagal'): Text(-0.1625887120596261, -0.21420266250971648, '1'),
#  ('Hyeon Chung',
#   'Tennys Sandgren'): Text(-0.8571572247963144, -0.1821943574139099, '2'),
#  ('Hyeon Chung',
#   'Taylor Harry Fritz'): Text(-0.7973716204990454, -0.2407407215453777, '2'),
#  ('Hyeon Chung',
#   'Marin Cilic'): Text(-0.6529457221426955, -0.3241250563358483, '1'),
#  ('Hyeon Chung',
#   'Denis Kudla'): Text(-0.006471541479650678, -0.01991741934393826, '1'),
#  ('Hyeon Chung',
#   'Dusan Lajovic'): Text(-0.28490198762533214, -0.3164156425921546, '1'),
#  ('Hyeon Chung',
#   'Joao Sousa'): Text(-0.24701167268334792, -0.29858580723084804, '2'),
#  ('Hyeon Chung',
#   'Tomas Berdych'): Text(-0.9677335262771507, 0.24847176015215408, '1'),
#  ('Hyeon Chung',
#   'Novak Djokovic'): Text(-0.530923883486743, -0.35274500129912933, '1'),
#  ('Hyeon Chung',
#   'Matthew Ebden'): Text(-0.114175435532748, -0.1977576367574763, '1'),
#  ('Hyeon Chung',
#   'Lorenzo Sonego'): Text(-0.6915494301746914, -0.30789754283290105, '1'),
#  ('Hyeon Chung',
#   'David Goffin'): Text(-0.9677334964748284, 0.04056006076664309, '1'),
#  ('Hyeon Chung',
#   'Kevin Anderson'): Text(-0.974717074658951, 0.08184939017137446, '1'),
#  ('Hyeon Chung',
#   'Alex De Minaur'): Text(-0.9063418748312352, -0.11449751804634431, '1'),
#  ('Hyeon Chung',
#   'Andrey Rublev'): Text(-0.32415115435366104, -0.3310122836119809, '1'),
#  ('Hyeon Chung',
#   'Pierre Hugues Herbert'): Text(-0.08681296975651454, -0.16605791980790577, '1'),
#  ('Hyeon Chung',
#   'Kyle Edmund'): Text(0.019586715068171612, 0.10267702623148957, '1'),
#  ...}

# %%
#CENTRALNOSTI
def calculate_centralities(G):

    DC_dict = nx.degree_centrality(G)
    CC_dict = nx.closeness_centrality(G)
    BC_dict = nx.betweenness_centrality(G)
    EVC_dict = nx.eigenvector_centrality(G)

    df1 = pd.DataFrame.from_dict(DC_dict, orient='index', columns=['DC'])
    df2 = pd.DataFrame.from_dict(CC_dict, orient='index', columns=['CC'])
    df3 = pd.DataFrame.from_dict(BC_dict, orient='index', columns=['BC'])
    df4 = pd.DataFrame.from_dict(EVC_dict, orient='index', columns=['EVC'])
    df = pd.concat([df1, df2, df3, df4], axis=1)
    return df
df = calculate_centralities(G)
print(df)
# Out:
#                         DC        CC        BC       EVC
# Tim Smyczek       0.031034  0.347998  0.000462  0.020600
# Bjorn Fratangelo  0.027586  0.332037  0.003535  0.017122
# Liam Broady       0.008621  0.321045  0.000060  0.006299
# Nick Kyrgios      0.105172  0.379331  0.006714  0.082028
# Robin Haase       0.115517  0.390276  0.010821  0.081146
# ...                    ...       ...       ...       ...
# Benjamin Bonzi    0.008621  0.294383  0.000048  0.002559
# Ulises Blanch     0.001724  0.279953  0.000000  0.001497
# Vladimir Ivanov   0.001724  0.288274  0.000000  0.001672
# Jason Kubler      0.010345  0.322253  0.000022  0.008594
# Tatsuma Ito       0.010345  0.304859  0.000068  0.005537
#
# [581 rows x 4 columns]

# %%
#Korelacija - kako jedna metrika zavisi od druge, pozitivna korelacija znači da veća vrednost jedne od metrikka povlači veću vrednost druge metrike. 
#Interesantno je posmatrati Kendalovu tau korelaciju (korelaciju po rangu, ne po numeričkoj vrednosti) između različitih mera centralnosti ove mreže.

# %%
import scipy.stats as stats
labele = ['DC', 'CC', 'BC', 'EVC']
cross_correlation_matrix = pd.DataFrame(columns = ['DC', 'CC', 'BC', 'EVC'], index = ['DC', 'CC', 'BC', 'EVC'])
p_val_matrix = pd.DataFrame(columns = ['DC', 'CC', 'BC', 'EVC'], index = ['DC', 'CC', 'BC', 'EVC'])
for ind in labele:
    for col in labele:
        cross_correlation_matrix[ind][col], p_val_matrix[ind][col] =  stats.kendalltau(df[ind], df[col])
print(cross_correlation_matrix)
# Out:
#            DC        CC        BC       EVC
# DC          1  0.823807  0.717742  0.819532
# CC   0.823807         1  0.565221  0.956007
# BC   0.717742  0.565221         1   0.54637
# EVC  0.819532  0.956007   0.54637         1

# %%
#BC-posmatra samo puteve, najslabije sa EVC

# %%
print(p_val_matrix)
#p treba da bude sto manji, kako ne bi bilo da se slucajno desilo
# Out:
#                DC            CC            BC           EVC
# DC   7.27304e-241  1.28116e-177  2.65134e-127  5.94403e-176
# CC   1.28116e-177  3.17396e-282   3.74667e-86  2.39684e-258
# BC   2.65134e-127   3.74667e-86  1.39453e-249   1.07616e-80
# EVC  5.94403e-176  2.39684e-258   1.07616e-80  1.03532e-282

# %%
df = calculate_centralities(G)

df_ = df
for metric in labele:
    df_[f"{metric}_rank"] = df[f"{metric}"].rank(ascending=False) 
    
df_['composite_rank'] = df_['DC_rank'] * df_['CC_rank'] * df_['BC_rank'] * df_['EVC_rank']

df_.sort_values(['composite_rank'], ascending = True)
df_.sort_values(['CC'], ascending = False, inplace=True)
print(df_)
# Out:
#                            DC        CC        BC           EVC  DC_rank  \
# Karen Khachanov      0.177586  0.431564  0.018198  1.313909e-01      1.0
# Stefanos Tsitsipas   0.170690  0.427259  0.068153  1.302291e-01      2.0
# Gael Monfils         0.162069  0.423388  0.009965  1.243215e-01      6.0
# Alexander Zverev     0.163793  0.421306  0.013706  1.249850e-01      5.0
# Dusan Lajovic        0.153448  0.419929  0.015747  1.167182e-01     15.5
# ...                       ...       ...       ...           ...      ...
# Shahin Khaledan      0.001724  0.001724  0.000000  3.129437e-12    502.0
# Sheil Kotecha        0.001724  0.001724  0.000000  3.129437e-12    502.0
# Jad Ballout          0.001724  0.001724  0.000000  3.129437e-12    502.0
# Nikoloz Davlianidze  0.001724  0.001724  0.000000  3.129437e-12    502.0
# Cristian Rodriguez   0.001724  0.001724  0.000000  3.129437e-12    502.0
#
#                      CC_rank  BC_rank  EVC_rank  composite_rank
# Karen Khachanov          1.0     20.0       1.0    2.000000e+01
# Stefanos Tsitsipas       2.0      1.0       2.0    8.000000e+00
# Gael Monfils             3.0     66.0       5.0    5.940000e+03
# Alexander Zverev         4.0     40.0       4.0    3.200000e+03
# Dusan Lajovic            5.0     26.0      12.0    2.418000e+04
# ...                      ...      ...       ...             ...
# Shahin Khaledan        564.5    495.0     564.5    7.918389e+10
# Sheil Kotecha          564.5    495.0     564.5    7.918389e+10
# Jad Ballout            564.5    495.0     564.5    7.918389e+10
# Nikoloz Davlianidze    564.5    495.0     564.5    7.918389e+10
# Cristian Rodriguez     564.5    495.0     564.5    7.918389e+10
#
# [581 rows x 9 columns]
