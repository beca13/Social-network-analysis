# %%
# Vizuelna podešavanja okruženja (samo razvuče notebook na širinu ekrana)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import pandas as pd

# %%
data2020 = pd.read_csv("../podaci/atp_matches_2020.csv")
data2020.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2020-8888      Atp Cup    Hard         24             A      20200106
# 1  2020-8888      Atp Cup    Hard         24             A      20200106
# 2  2020-8888      Atp Cup    Hard         24             A      20200106
# 3  2020-8888      Atp Cup    Hard         24             A      20200106
# 4  2020-8888      Atp Cup    Hard         24             A      20200106
#
#    match_num  winner_id winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        300     104925         NaN          NaN  ...    51.0     39.0
# 1        299     105138         NaN          NaN  ...    35.0     21.0
# 2        298     104925         NaN          NaN  ...    57.0     35.0
# 3        297     105583         NaN          NaN  ...    54.0     39.0
# 4        296     104745         NaN          NaN  ...    55.0     37.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced winner_rank winner_rank_points  \
# 0       6.0    10.0        6.0        8.0         2.0             9055.0
# 1       6.0     9.0        5.0       10.0        10.0             2335.0
# 2      25.0    14.0        6.0       11.0         2.0             9055.0
# 3      14.0    12.0        0.0        1.0        34.0             1251.0
# 4      10.0    14.0        1.0        5.0         1.0             9985.0
#
#   loser_rank loser_rank_points
# 0        1.0            9985.0
# 1       34.0            1251.0
# 2        5.0            5705.0
# 3       17.0            1840.0
# 4       18.0            1775.0
#
# [5 rows x 49 columns]

# %%
data2019 = pd.read_csv("../podaci/atp_matches_2019.csv")
data2019.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2019-M020     Brisbane    Hard         32             A      20181231
# 1  2019-M020     Brisbane    Hard         32             A      20181231
# 2  2019-M020     Brisbane    Hard         32             A      20181231
# 3  2019-M020     Brisbane    Hard         32             A      20181231
# 4  2019-M020     Brisbane    Hard         32             A      20181231
#
#    match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        300     105453          2.0          NaN  ...    54.0     34.0
# 1        299     106421          4.0          NaN  ...    52.0     36.0
# 2        298     105453          2.0          NaN  ...    27.0     15.0
# 3        297     104542          NaN           PR  ...    60.0     38.0
# 4        296     106421          4.0          NaN  ...    56.0     46.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank winner_rank_points  \
# 0      20.0    14.0       10.0       15.0          9.0             3590.0
# 1       7.0    10.0       10.0       13.0         16.0             1977.0
# 2       6.0     8.0        1.0        5.0          9.0             3590.0
# 3       9.0    11.0        4.0        6.0        239.0              200.0
# 4      19.0    15.0        2.0        4.0         16.0             1977.0
#
#   loser_rank loser_rank_points
# 0       16.0            1977.0
# 1      239.0             200.0
# 2       40.0            1050.0
# 3       31.0            1298.0
# 4       18.0            1855.0
#
# [5 rows x 49 columns]

# %%
data2018 = pd.read_csv("../podaci/atp_matches_2018.csv")
data2018.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2018-M020     Brisbane    Hard         32             A      20180101
# 1  2018-M020     Brisbane    Hard         32             A      20180101
# 2  2018-M020     Brisbane    Hard         32             A      20180101
# 3  2018-M020     Brisbane    Hard         32             A      20180101
# 4  2018-M020     Brisbane    Hard         32             A      20180101
#
#    match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        271     105992          NaN          NaN  ...    47.0     33.0
# 1        272     111577          NaN          NaN  ...    41.0     25.0
# 2        273     104797          NaN          NaN  ...    53.0     37.0
# 3        275     200282          NaN           WC  ...    43.0     33.0
# 4        276     111581          NaN            Q  ...    35.0     28.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank winner_rank_points  \
# 0      19.0    14.0        1.0        4.0         47.0             1010.0
# 1       7.0     9.0        7.0       11.0         54.0              890.0
# 2      29.0    15.0       10.0       16.0         63.0              809.0
# 3      17.0    11.0        4.0        6.0        208.0              245.0
# 4       5.0     9.0        0.0        2.0        175.0              299.0
#
#   loser_rank loser_rank_points
# 0       52.0             909.0
# 1       94.0             593.0
# 2       30.0            1391.0
# 3       44.0            1055.0
# 4       68.0             755.0
#
# [5 rows x 49 columns]

# %%
data = pd.concat([data2020, data2019, data2018])
data.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2020-8888      Atp Cup    Hard         24             A      20200106
# 1  2020-8888      Atp Cup    Hard         24             A      20200106
# 2  2020-8888      Atp Cup    Hard         24             A      20200106
# 3  2020-8888      Atp Cup    Hard         24             A      20200106
# 4  2020-8888      Atp Cup    Hard         24             A      20200106
#
#    match_num  winner_id winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        300     104925         NaN          NaN  ...    51.0     39.0
# 1        299     105138         NaN          NaN  ...    35.0     21.0
# 2        298     104925         NaN          NaN  ...    57.0     35.0
# 3        297     105583         NaN          NaN  ...    54.0     39.0
# 4        296     104745         NaN          NaN  ...    55.0     37.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced winner_rank winner_rank_points  \
# 0       6.0    10.0        6.0        8.0         2.0             9055.0
# 1       6.0     9.0        5.0       10.0        10.0             2335.0
# 2      25.0    14.0        6.0       11.0         2.0             9055.0
# 3      14.0    12.0        0.0        1.0        34.0             1251.0
# 4      10.0    14.0        1.0        5.0         1.0             9985.0
#
#   loser_rank loser_rank_points
# 0        1.0            9985.0
# 1       34.0            1251.0
# 2        5.0            5705.0
# 3       17.0            1840.0
# 4       18.0            1775.0
#
# [5 rows x 49 columns]

# %%
print("Broj redova: ", data.shape[0])
print("Broj kolona: ", data.shape[1])
# Out:
# Broj redova:  7117
# Broj kolona:  49

# %%
dataPlayers = pd.read_csv("../podaci/atp_players.csv")
dataPlayers.head()
# Out:
#    100001         Gardnar    Mulloy  R    19131122  USA
# 0  100002          Pancho    Segura  R  19210620.0  ECU
# 1  100003           Frank   Sedgman  R  19271002.0  AUS
# 2  100004        Giuseppe     Merlo  R  19271011.0  ITA
# 3  100005  Richard Pancho  Gonzales  R  19280509.0  USA
# 4  100006           Grant    Golden  R  19290821.0  USA

# %%
dataPlayers.columns=['player_id','first_name','last_name','hand','birth_date','country_code']
dataPlayers.head()
# Out:
#    player_id      first_name last_name hand  birth_date country_code
# 0     100002          Pancho    Segura    R  19210620.0          ECU
# 1     100003           Frank   Sedgman    R  19271002.0          AUS
# 2     100004        Giuseppe     Merlo    R  19271011.0          ITA
# 3     100005  Richard Pancho  Gonzales    R  19280509.0          USA
# 4     100006           Grant    Golden    R  19290821.0          USA

# %%
print(dataPlayers.dtypes)
# Out:
# player_id         int64
# first_name       object
# last_name        object
# hand             object
# birth_date      float64
# country_code     object
# dtype: object

# %%
print("Broj redova: ", dataPlayers.shape[0])
print("Broj kolona: ", dataPlayers.shape[1])
# Out:
# Broj redova:  54974
# Broj kolona:  6

# %%
#is there any empty field
dataPlayers.isna().any()
# Out:
# player_id       False
# first_name       True
# last_name        True
# hand             True
# birth_date       True
# country_code     True
# dtype: bool

# %%
print(dataPlayers['player_id'].isnull().values.any())
print(dataPlayers['player_id'].is_unique)
# Out:
# False
# True

# %%
#add new column winner with full name
dataPlayers["winner_full_name"] = dataPlayers["first_name"] + " " + dataPlayers["last_name"]
dataPlayers.head()
# Out:
#    player_id      first_name last_name hand  birth_date country_code  \
# 0     100002          Pancho    Segura    R  19210620.0          ECU
# 1     100003           Frank   Sedgman    R  19271002.0          AUS
# 2     100004        Giuseppe     Merlo    R  19271011.0          ITA
# 3     100005  Richard Pancho  Gonzales    R  19280509.0          USA
# 4     100006           Grant    Golden    R  19290821.0          USA
#
#           winner_full_name
# 0            Pancho Segura
# 1            Frank Sedgman
# 2           Giuseppe Merlo
# 3  Richard Pancho Gonzales
# 4             Grant Golden

# %%
#add new column winner with full name
dataPlayers["loser_full_name"] = dataPlayers["first_name"] + " " + dataPlayers["last_name"]
dataPlayers.head()
# Out:
#    player_id      first_name last_name hand  birth_date country_code  \
# 0     100002          Pancho    Segura    R  19210620.0          ECU
# 1     100003           Frank   Sedgman    R  19271002.0          AUS
# 2     100004        Giuseppe     Merlo    R  19271011.0          ITA
# 3     100005  Richard Pancho  Gonzales    R  19280509.0          USA
# 4     100006           Grant    Golden    R  19290821.0          USA
#
#           winner_full_name          loser_full_name
# 0            Pancho Segura            Pancho Segura
# 1            Frank Sedgman            Frank Sedgman
# 2           Giuseppe Merlo           Giuseppe Merlo
# 3  Richard Pancho Gonzales  Richard Pancho Gonzales
# 4             Grant Golden             Grant Golden

# %%
#check if match number is unique
print(data['match_num'].isnull().values.any())
print(data['match_num'].is_unique)
# Out:
# False
# False

# %%
#add column match_id as unique
data['match_id'] = data.index
data.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2020-8888      Atp Cup    Hard         24             A      20200106
# 1  2020-8888      Atp Cup    Hard         24             A      20200106
# 2  2020-8888      Atp Cup    Hard         24             A      20200106
# 3  2020-8888      Atp Cup    Hard         24             A      20200106
# 4  2020-8888      Atp Cup    Hard         24             A      20200106
#
#    match_num  winner_id winner_seed winner_entry  ... l_1stWon l_2ndWon  \
# 0        300     104925         NaN          NaN  ...     39.0      6.0
# 1        299     105138         NaN          NaN  ...     21.0      6.0
# 2        298     104925         NaN          NaN  ...     35.0     25.0
# 3        297     105583         NaN          NaN  ...     39.0     14.0
# 4        296     104745         NaN          NaN  ...     37.0     10.0
#
#    l_SvGms l_bpSaved  l_bpFaced  winner_rank winner_rank_points loser_rank  \
# 0     10.0       6.0        8.0          2.0             9055.0        1.0
# 1      9.0       5.0       10.0         10.0             2335.0       34.0
# 2     14.0       6.0       11.0          2.0             9055.0        5.0
# 3     12.0       0.0        1.0         34.0             1251.0       17.0
# 4     14.0       1.0        5.0          1.0             9985.0       18.0
#
#   loser_rank_points match_id
# 0            9985.0        0
# 1            1251.0        1
# 2            5705.0        2
# 3            1840.0        3
# 4            1775.0        4
#
# [5 rows x 50 columns]

# %%
data_short=data[['match_num','winner_id','loser_id','match_id']]
data_short.head()
# Out:
#    match_num  winner_id  loser_id  match_id
# 0        300     104925    104745         0
# 1        299     105138    105583         1
# 2        298     104925    106421         2
# 3        297     105583    111575         3
# 4        296     104745    200282         4

# %%
dataPlayers.head()
# Out:
#    player_id      first_name last_name hand  birth_date country_code  \
# 0     100002          Pancho    Segura    R  19210620.0          ECU
# 1     100003           Frank   Sedgman    R  19271002.0          AUS
# 2     100004        Giuseppe     Merlo    R  19271011.0          ITA
# 3     100005  Richard Pancho  Gonzales    R  19280509.0          USA
# 4     100006           Grant    Golden    R  19290821.0          USA
#
#           winner_full_name          loser_full_name
# 0            Pancho Segura            Pancho Segura
# 1            Frank Sedgman            Frank Sedgman
# 2           Giuseppe Merlo           Giuseppe Merlo
# 3  Richard Pancho Gonzales  Richard Pancho Gonzales
# 4             Grant Golden             Grant Golden

# %%
dataPlayers_short_winner = dataPlayers[['player_id','winner_full_name']]
dataPlayers_short_winner.head()
# Out:
#    player_id         winner_full_name
# 0     100002            Pancho Segura
# 1     100003            Frank Sedgman
# 2     100004           Giuseppe Merlo
# 3     100005  Richard Pancho Gonzales
# 4     100006             Grant Golden

# %%
dataPlayers_short_loser=dataPlayers[['player_id','loser_full_name']]
dataPlayers_short_loser.head()
# Out:
#    player_id          loser_full_name
# 0     100002            Pancho Segura
# 1     100003            Frank Sedgman
# 2     100004           Giuseppe Merlo
# 3     100005  Richard Pancho Gonzales
# 4     100006             Grant Golden

# %%
#merge three tables
merged_data=data_short.merge(dataPlayers_short_winner,left_on='winner_id', right_on='player_id').drop('player_id', axis=1).merge(dataPlayers_short_loser,left_on='loser_id', right_on='player_id').drop('player_id', axis=1)
merged_data.head()
# Out:
#    match_num  winner_id  loser_id  match_id winner_full_name loser_full_name
# 0        300     104925    104745         0   Novak Djokovic    Rafael Nadal
# 1        226     104925    104745       139   Novak Djokovic    Rafael Nadal
# 2        225     104925    104745      1838   Novak Djokovic    Rafael Nadal
# 3        299     106421    104745      1324  Daniil Medvedev    Rafael Nadal
# 4        293     106401    104745       528     Nick Kyrgios    Rafael Nadal

# %%
player_asm = merged_data[['winner_id','loser_id','match_id','winner_full_name','loser_full_name']]
player_asm.head()
# Out:
#    winner_id  loser_id  match_id winner_full_name loser_full_name
# 0     104925    104745         0   Novak Djokovic    Rafael Nadal
# 1     104925    104745       139   Novak Djokovic    Rafael Nadal
# 2     104925    104745      1838   Novak Djokovic    Rafael Nadal
# 3     106421    104745      1324  Daniil Medvedev    Rafael Nadal
# 4     106401    104745       528     Nick Kyrgios    Rafael Nadal

# %%
#id player unique
list_winner = set(player_asm['winner_full_name'].unique())
list_loser = set(player_asm['loser_full_name'].unique())

skup_id = list_winner.union(list_loser)
print(f"Postoji { len(skup_id) } različitih igrača") # formatiranje ispisa pomoću fstringa
# Out:
# Postoji 581 različitih igrača

# %%
import numpy as np
import matplotlib.pyplot as plt

data_reduced = player_asm[['winner_full_name','loser_full_name','match_id']]

# %%
import networkx as nx
G = nx.Graph() # pravi praznu mrežu
G.add_nodes_from(skup_id) # dodaje čvorove čije su labele u "skup_id"

# %%
#agregacija brojanjem
for _, winner_full_name, loser_full_name, _ in data_reduced.itertuples():
    if (winner_full_name, loser_full_name) in G.edges:
        G.edges[winner_full_name, loser_full_name]['weight'] += 1
    else:
        G.add_edge(winner_full_name, loser_full_name, weight=1)

# %%
print(G.edges.data("weight"))

nx.draw_networkx(G)#-> crta mrežu, ne pokušavati za mrežu sa ovoliko čvorova i grana!
# Out:
# [('Harri Heliovaara', 'Dennis Novak', 1), ('Harri Heliovaara', 'Ricardas Berankis', 1), ('Harri Heliovaara', 'Gerardo Lopez Villasenor', 1), ('Harri Heliovaara', 'Malek Jaziri', 1), ('Harri Heliovaara', 'Mohamed Safwat', 1), ('Harri Heliovaara', 'Karim Mohamed Maamoun', 1), ('Harri Heliovaara', 'Laurynas Grigelis', 1), ('Harri Heliovaara', 'Moez Chargui', 1), ('Francisco Llanes', 'Brandon Perez', 1), ('Jan Lennard Struff', 'Denis Shapovalov', 5), ('Jan Lennard Struff', 'Novak Djokovic', 4), ('Jan Lennard Struff', 'Roberto Bautista Agut', 2), ('Jan Lennard Struff', 'Rafael Nadal', 1), ('Jan Lennard Struff', 'Daniil Medvedev', 1), ('Jan Lennard Struff', 'Karen Khachanov', 3), ('Jan Lennard Struff', 'Daniel Evans', 1), ('Jan Lennard Struff', 'Nick Kyrgios', 3), ('Jan Lennard Struff', 'David Goffin', 3), ('Jan Lennard Struff', 'Gael Monfils', 1), ('Jan Lennard Struff', 'Yoshihito Nishioka', 2), ('Jan Lennard Struff', 'Go Soeda', 1), ('Jan Lennard Struff', 'Nikoloz Basilashvili', 3), ('Jan Lennard Struff', 'Grigor Dimitrov', 2), ('Jan Lennard Struff', 'Cameron Norrie', 1), ('Jan Lennard Struff', 'Borna Coric', 2), ('Jan Lennard Struff', 'Marin Cilic', 3), ('Jan Lennard Struff', 'Dominic Thiem', 1), ('Jan Lennard Struff', 'Stefanos Tsitsipas', 5), ('Jan Lennard Struff', 'Alex De Minaur', 3), ('Jan Lennard Struff', 'Felix Auger Aliassime', 2), ('Jan Lennard Struff', 'John Millman', 3), ('Jan Lennard Struff', 'Marton Fucsovics', 1), ('Jan Lennard Struff', 'Pierre Hugues Herbert', 1), ('Jan Lennard Struff', 'Jeremy Chardy', 2), ('Jan Lennard Struff', 'Mikhail Kukushkin', 1), ('Jan Lennard Struff', 'Pablo Carreno Busta', 3), ('Jan Lennard Struff', 'Alex Bolt', 1), ('Jan Lennard Struff', 'John Isner', 1), ('Jan Lennard Struff', 'Mikael Ymer', 1), ('Jan Lennard Struff', 'Thiago Monteiro', 2), ('Jan Lennard Struff', 'Marco Cecchinato', 3), ('Jan Lennard Struff', 'Vasek Pospisil', 1), ('Jan Lennard Struff', 'Yuichi Sugita', 2), ('Jan Lennard Struff', 'Alexander Zverev', 3), ('Jan Lennard Struff', 'Matteo Berrettini', 2), ('Jan Lennard Struff', 'Jordan Thompson', 1), ('Jan Lennard Struff', 'Roger Federer', 3), ('Jan Lennard Struff', 'Christian Garin', 1), ('Jan Lennard Struff', 'Milos Raonic', 2), ('Jan Lennard Struff', 'Richard Gasquet', 1), ('Jan Lennard Struff', 'Taro Daniel', 1), ('Jan Lennard Struff', 'Viktor Troicki', 1), ('Jan Lennard Struff', 'Reilly Opelka', 1), ('Jan Lennard Struff', 'Steve Johnson', 1), ('Jan Lennard Struff', 'Francis Tiafoe', 2), ('Jan Lennard Struff', 'Federico Coria', 1), ('Jan Lennard Struff', 'Kei Nishikori', 1), ('Jan Lennard Struff', 'Daniel Altmaier', 1), ('Jan Lennard Struff', 'Oscar Otte', 1), ('Jan Lennard Struff', 'Damir Dzumhur', 1), ('Jan Lennard Struff', 'Jo Wilfried Tsonga', 2), ('Jan Lennard Struff', 'Nicolas Jarry', 1), ('Jan Lennard Struff', 'Matthew Ebden', 1), ('Jan Lennard Struff', 'Rudolf Molleker', 1), ('Jan Lennard Struff', 'Alexey Vatutin', 1), ('Jan Lennard Struff', 'Diego Sebastian Schwartzman', 1), ('Jan Lennard Struff', 'Ricardas Berankis', 1), ('Jan Lennard Struff', 'Casper Ruud', 1), ('Jan Lennard Struff', 'Salvatore Caruso', 1), ('Jan Lennard Struff', 'Lucas Pouille', 1), ('Jan Lennard Struff', 'Taylor Harry Fritz', 1), ('Jan Lennard Struff', 'Henri Laaksonen', 1), ('Jan Lennard Struff', 'Benoit Paire', 1), ('Jan Lennard Struff', 'Feliciano Lopez', 1), ('Jan Lennard Struff', 'Michael Mmoh', 1), ('Jan Lennard Struff', 'Miomir Kecmanovic', 2), ('Jan Lennard Struff', 'Tomas Berdych', 1), ('Jan Lennard Struff', 'Fabio Fognini', 1), ('Jan Lennard Struff', 'Marius Copil', 1), ('Jan Lennard Struff', 'Ivo Karlovic', 2), ('Jan Lennard Struff', 'Laslo Djere', 2), ('Jan Lennard Struff', 'Andrey Rublev', 1), ('Jan Lennard Struff', 'Pedro Martinez Portero', 1), ('Jan Lennard Struff', 'Hugo Dellien', 1), ('Jan Lennard Struff', 'Soon Woo Kwon', 1), ('Jan Lennard Struff', 'Egor Gerasimov', 1), ('Jan Lennard Struff', 'Stefano Travaglia', 1), ('Jan Lennard Struff', 'Leonardo Mayer', 1), ('Jan Lennar ...
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
output = "models/undirected_count_aggregationFull.gml"

nx.write_gml(G, output)

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 581
# Number of edges: 5330
# Average degree:  18.3477

# %%
import matplotlib.pyplot as plt
import networkx as nx

def plot_degree_dist(G):
    degrees = [G.degree(n) for n in G.nodes()]
    plt.hist(degrees)
    plt.xlabel("Degree")
    plt.ylabel("Number of nodes")
    
    plt.show()

plot_degree_dist(G)

# %%
import networkx as nx
import matplotlib.pyplot as plt

degree_freq = nx.degree_histogram(G)
degrees = range(len(degree_freq))
plt.figure(figsize=(12, 8)) 
plt.loglog(degrees, degree_freq,'bo') 
plt.title("Distribution plot")
plt.xlabel('Degree')
plt.ylabel('Frequency of nodes')
#plt.savefig('./output/Gd_degree_distributionLog.pdf')
# Out:
# Text(0, 0.5, 'Frequency of nodes')

# %%
import collections
degree_sequence = sorted([d for n, d in G.degree()], reverse=True)  # degree sequence
degreeCount = collections.Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())
cs = np.cumsum(cnt)
plt.loglog(deg, cs, 'bo')
plt.title("Cumulative Distribution plot")
plt.ylabel("Sample with value > Degree")
plt.xlabel("Degree")
plt.show()

# %%
# možemo iskoristiti networkx.draw_network da predstavimo egomrežu tog čvora
ego_mreza = nx.ego_graph(G, 'Novak Djokovic')
print(f"Čvorovi ego mreže igrača Novak Djokovic su {ego_mreza.nodes}")
plt.figure(figsize=(15,10))
tezine_grana = nx.get_edge_attributes(ego_mreza,'weight')
pos = nx.circular_layout(ego_mreza)
#pos = nx.spring_layout(ego_mreza)
#print(pos)
nx.draw_networkx(ego_mreza, pos)
nx.draw_networkx_edge_labels(ego_mreza, pos, edge_labels = tezine_grana)
# Out:
# Čvorovi ego mreže igrača Novak Djokovic su ['Jan Lennard Struff', 'Rogerio Dutra Silva', 'Salvatore Caruso', 'Stanislas Wawrinka', 'Lucas Pouille', 'Alexandr Dolgopolov', 'Alexander Zverev', 'Richard Gasquet', 'Kyle Edmund', 'Joao Sousa', 'Tennys Sandgren', 'Ricardas Berankis', 'Dominic Thiem', 'Malek Jaziri', 'Filip Krajinovic', 'Martin Klizan', 'Mikael Ymer', 'Taro Daniel', 'Kei Nishikori', 'Tatsuma Ito', 'Juan Ignacio Londero', 'Gael Monfils', 'Roberto Bautista Agut', 'David Goffin', 'Go Soeda', 'Fernando Verdasco', 'Bjorn Fratangelo', 'Marton Fucsovics', 'Pablo Carreno Busta', 'Benoit Paire', 'Jeremy Chardy', 'Denis Kudla', 'Hyeon Chung', 'Jaume Munar', 'Daniel Elahi Galan Riveros', 'Stefanos Tsitsipas', 'Alexei Popyrin', 'Milos Raonic', 'Grigor Dimitrov', 'Kevin Anderson', 'Nikoloz Basilashvili', 'Daniil Medvedev', 'Horacio Zeballos', 'Mitchell Krueger', 'Denis Shapovalov', 'Christian Garin', 'Casper Ruud', 'Albert Ramos', 'Peter Polansky', 'Bernard Tomic', 'Karen Khachanov', 'Rafael Nadal', 'Donald Young', 'Novak Djokovic', 'Roberto Carballes Baena', 'Ugo Humbert', 'Marco Cecchinato', 'John Isner', 'Mirza Basic', 'Dominik Koepfer', 'Juan Martin Del Potro', 'Philipp Kohlschreiber', 'Marin Cilic', 'Jo Wilfried Tsonga', 'Adrian Mannarino', 'Federico Delbonis', 'Taylor Harry Fritz', 'Matteo Berrettini', 'Borna Coric', 'John Millman', 'Steve Johnson', 'Sam Querrey', 'Dusan Lajovic', 'Henri Laaksonen', 'Diego Sebastian Schwartzman', 'Damir Dzumhur', 'Hubert Hurkacz', 'Lorenzo Sonego', 'Roger Federer', 'Yoshihito Nishioka', 'Corentin Moutet']
# {('Jan Lennard Struff',
#   'Denis Shapovalov'): Text(0.018314568201969417, -0.13408630483403422, '5'),
#  ('Jan Lennard Struff',
#   'Novak Djokovic'): Text(0.21719649275680403, -0.41233744670684547, '4'),
#  ('Jan Lennard Struff',
#   'Roberto Bautista Agut'): Text(0.43233434741064314, 0.4954001976566923, '2'),
#  ('Jan Lennard Struff',
#   'Rafael Nadal'): Text(0.1568792147264199, -0.3636868540428589, '1'),
#  ('Jan Lennard Struff',
#   'Daniil Medvedev'): Text(0.0003760138787118894, -0.019387665462395353, '1'),
#  ('Jan Lennard Struff',
#   'Karen Khachanov'): Text(0.12972801747642326, -0.3360039535580674, '3'),
#  ('Jan Lennard Struff',
#   'David Goffin'): Text(0.3941480579633089, 0.48866692914369236, '3'),
#  ('Jan Lennard Struff',
#   'Gael Monfils'): Text(0.47092758757100495, 0.4991540981922428, '1'),
#  ('Jan Lennard Struff',
#   'Yoshihito Nishioka'): Text(0.9939949512360171, -0.07725931834656746, '2'),
#  ('Jan Lennard Struff',
#   'Go Soeda'): Text(0.35659837592578636, 0.47899476420712744, '1'),
#  ('Jan Lennard Struff',
#   'Nikoloz Basilashvili'): Text(0.0003760138787118894, 0.019387709728962258, '3'),
#  ('Jan Lennard Struff',
#   'Grigor Dimitrov'): Text(0.00937235154912347, 0.09635616743452717, '2'),
#  ('Jan Lennard Struff',
#   'Borna Coric'): Text(0.7666021282718181, -0.4229932670981292, '2'),
#  ('Jan Lennard Struff',
#   'Marin Cilic'): Text(0.54840553460527, -0.49765139288817023, '3'),
#  ('Jan Lennard Struff',
#   'Dominic Thiem'): Text(0.7985793050027874, 0.40106160159863036, '1'),
#  ('Jan Lennard Struff',
#   'Stefanos Tsitsipas'): Text(0.04481854841536276, 0.20690541641321444, '5'),
#  ('Jan Lennard Struff',
#   'John Millman'): Text(0.7985793050027874, -0.401061588997031, '3'),
#  ('Jan Lennard Struff',
#   'Marton Fucsovics'): Text(0.24999996867996666, 0.43301270129745756, '1'),
#  ('Jan Lennard Struff',
#   'Jeremy Chardy'): Text(0.15687915512177503, 0.3636868070398133, '2'),
#  ('Jan Lennard Struff',
#   'Pablo Carreno Busta'): Text(0.21719652255912647, 0.41233748911076723, '3'),
#  ('Jan Lennard Struff',
#   'John Isner'): Text(0.35659834612346386, -0.4789947516055281, '1'),
#  ('Jan Lennard Struff',
#   'Mikael Ymer'): Text(0.6618669473242864, 0.47307408581799476, '1'),
#  ('Jan Lennard Struff',
#   'Marco Cecchinato'): Text(0.3199111954516509, -0.4664418643788167, '3'),
#  ('Jan Lennard Struff',
#   'Alexander Zverev'): Text(0.9468163250800599, 0.224399603207611, '3'),
#  ('Jan Lennard Struff',
#   'Matteo Berrettini'): Text(0.733021765407081, -0.442380899745776, '2'),
#  ('Jan Lennard Struff',
#   'Roger Federer'): Text(0.9865224361146945, -0.11530797321825627, '3'),
#  ('Jan Lennard Struff',
#   'Christian Garin'): Text(0.030153689806051154, -0.17101007104492313, '1'),
#  ('Jan Lennard Struff',
#   'Milos Raonic'): Text(0.018314568201969417, 0.134086347237956, '2'),
#  ('Jan Lennard Struff',
#   'Richard Gasquet'): Text(0.9280834494565957, 0.25834969368463806, '1'),
#  ('Jan Lennard Struff',
#   'Taro Daniel'): Text(0.6247205950176139, 0.4841949714510796, '1'),
#  ('Jan Lennard Struff',
#   'Steve Johnson'): Text(0.8287606235853624, -0.3767180089402159, '1'),
#  ('Jan Lennard Struff',
#   'Kei Nishikori'): Text(0.5868241108043446, 0.49240387215777, '1'),
#  ('Jan Lennard Struff',
#   'Damir Dzumhur'): Text(0.9468163548823824, -0.22439953100136675, '1'),
#  ('Jan Lennard Struff',
#   'Jo Wilfried Tsonga'): Text(0.5868240735514416, -0.49240385955617066, '2'),
#  ('Jan Lennard Struff',
#   'Diego Sebastian Schwartzman'): Text(0.9280834196542733, -0.2583497406876836, '1'),
#  ('Jan Lennard Struff',
#   'Ricardas Berankis'): Text(0.8287606831900072, 0.37671796193717033, '1'),
#  ('Jan Lennard Struff',
#   'Casper Ruud'): Text(0.044818518613040315, -0.20690537400929265, '1'),
#  ('Jan Lennard Struff',
#   'Salvatore Caruso'): Text(0.9939949214336947, 0.07725940545397289, '1'),
#  ('Jan Lennard Struff',
#   'Lucas Pouille'): Text(0.9761239289754268, 0.15266301398830895, '1'),
#  ('Jan Lennard Struff',
#   'Taylor Harry Fritz'): Text(0.698039784416453, -0.4591080790684895, '1'),
#  ('Jan Lennard Struff',
#   'Henri Laaksonen'): Text(0.9067760704061383, -0.2907459976769167, '1'),
#  ('Jan Lennard Struff',
#   'Benoit Paire'): Text(0.18609389498039391, 0.3891824256731785, '1'),
#  ('Rogerio Dutra Silva',
#   'Tennys Sandgren'): Text(0.855461328929235, 0.38885490187476524, '1'),
#  ('Rogerio Dutra Silva',
#   'Novak Djokovic'): Text(0.2156929655893023, -0.3735912349506484, '1'),
#  ('Rogerio Dutra Silva',
#   'Denis Shapovalov'): Text(0.016811041034467678, -0.09534009307783714, '1'),
#  ('Rogerio Dutra Silva',
#   'Jeremy Chardy'): Text(0.1553756279542733, 0.4024330187960104, '1'),
#  ('Rogerio Dutra Silva',
#   'Albert Ramos'): Text(0.060717372185634055, -0.20281009904597114, '3'),
#  ('Rogerio Dutra Silva',
#   'Taro Daniel'): Text(0.6232170678501122, 0.5229411832072767, '1'),
#  ('Rogerio Dutra Silva',
#   'Horacio Zeballos'): Text(0.001877305872030166, -0.019300231036268364, '1'),
#  ('Salvatore Caruso',
#   'Tennys Sandgren'): Text(0.8509597775304314, 0.4273680892717414, '1'),
#  ('Salvatore Caruso',
#   'Novak Djokovic'): Text(0.2111914141904987, -0.3350780475536722, '2'),
#  ('Salvatore Caruso',
#   'Dusan Lajovic'): Text(0.8770170805349741, -0.244134472464242, '1'),
#  ('Salvatore Caruso',
#   'Casper Ruud'): Text(0.03881344004673498, -0.12964597485611942, '1'),
#  ('Salvatore Caruso',
#   'Stefanos Tsitsipas'): Text(0.038813469849057425, 0.2841648155663877, '1'),
#  ('Salvatore Caruso',
#   'Corentin Moutet'): Text(0.9924913942661929, 0.03851315644487274, '2'),
#  ('Salvatore Caruso',
#   'Filip Krajinovic'): Text(0.7270166719396144, 0.5196403115005486, '1'),
#  ('Salvatore Caruso',
#   'Federico Delbonis'): Text(0.6558618985603035, -0.39581467406322224, '1'),
#  ('Salvatore Caruso',
#   'Jaume Munar'): Text(0.0762510579012724, 0.3520139302409272, '2'),
#  ('Salvatore Caruso',
#   'Christian Garin'): Text(0.02414861123974582, -0.0937506718917499, '1'),
#  ('Salvatore Caruso',
#   'Richard Gasquet'): Text(0.9220783708902904, 0.33560909283781126, '1'),
#  ('Salvatore Caruso',
#   'Malek Jaziri'): Text(0.7605971391124802, 0.5002526192482568, '1'),
#  ('Salvatore Caruso',
#   'Borna Coric'): Text(0.7605970497055128, -0.345733867944956, '1'),
#  ('Stanislas Wawrinka',
#   'Daniil Medvedev'): Text(-0.013101550006593687, 0.09592026935317688, '2'),
#  ('Stanislas Wawrinka',
#   'Denis Shapovalov'): Text(0.00483700431666384, -0.018778370018461985, '3'),
#  ('Stanislas Wawrinka',
#   'Christian Garin'): Text(0.016676125920745577, -0.0557021362293509, '2'),
#  ('Stanislas Wawrinka',
#   'Diego Sebastian Schwartzman'): Text(0.9146058557689678, -0.1430418058721114, '1'),
#  ('Stanislas Wawrinka',
#   'Milos Raonic'): Text(0.00483700431666384, 0.24939428205352826, '3'),
#  ('Stanislas Wawrinka',
#   'Stefanos Tsitsipas'): Text(0.03134098453005718, 0.3222133512287867, '1'),
#  ('Stanislas Wawrinka',
#   'Karen Khachanov'): Text(0.11625045359111769, -0.22069601874249517, '3'),
#  ('Stanislas Wawrinka',
#   'Ricardas Berankis'): Text(0.8152831193047017, 0.49202589675274255, '1'),
#  ('Stanislas Wawrinka',
#   'Damir Dzumhur'): Text(0.9333387909970767, -0.10909159618579452, '3'),
#  ('Stanislas Wawrinka',
#   'Dominik Koepfer'): Text(0.4188567537230151, -0.38009225023952076, '1'),
#  ('Stanislas Wawrinka',
#   'Marton Fucsovics'): Text(0.23652240479466108, 0.5483206361130298, '4'),
#  ('Stanislas Wawrinka',
#   'Kei Nishikori'): Text(0.5733465469190391, 0.6077118069733423, '3'),
#  ('Stanislas Wawrinka',
#   'Lucas Pouille'): Text(0.9626463650901211, 0.26797094880388117, '1'),
#  ('Stanislas Wawrinka',
#   'Taylor Harry Fritz'): Text(0.6845622205311473, -0.3438001442529173, '1'),
#  ('Stanislas Wawrinka',
#   'Marin Cilic'): Text(0.5349279707199645, -0.382343458072598, '1'),
#  ('Stanislas Wawrinka',
#   'Jeremy Chardy'): Text(0.14340159123646945, 0.47899474185538554, '2'),
#  ('Stanislas Wawrinka',
#   'Ugo Humbert'): Text(0.27082934828068056, -0.33577574972450247, '1'),
#  ('Stanislas Wawrinka',
#   'John Isner'): Text(0.34312078223815834, -0.3636868167899559, '1'),
#  ('Stanislas Wawrinka',
#   'Grigor Dimitrov'): Text(-0.004105212336182107, 0.2116641022500994, '6'),
#  ('Stanislas Wawrinka',
#   'Benoit Paire'): Text(0.17261633109508834, 0.5044903604887507, '1'),
#  ('Stanislas Wawrinka',
#   'Steve Johnson'): Text(0.8152830597000568, -0.2614100741246437, '2'),
#  ('Stanislas Wawrinka',
#   'Novak Djokovic'): Text(0.20371892887149845, -0.29702951189127325, '1'),
#  ('Stanislas Wawrinka',
#   'Roberto Bautista Agut'): Text(0.41885678352533756, 0.6107081324722645, '1'),
#  ('Stanislas Wawrinka',
#   'Rafael Nadal'): Text(0.14340165084111434, -0.24837891922728667, '3'),
#  ('Stanislas Wawrinka',
#   'David Goffin'): Text(0.38067049407800324, 0.6039748639592646, '1'),
#  ('Stanislas Wawrinka',
#   'Gael Monfils'): Text(0.45745002368569937, 0.6144620330078151, '1'),
#  ('Stanislas Wawrinka',
#   'Borna Coric'): Text(0.7531245643865125, -0.30768533228255696, '1'),
#  ('Stanislas Wawrinka',
#   'Corentin Moutet'): Text(0.9850189089471927, 0.07656169210727175, '1'),
#  ('Stanislas Wawrinka',
#   'Filip Krajinovic'): Text(0.7195441866206141, 0.5576888471629475, '1'),
#  ('Stanislas Wawrinka',
#   'Sam Querrey'): Text(0.8434873220137535, -0.23480071289907417, '1'),
#  ('Stanislas Wawrinka',
#   'Tennys Sandgren'): Text(0.8434872922114311, 0.4654166249341404, '1'),
#  ('Stanislas Wawrinka',
#   'Marco Cecchinato'): Text(0.3064336315663453, -0.35113392956324446, '1'),
#  ('Stanislas Wawrinka',
#   'Alexander Zverev'): Text(0.9333387611947543, 0.3397075380231832, '2'),
#  ('Stanislas Wawrinka',
#   'Roger Federer'): Text(0.9730448722293888, -3.840268403276781e-08, '4'),
#  ('Stanislas Wawrinka',
#   'Martin Klizan'): Text(0.6845622950369534, 0.5744159966833386, '2'),
#  ('Stanislas Wawrinka',
#   'Mirza Basic'): Text(0.38067057603439003, -0.37335901152884327, '1'),
#  ('Stanislas Wawrinka',
#   'Donald Young'): Text(0.17261642050205567, -0.27387453786065186, '1'),
#  ('Lucas Pouille',
#   'Daniil Medvedev'): Text(-0.02350005714586134, 0.13327534222511395, '3'),
#  ('Lucas Pouille',
#   'Denis Shapovalov'): Text(-0.005561502822603814, 0.01857670285347507, '1'),
#  ('Lucas Pouille',
#   'Yoshihito Nishioka'): Text(0.9701188802114439, 0.07540368934094183, '1'),
#  ('Lucas Pouille',
#   'Milos Raonic'): Text(-0.005561502822603814, 0.28674935492546527, '3'),
#  ('Lucas Pouille',
#   'Karen Khachanov'): Text(0.10585194645185003, -0.1833409458705581, '4'),
#  ('Lucas Pouille',
#   'Philipp Kohlschreiber'): Text(0.485819571542338, -0.3472429606961749, '2'),
#  ('Lucas Pouille',
#   'Roberto Bautista Agut'): Text(0.4084582763860699, 0.6480632053442016, '2'),
#  ('Lucas Pouille',
#   'Filip Krajinovic'): Text(0.7091456794813464, 0.5950439200348846, '3'),
#  ('Lucas Pouille',
#   'Borna Coric'): Text(0.7427260572472448, -0.2703302594106199, '3'),
#  ('Lucas Pouille',
#   'Novak Djokovic'): Text(0.1933204217322308, -0.2596744390193362, '3'),
#  ('Lucas Pouille',
#   'Benoit Paire'): Text(0.16221782395582068, 0.5418454333606878, '2'),
#  ('Lucas Pouille',
#   'Marin Cilic'): Text(0.5245294635806967, -0.34498838520066094, '1'),
#  ('Lucas Pouille',
#   'Hubert Hurkacz'): Text(0.9389858840661367, -0.03643696877522354, '3'),
#  ('Lucas Pouille',
#   'Stefanos Tsitsipas'): Text(0.020942477390789527, 0.35956842410072376, '1'),
#  ('Lucas Pouille',
#   'John Millman'): Text(0.7747032339782141, -0.2483985813095217, '1'),
#  ('Lucas Pouille',
#   'Albert Ramos'): Text(0.038344828328562564, -0.08889330311465893, '1'),
#  ('Lucas Pouille',
#   'John Isner'): Text(0.33272227509889063, -0.32633174391801884, '1'),
#  ('Lucas Pouille',
#   'Kyle Edmund'): Text(0.8828999695792427, 0.4434090477683478, '1'),
#  ('Lucas Pouille',
#   'Tennys Sandgren'): Text(0.8330887850721636, 0.5027716978060774, '1'),
#  ('Lucas Pouille',
#   'Matteo Berrettini'): Text(0.7091456943825076, -0.2897178920582667, '1'),
#  ('Lucas Pouille',
#   'Roger Federer'): Text(0.9626463650901211, 0.03735503446925302, '1'),
#  ('Lucas Pouille',
#   'Joao Sousa'): Text(0.8591461476813511, 0.4740568024995565, '1'),
#  ('Lucas Pouille',
#   'Jo Wilfried Tsonga'): Text(0.5629480025268684, -0.3397408518686614, '2'),
#  ('Lucas Pouille',
#   'Denis Kudla'): Text(0.10585188684720515, 0.4886669142425311, '3'),
#  ('Lucas Pouille',
#   'Martin Klizan'): Text(0.6741637878976858, 0.6117710695552756, '1'),
#  ('Lucas Pouille',
#   'Alexei Popyrin'): Text(0.006277618781477923, 0.3236731211363542, '1'),
#  ('Lucas Pouille',
#   'Richard Gasquet'): Text(0.9042073784320226, 0.41101270137214735, '2'),
#  ('Lucas Pouille',
#   'Lorenzo Sonego'): Text(0.9522478877531759, 8.08066057955692e-08, '1'),
#  ('Alexandr Dolgopolov',
#   'Diego Sebastian Schwartzman'): Text(0.8909454045473058, -0.06924981752879603, '2'),
#  ('Alexandr Dolgopolov',
#   'Novak Djokovic'): Text(0.18005847764983646, -0.22323752354795787, '1'),
#  ('Alexandr Dolgopolov',
#   'Horacio Zeballos'): Text(-0.033757182067435665, 0.13105348036642214, '1'),
#  ('Alexander Zverev',
#   'Rafael Nadal'): Text(0.10369553980647983, -0.13928725713604756, '4'),
#  ('Alexander Zverev',
#   'Daniil Medvedev'): Text(-0.05280766104122819, 0.20501193144441598, '6'),
#  ('Alexander Zverev',
#   'Denis Shapovalov'): Text(-0.034869106717970666, 0.09031329207277711, '3'),
#  ('Alexander Zverev',
#   'Kevin Anderson'): Text(-0.04980284188040818, 0.28244608582848885, '1'),
#  ('Alexander Zverev',
#   'Diego Sebastian Schwartzman'): Text(0.8748997447343332, -0.0339501437808723, '4'),
#  ('Alexander Zverev',
#   'Roger Federer'): Text(0.9333387611947543, 0.10909162368855506, '2'),
#  ('Alexander Zverev',
#   'Dominic Thiem'): Text(0.7453956300828473, 0.6254611985054417, '5'),
#  ('Alexander Zverev',
#   'Stefanos Tsitsipas'): Text(-0.008365126504577325, 0.4313050133200258, '6'),
#  ('Alexander Zverev',
#   'Karen Khachanov'): Text(0.07654434255648318, -0.11160435665125606, '3'),
#  ('Alexander Zverev',
#   'Philipp Kohlschreiber'): Text(0.45651196764697116, -0.27550637147687285, '2'),
#  ('Alexander Zverev',
#   'Malek Jaziri'): Text(0.7134185427588453, 0.647392817001895, '2'),
#  ('Alexander Zverev',
#   'Roberto Bautista Agut'): Text(0.37915067249070306, 0.7197997945635036, '2'),
#  ('Alexander Zverev',
#   'Ricardas Berankis'): Text(0.7755770082700671, 0.6011175588439817, '1'),
#  ('Alexander Zverev',
#   'Damir Dzumhur'): Text(0.8936326799624423, 6.590544457396597e-08, '1'),
#  ('Alexander Zverev',
#   'Kyle Edmund'): Text(0.8535923656838758, 0.5151456369876498, '2'),
#  ('Alexander Zverev',
#   'Filip Krajinovic'): Text(0.6798380755859796, 0.6667805092541866, '1'),
#  ('Alexander Zverev',
#   'Mikael Ymer'): Text(0.6086832724043463, 0.697473682724806, '1'),
#  ('Alexander Zverev',
#   'Pablo Carreno Busta'): Text(0.1640128476391864, 0.6367370860175785, '2'),
#  ('Alexander Zverev',
#   'Borna Coric'): Text(0.7134184533518779, -0.19859367019131785, '3'),
#  ('Alexander Zverev',
#   'Novak Djokovic'): Text(0.16401281783686394, -0.18793784980003414, '5'),
#  ('Alexander Zverev',
#   'David Goffin'): Text(0.34096438304336874, 0.7130665260505037, '2'),
#  ('Alexander Zverev',
#   'Nikoloz Basilashvili'): Text(-0.05280766104122819, 0.24378730663577358, '3'),
#  ('Alexander Zverev',
#   'Taylor Harry Fritz'): Text(0.6448561094965128, -0.23470848216167817, '2'),
#  ('Alexander Zverev',
#   'John Isner'): Text(0.30341467120352383, -0.2545951546987168, '3'),
#  ('Alexander Zverev',
#   'Jaume Munar'): Text(0.02907246154763765, 0.49915412799456527, '1'),
#  ('Alexander Zverev',
#   'Matteo Berrettini'): Text(0.6798380904871408, -0.21798130283896466, '3'),
#  ('Alexander Zverev',
#   'Christian Garin'): Text(-0.02302998511388893, 0.05338952586188819, '1'),
#  ('Alexander Zverev',
#   'Milos Raonic'): Text(-0.034869106717970666, 0.3584859441447673, '1'),
#  ('Alexander Zverev',
#   'Kei Nishikori'): Text(0.5336404358844046, 0.7168034690645813, '2'),
#  ('Alexander Zverev',
#   'Joao Sousa'): Text(0.8298385437859843, 0.5457933917188585, '1'),
#  ('Alexander Zverev',
#   'Hyeon Chung'): Text(0.05161994503747891, 0.5306998267011324, '2'),
#  ('Alexander Zverev',
#   'Juan Martin Del Potro'): Text(0.41774400019538704, -0.2747544886838322, '1'),
#  ('Alexander Zverev',
#   'Federico Delbonis'): Text(0.6086833022066687, -0.2486744763095841, '2'),
#  ('Alexander Zverev',
#   'Marin Cilic'): Text(0.4952218596853299, -0.2732517959813589, '2'),
#  ('Alexander Zverev',
#   'Jeremy Chardy'): Text(0.10369548020183494, 0.5880864039466247, '2'),
#  ('Alexander Zverev',
#   'Hubert Hurkacz'): Text(0.9096782801707699, 0.0352996204440785, '1'),
#  ('Alexander Zverev',
#   'Sam Querrey'): Text(0.8037812109791191, -0.12570905080783507, '1'),
#  ('Alexander Zverev',
#   'Juan Ignacio Londero'): Text(0.45651199931193875, 0.7243055778920948, '1'),
#  ('Alexander Zverev',
#   'John Millman'): Text(0.7453956300828473, -0.17666199209021965, '2'),
#  ('Alexander Zverev',
#   'Alexei Popyrin'): Text(-0.02302998511388893, 0.39540971035565625, '2'),
#  ('Alexander Zverev',
#   'Dusan Lajovic'): Text(0.8298384841813393, -0.0969942747106039, '2'),
#  ('Alexander Zverev',
#   'Fernando Verdasco'): Text(0.2667274460259047, 0.6908414440849049, '3'),
#  ('Alexander Zverev',
#   'Adrian Mannarino'): Text(0.5715370095046413, -0.25979536194266895, '3'),
#  ('Alexander Zverev',
#   'Peter Polansky'): Text(0.029072431745315208, -0.05035492157934329, '1'),
#  ('Alexander Zverev',
#   'Steve Johnson'): Text(0.7755769486654223, -0.15231841203340457, '1'),
#  ('Alexander Zverev',
#   'Richard Gasquet'): Text(0.8748997745366557, 0.4827492905914494, '1'),
#  ('Alexander Zverev',
#   'Marco Cecchinato'): Text(0.2667275205317108, -0.24204226747200536, '2'),
#  ('Alexander Zverev',
#   'Martin Klizan'): Text(0.6448561840023189, 0.6835076587745776, '1'),
#  ('Richard Gasquet',
#   'Daniil Medvedev'): Text(-0.07154053666469234, 0.23896202192144306, '2'),
#  ('Richard Gasquet',
#   'Denis Shapovalov'): Text(-0.05360198234143482, 0.12426338254980418, '1'),
#  ('Richard Gasquet',
#   'Kevin Anderson'): Text(-0.06853571750387233, 0.3163961763055159, '1'),
#  ('Richard Gasquet',
#   'Diego Sebastian Schwartzman'): Text(0.856166869110869, -5.3303845226615465e-08, '3'),
#  ('Richard Gasquet',
#   'Stefanos Tsitsipas'): Text(-0.027098002128041476, 0.4652551037970528, '2'),
#  ('Richard Gasquet',
#   'Malek Jaziri'): Text(0.6946856671353812, 0.681342907478922, '1'),
#  ('Richard Gasquet',
#   'Roberto Bautista Agut'): Text(0.3604177968672389, 0.7537498850405306, '6'),
#  ('Richard Gasquet',
#   'Damir Dzumhur'): Text(0.8748998043389782, 0.03395015638247165, '1'),
#  ('Richard Gasquet',
#   'Casper Ruud'): Text(-0.02709803193036392, 0.05144431337454575, '1'),
#  ('Richard Gasquet',
#   'Kei Nishikori'): Text(0.5149075602609404, 0.7507535595416084, '2'),
#  ('Richard Gasquet',
#   'Federico Delbonis'): Text(0.5899504265832045, -0.21472438583255704, '1'),
#  ('Richard Gasquet',
#   'Bernard Tomic'): Text(0.032887129018659644, -0.0479505894135282, '1'),
#  ('Richard Gasquet',
#   'Taylor Harry Fritz'): Text(0.6261232338730487, -0.2007583916846511, '2'),
#  ('Richard Gasquet',
#   'Jeremy Chardy'): Text(0.08496260457837079, 0.6220364944236517, '5'),
#  ('Richard Gasquet',
#   'Henri Laaksonen'): Text(0.8348595198627341, -0.03239631029307832, '1'),
#  ('Richard Gasquet',
#   'Denis Kudla'): Text(0.05781140732837414, 0.5943535939388602, '1'),
#  ('Richard Gasquet',
#   'David Goffin'): Text(0.3222315074199046, 0.7470166165275307, '3'),
#  ('Richard Gasquet',
#   'Roberto Carballes Baena'): Text(0.17808349264236853, -0.17466303111434228, '1'),
#  ('Richard Gasquet',
#   'Juan Ignacio Londero'): Text(0.4377791236884746, 0.758255668369122, '3'),
#  ('Richard Gasquet',
#   'Benoit Paire'): Text(0.11417734443698968, 0.6475321130570169, '5'),
#  ('Richard Gasquet',
#   'Novak Djokovic'): Text(0.1452799422133998, -0.15398775932300707, '1'),
#  ('Richard Gasquet',
#   'Dusan Lajovic'): Text(0.8111056085578752, -0.06304418423357683, '1'),
#  ('Richard Gasquet',
#   'Rafael Nadal'): Text(0.08496266418301568, -0.10533716665902049, '1'),
#  ('Richard Gasquet',
#   'Gael Monfils'): Text(0.3990110370276007, 0.7575037855760812, '2'),
#  ('Richard Gasquet',
#   'Borna Coric'): Text(0.6946855777284138, -0.16464357971429078, '1'),
#  ('Richard Gasquet',
#   'Dominic Thiem'): Text(0.7266627544593831, 0.6594112889824688, '1'),
#  ('Richard Gasquet',
#   'Albert Ramos'): Text(-0.00969565119026844, 0.016793376581670183, '1'),
#  ('Richard Gasquet',
#   'Pablo Carreno Busta'): Text(0.14527997201572224, 0.6706871764946056, '1'),
#  ('Richard Gasquet',
#   'Kyle Edmund'): Text(0.8348594900604116, 0.5490957274646768, '2'),
#  ('Richard Gasquet',
#   'Mikael Ymer'): Text(0.5899503967808821, 0.7314237732018332, '1'),
#  ('Richard Gasquet',
#   'Matteo Berrettini'): Text(0.6611052148636767, -0.1840312123619376, '1'),
#  ('Richard Gasquet',
#   'Roger Federer'): Text(0.9146058855712902, 0.14304171416558215, '2'),
#  ('Richard Gasquet',
#   'Philipp Kohlschreiber'): Text(0.437779092023507, -0.24155628099984577, '1'),
#  ('Richard Gasquet',
#   'Lorenzo Sonego'): Text(0.904207408234345, 0.1056867605029349, '2'),
#  ('Richard Gasquet',
#   'Juan Martin Del Potro'): Text(0.3990111245719229, -0.2408043982068051, '1'),
#  ('Kyle Edmund',
#   'Daniil Medvedev'): Text(-0.09284794551747222, 0.2713583683176435, '3'),
#  ('Kyle Edmund',
#   'Denis Shapovalov'): Text(-0.07490939119421469, 0.1566597289460046, '3'),
#  ('Kyle Edmund',
#   'Gael Monfils'): Text(0.37770362817482084, 0.7899001319722816, '1'),
#  ('Kyle Edmund',
#   'Kevin Anderson'): Text(-0.0898431263566522, 0.34879252270171635, '2'),
#  ('Kyle Edmund',
#   'Diego Sebastian Schwartzman'): Text(0.8348594602580892, 0.0323962930923552, '4'),
#  ('Kyle Edmund',
#   'Milos Raonic'): Text(-0.07490939119421469, 0.4248323810179948, '1'),
#  ('Kyle Edmund',
#   'Philipp Kohlschreiber'): Text(0.41647168317072714, -0.20915993460364535, '1'),
#  ('Kyle Edmund',
#   'Malek Jaziri'): Text(0.6733782582826013, 0.7137392538751224, '2'),
#  ('Kyle Edmund',
#   'Ricardas Berankis'): Text(0.7355367237938231, 0.6674639957172092, '1'),
#  ('Kyle Edmund',
#   'Novak Djokovic'): Text(0.12397253336061992, -0.12159141292680664, '4'),
#  ('Kyle Edmund',
#   'Dusan Lajovic'): Text(0.7897981997050953, -0.0306478378373764, '2'),
#  ('Kyle Edmund',
#   'Yoshihito Nishioka'): Text(0.900770991839833, 0.21348671543347136, '1'),
#  ('Kyle Edmund',
#   'Nikoloz Basilashvili'): Text(-0.09284794551747222, 0.3101337435090011, '2'),
#  ('Kyle Edmund',
#   'Grigor Dimitrov'): Text(-0.08385160784706064, 0.387102201214566, '2'),
#  ('Kyle Edmund',
#   'Taylor Harry Fritz'): Text(0.6048158250202689, -0.16836204528845067, '2'),
#  ('Kyle Edmund',
#   'Marin Cilic'): Text(0.45518157520908586, -0.2069053591081314, '1'),
#  ('Kyle Edmund',
#   'Stefanos Tsitsipas'): Text(-0.04840541098082135, 0.4976514501932533, '1'),
#  ('Kyle Edmund',
#   'Fernando Verdasco'): Text(0.22668716154966068, 0.7571878809581324, '3'),
#  ('Kyle Edmund',
#   'Jeremy Chardy'): Text(0.06365519572559092, 0.6544328408198521, '2'),
#  ('Kyle Edmund',
#   'Filip Krajinovic'): Text(0.6397977911097356, 0.7331269461274141, '2'),
#  ('Kyle Edmund',
#   'John Isner'): Text(0.26337438672727975, -0.1882487178254893, '2'),
#  ('Kyle Edmund',
#   'Marco Cecchinato'): Text(0.22668723605546678, -0.17569583059877786, '1'),
#  ('Kyle Edmund',
#   'Matteo Berrettini'): Text(0.6397978060108969, -0.15163486596573716, '2'),
#  ('Kyle Edmund',
#   'Roger Federer'): Text(0.8932984767185104, 0.17543806056178257, '1'),
#  ('Kyle Edmund',
#   'Christian Garin'): Text(-0.06307026959013295, 0.11973596273511569, '1'),
#  ('Kyle Edmund',
#   'Steve Johnson'): Text(0.7355366641891783, -0.08597197516017707, '1'),
#  ('Kyle Edmund',
#   'Joao Sousa'): Text(0.7897982593097402, 0.612139828592086, '1'),
#  ('Kyle Edmund',
#   'Jo Wilfried Tsonga'): Text(0.4936001141552575, -0.20165782577613184, '2'),
#  ('Kyle Edmund',
#   'Denis Kudla'): Text(0.03650399847559427, 0.6267499403350607, '1'),
#  ('Kyle Edmund',
#   'Dominik Koepfer'): Text(0.3391103582121366, -0.20465415127505415, '1'),
#  ('Kyle Edmund',
#   'Marton Fucsovics'): Text(0.15677600928378255, 0.7237587350774963, '1'),
#  ('Kyle Edmund',
#   'Ugo Humbert'): Text(0.19108295276980203, -0.16033765076003587, '1'),
#  ('Kyle Edmund',
#   'David Goffin'): Text(0.30092409856712476, 0.7794129629237312, '1'),
#  ('Kyle Edmund',
#   'Roberto Carballes Baena'): Text(0.15677608378958865, -0.14226668471814186, '1'),
#  ('Kyle Edmund',
#   'Albert Ramos'): Text(-0.031003060043048314, 0.04918972297787061, '1'),
#  ('Kyle Edmund',
#   'Jaume Munar'): Text(-0.010967822928606374, 0.5655005648677928, '1'),
#  ('Kyle Edmund',
#   'Hyeon Chung'): Text(0.011579660561234884, 0.5970462635743599, '1'),
#  ('Joao Sousa',
#   'Daniil Medvedev'): Text(-0.11660176741536377, 0.3020061230488522, '3'),
#  ('Joao Sousa',
#   'Denis Shapovalov'): Text(-0.09866321309210624, 0.18730748367721334, '2'),
#  ('Joao Sousa',
#   'Stefanos Tsitsipas'): Text(-0.0721592328787129, 0.528299204924462, '1'),
#  ('Joao Sousa',
#   'Karen Khachanov'): Text(0.012750236182347607, -0.014610165046819834, '1'),
#  ('Joao Sousa',
#   'Philipp Kohlschreiber'): Text(0.3927178612728356, -0.17851217987243662, '1'),
#  ('Joao Sousa',
#   'Malek Jaziri'): Text(0.6496244363847098, 0.7443870086063311, '1'),
#  ('Joao Sousa',
#   'Roberto Bautista Agut'): Text(0.3153565661165675, 0.8167939861679399, '2'),
#  ('Joao Sousa',
#   'Filip Krajinovic'): Text(0.616043969211844, 0.7637747008586229, '3'),
#  ('Joao Sousa',
#   'Mikael Ymer'): Text(0.5448891660302106, 0.7944678743292424, '2'),
#  ('Joao Sousa',
#   'Pablo Carreno Busta'): Text(0.10021874126505081, 0.7337312776220148, '2'),
#  ('Joao Sousa',
#   'Nikoloz Basilashvili'): Text(-0.11660176741536377, 0.3407814982402098, '1'),
#  ('Joao Sousa',
#   'Marin Cilic'): Text(0.4314277533111943, -0.17625760437692267, '2'),
#  ('Joao Sousa',
#   'Hubert Hurkacz'): Text(0.8458841737966343, 0.13229381204851473, '2'),
#  ('Joao Sousa',
#   'David Goffin'): Text(0.2771702766692332, 0.8100607176549399, '2'),
#  ('Joao Sousa',
#   'Juan Ignacio Londero'): Text(0.3927178929378032, 0.821299769496531, '1'),
#  ('Joao Sousa',
#   'Alexei Popyrin'): Text(-0.0868240914880245, 0.4924039019600925, '1'),
#  ('Joao Sousa',
#   'Donald Young'): Text(0.06911620309328559, -0.06778868416497652, '1'),
#  ('Joao Sousa',
#   'Mirza Basic'): Text(0.2771703586256199, -0.16727315783316793, '2'),
#  ('Joao Sousa',
#   'Steve Johnson'): Text(0.7117828422912866, -0.05532422042896834, '1'),
#  ('Joao Sousa',
#   'Novak Djokovic'): Text(0.10021871146272837, -0.09094365819559791, '2'),
#  ('Joao Sousa',
#   'Rafael Nadal'): Text(0.03990143343234426, -0.04229306553161133, '1'),
#  ('Joao Sousa',
#   'Kevin Anderson'): Text(-0.11359694825454375, 0.3794402774329251, '1'),
#  ('Joao Sousa',
#   'Gael Monfils'): Text(0.3539498062769293, 0.8205478867034903, '1'),
#  ('Joao Sousa',
#   'Yoshihito Nishioka'): Text(0.8770171699419415, 0.2441344701646801, '1'),
#  ('Joao Sousa',
#   'Casper Ruud'): Text(-0.07215926268103534, 0.1144884145019549, '2'),
#  ('Joao Sousa',
#   'Borna Coric'): Text(0.6496243469777424, -0.10159947858688162, '2'),
#  ('Joao Sousa',
#   'John Millman'): Text(0.6816015237087116, -0.07966780048578342, '1'),
#  ('Joao Sousa',
#   'Marton Fucsovics'): Text(0.133022187385891, 0.7544064898087051, '1'),
#  ('Joao Sousa',
#   'Albert Ramos'): Text(-0.05475688194093986, 0.07983747770907934, '1'),
#  ('Joao Sousa',
#   'Federico Delbonis'): Text(0.5448891958325331, -0.15168028470514788, '2'),
#  ('Joao Sousa',
#   'Jaume Munar'): Text(-0.03472164482649792, 0.5961483195990015, '1'),
#  ('Joao Sousa',
#   'Roger Federer'): Text(0.8695446548206187, 0.2060858152929913, '1'),
#  ('Joao Sousa',
#   'Milos Raonic'): Text(-0.09866321309210624, 0.45548013574920354, '1'),
#  ('Joao Sousa',
#   'Adrian Mannarino'): Text(0.5077429031305056, -0.16280117033823271, '2'),
#  ('Joao Sousa',
#   'Lorenzo Sonego'): Text(0.8591461774836735, 0.16873086163034406, '1'),
#  ('Joao Sousa',
#   'Kei Nishikori'): Text(0.469846329510269, 0.8137976606690176, '1'),
#  ('Joao Sousa',
#   'Hyeon Chung'): Text(-0.012174161336656664, 0.6276940183055686, '2'),
#  ('Joao Sousa',
#   'Bernard Tomic'): Text(-0.012174101732011777, 0.015093511713880958, '1'),
#  ('Joao Sousa',
#   'Marco Cecchinato'): Text(0.20293341415757524, -0.14504807586756913, '1'),
#  ('Tennys Sandgren',
#   'Dominic Thiem'): Text(0.6555441610995241, 0.7511702854163989, '1'),
#  ('Tennys Sandgren',
#   'Philipp Kohlschreiber'): Text(0.36666049866364797, -0.14979728456591568, '2'),
#  ('Tennys Sandgren',
#   'Novak Djokovic'): Text(0.07416134885354075, -0.06222876288907697, '3'),
#  ('Tennys Sandgren',
#   'Roberto Bautista Agut'): Text(0.28929920350737987, 0.8455088814744608, '1'),
#  ('Tennys Sandgren',
#   'Yoshihito Nishioka'): Text(0.8509598073327538, 0.27284936547120103, '1'),
#  ('Tennys Sandgren',
#   'Grigor Dimitrov'): Text(-0.1336627923541398, 0.4464648512522957, '1'),
#  ('Tennys Sandgren',
#   'Hubert Hurkacz'): Text(0.8198268111874467, 0.16100870735503567, '2'),
#  ('Tennys Sandgren',
#   'Diego Sebastian Schwartzman'): Text(0.78504827575101, 0.09175894313008487, '1'),
#  ('Tennys Sandgren',
#   'Denis Shapovalov'): Text(-0.12472057570129386, 0.21602237898373428, '2'),
#  ('Tennys Sandgren',
#   'John Millman'): Text(0.6555441610995241, -0.050952905179262487, '1'),
#  ('Tennys Sandgren',
#   'Corentin Moutet'): Text(0.855461328929235, 0.311362441109468, '1'),
#  ('Tennys Sandgren',
#   'Sam Querrey'): Text(0.713929741995796, 3.6103122103003926e-08, '2'),
#  ('Tennys Sandgren',
#   'John Isner'): Text(0.21356320222020062, -0.12888606778775963, '2'),
#  ('Tennys Sandgren',
#   'Roger Federer'): Text(0.8434872922114311, 0.23480071059951224, '1'),
#  ('Tennys Sandgren',
#   'Adrian Mannarino'): Text(0.481685540521318, -0.13408627503171178, '2'),
#  ('Tennys Sandgren',
#   'Taro Daniel'): Text(0.4816854511143507, 0.8343036552688481, '1'),
#  ('Tennys Sandgren',
#   'Steve Johnson'): Text(0.6857254796820991, -0.026609325122447403, '2'),
#  ('Tennys Sandgren',
#   'Dominik Koepfer'): Text(0.2892991737050574, -0.14529150123732448, '1'),
#  ('Tennys Sandgren',
#   'Daniel Elahi Galan Riveros'): Text(-0.08081424455012748, 0.5916650370238585, '1'),
#  ('Tennys Sandgren',
#   'Malek Jaziri'): Text(0.6235670737755221, 0.7731019039128522, '1'),
#  ('Tennys Sandgren',
#   'Hyeon Chung'): Text(-0.03823152394584428, 0.6564089136120895, '2'),
#  ('Tennys Sandgren',
#   'Ricardas Berankis'): Text(0.685725539286744, 0.7268266457549388, '1'),
#  ('Tennys Sandgren',
#   'Nikoloz Basilashvili'): Text(-0.14265913002455138, 0.36949639354673075, '1'),
#  ('Tennys Sandgren',
#   'Jo Wilfried Tsonga'): Text(0.4437889296481783, -0.14229517573840217, '1'),
#  ('Tennys Sandgren',
#   'Jeremy Chardy'): Text(0.013844011218511754, 0.7137954908575819, '1'),
#  ('Tennys Sandgren',
#   'Roberto Carballes Baena'): Text(0.10696489928250949, -0.08290403468041219, '1'),
#  ('Tennys Sandgren',
#   'Matteo Berrettini'): Text(0.5899866215038176, -0.0922722159280075, '1'),
#  ('Tennys Sandgren',
#   'Mirza Basic'): Text(0.25111299601643233, -0.138558262526647, '1'),
#  ('Tennys Sandgren',
#   'Marco Cecchinato'): Text(0.17687605154838762, -0.11633318056104819, '1'),
#  ('Tennys Sandgren',
#   'Lorenzo Sonego'): Text(0.8330888148744859, 0.197445756936865, '1'),
#  ('Ricardas Berankis',
#   'Daniil Medvedev'): Text(-0.17086330293128088, 0.35733029017397533, '2'),
#  ('Ricardas Berankis',
#   'Denis Shapovalov'): Text(-0.15292474860802335, 0.24263165080233645, '3'),
#  ('Ricardas Berankis',
#   'Stefanos Tsitsipas'): Text(-0.12642076839463, 0.5836233720495851, '2'),
#  ('Ricardas Berankis',
#   'Novak Djokovic'): Text(0.04595717594681126, -0.035619491070474796, '2'),
#  ('Ricardas Berankis',
#   'Dusan Lajovic'): Text(0.7117828422912866, 0.055324084018955444, '1'),
#  ('Ricardas Berankis',
#   'Karen Khachanov'): Text(-0.04151129933356951, 0.04071400207830328, '1'),
#  ('Ricardas Berankis',
#   'David Goffin'): Text(0.22290874115331608, 0.865384884780063, '2'),
#  ('Ricardas Berankis',
#   'Gael Monfils'): Text(0.2996882707610122, 0.8758720538286136, '1'),
#  ('Ricardas Berankis',
#   'Nikoloz Basilashvili'): Text(-0.17086330293128088, 0.3961056653653329, '1'),
#  ('Ricardas Berankis',
#   'Jeremy Chardy'): Text(-0.014360161688217743, 0.740404762676184, '1'),
#  ('Ricardas Berankis',
#   'Pablo Carreno Busta'): Text(0.0459572057491337, 0.7890554447471378, '2'),
#  ('Ricardas Berankis',
#   'Sam Querrey'): Text(0.6857255690890665, 0.02660930792172428, '1'),
#  ('Ricardas Berankis',
#   'Adrian Mannarino'): Text(0.4534813676145885, -0.1074770032131096, '3'),
#  ('Ricardas Berankis',
#   'Roberto Carballes Baena'): Text(0.07876072637578, -0.05629476286181001, '2'),
#  ('Ricardas Berankis',
#   'Jo Wilfried Tsonga'): Text(0.4155847567414488, -0.11568590391979999, '1'),
#  ('Ricardas Berankis',
#   'Hyeon Chung'): Text(-0.06643569685257378, 0.6830181854306917, '1'),
#  ('Ricardas Berankis',
#   'Denis Kudla'): Text(-0.04151135893821439, 0.7127218621913924, '1'),
#  ('Ricardas Berankis',
#   'Steve Johnson'): Text(0.6575213067753696, -5.3303845226615465e-08, '1'),
#  ('Dominic Thiem',
#   'Rafael Nadal'): Text(-0.044541480270792744, 0.03737474125497181, '8'),
#  ('Dominic Thiem',
#   'Daniil Medvedev'): Text(-0.20104468111850077, 0.38167392983543535, '5'),
#  ('Dominic Thiem',
#   'Denis Shapovalov'): Text(-0.18310612679524324, 0.2669752904637965, '2'),
#  ('Dominic Thiem',
#   'Gael Monfils'): Text(0.2695068925737923, 0.9002156934900736, '5'),
#  ('Dominic Thiem',
#   'Kevin Anderson'): Text(-0.19803986195768075, 0.4591080842195082, '3'),
#  ('Dominic Thiem',
#   'Christian Garin'): Text(-0.1712670051911615, 0.23005152425290756, '1'),
#  ('Dominic Thiem',
#   'Diego Sebastian Schwartzman'): Text(0.7266627246570607, 0.14271185461014707, '5'),
#  ('Dominic Thiem',
#   'Milos Raonic'): Text(-0.18310612679524324, 0.5351479425357867, '2'),
#  ('Dominic Thiem',
#   'Roger Federer'): Text(0.7851017411174818, 0.28575362207957444, '4'),
#  ('Dominic Thiem',
#   'Novak Djokovic'): Text(0.01577579775959137, -0.01127585140901477, '6'),
#  ('Dominic Thiem',
#   'Dusan Lajovic'): Text(0.6816014641040667, 0.07966772368041547, '3'),
#  ('Dominic Thiem',
#   'Karen Khachanov'): Text(-0.0716926775207894, 0.0650576417397633, '3'),
#  ('Dominic Thiem',
#   'Grigor Dimitrov'): Text(-0.1920483434480892, 0.4974177627323579, '1'),
#  ('Dominic Thiem',
#   'Borna Coric'): Text(0.5651814332746055, -0.02193167180029848, '3'),
#  ('Dominic Thiem',
#   'Hubert Hurkacz'): Text(0.7614412600934973, 0.21196161883509787, '2'),
#  ('Dominic Thiem',
#   'Stefanos Tsitsipas'): Text(-0.1566021465818499, 0.6079670117110452, '8'),
#  ('Dominic Thiem',
#   'Fernando Verdasco'): Text(0.11849042594863213, 0.8675034424759243, '3'),
#  ('Dominic Thiem',
#   'Filip Krajinovic'): Text(0.5316010555087071, 0.843442507645206, '1'),
#  ('Dominic Thiem',
#   'Sam Querrey'): Text(0.6555441909018465, 0.050952947583184305, '2'),
#  ('Dominic Thiem',
#   'Alexei Popyrin'): Text(-0.1712670051911615, 0.5720717087466756, '1'),
#  ('Dominic Thiem',
#   'Matteo Berrettini'): Text(0.5316010704098683, -0.04131930444794529, '4'),
#  ('Dominic Thiem',
#   'Kei Nishikori'): Text(0.385403415807132, 0.8934654674556006, '3'),
#  ('Dominic Thiem',
#   'Martin Klizan'): Text(0.49661916392504635, 0.860169657165597, '3'),
#  ('Dominic Thiem',
#   'Juan Martin Del Potro'): Text(0.26950698011811447, -0.0980924902928128, '1'),
#  ('Dominic Thiem',
#   'Roberto Bautista Agut'): Text(0.23091365241343048, 0.896461792954523, '1'),
#  ('Dominic Thiem',
#   'Casper Ruud'): Text(-0.15660217638417234, 0.19415622128853804, '1'),
#  ('Dominic Thiem',
#   'Pablo Carreno Busta'): Text(0.015775827561913813, 0.8133990844085979, '2'),
#  ('Dominic Thiem',
#   'Nikoloz Basilashvili'): Text(-0.20104468111850077, 0.42044930502679295, '1'),
#  ('Dominic Thiem',
#   'Marton Fucsovics'): Text(0.048579273682754, 0.8340742965952883, '1'),
#  ('Dominic Thiem',
#   'Jo Wilfried Tsonga'): Text(0.3854033785542289, -0.09134226425833997, '1'),
#  ('Dominic Thiem',
#   'Federico Delbonis'): Text(0.46044628212939614, -0.07201247791856474, '1'),
#  ('Dominic Thiem',
#   'Taylor Harry Fritz'): Text(0.49661908941924027, -0.0580464837706588, '2'),
#  ('Dominic Thiem',
#   'Marin Cilic'): Text(0.3469848396080573, -0.09658979759033953, '3'),
#  ('Dominic Thiem',
#   'Denis Kudla'): Text(-0.07169273712543428, 0.7370655018528525, '1'),
#  ('Dominic Thiem',
#   'Roberto Carballes Baena'): Text(0.048579348188560106, -0.031951123200349985, '1'),
#  ('Dominic Thiem',
#   'John Millman'): Text(0.5971586100055747, 6.300799715308614e-09, '1'),
#  ('Dominic Thiem',
#   'Corentin Moutet'): Text(0.7970757778352856, 0.3623153525895302, '1'),
#  ('Dominic Thiem',
#   'Benoit Paire'): Text(-0.015326800016818742, 0.7902440209710092, '1'),
#  ('Dominic Thiem',
#   'Albert Ramos'): Text(-0.13919979564407686, 0.15950528449566248, '1'),
#  ('Dominic Thiem',
#   'Jaume Munar'): Text(-0.11916455852963492, 0.6758161263855846, '4'),
#  ('Dominic Thiem',
#   'Adrian Mannarino'): Text(0.42329998942736863, -0.08313336355164958, '2'),
#  ('Dominic Thiem',
#   'Horacio Zeballos'): Text(-0.19803986195768075, 0.34301515250536524, '1'),
#  ('Dominic Thiem',
#   'Mirza Basic'): Text(0.19272744492248292, -0.08760535104658479, '1'),
#  ('Dominic Thiem',
#   'Steve Johnson'): Text(0.6273399285881497, 0.0243435863576148, '1'),
#  ('Dominic Thiem',
#   'Marco Cecchinato'): Text(0.11849050045443824, -0.06538026908098599, '1'),
#  ('Dominic Thiem',
#   'Lorenzo Sonego'): Text(0.7747032637805366, 0.2483986684169272, '1'),
#  ('Malek Jaziri',
#   'Stefanos Tsitsipas'): Text(-0.1885792339058518, 0.6298986302074984, '2'),
#  ('Malek Jaziri',
#   'Novak Djokovic'): Text(-0.016201289564410526, 0.010655767087438484, '1'),
#  ('Malek Jaziri',
#   'Roberto Bautista Agut'): Text(0.19893656508942859, 0.9183934114509762, '1'),
#  ('Malek Jaziri',
#   'Dusan Lajovic'): Text(0.6496243767800649, 0.10159934217686872, '1'),
#  ('Malek Jaziri',
#   'David Goffin'): Text(0.1607502756420943, 0.9116601429379763, '1'),
#  ('Malek Jaziri',
#   'Nikoloz Basilashvili'): Text(-0.23302176844250266, 0.4423809235232462, '1'),
#  ('Malek Jaziri',
#   'Grigor Dimitrov'): Text(-0.22402543077209108, 0.5193493812288111, '2'),
#  ('Malek Jaziri',
#   'Taylor Harry Fritz'): Text(0.46464200209523837, -0.03611486527420554, '1'),
#  ('Malek Jaziri',
#   'Pablo Carreno Busta'): Text(-0.016201259762088083, 0.8353307029050512, '1'),
#  ('Malek Jaziri',
#   'Sam Querrey'): Text(0.6235671035778446, 0.07288456607963756, '1'),
#  ('Malek Jaziri',
#   'Federico Delbonis'): Text(0.42846919480539425, -0.05008085942211149, '1'),
#  ('Malek Jaziri',
#   'Jaume Munar'): Text(-0.15114164585363682, 0.697747744882038, '1'),
#  ('Malek Jaziri',
#   'Milos Raonic'): Text(-0.21508321411924514, 0.55707956103224, '1'),
#  ('Malek Jaziri',
#   'Taro Daniel'): Text(0.3913228126963994, 0.9071881852453636, '1'),
#  ('Malek Jaziri',
#   'Denis Kudla'): Text(-0.10366982444943618, 0.7589971203493058, '1'),
#  ('Malek Jaziri',
#   'Mirza Basic'): Text(0.16075035759848103, -0.06567373255013154, '1'),
#  ('Malek Jaziri',
#   'Marton Fucsovics'): Text(0.016602186358752102, 0.8560059150917415, '1'),
#  ('Malek Jaziri',
#   'Marin Cilic'): Text(0.3150077522840554, -0.07465817909388628, '1'),
#  ('Malek Jaziri',
#   'Fernando Verdasco'): Text(0.08651333862463023, 0.8894350609723776, '1'),
#  ('Malek Jaziri',
#   'Adrian Mannarino'): Text(0.39132290210336673, -0.06120174505519632, '1'),
#  ('Filip Krajinovic',
#   'Daniil Medvedev'): Text(-0.26660223561536844, 0.4229932405841803, '1'),
#  ('Filip Krajinovic',
#   'Yoshihito Nishioka'): Text(0.7270167017419368, 0.3651215877000082, '1'),
#  ('Filip Krajinovic',
#   'Casper Ruud'): Text(-0.22215973088104, 0.235475532037283, '1'),
#  ('Filip Krajinovic',
#   'Novak Djokovic'): Text(-0.04978175673727628, 0.030043459339730183, '2'),
#  ('Filip Krajinovic',
#   'Rafael Nadal'): Text(-0.11009903476766039, 0.07869405200371676, '1'),
#  ('Filip Krajinovic',
#   'Karen Khachanov'): Text(-0.13725023201765704, 0.10637695248850826, '2'),
#  ('Filip Krajinovic',
#   'David Goffin'): Text(0.12716980846922854, 0.931047835190268, '3'),
#  ('Filip Krajinovic',
#   'Gael Monfils'): Text(0.2039493380769246, 0.9415350042388184, '2'),
#  ('Filip Krajinovic',
#   'Grigor Dimitrov'): Text(-0.2576058979449568, 0.5387370734811028, '1'),
#  ('Filip Krajinovic',
#   'Borna Coric'): Text(0.49962387877773773, 0.019387638948446473, '2'),
#  ('Filip Krajinovic',
#   'Hubert Hurkacz'): Text(0.6958837055966297, 0.25328092958384285, '1'),
#  ('Filip Krajinovic',
#   'Stefanos Tsitsipas'): Text(-0.22215970107871755, 0.6492863224597901, '2'),
#  ('Filip Krajinovic',
#   'Denis Shapovalov'): Text(-0.2486636812921109, 0.30829460121254143, '1'),
#  ('Filip Krajinovic',
#   'Fernando Verdasco'): Text(0.05293287145176448, 0.9088227532246692, '2'),
#  ('Filip Krajinovic',
#   'Matteo Berrettini'): Text(0.46604351591300064, 6.3007996597974625e-09, '1'),
#  ('Filip Krajinovic',
#   'Roger Federer'): Text(0.7195441866206141, 0.3270729328283194, '4'),
#  ('Filip Krajinovic',
#   'Milos Raonic'): Text(-0.2486636812921109, 0.5764672532845316, '1'),
#  ('Filip Krajinovic',
#   'Steve Johnson'): Text(0.5617823740912821, 0.06566289710635975, '1'),
#  ('Filip Krajinovic',
#   'Dominik Koepfer'): Text(0.1653560681142404, -0.05301927900851733, '1'),
#  ('Filip Krajinovic',
#   'Juan Martin Del Potro'): Text(0.20394942562124682, -0.05677317954406785, '2'),
#  ('Filip Krajinovic',
#   'Mikael Ymer'): Text(0.3948886978302061, 0.9154549918645705, '2'),
#  ('Filip Krajinovic',
#   'Pablo Carreno Busta'): Text(-0.049781726934953835, 0.8547183951573429, '1'),
#  ('Filip Krajinovic',
#   'Marton Fucsovics'): Text(-0.01697828081411365, 0.8753936073440332, '1'),
#  ('Filip Krajinovic',
#   'Mitchell Krueger'): Text(-0.2576058979449568, 0.34602478101597023, '1'),
#  ('Filip Krajinovic',
#   'Jo Wilfried Tsonga'): Text(0.3198458240573613, -0.050022953509595014, '1'),
#  ('Filip Krajinovic',
#   'Taylor Harry Fritz'): Text(0.43106153492237265, -0.016727173021913844, '1'),
#  ('Filip Krajinovic',
#   'Roberto Carballes Baena'): Text(-0.016978206308307542, 0.009368187548394968, '1'),
#  ('Filip Krajinovic',
#   'Corentin Moutet'): Text(0.731518223338418, 0.40363466333827513, '1'),
#  ('Filip Krajinovic',
#   'Benoit Paire'): Text(-0.08088435451368639, 0.8315633317197542, '1'),
#  ('Filip Krajinovic',
#   'Marco Cecchinato'): Text(0.05293294595757059, -0.024060958332241034, '2'),
#  ('Filip Krajinovic',
#   'Taro Daniel'): Text(0.3577423455235336, 0.9265758774976552, '1'),
#  ('Filip Krajinovic',
#   'Martin Klizan'): Text(0.4310616094281787, 0.9014889679143421, '1'),
#  ('Martin Klizan',
#   'Denis Shapovalov'): Text(-0.2836455728757715, 0.3250217507329325, '2'),
#  ('Martin Klizan',
#   'Damir Dzumhur'): Text(0.6448562138046414, 0.23470852456559996, '1'),
#  ('Martin Klizan',
#   'Federico Delbonis'): Text(0.35990683604886786, -0.01396601764942873, '3'),
#  ('Martin Klizan',
#   'Alexei Popyrin'): Text(-0.2718064512716898, 0.6301181690158116, '1'),
#  ('Martin Klizan',
#   'Dusan Lajovic'): Text(0.5810620180235384, 0.13771418394955148, '1'),
#  ('Martin Klizan',
#   'Jaume Munar'): Text(-0.21970400461016323, 0.7338625866547206, '1'),
#  ('Martin Klizan',
#   'Mirza Basic'): Text(0.09218799884195461, -0.029558890777448776, '3'),
#  ('Martin Klizan',
#   'Steve Johnson'): Text(0.5268004825076213, 0.08239004662675081, '1'),
#  ('Martin Klizan',
#   'Novak Djokovic'): Text(-0.08476364832093694, 0.04677060886012124, '1'),
#  ('Martin Klizan',
#   'Rafael Nadal'): Text(-0.14508092635132105, 0.09542120152410782, '1'),
#  ('Martin Klizan',
#   'Daniil Medvedev'): Text(-0.30158412719902905, 0.43972039010457137, '2'),
#  ('Martin Klizan',
#   'Karen Khachanov'): Text(-0.1722321236013177, 0.12310410200889932, '1'),
#  ('Martin Klizan',
#   'Gael Monfils'): Text(0.16896744649326395, 0.9582621537592095, '1'),
#  ('Martin Klizan',
#   'Marin Cilic'): Text(0.246445393527529, -0.03854333732120352, '2'),
#  ('Martin Klizan',
#   'Marton Fucsovics'): Text(-0.05196017239777431, 0.8921207568644243, '1'),
#  ('Martin Klizan',
#   'Jeremy Chardy'): Text(-0.14508098595596594, 0.82279486260678, '1'),
#  ('Martin Klizan',
#   'Marco Cecchinato'): Text(0.017951054373909925, -0.007333808811849973, '1'),
#  ('Martin Klizan',
#   'Christian Garin'): Text(-0.2718064512716898, 0.2880979845220436, '1'),
#  ('Martin Klizan',
#   'Adrian Mannarino'): Text(0.32276054334684035, -0.025086903282513562, '1'),
#  ('Martin Klizan',
#   'Roberto Carballes Baena'): Text(-0.051960097891968204, 0.02609533706878603, '1'),
#  ('Martin Klizan',
#   'Lorenzo Sonego'): Text(0.6741638177000082, 0.3064451286860632, '1'),
#  ('Martin Klizan',
#   'Jo Wilfried Tsonga'): Text(0.2848639324737006, -0.033295803989203954, '1'),
#  ('Martin Klizan',
#   'Hyeon Chung'): Text(-0.19715652112032198, 0.7654082853612878, '1'),
#  ('Mikael Ymer',
#   'Novak Djokovic'): Text(-0.12093655991890961, 0.06073663281034963, '1'),
#  ('Mikael Ymer',
#   'Karen Khachanov'): Text(-0.20840503519929038, 0.1370701259591277, '1'),
#  ('Mikael Ymer',
#   'Hubert Hurkacz'): Text(0.6247289024149963, 0.28397410305446225, '1'),
#  ('Mikael Ymer',
#   'Stefanos Tsitsipas'): Text(-0.2933145042603509, 0.6799794959304095, '1'),
#  ('Mikael Ymer',
#   'Milos Raonic'): Text(-0.3198184844737442, 0.6071604267551511, '1'),
#  ('Mikael Ymer',
#   'Daniel Elahi Galan Riveros'): Text(-0.27591215332257785, 0.7146304327232851, '1'),
#  ('Taro Daniel',
#   'Christian Garin'): Text(-0.3451257151763349, 0.31318489410535677, '1'),
#  ('Taro Daniel',
#   'Tatsuma Ito'): Text(0.1731260439412069, 0.9818463706400495, '1'),
#  ('Taro Daniel',
#   'Dominik Koepfer'): Text(0.05705491262593464, -0.011205219904813046, '1'),
#  ('Taro Daniel',
#   'Borna Coric'): Text(0.391322723289432, 0.061201698052150755, '1'),
#  ('Taro Daniel',
#   'Jeremy Chardy'): Text(-0.21840024986061102, 0.8478817721900933, '1'),
#  ('Taro Daniel',
#   'Ugo Humbert'): Text(-0.09097249281639992, 0.03311128061020524, '1'),
#  ('Taro Daniel',
#   'Sam Querrey'): Text(0.4816854809166731, 0.13408631743563354, '1'),
#  ('Taro Daniel',
#   'Roberto Carballes Baena'): Text(-0.1252793617966133, 0.05118224665209925, '2'),
#  ('Taro Daniel',
#   'John Millman'): Text(0.4232999000204013, 0.08313337615324895, '2'),
#  ('Taro Daniel',
#   'Matteo Berrettini'): Text(0.35774236042469487, 0.04181406540450394, '1'),
#  ('Taro Daniel',
#   'Novak Djokovic'): Text(-0.15808291222558202, 0.07185751844343446, '1'),
#  ('Taro Daniel',
#   'Roberto Bautista Agut'): Text(0.05705494242825708, 0.9795951628069722, '1'),
#  ('Taro Daniel',
#   'Dusan Lajovic'): Text(0.5077427541188934, 0.1628010935328647, '1'),
#  ('Taro Daniel',
#   'Daniil Medvedev'): Text(-0.37490339110367416, 0.4648072996878846, '1'),
#  ('Taro Daniel',
#   'Gael Monfils'): Text(0.09564818258861886, 0.9833490633425228, '1'),
#  ('Taro Daniel',
#   'Stefanos Tsitsipas'): Text(-0.3304608565670233, 0.6911003815634944, '1'),
#  ('Taro Daniel',
#   'Denis Shapovalov'): Text(-0.35696483678041663, 0.3501086603162457, '1'),
#  ('Taro Daniel',
#   'Fernando Verdasco'): Text(-0.055368284036541274, 0.9506368123283735, '1'),
#  ('Taro Daniel',
#   'Jaume Munar'): Text(-0.2930232685148083, 0.7589494962380339, '1'),
#  ('Taro Daniel',
#   'Philipp Kohlschreiber'): Text(0.1344162375845252, -0.01571100323340424, '1'),
#  ('Taro Daniel',
#   'Milos Raonic'): Text(-0.35696483678041663, 0.6182813123882359, '1'),
#  ('Taro Daniel',
#   'Jo Wilfried Tsonga'): Text(0.21154466856905552, -0.008208894405890732, '1'),
#  ('Kei Nishikori',
#   'Daniil Medvedev'): Text(-0.41279987531694345, 0.473016200394575, '4'),
#  ('Kei Nishikori',
#   'Denis Shapovalov'): Text(-0.3948613209936859, 0.3583175610229361, '2'),
#  ('Kei Nishikori',
#   'Gael Monfils'): Text(0.05775169837534956, 0.9915579640492131, '1'),
#  ('Kei Nishikori',
# ...
#  ('Jaume Munar',
#   'Borna Coric'): Text(-0.1511417352606042, -0.1482387423111749, '2'),
#  ('Jaume Munar',
#   'Hubert Hurkacz'): Text(0.04511809155828772, 0.08565454832422145, '1'),
#  ('Jaume Munar',
#   'Diego Sebastian Schwartzman'): Text(0.010339556121851057, 0.016404784099270653, '2'),
#  ('Jaume Munar',
#   'Stefanos Tsitsipas'): Text(-0.8729253151170595, 0.48165994120016875, '2'),
#  ('Jaume Munar',
#   'Albert Ramos'): Text(-0.8555229641792865, 0.03319821398478606, '2'),
#  ('Jaume Munar',
#   'Alexei Popyrin'): Text(-0.8875901737263712, 0.4457646382357992, '2'),
#  ('Jaume Munar',
#   'Christian Garin'): Text(-0.8875901737263712, 0.10374445374203115, '1'),
#  ('Jaume Munar',
#   'Roberto Carballes Baena'): Text(-0.6677438203466495, -0.1582581937112264, '2'),
#  ('Jaume Munar',
#   'Steve Johnson'): Text(-0.08898323994705992, -0.10196348415326162, '1'),
#  ('Jaume Munar',
#   'Dominik Koepfer'): Text(-0.48540954592410157, -0.2206456602681387, '1'),
#  ('Jaume Munar',
#   'Marco Cecchinato'): Text(-0.5978326680807714, -0.1916873395918624, '1'),
#  ('Daniel Elahi Galan Riveros',
#   'Novak Djokovic'): Text(-0.7205826078900601, -0.17078109980155512, '1'),
#  ('Daniel Elahi Galan Riveros',
#   'Casper Ruud'): Text(-0.8929605820338239, 0.034650972895997695, '1'),
#  ('Daniel Elahi Galan Riveros',
#   'Peter Polansky'): Text(-0.8555229939816089, -0.03319817158086427, '1'),
#  ('Daniel Elahi Galan Riveros',
#   'Steve Johnson'): Text(-0.10901847706150186, -0.13516166203492555, '1'),
#  ('Stefanos Tsitsipas',
#   'Rafael Nadal'): Text(-0.7983022368582173, -0.1567814439304441, '7'),
#  ('Stefanos Tsitsipas',
#   'Daniil Medvedev'): Text(-0.9548054377059254, 0.18751774465001944, '6'),
#  ('Stefanos Tsitsipas',
#   'Denis Shapovalov'): Text(-0.9368668833826679, 0.07281910527838056, '4'),
#  ('Stefanos Tsitsipas',
#   'Kevin Anderson'): Text(-0.9518006185451053, 0.26495189903409233, '4'),
#  ('Stefanos Tsitsipas',
#   'Christian Garin'): Text(-0.925027761778586, 0.03589533906749165, '1'),
#  ('Stefanos Tsitsipas',
#   'Diego Sebastian Schwartzman'): Text(-0.02709803193036392, -0.05144433057526884, '1'),
#  ('Stefanos Tsitsipas',
#   'Roger Federer'): Text(0.03134098453005718, 0.09159743689415852, '5'),
#  ('Stefanos Tsitsipas',
#   'Novak Djokovic'): Text(-0.7379849588278332, -0.20543203659443068, '6'),
#  ('Stefanos Tsitsipas',
#   'Grigor Dimitrov'): Text(-0.9458091000355138, 0.30326157754694194, '2'),
#  ('Stefanos Tsitsipas',
#   'Borna Coric'): Text(-0.18857932331281918, -0.2160878569857144, '2'),
#  ('Stefanos Tsitsipas',
#   'Hubert Hurkacz'): Text(0.0076805035060727445, 0.017805433649681957, '6'),
#  ('Stefanos Tsitsipas',
#   'Ugo Humbert'): Text(-0.670874539418651, -0.2441782744276599, '1'),
#  ('Stefanos Tsitsipas',
#   'John Isner'): Text(-0.5985831054611733, -0.27208934149311337, '3'),
#  ('Stefanos Tsitsipas',
#   'Milos Raonic'): Text(-0.9368668833826679, 0.3409917573503708, '2'),
#  ('Stefanos Tsitsipas',
#   'Adrian Mannarino'): Text(-0.33046076716005596, -0.27728954873706546, '2'),
#  ('Stefanos Tsitsipas',
#   'Damir Dzumhur'): Text(-0.008365096702254882, -0.01749412088895197, '3'),
#  ('Stefanos Tsitsipas',
#   'Juan Martin Del Potro'): Text(-0.4842537764693101, -0.29224867547822875, '1'),
#  ('Stefanos Tsitsipas',
#   'Karen Khachanov'): Text(-0.825453434108214, -0.1290985434456526, '1'),
#  ('Stefanos Tsitsipas',
#   'Philipp Kohlschreiber'): Text(-0.445485809017726, -0.29300055827126936, '3'),
#  ('Stefanos Tsitsipas',
#   'Nikoloz Basilashvili'): Text(-0.9548054377059254, 0.22629311984137704, '2'),
#  ('Stefanos Tsitsipas',
#   'Taylor Harry Fritz'): Text(-0.2571416671681843, -0.2522026689560747, '1'),
#  ('Stefanos Tsitsipas',
#   'Roberto Carballes Baena'): Text(-0.7051814083988645, -0.2261073083857659, '1'),
#  ('Stefanos Tsitsipas',
#   'John Millman'): Text(-0.1566021465818499, -0.1941561788846162, '1'),
#  ('Stefanos Tsitsipas',
#   'Corentin Moutet'): Text(0.04331502124786102, 0.1681591674041143, '1'),
#  ('Stefanos Tsitsipas',
#   'Matteo Berrettini'): Text(-0.22215968617755633, -0.2354754896333612, '1'),
#  ('Stefanos Tsitsipas',
#   'Albert Ramos'): Text(-0.8929605522315014, -0.03465090068975343, '3'),
#  ('Stefanos Tsitsipas',
#   'Dusan Lajovic'): Text(-0.07215929248335784, -0.11448846150500044, '2'),
#  ('Alexei Popyrin',
#   'Jo Wilfried Tsonga'): Text(-0.38302223664250723, -0.3213937524081254, '1'),
#  ('Alexei Popyrin',
#   'Federico Delbonis'): Text(-0.30797933306734004, -0.3020639660683502, '1'),
#  ('Alexei Popyrin',
#   'Ugo Humbert'): Text(-0.6855393980279627, -0.2800735773920294, '1'),
#  ('Alexei Popyrin',
#   'Novak Djokovic'): Text(-0.7526498174371448, -0.2413273395588002, '1'),
#  ('Alexei Popyrin',
#   'Daniil Medvedev'): Text(-0.969470296315237, 0.15162244168564992, '2'),
#  ('Alexei Popyrin',
#   'Denis Shapovalov'): Text(-0.9515317419919794, 0.036923802314011045, '1'),
#  ('Alexei Popyrin',
#   'John Millman'): Text(-0.1712670051911615, -0.23005148184898572, '2'),
#  ('Alexei Popyrin',
#   'John Isner'): Text(-0.613247964070485, -0.30798464445748286, '1'),
#  ('Alexei Popyrin',
#   'Matteo Berrettini'): Text(-0.23682454478686793, -0.2713707925977307, '1'),
#  ('Alexei Popyrin',
#   'Milos Raonic'): Text(-0.9515317419919794, 0.3050964543860013, '1'),
#  ('Alexei Popyrin',
#   'Adrian Mannarino'): Text(-0.34512562576936756, -0.313184851701435, '2'),
#  ('Milos Raonic',
#   'Denis Shapovalov'): Text(-0.9633708635960612, 3.61031221307595e-08, '2'),
#  ('Milos Raonic',
#   'Christian Garin'): Text(-0.9515317419919794, -0.03692373010776678, '1'),
#  ('Milos Raonic',
#   'Diego Sebastian Schwartzman'): Text(-0.05360201214375726, -0.12426339975052728, '1'),
#  ('Milos Raonic',
#   'Novak Djokovic'): Text(-0.7644889390412266, -0.27825110576968914, '3'),
#  ('Milos Raonic',
#   'Dusan Lajovic'): Text(-0.09866327269675118, -0.18730753068025888, '2'),
#  ('Milos Raonic',
#   'Daniil Medvedev'): Text(-0.9813094179193187, 0.11469867547476101, '3'),
#  ('Milos Raonic',
#   'Borna Coric'): Text(-0.21508330352621252, -0.2889069261609728, '1'),
#  ('Milos Raonic',
#   'Marin Cilic'): Text(-0.4332798971927606, -0.36356505195101385, '2'),
#  ('Milos Raonic',
#   'Corentin Moutet'): Text(0.016811041034467678, 0.09534009822885586, '1'),
#  ('Milos Raonic',
#   'John Isner'): Text(-0.6250870856745667, -0.34490841066837175, '2'),
#  ('Milos Raonic',
#   'Roger Federer'): Text(0.00483700431666384, 0.018778367718900082, '2'),
#  ('Milos Raonic',
#   'Steve Johnson'): Text(-0.15292480821266824, -0.24263166800305955, '2'),
#  ('Milos Raonic',
#   'Juan Martin Del Potro'): Text(-0.5107577566827035, -0.3650677446534871, '2'),
#  ('Milos Raonic',
#   'Karen Khachanov'): Text(-0.8519574143216073, -0.20191761262091104, '1'),
#  ('Milos Raonic',
#   'Philipp Kohlschreiber'): Text(-0.47198978923111934, -0.36581962744652785, '1'),
#  ('Milos Raonic',
#   'Jo Wilfried Tsonga'): Text(-0.39486135824658897, -0.3583175186190143, '2'),
#  ('Milos Raonic',
#   'Ugo Humbert'): Text(-0.6973785196320444, -0.3169973436029183, '1'),
#  ('Milos Raonic',
#   'Sam Querrey'): Text(-0.12472054589897141, -0.21602230677749004, '3'),
#  ('Milos Raonic',
#   'John Millman'): Text(-0.18310612679524324, -0.2669752480598746, '1'),
#  ('Milos Raonic',
#   'Grigor Dimitrov'): Text(-0.9723130802489071, 0.2304425083716835, '1'),
#  ('Milos Raonic',
#   'Adrian Mannarino'): Text(-0.3569647473734493, -0.35010861791232395, '2'),
#  ('Milos Raonic',
#   'Mirza Basic'): Text(-0.587537291878335, -0.3545806054072591, '1'),
#  ('Milos Raonic',
#   'Marco Cecchinato'): Text(-0.6617742363463797, -0.3323555234416603, '2'),
#  ('Grigor Dimitrov',
#   'Denis Shapovalov'): Text(-0.9723130802489071, -0.03773014370030671, '2'),
#  ('Grigor Dimitrov',
#   'Christian Garin'): Text(-0.9604739586448254, -0.07465390991119562, '1'),
#  ('Grigor Dimitrov',
#   'Yoshihito Nishioka'): Text(0.00336730278514058, 0.019096842787160048, '2'),
#  ('Grigor Dimitrov',
#   'Roger Federer'): Text(-0.004105212336182107, -0.018951812084528757, '2'),
#  ('Grigor Dimitrov',
#   'Karen Khachanov'): Text(-0.8608996309744532, -0.23964779242433987, '1'),
#  ('Grigor Dimitrov',
#   'Philipp Kohlschreiber'): Text(-0.4809320058839653, -0.40354980724995665, '1'),
#  ('Grigor Dimitrov',
#   'Damir Dzumhur'): Text(-0.04381129356849417, -0.12804336986763926, '3'),
#  ('Grigor Dimitrov',
#   'Borna Coric'): Text(-0.22402552017905847, -0.32663710596440165, '1'),
#  ('Grigor Dimitrov',
#   'Marin Cilic'): Text(-0.44222211384560656, -0.4012952317544427, '2'),
#  ('Grigor Dimitrov',
#   'Ugo Humbert'): Text(-0.7063207362848904, -0.35472752340634717, '2'),
#  ('Grigor Dimitrov',
#   'Roberto Carballes Baena'): Text(-0.7406276052651037, -0.33665655736445316, '1'),
#  ('Grigor Dimitrov',
#   'John Millman'): Text(-0.1920483434480892, -0.30470542786330346, '2'),
#  ('Grigor Dimitrov',
#   'Novak Djokovic'): Text(-0.7734311556940725, -0.31598128557311794, '3'),
#  ('Grigor Dimitrov',
#   'Dusan Lajovic'): Text(-0.10760548934959713, -0.2250377104836877, '1'),
#  ('Grigor Dimitrov',
#   'Rafael Nadal'): Text(-0.8337484337244566, -0.26733069290913136, '3'),
#  ('Grigor Dimitrov',
#   'Daniil Medvedev'): Text(-0.9902516345721646, 0.07696849567133215, '1'),
#  ('Grigor Dimitrov',
#   'Kevin Anderson'): Text(-0.9872468154113446, 0.15440265005540504, '1'),
#  ('Grigor Dimitrov',
#   'Taylor Harry Fritz'): Text(-0.2925878640344236, -0.36275191793476197, '1'),
#  ('Grigor Dimitrov',
#   'Corentin Moutet'): Text(0.00786882438162173, 0.05760991842542702, '1'),
#  ('Grigor Dimitrov',
#   'Sam Querrey'): Text(-0.13366276255181736, -0.25375248658091887, '1'),
#  ('Grigor Dimitrov',
#   'Federico Delbonis'): Text(-0.32876067132426773, -0.3767179120826679, '1'),
#  ('Grigor Dimitrov',
#   'Matteo Berrettini'): Text(-0.2576058830437956, -0.34602473861204847, '2'),
#  ('Grigor Dimitrov',
#   'Adrian Mannarino'): Text(-0.36590696402629524, -0.38783879771575275, '1'),
#  ('Grigor Dimitrov',
#   'Steve Johnson'): Text(-0.1618670248655142, -0.2803618478064884, '1'),
#  ('Kevin Anderson',
#   'Daniil Medvedev'): Text(-0.9962431530817561, 0.03865881715848252, '2'),
#  ('Kevin Anderson',
#   'Denis Shapovalov'): Text(-0.9783045987584986, -0.07603982221315636, '1'),
#  ('Kevin Anderson',
#   'Novak Djokovic'): Text(-0.7794226742036641, -0.3542909640859676, '4'),
#  ('Kevin Anderson',
#   'Taylor Harry Fritz'): Text(-0.29857938254401517, -0.40106159644761163, '1'),
#  ('Kevin Anderson',
#   'Borna Coric'): Text(-0.23001703868865003, -0.3649467844772513, '2'),
#  ('Kevin Anderson',
#   'Diego Sebastian Schwartzman'): Text(-0.06853574730619477, -0.20030325806680577, '1'),
#  ('Kevin Anderson',
#   'Ugo Humbert'): Text(-0.712312254794482, -0.39303720191919683, '1'),
#  ('Kevin Anderson',
#   'Roger Federer'): Text(-0.010096730845773672, -0.0572614905973784, '3'),
#  ('Kevin Anderson',
#   'Juan Martin Del Potro'): Text(-0.525691491845141, -0.44110760296976564, '1'),
#  ('Kevin Anderson',
#   'Christian Garin'): Text(-0.966465477154417, -0.11296358842404527, '1'),
#  ('Kevin Anderson',
#   'Karen Khachanov'): Text(-0.8668911494840448, -0.27795747093718953, '1'),
#  ('Kevin Anderson',
#   'Philipp Kohlschreiber'): Text(-0.48692352439355685, -0.4418594857628063, '2'),
#  ('Kevin Anderson',
#   'Nikoloz Basilashvili'): Text(-0.9962431530817561, 0.07743419234984013, '3'),
#  ('Kevin Anderson',
#   'Sam Querrey'): Text(-0.13965428106140892, -0.29206216509376853, '1'),
#  ('Kevin Anderson',
#   'John Isner'): Text(-0.6400208208370042, -0.42094826898465026, '1'),
#  ('Kevin Anderson',
#   'Dusan Lajovic'): Text(-0.11359700785918869, -0.26334738899653737, '2'),
#  ('Kevin Anderson',
#   'Adrian Mannarino'): Text(-0.3718984825358868, -0.4261484762286024, '2'),
#  ('Nikoloz Basilashvili',
#   'Denis Shapovalov'): Text(-0.9813094179193187, -0.11469860140587163, '2'),
#  ('Nikoloz Basilashvili',
#   'Karen Khachanov'): Text(-0.8698959686448648, -0.3166162501299048, '1'),
#  ('Nikoloz Basilashvili',
#   'Philipp Kohlschreiber'): Text(-0.48992834355437687, -0.4805182649555216, '1'),
#  ('Nikoloz Basilashvili',
#   'Novak Djokovic'): Text(-0.7824274933644841, -0.3929497432786829, '2'),
#  ('Nikoloz Basilashvili',
#   'Dusan Lajovic'): Text(-0.11660182702000871, -0.30200616818925263, '3'),
#  ('Nikoloz Basilashvili',
#   'Rafael Nadal'): Text(-0.8427447713948681, -0.3442991506146963, '3'),
#  ('Nikoloz Basilashvili',
#   'Yoshihito Nishioka'): Text(-0.005629034885271, -0.05787161491840486, '1'),
#  ('Nikoloz Basilashvili',
#   'Borna Coric'): Text(-0.23302185784947005, -0.4036055636699666, '3'),
#  ('Nikoloz Basilashvili',
#   'John Millman'): Text(-0.20104468111850077, -0.3816738855688684, '2'),
#  ('Nikoloz Basilashvili',
#   'Sam Querrey'): Text(-0.14265910022222894, -0.3307209442864838, '1'),
#  ('Nikoloz Basilashvili',
#   'Federico Delbonis'): Text(-0.3377570089946793, -0.45368636978823285, '1'),
#  ('Nikoloz Basilashvili',
#   'Matteo Berrettini'): Text(-0.2666022207142072, -0.4229931963176134, '3'),
#  ('Nikoloz Basilashvili',
#   'Steve Johnson'): Text(-0.17086336253592577, -0.3573303055120533, '1'),
#  ('Nikoloz Basilashvili',
#   'Dominik Koepfer'): Text(-0.5672896685129674, -0.4760124816269304, '1'),
#  ('Nikoloz Basilashvili',
#   'Lorenzo Sonego'): Text(-0.0235000273435389, -0.1332752234527409, '1'),
#  ('Nikoloz Basilashvili',
#   'Jo Wilfried Tsonga'): Text(-0.4127999125698465, -0.47301615612800807, '2'),
#  ('Nikoloz Basilashvili',
#   'Juan Martin Del Potro'): Text(-0.528696311005961, -0.4797663821624809, '1'),
#  ('Nikoloz Basilashvili',
#   'Ugo Humbert'): Text(-0.715317073955302, -0.4316959811119121, '1'),
#  ('Nikoloz Basilashvili',
#   'Roberto Carballes Baena'): Text(-0.7496239429355154, -0.4136250150700181, '1'),
#  ('Nikoloz Basilashvili',
#   'Albert Ramos'): Text(-0.9374030867681523, -0.22216860737400562, '1'),
#  ('Daniil Medvedev',
#   'Rafael Nadal'): Text(-0.8427447713948681, -0.3830745258060539, '4'),
#  ('Daniil Medvedev',
#   'Novak Djokovic'): Text(-0.7824274933644841, -0.43172511847004047, '5'),
#  ('Daniil Medvedev',
#   'Dusan Lajovic'): Text(-0.11660182702000871, -0.34078154338061023, '2'),
#  ('Daniil Medvedev',
#   'Karen Khachanov'): Text(-0.8698959686448648, -0.3553916253212624, '2'),
#  ('Daniil Medvedev',
#   'Borna Coric'): Text(-0.23302185784947005, -0.4423809388613242, '5'),
#  ('Daniil Medvedev',
#   'Denis Shapovalov'): Text(-0.9813094179193187, -0.15347397659722922, '2'),
#  ('Daniil Medvedev',
#   'Ugo Humbert'): Text(-0.715317073955302, -0.4704713563032697, '1'),
#  ('Daniil Medvedev',
#   'Roger Federer'): Text(-0.013101550006593687, -0.13469564498145128, '3'),
#  ('Daniil Medvedev',
#   'Adrian Mannarino'): Text(-0.3749033016967068, -0.5035826306126753, '2'),
#  ('Daniil Medvedev',
#   'Steve Johnson'): Text(-0.17086336253592577, -0.3961056807034109, '3'),
#  ('Daniil Medvedev',
#   'Christian Garin'): Text(-0.969470296315237, -0.19039774280811814, '1'),
#  ('Daniil Medvedev',
#   'Diego Sebastian Schwartzman'): Text(-0.07154056646701479, -0.27773741245087863, '5'),
#  ('Daniil Medvedev',
#   'Philipp Kohlschreiber'): Text(-0.48992834355437687, -0.5192936401468792, '1'),
#  ('Daniil Medvedev',
#   'Casper Ruud'): Text(-0.9548054675082478, -0.22629304577248766, '1'),
#  ('Daniil Medvedev',
#   'Dominik Koepfer'): Text(-0.5672896685129674, -0.514787856818288, '1'),
#  ('Daniil Medvedev',
#   'Jo Wilfried Tsonga'): Text(-0.4127999125698465, -0.5117915313193657, '2'),
#  ('Daniil Medvedev',
#   'Federico Delbonis'): Text(-0.3377570089946793, -0.49246174497959044, '1'),
#  ('Daniil Medvedev',
#   'Marin Cilic'): Text(-0.45121845151601814, -0.5170390646513653, '1'),
#  ('Daniil Medvedev',
#   'Henri Laaksonen'): Text(-0.09284791571514978, -0.3101336694401117, '1'),
#  ('Daniil Medvedev',
#   'John Isner'): Text(-0.6430256399978242, -0.4983824233687231, '1'),
#  ('Daniil Medvedev',
#   'Matteo Berrettini'): Text(-0.2666022207142072, -0.461768571508971, '1'),
#  ('Daniil Medvedev',
#   'Albert Ramos'): Text(-0.9374030867681523, -0.2609439825653632, '1'),
#  ('Daniil Medvedev',
#   'Mirza Basic'): Text(-0.6054758462015926, -0.5080546181076105, '1'),
#  ('Horacio Zeballos',
#   'Yoshihito Nishioka'): Text(-0.0026242157244509845, -0.13530576743983258, '1'),
#  ('Horacio Zeballos',
#   'Novak Djokovic'): Text(-0.7794226742036641, -0.4703838958001106, '1'),
#  ('Horacio Zeballos',
#   'Dusan Lajovic'): Text(-0.11359700785918869, -0.37944032071068035, '2'),
#  ('Horacio Zeballos',
#   'John Isner'): Text(-0.6400208208370042, -0.5370412006987932, '1'),
#  ...}

# %%
from collections import Counter
from operator import itemgetter
def plot_deg_frequency(G, weighted=False, xscale = "log", yscale = "log"):

    if weighted:
        degrees = G.degree(weight="weight")
    else:
        degrees = G.degree()
    _, deg_list = zip(*degrees)
    deg_counts = Counter(deg_list)  #broji koliko ima odigranih meceva?????????????????      
    print(deg_counts)
    x, y = zip(*deg_counts.items())                                                      

    plt.figure(1)   

    # prep axes   
    if weighted:
        plt.xlabel('weighted degree')  
    else:
        plt.xlabel('degree')                                                                                                             
    plt.xscale(xscale)                                                                                                                
    plt.xlim(1, max(x))  

    plt.ylabel('frequency')                                                                                                          
    plt.yscale(yscale)                                                                                                                
    plt.ylim(1, max(y))                                                                                                             
                                                                                                                                                                                                    
    plt.scatter(x, y, marker='.')                                                                                                    
    plt.show()

# %%
 plot_deg_frequency(G)
# Out:
# Counter({1: 159, 2: 70, 3: 43, 5: 25, 6: 25, 4: 22, 7: 14, 8: 10, 9: 10, 13: 7, 10: 7, 80: 6, 23: 6, 22: 6, 20: 6, 48: 5, 52: 5, 29: 5, 35: 5, 71: 5, 14: 4, 16: 4, 41: 4, 18: 4, 19: 4, 17: 4, 74: 4, 66: 4, 84: 3, 75: 3, 30: 3, 64: 3, 27: 3, 15: 3, 67: 3, 65: 3, 11: 3, 86: 3, 83: 3, 90: 3, 12: 3, 93: 2, 56: 2, 63: 2, 36: 2, 49: 2, 57: 2, 54: 2, 21: 2, 38: 2, 60: 2, 55: 2, 42: 2, 78: 2, 81: 2, 89: 2, 32: 2, 79: 2, 92: 2, 61: 2, 46: 2, 28: 2, 25: 2, 82: 2, 94: 1, 70: 1, 68: 1, 85: 1, 53: 1, 73: 1, 26: 1, 40: 1, 91: 1, 37: 1, 95: 1, 44: 1, 45: 1, 50: 1, 96: 1, 47: 1, 99: 1, 97: 1, 103: 1, 77: 1, 62: 1, 88: 1, 34: 1})

# %%
plot_deg_frequency(G, weighted = True)
# Out:
# Counter({1: 159, 2: 70, 3: 41, 6: 26, 4: 24, 5: 23, 7: 12, 10: 11, 8: 10, 9: 9, 23: 7, 21: 6, 24: 5, 14: 5, 13: 5, 126: 4, 38: 4, 16: 4, 50: 4, 17: 4, 31: 4, 18: 4, 61: 3, 131: 3, 74: 3, 20: 3, 89: 3, 29: 3, 55: 3, 36: 3, 11: 3, 114: 3, 19: 3, 73: 3, 62: 2, 88: 2, 104: 2, 15: 2, 41: 2, 25: 2, 102: 2, 101: 2, 84: 2, 83: 2, 40: 2, 32: 2, 66: 2, 71: 2, 151: 2, 118: 2, 183: 2, 60: 2, 12: 2, 49: 2, 39: 2, 87: 2, 142: 1, 68: 1, 72: 1, 109: 1, 43: 1, 22: 1, 180: 1, 134: 1, 47: 1, 138: 1, 100: 1, 96: 1, 91: 1, 65: 1, 98: 1, 127: 1, 124: 1, 119: 1, 128: 1, 107: 1, 44: 1, 33: 1, 135: 1, 80: 1, 45: 1, 116: 1, 176: 1, 94: 1, 108: 1, 115: 1, 63: 1, 139: 1, 59: 1, 196: 1, 161: 1, 158: 1, 122: 1, 26: 1, 111: 1, 46: 1, 165: 1, 95: 1, 58: 1, 28: 1, 85: 1, 110: 1, 120: 1, 146: 1, 112: 1, 30: 1, 136: 1, 141: 1, 52: 1, 106: 1, 140: 1, 121: 1, 56: 1, 42: 1, 93: 1, 129: 1})

# %%
#slucajno generisana mreza Gnm ima normalnu distribuciju!
n = G.number_of_nodes()
m = G.number_of_edges()
Gnm = nx.gnm_random_graph(n, m) 

plot_deg_frequency(Gnm, xscale = 'linear', yscale = 'linear')
plot_deg_frequency(Gnm, xscale = 'log', yscale = 'log')
# Out:
# Counter({18: 53, 16: 52, 19: 52, 17: 50, 22: 50, 14: 43, 21: 41, 15: 40, 20: 38, 13: 29, 24: 20, 23: 20, 12: 18, 26: 15, 25: 14, 11: 13, 10: 9, 28: 7, 27: 6, 29: 3, 9: 3, 30: 2, 8: 1, 34: 1, 33: 1})
# Counter({18: 53, 16: 52, 19: 52, 17: 50, 22: 50, 14: 43, 21: 41, 15: 40, 20: 38, 13: 29, 24: 20, 23: 20, 12: 18, 26: 15, 25: 14, 11: 13, 10: 9, 28: 7, 27: 6, 29: 3, 9: 3, 30: 2, 8: 1, 34: 1, 33: 1})

# %%
#Kako bi se ponašala Erdos-Renyi mreža sa koja ima isti broj čvorova n, a verovatnoća formiranja grane je takva da je očekivani broj grana u mreži m?
p = ( 2*float(m) ) / ( n* (n-1) )
print(p)

er_mreza = nx.erdos_renyi_graph(n,p)

delta_m = m - er_mreza.number_of_edges()
print(f"Broj čvorova originalne mreže minus broj čvorova u ER mreži iznosi {delta_m}, što je odstupanje od {abs(float(delta_m)) * 100 / m}%")

plot_deg_frequency(er_mreza, xscale = 'linear', yscale = 'linear')
plot_deg_frequency(er_mreza, xscale = 'log', yscale = 'log')
#Šta nam informacije o raspodeli stepena čvora govore o ovoj mreži?

# Da je mreža bila sa slučajnim vezivanjem, očekivali bismo da raspodela bude slična normalnoj raspodeli! Sto i lici!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Out:
# 0.03163392486200962
# Broj čvorova originalne mreže minus broj čvorova u ER mreži iznosi 114, što je odstupanje od 2.1388367729831144%
# Counter({16: 67, 17: 60, 18: 58, 19: 55, 15: 44, 20: 42, 22: 36, 21: 35, 14: 34, 13: 31, 23: 21, 24: 20, 12: 19, 26: 12, 25: 12, 11: 9, 10: 8, 9: 5, 27: 4, 8: 3, 29: 2, 33: 1, 30: 1, 31: 1, 34: 1})
# Counter({16: 67, 17: 60, 18: 58, 19: 55, 15: 44, 20: 42, 22: 36, 21: 35, 14: 34, 13: 31, 23: 21, 24: 20, 12: 19, 26: 12, 25: 12, 11: 9, 10: 8, 9: 5, 27: 4, 8: 3, 29: 2, 33: 1, 30: 1, 31: 1, 34: 1})

# %%
#Asortativnost (eng. assortativity) meri stepen tendencije čvorova mreže da se vezuju sa sličnim čvorovima. 
#U ovoj analizi ćemo prvo sprovesti analizu asortativnosti na osnovu stepena čvora, jer nas interesuje da li se međusobno vezuju čvorovi koji su sličnog stepena, 
#ili habovi (čvorovi velikog stepena) teže da se slabo međusobno vezuju, a mnogo vezuju sa čvorovima malog stepena.
#Uvodi se koeficijent asortativnosti r, koji je u opsegu od -1 do 1. 
#Mreža sa r = 1 iskazuje savršeno asortativno mešanje (perfect assortative mixing pattern), kad je r = 0 mreža je neasortativna ili neutralna, dok je u slučaju r = −1 mreža potpuno disasortativna.
# asortativnost na osnovu netežinskog stepena čvora
r1 = nx.degree_assortativity_coefficient(G)
print(f"Koeficijent asortativnosti na osnovu netežinskog stepena čvora: {r1}")

# asortativnost na osnovu težinskog stepena čvora
r2 = nx.degree_assortativity_coefficient(G, weight='weight')
print(f"Koeficijent asortativnosti na osnovu težinskog stepena čvora: {r2}")
# Out:
# Koeficijent asortativnosti na osnovu netežinskog stepena čvora: 0.16919387110544537
# Koeficijent asortativnosti na osnovu težinskog stepena čvora: 0.14652712553286887

# %%
#Kao što vidimo, mreža je neutralna tj. neasortativna, odnosno, čvorovi sličnog stepena uglavnom se ne vezuju međusobno.

# %%
#ANALIZA KOMUNA
#Stepen klasterisanja može se proceniti na osnovu koeficijenta klasterisanja.
id_igraca, clustering_coef = zip(*nx.clustering(G, weight = "weight").items())

nenula = [(id_ig, cc)  for id_ig, cc in zip(id_igraca, clustering_coef) if cc > 0]

df = pd.DataFrame(nenula, columns = ["id", "cc"])
df.sort_values('cc', inplace = True)

max_lokalni_stepen_klasterisanja = max(clustering_coef)

prosecni_stepen_klasterisanja = nx.average_clustering(G)

print(f"Max lokalni cc: {max_lokalni_stepen_klasterisanja}")
print(f"Prosečan cc: {prosecni_stepen_klasterisanja}")
print("Lokalni stepeni klasterisanja koji nisu nula:")
print(df)
# Out:
# Max lokalni cc: 0.16508715292071477
# Prosečan cc: 0.1866939496703153
# Lokalni stepeni klasterisanja koji nisu nula:
#                                      id        cc
# 166  Juan Pablo Varillas Patino Samudio  0.003472
# 211                      Roberto Quiroz  0.007500
# 213                       Benjamin Lock  0.008333
# 52                     Altug Celikbilek  0.008333
# 90                          Tatsuma Ito  0.008333
# ..                                  ...       ...
# 223                    Andrey Kuznetsov  0.157490
# 60                  Francisco Cerundolo  0.157490
# 74                           Luca Vanni  0.157490
# 202                    Thiemo De Bakker  0.160305
# 119                Michail Pervolarakis  0.165087
#
# [308 rows x 2 columns]

# %%
# možemo iskoristiti networkx.draw_network da predstavimo egomrežu tog čvora
ego_mreza = nx.ego_graph(G, 'Michail Pervolarakis')
print(f"Čvorovi ego mreže igrača Michail Pervolarakis su {ego_mreza.nodes}")
plt.figure(figsize=(15,10))
tezine_grana = nx.get_edge_attributes(ego_mreza,'weight')
pos = nx.circular_layout(ego_mreza)
#pos = nx.spring_layout(ego_mreza)
#print(pos)
nx.draw_networkx(ego_mreza, pos)
nx.draw_networkx_edge_labels(ego_mreza, pos, edge_labels = tezine_grana)
# Out:
# Čvorovi ego mreže igrača Michail Pervolarakis su ['Jan Lennard Struff', 'John Millman', 'Felix Auger Aliassime', 'Michail Pervolarakis']
# {('Jan Lennard Struff',
#   'Felix Auger Aliassime'): Text(7.946626690014114e-09, -2.1855693665697605e-08, '2'),
#  ('Jan Lennard Struff',
#   'John Millman'): Text(0.4999999751630862, 0.5000000109278468, '3'),
#  ('Jan Lennard Struff',
#   'Michail Pervolarakis'): Text(0.50000000298122, -0.49999996721645945, '1'),
#  ('John Millman',
#   'Felix Auger Aliassime'): Text(-0.50000000298122, 0.4999999672164595, '2'),
#  ('John Millman',
#   'Michail Pervolarakis'): Text(-7.946626738379675e-09, 2.1855693699279755e-08, '1'),
#  ('Felix Auger Aliassime',
#   'Michail Pervolarakis'): Text(-0.49999997516308625, -0.5000000109278468, '1')}

# %%
# možemo iskoristiti networkx.draw_network da predstavimo egomrežu tog čvora
ego_mreza = nx.ego_graph(G, 'Francisco Cerundolo')
print(f"Čvorovi ego mreže igrača Francisco Cerundolo su {ego_mreza.nodes}")
plt.figure(figsize=(15,10))
tezine_grana = nx.get_edge_attributes(ego_mreza,'weight')
pos = nx.circular_layout(ego_mreza)
#pos = nx.spring_layout(ego_mreza)
#print(pos)
nx.draw_networkx(ego_mreza, pos)
nx.draw_networkx_edge_labels(ego_mreza, pos, edge_labels = tezine_grana)
# Out:
# Čvorovi ego mreže igrača Francisco Cerundolo su ['Guido Pella', 'Laslo Djere', 'Francisco Cerundolo']
# {('Guido Pella',
#   'Laslo Djere'): Text(0.24999996274709668, 0.43301271829021687, '2'),
#  ('Guido Pella',
#   'Francisco Cerundolo'): Text(0.2500000372529033, -0.43301270835610933, '1'),
#  ('Laslo Djere',
#   'Francisco Cerundolo'): Text(-0.5, -9.934107536579972e-09, '1')}

# %%
# možemo iskoristiti networkx.draw_network da predstavimo egomrežu tog čvora
ego_mreza = nx.ego_graph(G, 'Rafael Nadal')
print(f"Čvorovi ego mreže igrača Rafael Nadal su {ego_mreza.nodes}")
plt.figure(figsize=(15,10))
tezine_grana = nx.get_edge_attributes(ego_mreza,'weight')
pos = nx.circular_layout(ego_mreza)
#pos = nx.spring_layout(ego_mreza)
#print(pos)
nx.draw_networkx(ego_mreza, pos)
nx.draw_networkx_edge_labels(ego_mreza, pos, edge_labels = tezine_grana)
# Out:
# Čvorovi ego mreže igrača Rafael Nadal su ['Hugo Dellien', 'Soon Woo Kwon', 'Jan Lennard Struff', 'Guillermo Garcia Lopez', 'Pablo Andujar', 'Nick Kyrgios', 'Matthew Ebden', 'Stanislas Wawrinka', 'Simone Bolelli', 'Guido Pella', 'Daniel Evans', 'Tomas Berdych', 'Alexander Zverev', 'Richard Gasquet', 'Joao Sousa', 'Mischa Zverev', 'Dominic Thiem', 'Leonardo Mayer', 'Vasek Pospisil', 'Filip Krajinovic', 'Martin Klizan', 'Aljaz Bedene', 'Kei Nishikori', 'Felix Auger Aliassime', 'Juan Ignacio Londero', 'Gael Monfils', 'Roberto Bautista Agut', 'Thanasi Kokkinakis', 'David Goffin', 'Fernando Verdasco', 'Dudi Sela', 'Victor Estrella', 'Pablo Carreno Busta', 'Benoit Paire', 'Francis Tiafoe', 'Fabio Fognini', 'Andrey Rublev', 'James Duckworth', 'Jeremy Chardy', 'Feliciano Lopez', 'Maximilian Marterer', 'Alex De Minaur', 'Stefano Travaglia', 'Hyeon Chung', 'Borna Gojo', 'Yannick Hanfmann', 'David Ferrer', 'Stefanos Tsitsipas', 'Grigor Dimitrov', 'Nikoloz Basilashvili', 'Daniil Medvedev', 'Mikhail Kukushkin', 'Denis Shapovalov', 'Karen Khachanov', 'Rafael Nadal', 'Yuichi Sugita', 'Sebastian Korda', 'Novak Djokovic', 'Roberto Carballes Baena', 'Yannick Maden', 'Juan Martin Del Potro', 'Philipp Kohlschreiber', 'Marin Cilic', 'Jo Wilfried Tsonga', 'Jiri Vesely', 'Jannik Sinner', 'Adrian Mannarino', 'Egor Gerasimov', 'Jared Donaldson', 'Federico Delbonis', 'Taylor Harry Fritz', 'Matteo Berrettini', 'Jordan Thompson', 'Mackenzie Mcdonald', 'Pablo Cuevas', 'John Millman', 'Sam Querrey', 'Dusan Lajovic', 'Diego Sebastian Schwartzman', 'Damir Dzumhur', 'Miomir Kecmanovic', 'Roger Federer', 'Yoshihito Nishioka']
# {('Hugo Dellien',
#   'Roberto Carballes Baena'): Text(0.34189626335261086, -0.47434503259347993, '2'),
#  ('Hugo Dellien',
#   'Juan Ignacio Londero'): Text(0.3782230816528412, 0.48494368721026065, '2'),
#  ('Hugo Dellien',
#   'Rafael Nadal'): Text(0.20764049599592949, -0.4056179562900016, '1'),
#  ('Hugo Dellien',
#   'Daniil Medvedev'): Text(0.09998726517585782, -0.2999830281563295, '1'),
#  ('Hugo Dellien',
#   'Nikoloz Basilashvili'): Text(0.07844555042926848, -0.2688714598307134, '1'),
#  ('Hugo Dellien',
#   'Stefanos Tsitsipas'): Text(0.04271554598876326, -0.2022150935977438, '1'),
#  ('Hugo Dellien',
#   'Jan Lennard Struff'): Text(0.9942802786619146, 0.0754121445527091, '1'),
#  ('Hugo Dellien',
#   'Alex De Minaur'): Text(0.0003581308739106781, 0.01892074516346388, '1'),
#  ('Hugo Dellien',
#   'John Millman'): Text(0.9110779759035286, -0.28463113658287814, '1'),
#  ('Hugo Dellien',
#   'Aljaz Bedene'): Text(0.49053794612293744, 0.49991047317241816, '1'),
#  ('Hugo Dellien',
#   'Pablo Cuevas'): Text(0.8883744772190759, -0.31490520004171035, '1'),
#  ('Hugo Dellien',
#   'Federico Delbonis'): Text(0.7445170423041033, -0.4361323456774419, '1'),
#  ('Hugo Dellien',
#   'Alexander Zverev'): Text(0.8074992292081483, 0.3942641605515525, '1'),
#  ('Hugo Dellien',
#   'Kei Nishikori'): Text(0.4527574571443499, 0.4977631264296108, '1'),
#  ('Hugo Dellien',
#   'Soon Woo Kwon'): Text(0.9985680282063877, 0.03781436895673192, '1'),
#  ('Soon Woo Kwon',
#   'Juan Ignacio Londero'): Text(0.37679110985922887, 0.5227580586355585, '1'),
#  ('Soon Woo Kwon',
#   'Dusan Lajovic'): Text(0.9478728173268174, -0.18156024381457234, '1'),
#  ('Soon Woo Kwon',
#   'Adrian Mannarino'): Text(0.63860867786153, -0.44217376073513026, '1'),
#  ('Soon Woo Kwon',
#   'Richard Gasquet'): Text(0.7753688982903276, 0.454205147104747, '1'),
#  ('Soon Woo Kwon',
#   'Rafael Nadal'): Text(0.20620852420231717, -0.36780358486470377, '1'),
#  ('Soon Woo Kwon',
#   'Karen Khachanov'): Text(0.17636954484960465, -0.3445312194484468, '1'),
#  ('Soon Woo Kwon',
#   'Benoit Paire'): Text(0.098555323184568, 0.33779742444681793, '1'),
#  ('Soon Woo Kwon',
#   'Nikoloz Basilashvili'): Text(0.07701357863565617, -0.2310570884054156, '1'),
#  ('Soon Woo Kwon',
#   'Guido Pella'): Text(0.8869424458208186, 0.35271962613452135, '2'),
#  ('Soon Woo Kwon',
#   'Jan Lennard Struff'): Text(0.9928483068683023, 0.1132265159780069, '1'),
#  ('Soon Woo Kwon',
#   'Denis Shapovalov'): Text(0.1483759253058471, -0.3190686515496331, '1'),
#  ('Soon Woo Kwon',
#   'Egor Gerasimov'): Text(0.6745086151449077, -0.4302079792413568, '1'),
#  ('Soon Woo Kwon',
#   'Damir Dzumhur'): Text(0.9758200346544486, -0.11128466863652212, '1'),
#  ('Jan Lennard Struff',
#   'Denis Shapovalov'): Text(0.144088175761374, -0.28147087595365594, '5'),
#  ('Jan Lennard Struff',
#   'Novak Djokovic'): Text(0.3007551257223055, -0.3856171482763282, '4'),
#  ('Jan Lennard Struff',
#   'Roberto Bautista Agut'): Text(0.300755155524628, 0.5364414671840689, '2'),
#  ('Jan Lennard Struff',
#   'Rafael Nadal'): Text(0.20192077465784408, -0.33020580926872656, '1'),
#  ('Jan Lennard Struff',
#   'Daniil Medvedev'): Text(0.09426754383777242, -0.2245708811350545, '1'),
#  ('Jan Lennard Struff',
#   'Karen Khachanov'): Text(0.17208179530513157, -0.30693344385246957, '3'),
#  ('Jan Lennard Struff',
#   'Daniel Evans'): Text(0.8577265138222083, 0.41878779882954775, '1'),
#  ('Jan Lennard Struff',
#   'Nick Kyrgios'): Text(0.9588893054421244, 0.2601780652674217, '3'),
#  ('Jan Lennard Struff',
#   'David Goffin'): Text(0.23343455512786665, 0.5019792833448679, '3'),
#  ('Jan Lennard Struff',
#   'Gael Monfils'): Text(0.33617645260755796, 0.5497571448753006, '1'),
#  ('Jan Lennard Struff',
#   'Yoshihito Nishioka'): Text(0.9928483068683023, 0.03759775450095976, '2'),
#  ('Jan Lennard Struff',
#   'Nikoloz Basilashvili'): Text(0.07272582909118308, -0.19345931280943843, '3'),
#  ('Jan Lennard Struff',
#   'Grigor Dimitrov'): Text(0.05359875811786807, -0.16080764986419444, '2'),
#  ('Jan Lennard Struff',
#   'Marin Cilic'): Text(0.4848182527245294, -0.42449833108827495, '3'),
#  ('Jan Lennard Struff',
#   'Dominic Thiem'): Text(0.6702207761934671, 0.5434345225531202, '1'),
#  ('Jan Lennard Struff',
#   'Stefanos Tsitsipas'): Text(0.036995824650677855, -0.12680294657646884, '5'),
#  ('Jan Lennard Struff',
#   'Alex De Minaur'): Text(-0.005361590464174726, 0.09433289218473886, '3'),
#  ('Jan Lennard Struff',
#   'Felix Auger Aliassime'): Text(0.40952779137997347, 0.568176798119527, '2'),
#  ('Jan Lennard Struff',
#   'John Millman'): Text(0.905358254565443, -0.20921898956160315, '3'),
#  ('Jan Lennard Struff',
#   'Jeremy Chardy'): Text(0.011727925522408367, 0.20634435690463188, '2'),
#  ('Jan Lennard Struff',
#   'Mikhail Kukushkin'): Text(0.11810049094018005, -0.2539641965571612, '1'),
#  ('Jan Lennard Struff',
#   'Pablo Carreno Busta'): Text(0.11810052074250255, 0.4047885154649018, '3'),
#  ('Jan Lennard Struff',
#   'Vasek Pospisil'): Text(0.5976190105353107, 0.5646167020811174, '1'),
#  ('Jan Lennard Struff',
#   'Yuichi Sugita'): Text(0.23343455512786665, -0.3511549644371271, '2'),
#  ('Jan Lennard Struff',
#   'Alexander Zverev'): Text(0.8017795078700629, 0.4696763075728275, '3'),
#  ('Jan Lennard Struff',
#   'Matteo Berrettini'): Text(0.8017795078700629, -0.3188519886650868, '2'),
#  ('Jan Lennard Struff',
#   'Jordan Thompson'): Text(0.8307164603277877, -0.2944671621546976, '1'),
#  ('Jan Lennard Struff',
#   'Roger Federer'): Text(0.9885605871261517, 1.0929014350458122e-07, '3'),
#  ('Jan Lennard Struff',
#   'Richard Gasquet'): Text(0.7710811487458545, 0.49180292270072423, '1'),
#  ('Jan Lennard Struff',
#   'Francis Tiafoe'): Text(0.07272585889350558, 0.34428363171717913, '2'),
#  ('Jan Lennard Struff',
#   'Kei Nishikori'): Text(0.4470377358062645, 0.5731752734508858, '1'),
#  ('Jan Lennard Struff',
#   'Damir Dzumhur'): Text(0.9715322851099755, -0.07368689304054493, '1'),
#  ('Jan Lennard Struff',
#   'Jo Wilfried Tsonga'): Text(0.5226528198799311, -0.42378221108101755, '2'),
#  ('Jan Lennard Struff',
#   'Matthew Ebden'): Text(0.9435850677823443, 0.2947866977193684, '1'),
#  ('Jan Lennard Struff',
#   'Diego Sebastian Schwartzman'): Text(0.958889335244447, -0.10935373145851979, '1'),
#  ('Jan Lennard Struff',
#   'Taylor Harry Fritz'): Text(0.771081059338887, -0.340978693199951, '1'),
#  ('Jan Lennard Struff',
#   'Benoit Paire'): Text(0.09426757364009491, 0.37539520004279514, '1'),
#  ('Jan Lennard Struff',
#   'Feliciano Lopez'): Text(0.0032077097416923217, 0.1694745551896849, '1'),
#  ('Jan Lennard Struff',
#   'Miomir Kecmanovic'): Text(0.9814416467468771, -0.03716581575170477, '2'),
#  ('Jan Lennard Struff',
#   'Tomas Berdych'): Text(0.8307165497347553, 0.4452913618531482, '1'),
#  ('Jan Lennard Struff',
#   'Fabio Fognini'): Text(0.05359875811786807, 0.3116319687719351, '1'),
#  ('Jan Lennard Struff',
#   'Andrey Rublev'): Text(0.036995854453000354, 0.2776272654842096, '1'),
#  ('Jan Lennard Struff',
#   'Egor Gerasimov'): Text(0.6702208656004346, -0.3926102036453796, '1'),
#  ('Jan Lennard Struff',
#   'Stefano Travaglia'): Text(-0.005361590464174726, 0.05649142858564701, '1'),
#  ('Jan Lennard Struff',
#   'Leonardo Mayer'): Text(0.6343209730205407, 0.5554002742445713, '1'),
#  ('Jan Lennard Struff',
#   'Yannick Maden'): Text(0.3725033305124333, -0.40953154512611745, '1'),
#  ('Guillermo Garcia Lopez',
#   'Pablo Carreno Busta'): Text(0.11098161016555042, 0.44195433619862134, '1'),
#  ('Guillermo Garcia Lopez',
#   'Kei Nishikori'): Text(0.43991882522931236, 0.6103410941846054, '1'),
#  ('Guillermo Garcia Lopez',
#   'Federico Delbonis'): Text(0.7316784103890658, -0.3235543779224474, '3'),
#  ('Guillermo Garcia Lopez',
#   'John Millman'): Text(0.898239343988491, -0.17205316882788363, '1'),
#  ('Guillermo Garcia Lopez',
#   'Benoit Paire'): Text(0.08714866306314278, 0.41256102077651463, '1'),
#  ('Guillermo Garcia Lopez',
#   'Adrian Mannarino'): Text(0.6272020177401048, -0.36741016440543356, '1'),
#  ('Guillermo Garcia Lopez',
#   'Stanislas Wawrinka'): Text(0.9185883697887887, 0.3653045806804726, '1'),
#  ('Guillermo Garcia Lopez',
#   'Roberto Bautista Agut'): Text(0.2936362449476759, 0.5736072879177885, '1'),
#  ('Guillermo Garcia Lopez',
#   'Dusan Lajovic'): Text(0.9364661572053921, -0.10679664748487562, '1'),
#  ('Guillermo Garcia Lopez',
#   'Rafael Nadal'): Text(0.19480186408089195, -0.29303998853500707, '1'),
#  ('Guillermo Garcia Lopez',
#   'Daniil Medvedev'): Text(0.08714863326082029, -0.18740506040133498, '1'),
#  ('Guillermo Garcia Lopez',
#   'Karen Khachanov'): Text(0.16496288472817944, -0.2697676231187501, '1'),
#  ('Guillermo Garcia Lopez',
#   'Gael Monfils'): Text(0.32905754203060583, 0.5869229656090201, '1'),
#  ('Guillermo Garcia Lopez',
#   'Fabio Fognini'): Text(0.04647984754091594, 0.34879778950565465, '1'),
#  ('Guillermo Garcia Lopez',
#   'Dominic Thiem'): Text(0.663101865616515, 0.5806003432868397, '1'),
#  ('Guillermo Garcia Lopez',
#   'Diego Sebastian Schwartzman'): Text(0.9517704246674947, -0.07218791072480026, '1'),
#  ('Guillermo Garcia Lopez',
#   'Andrey Rublev'): Text(0.029876943876048223, 0.3147930862179291, '1'),
#  ('Guillermo Garcia Lopez',
#   'Fernando Verdasco'): Text(0.19480189388321445, 0.5181959191078643, '1'),
#  ('Guillermo Garcia Lopez',
#   'Jeremy Chardy'): Text(0.004609014945456236, 0.24351017763835142, '1'),
#  ('Guillermo Garcia Lopez',
#   'Sam Querrey'): Text(0.9185883995911113, -0.1401486203052929, '2'),
#  ('Guillermo Garcia Lopez',
#   'Feliciano Lopez'): Text(-0.003911200835259809, 0.20664037592340445, '1'),
#  ('Guillermo Garcia Lopez',
#   'Matteo Berrettini'): Text(0.7946605972931108, -0.2816861679313673, '1'),
#  ('Guillermo Garcia Lopez',
#   'Richard Gasquet'): Text(0.7639622381689024, 0.5289687434344438, '1'),
#  ('Guillermo Garcia Lopez',
#   'Roberto Carballes Baena'): Text(0.32905763143757333, -0.3617670648384854, '1'),
#  ('Guillermo Garcia Lopez',
#   'Mackenzie Mcdonald'): Text(0.8506076032452563, -0.2307976889904101, '1'),
#  ('Guillermo Garcia Lopez',
#   'Tomas Berdych'): Text(0.823597639157803, 0.48245718258686776, '1'),
#  ('Guillermo Garcia Lopez',
#   'Hyeon Chung'): Text(-0.009618613814154409, 0.0559241637286767, '1'),
#  ('Guillermo Garcia Lopez',
#   'Jared Donaldson'): Text(0.6979938883530764, -0.34079788250936754, '1'),
#  ('Guillermo Garcia Lopez',
#   'Yuichi Sugita'): Text(0.22631564455091452, -0.31398914370340764, '1'),
#  ('Pablo Andujar',
#   'Philipp Kohlschreiber'): Text(0.43000940398776577, -0.3486641682792948, '2'),
#  ('Pablo Andujar',
#   'Federico Delbonis'): Text(0.7217690785544867, -0.2870333825899941, '2'),
#  ('Pablo Andujar',
#   'Dusan Lajovic'): Text(0.926556825370813, -0.07027565215242232, '1'),
#  ('Pablo Andujar',
#   'Fernando Verdasco'): Text(0.18489256204863536, 0.5547169144403176, '2'),
#  ('Pablo Andujar',
#   'Joao Sousa'): Text(0.7217690487521642, 0.5852313038277579, '1'),
#  ('Pablo Andujar',
#   'Roberto Bautista Agut'): Text(0.2837269131130968, 0.6101282832502417, '2'),
#  ('Pablo Andujar',
#   'Rafael Nadal'): Text(0.18489253224631286, -0.2565189932025538, '1'),
#  ('Pablo Andujar',
#   'David Goffin'): Text(0.21640631271633542, 0.5756660994110406, '1'),
#  ('Pablo Andujar',
#   'Benoit Paire'): Text(0.07723933122856369, 0.4490820161089679, '1'),
#  ('Pablo Andujar',
#   'Gael Monfils'): Text(0.31914821019602674, 0.6234439609414735, '1'),
#  ('Pablo Andujar',
#   'Yoshihito Nishioka'): Text(0.975820064456771, 0.11128457056713259, '1'),
#  ('Pablo Andujar',
#   'Fabio Fognini'): Text(0.03657051570633685, 0.385318784838108, '1'),
#  ('Pablo Andujar',
#   'Stefano Travaglia'): Text(-0.02238983287570595, 0.13017824465181985, '2'),
#  ('Pablo Andujar',
#   'Dominic Thiem'): Text(0.6531925337819359, 0.6171213386192931, '2'),
#  ('Pablo Andujar',
#   'Stefanos Tsitsipas'): Text(0.01996758223914663, -0.05311613051029601, '1'),
#  ('Pablo Andujar',
#   'Denis Shapovalov'): Text(0.12705993334984278, -0.20778405988748308, '1'),
#  ('Pablo Andujar',
#   'John Millman'): Text(0.8883300121539119, -0.1355321734954303, '1'),
#  ('Pablo Andujar',
#   'Mikhail Kukushkin'): Text(0.10107224852864882, -0.18027738049098832, '1'),
#  ('Pablo Andujar',
#   'Feliciano Lopez'): Text(-0.013820532669838903, 0.24316137125585774, '3'),
#  ('Pablo Andujar',
#   'Matteo Berrettini'): Text(0.7847512654585317, -0.245165172598914, '1'),
#  ('Pablo Andujar',
#   'Kei Nishikori'): Text(0.43000949339473327, 0.6468620895170586, '1'),
#  ('Pablo Andujar',
#   'Jo Wilfried Tsonga'): Text(0.5056245774683998, -0.35009539501484477, '1'),
#  ('Pablo Andujar',
#   'Leonardo Mayer'): Text(0.6172927306090095, 0.6290870903107441, '2'),
#  ('Pablo Andujar',
#   'Jiri Vesely'): Text(0.5432968644585526, -0.3465199209780271, '1'),
#  ('Nick Kyrgios',
#   'Rafael Nadal'): Text(0.1722495227761393, -0.22085203557528893, '3'),
#  ('Nick Kyrgios',
#   'Daniil Medvedev'): Text(0.06459629195606764, -0.11521710744161684, '2'),
#  ('Nick Kyrgios',
#   'Yoshihito Nishioka'): Text(0.9631770549865974, 0.1469515281943974, '2'),
#  ('Nick Kyrgios',
#   'Stefanos Tsitsipas'): Text(0.007324572768973081, -0.01744917288303119, '2'),
#  ('Nick Kyrgios',
#   'Karen Khachanov'): Text(0.1424105434234268, -0.19757967015903194, '2'),
#  ('Nick Kyrgios',
#   'Alexander Zverev'): Text(0.7721082559883581, 0.5790300812662652, '3'),
#  ('Nick Kyrgios',
#   'Jo Wilfried Tsonga'): Text(0.49298156799822634, -0.3144284373875799, '1'),
#  ('Nick Kyrgios',
#   'Roberto Carballes Baena'): Text(0.3065052901328207, -0.2895791118787673, '1'),
#  ('Nick Kyrgios',
#   'John Millman'): Text(0.8756870026837383, -0.09986521586816549, '1'),
#  ('Nick Kyrgios',
#   'Grigor Dimitrov'): Text(0.0239275062361633, -0.05145387617075678, '2'),
#  ('Nick Kyrgios',
#   'Dusan Lajovic'): Text(0.9139138159006395, -0.034608694525157496, '2'),
#  ('Nick Kyrgios',
#   'Roberto Bautista Agut'): Text(0.27108390364292323, 0.6457952408775065, '1'),
#  ('Nick Kyrgios',
#   'Marin Cilic'): Text(0.4551470008428246, -0.3151445573948373, '1'),
#  ('Nick Kyrgios',
#   'Felix Auger Aliassime'): Text(0.3798565394982687, 0.6775305718129647, '1'),
#  ('Nick Kyrgios',
#   'Andrey Rublev'): Text(0.00732460257129558, 0.38698103917764726, '2'),
#  ('Nick Kyrgios',
#   'Stanislas Wawrinka'): Text(0.8960360284840361, 0.43749253364019075, '2'),
#  ('Nick Kyrgios',
#   'Jeremy Chardy'): Text(-0.017943326359296408, 0.3156981305980695, '1'),
#  ('Nick Kyrgios',
#   'Matteo Berrettini'): Text(0.7721082559883581, -0.20949821497164917, '1'),
#  ('Nick Kyrgios',
#   'Roger Federer'): Text(0.958889335244447, 0.10935388298358116, '2'),
#  ('Nick Kyrgios',
#   'Philipp Kohlschreiber'): Text(0.4173663945175922, -0.31299721065202996, '1'),
#  ('Nick Kyrgios',
#   'Richard Gasquet'): Text(0.7414098968641498, 0.6011566963941619, '1'),
#  ('Nick Kyrgios',
#   'Kei Nishikori'): Text(0.4173664839245597, 0.6825290471443235, '1'),
#  ('Nick Kyrgios',
#   'Juan Martin Del Potro'): Text(0.3798566289052362, -0.30799876512299373, '1'),
#  ('Nick Kyrgios',
#   'Feliciano Lopez'): Text(-0.026463542140012453, 0.2788283288831226, '2'),
#  ('Nick Kyrgios',
#   'Matthew Ebden'): Text(0.9139138159006395, 0.404140471412806, '1'),
#  ('Nick Kyrgios',
#   'Fabio Fognini'): Text(0.0239275062361633, 0.4209857424653728, '1'),
#  ('Nick Kyrgios',
#   'Jordan Thompson'): Text(0.801045208446083, -0.1851133884612599, '1'),
#  ('Nick Kyrgios',
#   'Maximilian Marterer'): Text(-0.03217095511890705, 0.2414197496062212, '1'),
#  ('Matthew Ebden',
#   'Dominic Thiem'): Text(0.6252452866519821, 0.6873969286985044, '1'),
#  ('Matthew Ebden',
#   'Philipp Kohlschreiber'): Text(0.40206215685781205, -0.27838857820008334, '2'),
#  ('Matthew Ebden',
#   'Filip Krajinovic'): Text(0.5153495875262765, 0.7149934322950023, '1'),
#  ('Matthew Ebden',
#   'David Goffin'): Text(0.1884590655863817, 0.6459416894902521, '1'),
#  ('Matthew Ebden',
#   'Sam Querrey'): Text(0.8807318206265784, -0.033352034893628146, '1'),
#  ('Matthew Ebden',
#   'Matteo Berrettini'): Text(0.756804018328578, -0.17488958251970255, '1'),
#  ('Matthew Ebden',
#   'Roberto Bautista Agut'): Text(0.25577966598314306, 0.6804038733294532, '1'),
#  ('Matthew Ebden',
#   'Rafael Nadal'): Text(0.15694528511635913, -0.1862434031233423, '1'),
#  ('Matthew Ebden',
#   'Karen Khachanov'): Text(0.12710630576364662, -0.16297103770708532, '1'),
#  ('Matthew Ebden',
#   'Gael Monfils'): Text(0.291200963066073, 0.6937195510206848, '1'),
#  ('Matthew Ebden',
#   'Fabio Fognini'): Text(0.008623268576383125, 0.4555943749173194, '1'),
#  ('Matthew Ebden',
#   'Taylor Harry Fritz'): Text(0.7261055697974022, -0.19701628705456675, '1'),
#  ('Matthew Ebden',
#   'Diego Sebastian Schwartzman'): Text(0.913913845702962, 0.03460867468686449, '1'),
#  ('Matthew Ebden',
#   'Stefanos Tsitsipas'): Text(-0.007979664890807092, 0.01715945956891543, '1'),
#  ('Matthew Ebden',
#   'Fernando Verdasco'): Text(0.15694531491868163, 0.624992504519529, '2'),
#  ('Matthew Ebden',
#   'Jeremy Chardy'): Text(-0.03324756401907658, 0.3503067630500162, '1'),
#  ('Matthew Ebden',
#   'Roger Federer'): Text(0.9435850975846667, 0.1439625154355278, '1'),
#  ('Matthew Ebden',
#   'Francis Tiafoe'): Text(0.027750369352020632, 0.4882460378625634, '3'),
#  ('Matthew Ebden',
#   'Damir Dzumhur'): Text(0.9265567955684906, 0.07027551310483934, '1'),
#  ('Matthew Ebden',
#   'Hyeon Chung'): Text(-0.047475192778687225, 0.16272074914034146, '1'),
#  ('Matthew Ebden',
#   'Jared Donaldson'): Text(0.6601373093885436, -0.2340012970977028, '1'),
#  ('Stanislas Wawrinka',
#   'Daniil Medvedev'): Text(0.03141426687968407, -0.04725641276228548, '2'),
#  ('Stanislas Wawrinka',
#   'Denis Shapovalov'): Text(0.08123489880328566, -0.1041564075808869, '3'),
#  ('Stanislas Wawrinka',
#   'Diego Sebastian Schwartzman'): Text(0.8960360582863586, 0.06796073691424923, '1'),
#  ('Stanislas Wawrinka',
#   'Stefanos Tsitsipas'): Text(-0.02585745230741049, 0.05051152179630017, '1'),
#  ('Stanislas Wawrinka',
#   'Karen Khachanov'): Text(0.10922851834704322, -0.12961897547970058, '3'),
#  ('Stanislas Wawrinka',
#   'Damir Dzumhur'): Text(0.9086790081518872, 0.10362757533222408, '3'),
#  ('Stanislas Wawrinka',
#   'Kei Nishikori'): Text(0.38418445884817615, 0.7504897418236548, '3'),
#  ('Stanislas Wawrinka',
#   'Taylor Harry Fritz'): Text(0.7082277823807988, -0.16366422482718201, '1'),
#  ('Stanislas Wawrinka',
#   'Marin Cilic'): Text(0.42196497576644104, -0.24718386271550596, '1'),
#  ('Stanislas Wawrinka',
#   'Jeremy Chardy'): Text(-0.05112535143567998, 0.3836588252774009, '2'),
#  ('Stanislas Wawrinka',
#   'Grigor Dimitrov'): Text(-0.009254518840220272, 0.016506818508574578, '6'),
#  ('Stanislas Wawrinka',
#   'Benoit Paire'): Text(0.03141429668200657, 0.5527096684155641, '1'),
#  ('Stanislas Wawrinka',
#   'Feliciano Lopez'): Text(-0.05964556721639602, 0.3467890235624539, '1'),
#  ('Stanislas Wawrinka',
#   'Novak Djokovic'): Text(0.23790184876421716, -0.20830267990355922, '1'),
#  ('Stanislas Wawrinka',
#   'Roberto Bautista Agut'): Text(0.23790187856653966, 0.7137559355568379, '1'),
#  ('Stanislas Wawrinka',
#   'Rafael Nadal'): Text(0.13906749769975574, -0.15289134089595757, '3'),
#  ('Stanislas Wawrinka',
#   'David Goffin'): Text(0.1705812781697783, 0.6792937517176368, '1'),
#  ('Stanislas Wawrinka',
#   'Gael Monfils'): Text(0.2733231756494696, 0.7270716132480697, '1'),
#  ('Stanislas Wawrinka',
#   'Andrey Rublev'): Text(-0.02585742250508799, 0.45494173385697856, '2'),
#  ('Stanislas Wawrinka',
#   'Filip Krajinovic'): Text(0.497471800109673, 0.7483454945223871, '1'),
#  ('Stanislas Wawrinka',
#   'Sam Querrey'): Text(0.862854033209975, 2.7333756591474412e-08, '1'),
#  ('Stanislas Wawrinka',
#   'Alexander Zverev'): Text(0.7389262309119746, 0.6469907759455965, '2'),
#  ('Stanislas Wawrinka',
#   'Roger Federer'): Text(0.9257073101680633, 0.17731457766291253, '4'),
#  ('Stanislas Wawrinka',
#   'Martin Klizan'): Text(0.4597996341914554, 0.7519209685592048, '2'),
#  ('Stanislas Wawrinka',
#   'Guido Pella'): Text(0.8198014193182572, 0.5676318701032675, '1'),
#  ('Stanislas Wawrinka',
#   'Francis Tiafoe'): Text(0.009872581935417235, 0.5215981000899481, '2'),
#  ('Stanislas Wawrinka',
#   'Jared Donaldson'): Text(0.6422595219719403, -0.20064923487031805, '1'),
#  ('Stanislas Wawrinka',
#   'Pablo Cuevas'): Text(0.8198014789229022, -0.062178584647666346, '1'),
#  ('Stanislas Wawrinka',
#   'Aljaz Bedene'): Text(0.4219649478267637, 0.7526370885664622, '2'),
#  ('Stanislas Wawrinka',
#   'Jannik Sinner'): Text(0.5347658155336092, -0.23647794460293015, '2'),
#  ('Stanislas Wawrinka',
#   'Daniel Evans'): Text(0.79487323686412, 0.5961022672023168, '4'),
#  ('Simone Bolelli',
#   'Diego Sebastian Schwartzman'): Text(0.8756870622883833, 0.09986525563451745, '1'),
#  ('Simone Bolelli',
#   'Federico Delbonis'): Text(0.6555950480099544, -0.15150121156312968, '1'),
#  ('Simone Bolelli',
#   'Roberto Carballes Baena'): Text(0.2529742690584619, -0.1897138984791677, '1'),
#  ('Simone Bolelli',
#   'Pablo Cuevas'): Text(0.799452482924927, -0.03027406592739812, '1'),
#  ('Simone Bolelli',
#   'Rafael Nadal'): Text(0.1187185017017805, -0.12098682217568935, '1'),
#  ('Simone Bolelli',
#   'Benoit Paire'): Text(0.011065300684031332, 0.5846141871358324, '1'),
#  ('Simone Bolelli',
#   'Fabio Fognini'): Text(-0.02960351483819551, 0.5208509558649723, '1'),
#  ('Simone Bolelli',
#   'Francis Tiafoe'): Text(-0.010476414062558004, 0.5535026188102163, '1'),
#  ('Guido Pella',
#   'Daniil Medvedev'): Text(-0.011638317209711257, 0.014922229021459954, '1'),
#  ('Guido Pella',
#   'Yoshihito Nishioka'): Text(0.8869424458208186, 0.27709086465747423, '1'),
#  ('Guido Pella',
#   'Diego Sebastian Schwartzman'): Text(0.8529834741969633, 0.13013937869799466, '3'),
#  ('Guido Pella',
#   'Karen Khachanov'): Text(0.0661759342576479, -0.06744033369595515, '2'),
#  ('Guido Pella',
#   'Pablo Carreno Busta'): Text(0.012194659695018872, 0.6442816256214163, '3'),
#  ('Guido Pella',
#   'Marin Cilic'): Text(0.3789123916770457, -0.18500522093176053, '3'),
#  ('Guido Pella',
#   'David Goffin'): Text(0.12752869408038298, 0.7414723935013823, '3'),
#  ('Guido Pella',
#   'Sam Querrey'): Text(0.8198014491205796, 0.06217866911750203, '3'),
#  ('Guido Pella',
#   'Roberto Carballes Baena'): Text(0.23027068096704179, -0.1594397754156905, '2'),
#  ('Guido Pella',
#   'John Millman'): Text(0.7994523935179594, 0.030274120594911302, '2'),
#  ('Guido Pella',
#   'Grigor Dimitrov'): Text(-0.0523071029296156, 0.07868546029232001, '1'),
#  ('Guido Pella',
#   'Benoit Paire'): Text(-0.011638287407388759, 0.6148883101993096, '1'),
#  ('Guido Pella',
#   'Dusan Lajovic'): Text(0.8376792067348606, 0.0955306419379193, '1'),
#  ('Guido Pella',
#   'Fernando Verdasco'): Text(0.09601494341268291, 0.7205232085306592, '2'),
#  ('Guido Pella',
#   'Joao Sousa'): Text(0.6328914301162117, 0.7510375979180995, '4'),
#  ('Guido Pella',
#   'Roberto Bautista Agut'): Text(0.19484929447714433, 0.7759345773405834, '2'),
#  ('Guido Pella',
#   'Rafael Nadal'): Text(0.09601491361036041, -0.09071269911221214, '3'),
#  ('Guido Pella',
#   'Nikoloz Basilashvili'): Text(-0.03318003195630059, 0.04603379734707602, '2'),
#  ('Guido Pella',
#   'Fabio Fognini'): Text(-0.0523071029296156, 0.5511250789284496, '1'),
#  ('Guido Pella',
#   'Taylor Harry Fritz'): Text(0.6651751982914034, -0.10148558304343658, '2'),
#  ('Guido Pella',
#   'Dominic Thiem'): Text(0.5643149151459834, 0.7829276327096346, '3'),
#  ('Guido Pella',
#   'Denis Shapovalov'): Text(0.03818231471389033, -0.041977765797141464, '1'),
#  ('Guido Pella',
#   'Andrey Rublev'): Text(-0.06891000659448332, 0.517120375640724, '1'),
#  ('Guido Pella',
#   'Aljaz Bedene'): Text(0.37891236373736836, 0.8148157303502076, '2'),
#  ('Guido Pella',
#   'Feliciano Lopez'): Text(-0.10269815130579135, 0.4089676653461993, '1'),
#  ('Guido Pella',
#   'Yuichi Sugita'): Text(0.12752869408038298, -0.1116618542806127, '1'),
#  ('Guido Pella',
#   'Roger Federer'): Text(0.882654726078668, 0.23949321944665797, '1'),
#  ('Guido Pella',
#   'Philipp Kohlschreiber'): Text(0.3411317853518133, -0.18285787418895316, '1'),
#  ('Guido Pella',
#   'Juan Ignacio Londero'): Text(0.2665974992672721, 0.7998489443880501, '2'),
#  ('Guido Pella',
#   'Mackenzie Mcdonald'): Text(0.7518206527747247, -0.028470399567615157, '1'),
#  ('Guido Pella',
#   'Damir Dzumhur'): Text(0.8656264240624918, 0.16580621711596952, '1'),
#  ('Guido Pella',
#   'Jo Wilfried Tsonga'): Text(0.41674695883244744, -0.18428910092450312, '1'),
#  ('Guido Pella',
#   'Leonardo Mayer'): Text(0.528415111973057, 0.7948933844010857, '2'),
#  ('Guido Pella',
#   'Pablo Cuevas'): Text(0.7767488948335068, 5.713607909019203e-08, '1'),
#  ('Guido Pella',
#   'Stefano Travaglia'): Text(-0.1112674515116584, 0.29598453874216146, '1'),
#  ('Guido Pella',
#   'Mischa Zverev'): Text(0.5992069676848674, 0.7682810727026972, '1'),
#  ('Daniel Evans',
#   'Karen Khachanov'): Text(0.04124775180351076, -0.038969936596905896, '1'),
#  ('Daniel Evans',
#   'Philipp Kohlschreiber'): Text(0.3162036028976762, -0.1543874770899039, '1'),
#  ('Daniel Evans',
#   'Nikoloz Basilashvili'): Text(-0.05810821441043773, 0.07450419444612527, '1'),
#  ('Daniel Evans',
#   'Federico Delbonis'): Text(0.607963277464397, -0.09275669140060322, '1'),
#  ('Daniel Evans',
#   'David Goffin'): Text(0.10260051162624584, 0.7699427906004315, '1'),
#  ('Daniel Evans',
#   'Juan Ignacio Londero'): Text(0.24166931681313497, 0.8283193414870993, '1'),
#  ('Daniel Evans',
#   'Grigor Dimitrov'): Text(-0.07723528538375274, 0.10715585739136926, '3'),
#  ('Daniel Evans',
#   'Adrian Mannarino'): Text(0.5034868848154361, -0.13661247788358938, '2'),
#  ('Daniel Evans',
#   'Fabio Fognini'): Text(-0.07723528538375274, 0.5795954760274988, '1'),
#  ('Daniel Evans',
#   'Francis Tiafoe'): Text(-0.05810818460811523, 0.6122471389727429, '2'),
#  ('Daniel Evans',
#   'Andrey Rublev'): Text(-0.09383818904862046, 0.5455907727397733, '3'),
#  ('Daniel Evans',
#   'Mackenzie Mcdonald'): Text(0.7268924703205876, -2.468565907243203e-09, '1'),
#  ('Daniel Evans',
#   'Aljaz Bedene'): Text(0.3539841812832312, 0.8432861274492569, '1'),
#  ('Daniel Evans',
#   'Alex De Minaur'): Text(-0.13619563396579554, 0.36229639944030256, '2'),
#  ('Daniel Evans',
#   'Rafael Nadal'): Text(0.07108673115622327, -0.06224230201316289, '2'),
#  ('Daniel Evans',
#   'Gael Monfils'): Text(0.20534240910593715, 0.8177206521308643, '1'),
#  ('Daniel Evans',
#   'Yoshihito Nishioka'): Text(0.8620142633666814, 0.30556126175652343, '2'),
#  ('Daniel Evans',
#   'Stefanos Tsitsipas'): Text(-0.09383821885094296, 0.14116056067909485, '2'),
#  ('Daniel Evans',
#   'Denis Shapovalov'): Text(0.013254132259753193, -0.013507368698092215, '1'),
#  ('Daniel Evans',
#   'Fernando Verdasco'): Text(0.07108676095854577, 0.7489936056297084, '1'),
#  ('Daniel Evans',
#   'Filip Krajinovic'): Text(0.42949103356614055, 0.8389945334051818, '1'),
#  ('Daniel Evans',
#   'Roger Federer'): Text(0.8577265436245309, 0.2679636165457072, '2'),
#  ('Daniel Evans',
#   'Kei Nishikori'): Text(0.3162036923046437, 0.8411387807064494, '1'),
#  ('Daniel Evans',
#   'Joao Sousa'): Text(0.6079632476620747, 0.7795079950171488, '1'),
#  ('Tomas Berdych',
#   'Yoshihito Nishioka'): Text(0.8350042992792284, 0.3320648247801239, '1'),
#  ('Tomas Berdych',
#   'Diego Sebastian Schwartzman'): Text(0.801045327655373, 0.18511333882064437, '1'),
#  ('Tomas Berdych',
#   'Philipp Kohlschreiber'): Text(0.28919363881022303, -0.12788391406630345, '1'),
#  ('Tomas Berdych',
#   'Damir Dzumhur'): Text(0.8136882775209016, 0.22078017723861923, '1'),
#  ('Tomas Berdych',
#   'Filip Krajinovic'): Text(0.4024810694786874, 0.8654980964287822, '2'),
#  ('Tomas Berdych',
#   'Juan Martin Del Potro'): Text(0.251683873197867, -0.12288546853726723, '1'),
#  ('Tomas Berdych',
#   'Benoit Paire'): Text(-0.06357643394897905, 0.6698622703219592, '2'),
#  ('Tomas Berdych',
#   'Fernando Verdasco'): Text(0.044076796871092616, 0.775497168653309, '1'),
#  ('Tomas Berdych',
#   'Roberto Bautista Agut'): Text(0.14291114793555404, 0.830908537463233, '1'),
#  ('Tomas Berdych',
#   'Rafael Nadal'): Text(0.04407676706877012, -0.035738738989562424, '1'),
#  ('Tomas Berdych',
#   'Karen Khachanov'): Text(0.014237787716057604, -0.012466373573305434, '1'),
#  ('Tomas Berdych',
#   'David Goffin'): Text(0.07559054753879269, 0.796446353624032, '1'),
#  ('Tomas Berdych',
#   'Taylor Harry Fritz'): Text(0.6132370517498131, -0.046511622920786866, '1'),
#  ('Tomas Berdych',
#   'Denis Shapovalov'): Text(-0.01375583182769996, 0.012996194325508248, '2'),
#  ('Tomas Berdych',
#   'Jeremy Chardy'): Text(-0.1461160820666656, 0.500811427183796, '1'),
#  ('Tomas Berdych',
#   'Feliciano Lopez'): Text(-0.15463629784738164, 0.4639416254688491, '1'),
#  ('Tomas Berdych',
#   'Roger Federer'): Text(0.8307165795370777, 0.2944671795693077, '1'),
#  ('Tomas Berdych',
#   'Richard Gasquet'): Text(0.6132371411567805, 0.7862699929798884, '1'),
#  ('Tomas Berdych',
#   'Francis Tiafoe'): Text(-0.08511814869556839, 0.6387507019963432, '1'),
#  ('Tomas Berdych',
#   'Kei Nishikori'): Text(0.2891937282171905, 0.86764234373005, '1'),
#  ('Tomas Berdych',
#   'Hyeon Chung'): Text(-0.16034371082627624, 0.31322541327412134, '1'),
#  ('Tomas Berdych',
#   'Fabio Fognini'): Text(-0.10424524947120589, 0.6060990390510993, '1'),
#  ('Tomas Berdych',
#   'Alex De Minaur'): Text(-0.1632055980532487, 0.388799962463903, '1'),
#  ('Tomas Berdych',
#   'Stefano Travaglia'): Text(-0.1632055980532487, 0.3509584988648112, '1'),
#  ('Tomas Berdych',
#   'Mischa Zverev'): Text(0.5472688211432771, 0.823255032825347, '1'),
#  ('Tomas Berdych',
#   'Maximilian Marterer'): Text(-0.16034371082627624, 0.4265330461919477, '1'),
#  ('Alexander Zverev',
#   'Rafael Nadal'): Text(0.015139725204077803, -0.011353793269883172, '4'),
#  ('Alexander Zverev',
#   'Daniil Medvedev'): Text(-0.09251350561599386, 0.09428113486378892, '6'),
#  ('Alexander Zverev',
#   'Denis Shapovalov'): Text(-0.042692873692392275, 0.0373811400451875, '3'),
#  ('Alexander Zverev',
#   'Diego Sebastian Schwartzman'): Text(0.7721082857906807, 0.20949828454032363, '4'),
#  ('Alexander Zverev',
#   'Roger Federer'): Text(0.8017795376723854, 0.31885212528898693, '2'),
#  ('Alexander Zverev',
#   'Dominic Thiem'): Text(0.4834397267397008, 0.8622865385519636, '5'),
#  ('Alexander Zverev',
#   'Stefanos Tsitsipas'): Text(-0.14978522480308842, 0.19204906942237457, '6'),
#  ('Alexander Zverev',
#   'Karen Khachanov'): Text(-0.01469925414863471, 0.011918572146373818, '3'),
#  ('Alexander Zverev',
#   'Philipp Kohlschreiber'): Text(0.2602565969455307, -0.1034989683466242, '2'),
#  ('Alexander Zverev',
#   'Roberto Bautista Agut'): Text(0.11397410607086172, 0.8552934831829123, '2'),
#  ('Alexander Zverev',
#   'Damir Dzumhur'): Text(0.7847512356562092, 0.24516512295829848, '1'),
#  ('Alexander Zverev',
#   'Filip Krajinovic'): Text(0.3735440276139951, 0.8898830421484615, '1'),
#  ('Alexander Zverev',
#   'Pablo Carreno Busta'): Text(-0.06868052871126373, 0.7236405314637453, '2'),
#  ('Alexander Zverev',
#   'Novak Djokovic'): Text(0.11397407626853923, -0.06676513227748482, '5'),
#  ('Alexander Zverev',
#   'David Goffin'): Text(0.04665350567410037, 0.8208312993437112, '2'),
#  ('Alexander Zverev',
#   'Nikoloz Basilashvili'): Text(-0.1140552203625832, 0.12539270318940499, '3'),
#  ('Alexander Zverev',
#   'Fabio Fognini'): Text(-0.1331822913358982, 0.6304839847707786, '2'),
#  ('Alexander Zverev',
#   'Taylor Harry Fritz'): Text(0.5843000098851208, -0.022126677201107614, '2'),
#  ('Alexander Zverev',
#   'Alex De Minaur'): Text(-0.192142639917941, 0.4131849081835823, '5'),
#  ('Alexander Zverev',
#   'Miomir Kecmanovic'): Text(0.7946605972931108, 0.28168620024713864, '2'),
#  ('Alexander Zverev',
#   'Matteo Berrettini'): Text(0.6149984584162966, 2.7333756591474412e-08, '3'),
#  ('Alexander Zverev',
#   'Jannik Sinner'): Text(0.41083804303793137, -0.09494039697685575, '2'),
#  ('Alexander Zverev',
#   'Jiri Vesely'): Text(0.3735440574163176, -0.10135472104535648, '1'),
#  ('Alexander Zverev',
#   'Kei Nishikori'): Text(0.2602566863524982, 0.8920272894497292, '2'),
#  ('Alexander Zverev',
#   'Joao Sousa'): Text(0.5520162417099291, 0.8303965037604285, '1'),
#  ('Alexander Zverev',
#   'David Ferrer'): Text(-0.16376883214610144, 0.22721203997390882, '6'),
#  ('Alexander Zverev',
#   'Hyeon Chung'): Text(-0.18928075269096856, 0.3376103589938006, '2'),
#  ('Alexander Zverev',
#   'Juan Martin Del Potro'): Text(0.2227468313331747, -0.09850052281758798, '1'),
#  ('Alexander Zverev',
#   'Federico Delbonis'): Text(0.5520162715122516, -0.041868182657323505, '2'),
#  ('Alexander Zverev',
#   'Marin Cilic'): Text(0.2980372032707631, -0.10564631508943156, '2'),
#  ('Alexander Zverev',
#   'Jeremy Chardy'): Text(-0.1750531239313579, 0.5251963729034753, '2'),
#  ('Alexander Zverev',
#   'Sam Querrey'): Text(0.738926260714297, 0.141537574959831, '1'),
#  ('Alexander Zverev',
#   'Juan Ignacio Londero'): Text(0.1857223108609895, 0.8792078502303791, '1'),
#  ('Alexander Zverev',
#   'John Millman'): Text(0.7185772051116768, 0.10963302643724027, '2'),
#  ('Alexander Zverev',
#   'Dusan Lajovic'): Text(0.756804018328578, 0.17488954778024826, '2'),
#  ('Alexander Zverev',
#   'Fernando Verdasco'): Text(0.015139755006400302, 0.7998821143729882, '3'),
#  ('Alexander Zverev',
#   'Adrian Mannarino'): Text(0.4475398788632906, -0.08572396914030966, '3'),
#  ('Alexander Zverev',
#   'Richard Gasquet'): Text(0.5843000992920883, 0.8106549386995676, '1'),
#  ('Alexander Zverev',
#   'Francis Tiafoe'): Text(-0.1140551905602607, 0.6631356477160225, '3'),
#  ('Alexander Zverev',
#   'Felix Auger Aliassime'): Text(0.2227467419262072, 0.8870288141183704, '3'),
#  ('Alexander Zverev',
#   'Andrey Rublev'): Text(-0.14978519500076592, 0.596479281483053, '2'),
#  ('Alexander Zverev',
#   'Mackenzie Mcdonald'): Text(0.670945464368442, 0.05088850627471381, '1'),
#  ('Alexander Zverev',
#   'Aljaz Bedene'): Text(0.29803717533108576, 0.8941746361925366, '2'),
#  ('Alexander Zverev',
#   'Egor Gerasimov'): Text(0.4834398161466683, -0.07375818764653619, '1'),
#  ('Alexander Zverev',
#   'James Duckworth'): Text(-0.16376886194842394, 0.56131620662339, '1'),
#  ('Alexander Zverev',
#   'Mischa Zverev'): Text(0.5183317792785848, 0.8476399785450262, '1'),
#  ('Alexander Zverev',
#   'Leonardo Mayer'): Text(0.4475399235667744, 0.8742522902434147, '1'),
#  ('Alexander Zverev',
#   'Yannick Hanfmann'): Text(-0.1750530941290354, 0.2633318736938235, '1'),
#  ('Alexander Zverev',
#   'Martin Klizan'): Text(0.3358718616957775, 0.8934585161852792, '1'),
#  ('Richard Gasquet',
#   'Daniil Medvedev'): Text(-0.12321186474020224, 0.11640774999168563, '2'),
#  ('Richard Gasquet',
#   'Denis Shapovalov'): Text(-0.07339123281660065, 0.05950775517308421, '1'),
#  ('Richard Gasquet',
#   'Diego Sebastian Schwartzman'): Text(0.7414099266664722, 0.23162489966822034, '3'),
#  ('Richard Gasquet',
#   'Stefanos Tsitsipas'): Text(-0.1804835839272968, 0.21417568455027128, '2'),
#  ('Richard Gasquet',
#   'Roberto Bautista Agut'): Text(0.08327574694665335, 0.877420098310809, '6'),
#  ('Richard Gasquet',
#   'Damir Dzumhur'): Text(0.7540528765320008, 0.2672917380861952, '1'),
#  ('Richard Gasquet',
#   'Kei Nishikori'): Text(0.22955832722828984, 0.9141539045776259, '2'),
#  ('Richard Gasquet',
#   'Federico Delbonis'): Text(0.5213179123880433, -0.019741567529426796, '1'),
#  ('Richard Gasquet',
#   'Taylor Harry Fritz'): Text(0.5536016507609124, -6.207321090467843e-08, '2'),
#  ('Richard Gasquet',
#   'Jeremy Chardy'): Text(-0.2057514830555663, 0.547322988031372, '5'),
#  ('Richard Gasquet',
#   'David Goffin'): Text(0.015955146549891996, 0.842957914471608, '3'),
#  ('Richard Gasquet',
#   'Roberto Carballes Baena'): Text(0.1186971334365508, -0.057954254445464815, '1'),
#  ('Richard Gasquet',
#   'Juan Ignacio Londero'): Text(0.15502395173678113, 0.9013344653582758, '3'),
#  ('Richard Gasquet',
#   'Benoit Paire'): Text(-0.12321183493787974, 0.7163738311695352, '5'),
#  ('Richard Gasquet',
#   'Novak Djokovic'): Text(0.08327571714433085, -0.04463851714958811, '1'),
#  ('Richard Gasquet',
#   'Dusan Lajovic'): Text(0.7261056592043695, 0.19701616290814497, '1'),
#  ('Richard Gasquet',
#   'Rafael Nadal'): Text(-0.015558633920130571, 0.010772821858013537, '1'),
#  ('Richard Gasquet',
#   'Gael Monfils'): Text(0.11869704402958331, 0.8907357760020407, '2'),
#  ('Richard Gasquet',
#   'Fabio Fognini'): Text(-0.16388065046010658, 0.6526105998986753, '1'),
#  ('Richard Gasquet',
#   'Dominic Thiem'): Text(0.45274136761549244, 0.8844131536798603, '1'),
#  ('Richard Gasquet',
#   'Alex De Minaur'): Text(-0.22284099904214938, 0.435311523311479, '2'),
#  ('Richard Gasquet',
#   'Pablo Carreno Busta'): Text(-0.09937888783547211, 0.745767146591642, '1'),
#  ('Richard Gasquet',
#   'Vasek Pospisil'): Text(0.3801396019573361, 0.9055953332078575, '2'),
#  ('Richard Gasquet',
#   'Matteo Berrettini'): Text(0.5843000992920883, 0.0221266424616533, '1'),
#  ('Richard Gasquet',
#   'Jordan Thompson'): Text(0.6132370517498131, 0.04651146897204256, '1'),
#  ('Richard Gasquet',
#   'Roger Federer'): Text(0.771081178548177, 0.34097874041688364, '2'),
#  ('Richard Gasquet',
#   'Philipp Kohlschreiber'): Text(0.22955823782132234, -0.08137235321872749, '1'),
#  ('Richard Gasquet',
#   'Juan Martin Del Potro'): Text(0.19204847220896631, -0.07637390768969127, '1'),
#  ('Richard Gasquet',
#   'Feliciano Lopez'): Text(-0.21427169883628233, 0.510453186316425, '1'),
#  ('Richard Gasquet',
#   'Jiri Vesely'): Text(0.3428456982921092, -0.07922810591745977, '1'),
#  ('Richard Gasquet',
#   'Aljaz Bedene'): Text(0.2673388162068774, 0.9163012513204333, '1'),
#  ('Richard Gasquet',
#   'Mischa Zverev'): Text(0.4876334201543764, 0.8697665936729229, '2'),
#  ('Richard Gasquet',
#   'Leonardo Mayer'): Text(0.41684156444256604, 0.8963789053713114, '1'),
#  ('Richard Gasquet',
#   'Yuichi Sugita'): Text(0.015955146549891996, -0.010176333310387031, '1'),
#  ('Richard Gasquet',
#   'Victor Estrella'): Text(-0.0733912030142782, 0.7732738259881367, '1'),
#  ('Richard Gasquet',
#   'Mikhail Kukushkin'): Text(-0.0993789176377946, 0.08701443456957897, '1'),
#  ('Joao Sousa',
#   'Daniil Medvedev'): Text(-0.15549572232236136, 0.13614931505254652, '3'),
#  ('Joao Sousa',
#   'Denis Shapovalov'): Text(-0.10567509039875977, 0.0792493202339451, '2'),
#  ('Joao Sousa',
#   'Stefanos Tsitsipas'): Text(-0.21276744150945592, 0.23391724961113217, '1'),
#  ('Joao Sousa',
#   'Karen Khachanov'): Text(-0.07768147085500221, 0.053786752335131416, '1'),
#  ('Joao Sousa',
#   'Philipp Kohlschreiber'): Text(0.19727438023916322, -0.0616307881578666, '1'),
#  ('Joao Sousa',
#   'Roberto Bautista Agut'): Text(0.050991889364494225, 0.8971616633716699, '2'),
#  ('Joao Sousa',
#   'Filip Krajinovic'): Text(0.3105618109076276, 0.9317512223372191, '3'),
#  ('Joao Sousa',
#   'Pablo Carreno Busta'): Text(-0.13166274541763123, 0.7655087116525028, '2'),
#  ('Joao Sousa',
#   'Nikoloz Basilashvili'): Text(-0.1770374370689507, 0.16726088337816258, '1'),
#  ('Joao Sousa',
#   'Marin Cilic'): Text(0.23505498656439558, -0.06377813490067397, '2'),
#  ('Joao Sousa',
#   'David Goffin'): Text(-0.01632871103226713, 0.8626994795324688, '2'),
#  ('Joao Sousa',
#   'Juan Ignacio Londero'): Text(0.122740094154622, 0.9210760304191367, '1'),
#  ('Joao Sousa',
#   'Novak Djokovic'): Text(0.050991859562171726, -0.02489695208872722, '2'),
#  ('Joao Sousa',
#   'Rafael Nadal'): Text(-0.0478424915022897, 0.030514386918874425, '1'),
#  ('Joao Sousa',
#   'Gael Monfils'): Text(0.08641318644742418, 0.9104773410629017, '1'),
#  ('Joao Sousa',
#   'Yoshihito Nishioka'): Text(0.7430850407081685, 0.3983179506885608, '1'),
#  ('Joao Sousa',
#   'John Millman'): Text(0.6555949884053094, 0.15150120662599786, '1'),
#  ('Joao Sousa',
#   'Andrey Rublev'): Text(-0.21276741170713342, 0.6383474616718106, '1'),
#  ('Joao Sousa',
#   'Aljaz Bedene'): Text(0.23505495862471826, 0.9360428163812942, '1'),
#  ('Joao Sousa',
#   'Mikhail Kukushkin'): Text(-0.13166277521995373, 0.10675599963043986, '2'),
#  ('Joao Sousa',
#   'Pablo Cuevas'): Text(0.6328914897208567, 0.12122714316716565, '1'),
#  ('Joao Sousa',
#   'Vasek Pospisil'): Text(0.34785574437517697, 0.9253368982687183, '3'),
#  ('Joao Sousa',
#   'Federico Delbonis'): Text(0.48903405480588413, -2.468565907243203e-09, '2'),
#  ('Joao Sousa',
#   'Egor Gerasimov'): Text(0.4204575994403008, -0.03189000745777859, '1'),
#  ('Joao Sousa',
#   'Jordan Thompson'): Text(0.580953194167654, 0.06625303403290345, '1'),
#  ('Joao Sousa',
#   'Roger Federer'): Text(0.7387973209660179, 0.36072030547774453, '1'),
#  ('Joao Sousa',
#   'Adrian Mannarino'): Text(0.3845576621569231, -0.043855788951552066, '2'),
#  ('Joao Sousa',
#   'Francis Tiafoe'): Text(-0.1770374072666282, 0.7050038279047801, '3'),
#  ('Joao Sousa',
#   'Mackenzie Mcdonald'): Text(0.6079632476620747, 0.0927566864634714, '1'),
#  ('Joao Sousa',
#   'Maximilian Marterer'): Text(-0.25226296939733606, 0.49278617210038456, '1'),
#  ('Joao Sousa',
#   'Kei Nishikori'): Text(0.1972744696461307, 0.9338954696384868, '1'),
#  ('Joao Sousa',
#   'David Ferrer'): Text(-0.22675104885246894, 0.2690802201626664, '1'),
#  ('Joao Sousa',
#   'Hyeon Chung'): Text(-0.25226296939733606, 0.3794785391825582, '2'),
#  ('Joao Sousa',
#   'Felix Auger Aliassime'): Text(0.1597645252198397, 0.9288969943071281, '1'),
#  ('Joao Sousa',
#   'Jared Donaldson'): Text(0.45534953276989476, -0.01724350705548605, '1'),
#  ('Joao Sousa',
#   'Leonardo Mayer'): Text(0.3845577068604069, 0.9161204704321723, '1'),
#  ('Mischa Zverev',
#   'Denis Shapovalov'): Text(-0.13935955283010412, 0.09649279501854274, '1'),
#  ('Mischa Zverev',
#   'Damir Dzumhur'): Text(0.6880845565184973, 0.30427677793165375, '1'),
#  ('Mischa Zverev',
#   'John Millman'): Text(0.621910525973965, 0.1687446814105955, '1'),
#  ('Mischa Zverev',
#   'Felix Auger Aliassime'): Text(0.12608006278849535, 0.9461404690917257, '1'),
#  ('Mischa Zverev',
#   'Rafael Nadal'): Text(-0.08152695393363404, 0.04775786170347207, '1'),
#  ('Mischa Zverev',
#   'Karen Khachanov'): Text(-0.11136593328634656, 0.07103022711972906, '2'),
#  ('Mischa Zverev',
#   'Benoit Paire'): Text(-0.1891801549513832, 0.7533588710149938, '3'),
#  ('Mischa Zverev',
#   'Nikoloz Basilashvili'): Text(-0.21072189950029505, 0.18450435816276023, '1'),
#  ('Mischa Zverev',
#   'Grigor Dimitrov'): Text(-0.22984897047361005, 0.21715602110800422, '1'),
#  ('Mischa Zverev',
#   'Taylor Harry Fritz'): Text(0.4876333307474089, 0.03698497777224763, '1'),
#  ('Mischa Zverev',
#   'Filip Krajinovic'): Text(0.27687734847628326, 0.9489946971218167, '1'),
#  ('Mischa Zverev',
#   'Sam Querrey'): Text(0.6422595815765852, 0.20064922993318624, '1'),
#  ('Mischa Zverev',
#   'Vasek Pospisil'): Text(0.31417128194383265, 0.942580373053316, '1'),
#  ('Mischa Zverev',
#   'Federico Delbonis'): Text(0.45534959237453976, 0.017243472316031738, '1'),
#  ('Mischa Zverev',
#   'Roger Federer'): Text(0.7051128585346735, 0.3779637802623422, '1'),
#  ('Mischa Zverev',
#   'Philipp Kohlschreiber'): Text(0.1635899178078189, -0.044387313373268955, '1'),
#  ('Mischa Zverev',
#   'Juan Ignacio Londero'): Text(0.08905563172327766, 0.9383195052037343, '1'),
#  ('Mischa Zverev',
#   'Jo Wilfried Tsonga'): Text(0.239205091288453, -0.04581854010881892, '1'),
#  ('Mischa Zverev',
#   'Leonardo Mayer'): Text(0.35087324442906254, 0.9333639452167699, '2'),
#  ('Mischa Zverev',
#   'David Ferrer'): Text(-0.26043551128381326, 0.28632369494726406, '1'),
#  ('Mischa Zverev',
#   'Martin Klizan'): Text(0.23920518255806564, 0.9525701711586344, '1'),
#  ('Mischa Zverev',
#   'Hyeon Chung'): Text(-0.28594743182868043, 0.39672201396715584, '1'),
#  ('Mischa Zverev',
#   'Yannick Maden'): Text(0.08905560192095516, -0.03156787415391882, '1'),
#  ('Mischa Zverev',
#   'Juan Martin Del Potro'): Text(0.1260801521954628, -0.03938886784423273, '1'),
#  ('Mischa Zverev',
#   'Mikhail Kukushkin'): Text(-0.16534723765129808, 0.1239994744150375, '2'),
#  ('Dominic Thiem',
#   'Rafael Nadal'): Text(-0.11641900647251804, 0.06240442171040955, '8'),
#  ('Dominic Thiem',
#   'Daniil Medvedev'): Text(-0.2240722372925897, 0.16803934984408164, '5'),
#  ('Dominic Thiem',
#   'Denis Shapovalov'): Text(-0.17425160536898812, 0.11113935502548022, '2'),
#  ('Dominic Thiem',
#   'Gael Monfils'): Text(0.017836671477195837, 0.9423673758544368, '5'),
#  ('Dominic Thiem',
#   'Diego Sebastian Schwartzman'): Text(0.6405495541140848, 0.2832564995206164, '5'),
#  ('Dominic Thiem',
#   'Roger Federer'): Text(0.6702208059957896, 0.39261034026927966, '4'),
#  ('Dominic Thiem',
#   'Novak Djokovic'): Text(-0.01758465540805662, 0.006993082702807907, '6'),
#  ('Dominic Thiem',
#   'Dusan Lajovic'): Text(0.6252452866519821, 0.24864776276054099, '3'),
#  ('Dominic Thiem',
#   'Karen Khachanov'): Text(-0.14625798582523056, 0.08567678712666654, '3'),
#  ('Dominic Thiem',
#   'Grigor Dimitrov'): Text(-0.264741023012494, 0.2318025811149417, '1'),
#  ('Dominic Thiem',
#   'Fabio Fognini'): Text(-0.264741023012494, 0.7042421997510713, '2'),
#  ('Dominic Thiem',
#   'Stefanos Tsitsipas'): Text(-0.28134395647968424, 0.2658072844026673, '8'),
#  ('Dominic Thiem',
#   'Andrey Rublev'): Text(-0.28134392667736174, 0.6702374964633457, '4'),
#  ('Dominic Thiem',
#   'Fernando Verdasco'): Text(-0.11641897667019555, 0.8736403293532808, '3'),
#  ('Dominic Thiem',
#   'Filip Krajinovic'): Text(0.24198529593739926, 0.9636412571287543, '1'),
#  ('Dominic Thiem',
#   'Pablo Cuevas'): Text(0.5643149747506284, 0.15311717795870078, '4'),
#  ('Dominic Thiem',
#   'Sam Querrey'): Text(0.6073675290377012, 0.21529578994012372, '2'),
#  ('Dominic Thiem',
#   'Yuichi Sugita'): Text(-0.08490522600249548, 0.041455266542008984, '1'),
#  ('Dominic Thiem',
#   'Matteo Berrettini'): Text(0.4834397267397008, 0.07375824231404932, '4'),
#  ('Dominic Thiem',
#   'Kei Nishikori'): Text(0.12869795467590237, 0.9657855044300219, '3'),
#  ('Dominic Thiem',
#   'Martin Klizan'): Text(0.20431313001918164, 0.9672167311655719, '3'),
#  ('Dominic Thiem',
#   'Juan Martin Del Potro'): Text(0.09118809965657883, -0.024742307837295252, '1'),
#  ('Dominic Thiem',
#   'Roberto Bautista Agut'): Text(-0.017584625605734122, 0.9290516981632051, '1'),
#  ('Dominic Thiem',
#   'Pablo Carreno Busta'): Text(-0.20023926038785958, 0.797398746444038, '2'),
#  ('Dominic Thiem',
#   'Nikoloz Basilashvili'): Text(-0.24561395203917905, 0.1991509181696977, '1'),
#  ('Dominic Thiem',
#   'Jo Wilfried Tsonga'): Text(0.204313038749569, -0.031171980101881436, '1'),
#  ('Dominic Thiem',
#   'Federico Delbonis'): Text(0.4204575398356558, 0.03189003232296922, '1'),
#  ('Dominic Thiem',
#   'Taylor Harry Fritz'): Text(0.45274127820852494, 0.05163153777918511, '2'),
#  ('Dominic Thiem',
#   'Marin Cilic'): Text(0.16647847159416723, -0.03188810010913884, '3'),
#  ('Dominic Thiem',
#   'Roberto Carballes Baena'): Text(0.017836760884163333, -0.006322654593068799, '1'),
#  ('Dominic Thiem',
#   'John Millman'): Text(0.587018473435081, 0.183391241417533, '1'),
#  ('Dominic Thiem',
#   'Benoit Paire'): Text(-0.2240722074902672, 0.7680054310219313, '1'),
#  ('Dominic Thiem',
#   'Adrian Mannarino'): Text(0.3159811471866948, -0.01196575416001694, '2'),
#  ('Dominic Thiem',
#   'Felix Auger Aliassime'): Text(0.09118801024961135, 0.9607870290986632, '1'),
#  ('Dominic Thiem',
#   'Aljaz Bedene'): Text(0.16647844365448988, 0.9679328511728293, '2'),
#  ('Dominic Thiem',
#   'Alex De Minaur'): Text(-0.3237013715945368, 0.486943123163875, '2'),
#  ('Dominic Thiem',
#   'Jordan Thompson'): Text(0.5123766791974256, 0.09814306882443857, '2'),
#  ('Dominic Thiem',
#   'Maximilian Marterer'): Text(-0.3208394843675644, 0.5246762068919196, '1'),
#  ('Leonardo Mayer',
#   'Gael Monfils'): Text(-0.018063131695730567, 0.9543331275458877, '3'),
#  ('Leonardo Mayer',
#   'Diego Sebastian Schwartzman'): Text(0.6046497509411584, 0.29522225121206735, '2'),
#  ('Leonardo Mayer',
# ...
#  ('Pablo Carreno Busta',
#   'Federico Delbonis'): Text(-0.13166271561530873, -0.10675597476524917, '1'),
#  ('Pablo Carreno Busta',
#   'Sam Querrey'): Text(0.0552472735867367, 0.07664978285190532, '1'),
#  ('Pablo Carreno Busta',
#   'John Millman'): Text(0.034898217984116464, 0.0447452343293146, '2'),
#  ('Pablo Carreno Busta',
#   'Grigor Dimitrov'): Text(-0.8168612784634586, 0.09315657402672331, '1'),
#  ('Pablo Carreno Busta',
#   'Dusan Lajovic'): Text(0.0731250312010176, 0.1100017556723226, '1'),
#  ('Pablo Carreno Busta',
#   'Adrian Mannarino'): Text(-0.23613910826426973, -0.15061176124823533, '2'),
#  ('Pablo Carreno Busta',
#   'Fabio Fognini'): Text(-0.8168612784634586, 0.5655961926628529, '2'),
#  ('Pablo Carreno Busta',
#   'Jared Donaldson'): Text(-0.16534723765129808, -0.12399947935216932, '1'),
#  ('Pablo Carreno Busta',
#   'Alex De Minaur'): Text(-0.8758216270455014, 0.3482971160756566, '1'),
#  ('Pablo Carreno Busta',
#   'Jannik Sinner'): Text(-0.272840944089629, -0.1598281890847814, '1'),
#  ('Pablo Carreno Busta',
#   'David Ferrer'): Text(-0.8474478192736619, 0.16232424786598315, '1'),
#  ('Pablo Carreno Busta',
#   'Yannick Hanfmann'): Text(-0.8587320812565957, 0.19844408158589785, '1'),
#  ('Pablo Carreno Busta',
#   'Hyeon Chung'): Text(-0.8729597398185289, 0.27272256688587493, '1'),
#  ('Pablo Carreno Busta',
#   'Mikhail Kukushkin'): Text(-0.7523595456411466, 2.7333756591474412e-08, '1'),
#  ('Benoit Paire',
#   'Denis Shapovalov'): Text(-0.7502048079223602, -0.05689996748484488, '3'),
#  ('Benoit Paire',
#   'Yoshihito Nishioka'): Text(0.098555323184568, 0.2621686629697708, '1'),
#  ('Benoit Paire',
#   'Diego Sebastian Schwartzman'): Text(0.06459635156071264, 0.11521717701029124, '2'),
#  ('Benoit Paire',
#   'Damir Dzumhur'): Text(0.07723930142624119, 0.1508840154282661, '1'),
#  ('Benoit Paire',
#   'Jo Wilfried Tsonga'): Text(-0.37164016380380316, -0.19921130261220654, '2'),
#  ('Benoit Paire',
#   'Taylor Harry Fritz'): Text(-0.12321192434484723, -0.11640778473114, '2'),
#  ('Benoit Paire',
#   'Marin Cilic'): Text(-0.4094747309592049, -0.19992742261946395, '3'),
#  ('Benoit Paire',
#   'Roberto Carballes Baena'): Text(-0.5581164416692088, -0.1743619771033939, '1'),
#  ('Benoit Paire',
#   'John Millman'): Text(0.011065270881708833, 0.015351918907207884, '2'),
#  ('Benoit Paire',
#   'Novak Djokovic'): Text(-0.5935378579614288, -0.1610462398075172, '2'),
#  ('Benoit Paire',
#   'Rafael Nadal'): Text(-0.6923722090258901, -0.10563490079991555, '1'),
#  ('Benoit Paire',
#   'Daniil Medvedev'): Text(-0.8000254398459619, 2.733375653596326e-08, '1'),
#  ('Benoit Paire',
#   'Nikoloz Basilashvili'): Text(-0.8215671545925511, 0.031111595659372604, '1'),
#  ('Benoit Paire',
#   'Stefanos Tsitsipas'): Text(-0.8572971590330565, 0.09776796189234219, '1'),
#  ('Benoit Paire',
#   'Alex De Minaur'): Text(-0.899654574147909, 0.3189038006535499, '2'),
#  ('Benoit Paire',
#   'Jeremy Chardy'): Text(-0.8825650581613259, 0.43091526537344294, '1'),
#  ('Benoit Paire',
#   'Mikhail Kukushkin'): Text(-0.7761924927435542, -0.029393288088350122, '1'),
#  ('Benoit Paire',
#   'Feliciano Lopez'): Text(-0.891085273942042, 0.3940454636584959, '2'),
#  ('Benoit Paire',
#   'Egor Gerasimov'): Text(-0.22407211808329972, -0.16803929517656857, '1'),
#  ('Benoit Paire',
#   'Jannik Sinner'): Text(-0.29667389119203663, -0.18922150450688813, '2'),
#  ('Benoit Paire',
#   'Roger Federer'): Text(0.09426760344241741, 0.22457101775895455, '2'),
#  ('Benoit Paire',
#   'Yannick Maden'): Text(-0.521789653171301, -0.18496063665730644, '1'),
#  ('Benoit Paire',
#   'Juan Martin Del Potro'): Text(-0.4847651028967933, -0.19278163034762036, '1'),
#  ('Benoit Paire',
#   'Dusan Lajovic'): Text(0.04929208409860997, 0.08060844025021588, '1'),
#  ('Benoit Paire',
#   'Miomir Kecmanovic'): Text(0.08714866306314278, 0.18740509271710626, '1'),
#  ('Benoit Paire',
#   'Jiri Vesely'): Text(-0.3339678768136504, -0.19563582857538886, '2'),
#  ('Benoit Paire',
#   'Jared Donaldson'): Text(-0.1891801847537057, -0.15339279477427603, '1'),
#  ('Benoit Paire',
#   'Mackenzie Mcdonald'): Text(-0.036566469861525897, -0.043392601255318575, '1'),
#  ('Benoit Paire',
#   'Pablo Cuevas'): Text(-0.011638227802743761, -0.014922144551624328, '1'),
#  ('Benoit Paire',
#   'David Ferrer'): Text(-0.8712807663760694, 0.13293093244387644, '1'),
#  ('Francis Tiafoe',
#   'Denis Shapovalov'): Text(-0.7717465226689496, -0.0880115358104609, '4'),
#  ('Francis Tiafoe',
#   'Yoshihito Nishioka'): Text(0.07701360843797866, 0.23105709464415478, '1'),
#  ('Francis Tiafoe',
#   'Philipp Kohlschreiber'): Text(-0.4687970520310266, -0.2288916442022726, '1'),
#  ('Francis Tiafoe',
#   'Nikoloz Basilashvili'): Text(-0.8431088693391405, 2.7333756591474412e-08, '1'),
#  ('Francis Tiafoe',
#   'Jeremy Chardy'): Text(-0.9041067729079153, 0.3998036970478269, '2'),
#  ('Francis Tiafoe',
#   'Juan Martin Del Potro'): Text(-0.5063068176433827, -0.22389319867323637, '2'),
#  ('Francis Tiafoe',
#   'John Millman'): Text(-0.010476443864880502, -0.015759649418408128, '3'),
#  ('Francis Tiafoe',
#   'Grigor Dimitrov'): Text(-0.8622359403124555, 0.032651690279000584, '2'),
#  ('Francis Tiafoe',
#   'Adrian Mannarino'): Text(-0.2815137701132667, -0.21111664499595806, '1'),
#  ('Francis Tiafoe',
#   'Miomir Kecmanovic'): Text(0.06560694831655345, 0.15629352439149025, '2'),
#  ('Francis Tiafoe',
#   'Dusan Lajovic'): Text(0.027750369352020632, 0.04949687192459987, '1'),
#  ('Francis Tiafoe',
#   'Rafael Nadal'): Text(-0.7139139237724795, -0.13674646912553157, '2'),
#  ('Francis Tiafoe',
#   'Daniil Medvedev'): Text(-0.8215671545925511, -0.031111540991859477, '3'),
#  ('Francis Tiafoe',
#   'Karen Khachanov'): Text(-0.743752903125192, -0.11347410370927458, '1'),
#  ('Francis Tiafoe',
#   'Fabio Fognini'): Text(-0.8622359403124555, 0.5050913089151301, '1'),
#  ('Francis Tiafoe',
#   'Taylor Harry Fritz'): Text(-0.14475363909143657, -0.147519353056756, '1'),
#  ('Francis Tiafoe',
#   'Marin Cilic'): Text(-0.4310164457057942, -0.23103899094507996, '1'),
#  ('Francis Tiafoe',
#   'Stefanos Tsitsipas'): Text(-0.8788388737796458, 0.06665639356672617, '1'),
#  ('Francis Tiafoe',
#   'Alex De Minaur'): Text(-0.9211962888944983, 0.2877922323279339, '1'),
#  ('Francis Tiafoe',
#   'Pablo Cuevas'): Text(-0.0331799425493331, -0.04603371287724034, '1'),
#  ('Francis Tiafoe',
#   'Sam Querrey'): Text(0.009872611737739734, 0.016144899104182597, '1'),
#  ('Francis Tiafoe',
#   'Feliciano Lopez'): Text(-0.9126269886886313, 0.3629338953328799, '1'),
#  ('Francis Tiafoe',
#   'Matteo Berrettini'): Text(-0.1140551905602607, -0.1253926485218918, '1'),
#  ('Francis Tiafoe',
#   'Jordan Thompson'): Text(-0.08511823810253588, -0.10100782201150255, '2'),
#  ('Francis Tiafoe',
#   'Jannik Sinner'): Text(-0.31821560593862597, -0.22033307283250414, '1'),
#  ('Francis Tiafoe',
#   'Mackenzie Mcdonald'): Text(-0.05810818460811523, -0.07450416958093459, '2'),
#  ('Francis Tiafoe',
#   'Jared Donaldson'): Text(-0.21072189950029505, -0.18450436309989204, '1'),
#  ('Francis Tiafoe',
#   'Egor Gerasimov'): Text(-0.24561383282988905, -0.19915086350218458, '1'),
#  ('Francis Tiafoe',
#   'Sebastian Korda'): Text(-0.6493924916149978, -0.17620134664552717, '1'),
#  ('Francis Tiafoe',
#   'David Ferrer'): Text(-0.8928224811226588, 0.10181936411826042, '1'),
#  ('Francis Tiafoe',
#   'Yannick Maden'): Text(-0.5433313679178904, -0.21607220498292246, '1'),
#  ('Francis Tiafoe',
#   'Hyeon Chung'): Text(-0.9183344016675259, 0.2122176831381522, '1'),
#  ('Francis Tiafoe',
#   'Maximilian Marterer'): Text(-0.9183344016675259, 0.32552531605597856, '1'),
#  ('Francis Tiafoe',
#   'Mikhail Kukushkin'): Text(-0.7977342074901436, -0.060504856413966135, '1'),
#  ('Fabio Fognini',
#   'Rafael Nadal'): Text(-0.733041024548117, -0.16939813207077553, '3'),
#  ('Fabio Fognini',
#   'Yoshihito Nishioka'): Text(0.05788650766234116, 0.1984054316989108, '1'),
#  ('Fabio Fognini',
#   'Karen Khachanov'): Text(-0.7628800039008296, -0.14612576665451854, '3'),
#  ('Fabio Fognini',
#   'Philipp Kohlschreiber'): Text(-0.4879241528066641, -0.26154330714751656, '2'),
#  ('Fabio Fognini',
#   'Damir Dzumhur'): Text(0.03657048590401435, 0.08712078415740612, '1'),
#  ('Fabio Fognini',
#   'Jo Wilfried Tsonga'): Text(-0.41230897932603, -0.2629745338830665, '1'),
#  ('Fabio Fognini',
#   'Federico Delbonis'): Text(-0.1961644782399432, -0.19991252145821586, '2'),
#  ('Fabio Fognini',
#   'Taylor Harry Fritz'): Text(-0.16388073986707408, -0.18017101600199997, '2'),
#  ('Fabio Fognini',
#   'Jeremy Chardy'): Text(-0.9232338736835528, 0.3671520341025829, '2'),
#  ('Fabio Fognini',
#   'Juan Martin Del Potro'): Text(-0.5254339184190202, -0.25654486161848034, '2'),
#  ('Fabio Fognini',
#   'Sam Querrey'): Text(-0.009254489037897773, -0.016506763841061367, '1'),
#  ('Fabio Fognini',
#   'John Millman'): Text(-0.02960354464051801, -0.04841131236365209, '2'),
#  ('Fabio Fognini',
#   'Dusan Lajovic'): Text(0.008623268576383125, 0.016845208979355902, '1'),
#  ('Fabio Fognini',
#   'Adrian Mannarino'): Text(-0.30064087088890423, -0.24376830794120202, '2'),
#  ('Fabio Fognini',
#   'Daniil Medvedev'): Text(-0.8406942553681886, -0.06376320393710344, '3'),
#  ('Fabio Fognini',
#   'Stefano Travaglia'): Text(-0.9403233896701358, 0.21729910578359807, '1'),
#  ('Fabio Fognini',
#   'Marin Cilic'): Text(-0.45014354648143173, -0.2636906538903239, '1'),
#  ('Fabio Fognini',
#   'Stefanos Tsitsipas'): Text(-0.8979659745552833, 0.03400473062148221, '2'),
#  ('Fabio Fognini',
#   'Denis Shapovalov'): Text(-0.7908736234445871, -0.12066319875570486, '2'),
#  ('Fabio Fognini',
#   'Mikhail Kukushkin'): Text(-0.8168613082657811, -0.0931565193592101, '2'),
#  ('Fabio Fognini',
#   'Feliciano Lopez'): Text(-0.9317540894642689, 0.330282232387636, '1'),
#  ('Fabio Fognini',
#   'Roger Federer'): Text(0.05359878792019057, 0.16080778648809457, '1'),
#  ('Fabio Fognini',
#   'Jiri Vesely'): Text(-0.37463669233587726, -0.25939905984624884, '2'),
#  ('Fabio Fognini',
#   'Andrey Rublev'): Text(-0.8979659447529608, 0.43843494268216066, '3'),
#  ('Fabio Fognini',
#   'Pablo Cuevas'): Text(-0.052307043324970603, -0.0786853758224843, '1'),
#  ('Fabio Fognini',
#   'Jordan Thompson'): Text(-0.10424533887817339, -0.1336594849567465, '1'),
#  ('Fabio Fognini',
#   'Yuichi Sugita'): Text(-0.7015272440780944, -0.1903472872391761, '1'),
#  ('Fabio Fognini',
#   'Hyeon Chung'): Text(-0.9374615024431634, 0.17956602019290824, '1'),
#  ('Andrey Rublev',
#   'Denis Shapovalov'): Text(-0.8074765271094548, -0.15466790204343042, '3'),
#  ('Andrey Rublev',
#   'Roger Federer'): Text(0.03699588425532285, 0.12680308320036898, '1'),
#  ('Andrey Rublev',
#   'Stefanos Tsitsipas'): Text(-0.914568878220151, 2.7333756646985563e-08, '5'),
#  ('Andrey Rublev',
#   'Damir Dzumhur'): Text(0.01996758223914663, 0.05311608086968056, '1'),
#  ('Andrey Rublev',
#   'Nikoloz Basilashvili'): Text(-0.8788388737796458, -0.06665633889921294, '4'),
#  ('Andrey Rublev',
#   'Jo Wilfried Tsonga'): Text(-0.4289118829908977, -0.2969792371707921, '3'),
#  ('Andrey Rublev',
#   'Taylor Harry Fritz'): Text(-0.1804836435319418, -0.21417571928972554, '2'),
#  ('Andrey Rublev',
#   'Marin Cilic'): Text(-0.46674645014629945, -0.2976953571780495, '2'),
#  ('Andrey Rublev',
#   'Jeremy Chardy'): Text(-0.9398367773484204, 0.33314733081485737, '3'),
#  ('Andrey Rublev',
#   'Sam Querrey'): Text(-0.02585739270276549, -0.05051146712878693, '4'),
#  ('Andrey Rublev',
#   'John Millman'): Text(-0.04620644830538573, -0.08241601565137766, '1'),
#  ('Andrey Rublev',
#   'Grigor Dimitrov'): Text(-0.8979659447529608, -0.034004675953968944, '3'),
#  ('Andrey Rublev',
#   'Matteo Berrettini'): Text(-0.14978519500076592, -0.19204901475486133, '5'),
#  ('Andrey Rublev',
#   'Adrian Mannarino'): Text(-0.31724377455377195, -0.2777730112289276, '1'),
#  ('Andrey Rublev',
#   'Miomir Kecmanovic'): Text(0.029876943876048223, 0.08963715815852072, '1'),
#  ('Andrey Rublev',
#   'Dusan Lajovic'): Text(-0.007979635088484593, -0.01715949430836966, '1'),
#  ('Andrey Rublev',
#   'Rafael Nadal'): Text(-0.7496439282129848, -0.2034028353585011, '1'),
#  ('Andrey Rublev',
#   'Daniil Medvedev'): Text(-0.8572971590330565, -0.097767907224829, '3'),
#  ('Andrey Rublev',
#   'Karen Khachanov'): Text(-0.7794829075656973, -0.1801304699422441, '1'),
#  ('Andrey Rublev',
#   'Yoshihito Nishioka'): Text(0.04128360399747344, 0.16440072841118525, '1'),
#  ('Andrey Rublev',
#   'Alex De Minaur'): Text(-0.9569262933350036, 0.22113586609496436, '2'),
#  ('Andrey Rublev',
#   'Mikhail Kukushkin'): Text(-0.8334642119306488, -0.12716122264693566, '3'),
#  ('Andrey Rublev',
#   'Mackenzie Mcdonald'): Text(-0.09383818904862046, -0.14116053581390411, '1'),
#  ('Andrey Rublev',
#   'David Ferrer'): Text(-0.9285524855631639, 0.0351629978852909, '2'),
#  ('Andrey Rublev',
#   'Egor Gerasimov'): Text(-0.28134383727039425, -0.26580722973515414, '1'),
#  ('Andrey Rublev',
#   'Jannik Sinner'): Text(-0.3539456103791312, -0.2869894390654737, '1'),
#  ('Andrey Rublev',
#   'Yuichi Sugita'): Text(-0.7181301477429622, -0.22435199052690166, '1'),
#  ('Andrey Rublev',
#   'Hyeon Chung'): Text(-0.9540644061080311, 0.14556131690518265, '1'),
#  ('Andrey Rublev',
#   'Borna Gojo'): Text(-0.9483569931291365, 0.1081527376282813, '1'),
#  ('James Duckworth',
#   'Federico Delbonis'): Text(-0.22675104885246894, -0.2690802996056044, '1'),
#  ('James Duckworth',
#   'Rafael Nadal'): Text(-0.7636275951606428, -0.2385659102181641, '1'),
#  ('James Duckworth',
#   'Karen Khachanov'): Text(-0.7934665745133553, -0.2152935448019071, '1'),
#  ('James Duckworth',
#   'Marin Cilic'): Text(-0.48073011709395747, -0.3328584320377125, '1'),
#  ('James Duckworth',
#   'Stefanos Tsitsipas'): Text(-0.9285525451678089, -0.03516304752590635, '1'),
#  ('James Duckworth',
#   'Egor Gerasimov'): Text(-0.2953275042180523, -0.3009703045948171, '1'),
#  ('James Duckworth',
#   'Jordan Thompson'): Text(-0.13483190949069912, -0.20282726310413507, '1'),
#  ('James Duckworth',
#   'Jannik Sinner'): Text(-0.3679292773267892, -0.32215251392513666, '1'),
#  ('Jeremy Chardy',
#   'Daniil Medvedev'): Text(-0.8825650879636484, -0.1690508158044067, '3'),
#  ('Jeremy Chardy',
#   'Diego Sebastian Schwartzman'): Text(-0.01794329655697391, -0.05383366612787199, '1'),
#  ('Jeremy Chardy',
#   'Stefanos Tsitsipas'): Text(-0.939836807150743, -0.07128288124582105, '3'),
#  ('Jeremy Chardy',
#   'Damir Dzumhur'): Text(-0.005300346691445357, -0.018166827709897138, '1'),
#  ('Jeremy Chardy',
#   'Nikoloz Basilashvili'): Text(-0.9041068027102377, -0.13793924747879063, '2'),
#  ('Jeremy Chardy',
#   'Novak Djokovic'): Text(-0.6760775060791153, -0.3300970829456804, '3'),
#  ('Jeremy Chardy',
#   'Rafael Nadal'): Text(-0.7749118571435767, -0.27468574393807876, '1'),
#  ('Jeremy Chardy',
#   'Karen Khachanov'): Text(-0.8047508364962892, -0.2514133785218218, '1'),
#  ('Jeremy Chardy',
#   'Marin Cilic'): Text(-0.49201437907689144, -0.36897826575762716, '1'),
#  ('Jeremy Chardy',
#   'Denis Shapovalov'): Text(-0.8327444560400468, -0.22595081062300812, '2'),
#  ('Jeremy Chardy',
#   'Mikhail Kukushkin'): Text(-0.8587321408612407, -0.19844413122651336, '2'),
#  ('Jeremy Chardy',
#   'Matteo Berrettini'): Text(-0.1750531239313579, -0.263331923334439, '1'),
#  ('Jeremy Chardy',
#   'Roger Federer'): Text(0.011727955324730865, 0.0555201746207913, '1'),
#  ('Jeremy Chardy',
#   'Jo Wilfried Tsonga'): Text(-0.4541798119214897, -0.36826214575036975, '1'),
#  ('Jeremy Chardy',
#   'Juan Martin Del Potro'): Text(-0.5673047510144799, -0.3618324734857836, '1'),
#  ('Jeremy Chardy',
#   'Sam Querrey'): Text(-0.05112532163335748, -0.12179437570836463, '1'),
#  ('Jeremy Chardy',
#   'Grigor Dimitrov'): Text(-0.9232338736835528, -0.10528758453354664, '1'),
#  ('Jeremy Chardy',
#   'Dusan Lajovic'): Text(-0.03324756401907658, -0.08844240288794736, '2'),
#  ('Jeremy Chardy',
#   'Adrian Mannarino'): Text(-0.3425117034843639, -0.34905591980850526, '2'),
#  ('Jeremy Chardy',
#   'Miomir Kecmanovic'): Text(0.004609014945456236, 0.01835424957894302, '1'),
#  ('Jeremy Chardy',
#   'Mackenzie Mcdonald'): Text(-0.11910611797921244, -0.2124434443934818, '1'),
#  ('Jeremy Chardy',
#   'Stefano Travaglia'): Text(-0.9821942222655955, 0.11201149391629481, '1'),
#  ('Jeremy Chardy',
#   'Maximilian Marterer'): Text(-0.9793323350386232, 0.1875860412434313, '1'),
#  ('Feliciano Lopez',
#   'Yoshihito Nishioka'): Text(0.007495459286165407, 0.05624801811666058, '1'),
#  ...}

# %%
# možemo iskoristiti networkx.draw_network da predstavimo egomrežu tog čvora
ego_mreza = nx.ego_graph(G, 'Roger Federer')
print(f"Čvorovi ego mreže igrača Roger Federer su {ego_mreza.nodes}")
plt.figure(figsize=(15,10))
tezine_grana = nx.get_edge_attributes(ego_mreza,'weight')
pos = nx.circular_layout(ego_mreza)
#pos = nx.spring_layout(ego_mreza)
#print(pos)
nx.draw_networkx(ego_mreza, pos)
nx.draw_networkx_edge_labels(ego_mreza, pos, edge_labels = tezine_grana)
# Out:
# Čvorovi ego mreže igrača Roger Federer su ['Oscar Otte', 'Jay Clarke', 'Daniil Medvedev', 'Peter Gojowczyk', 'Jan Lennard Struff', 'Kei Nishikori', 'Marin Cilic', 'Juan Ignacio Londero', 'Denis Shapovalov', 'Jo Wilfried Tsonga', 'Gael Monfils', 'Adrian Mannarino', 'Roberto Bautista Agut', 'Thanasi Kokkinakis', 'Casper Ruud', 'David Goffin', 'Nick Kyrgios', 'Albert Ramos', 'Stanislas Wawrinka', 'Fernando Verdasco', 'Matthew Ebden', 'Marius Copil', 'Sumit Nagal', 'Lukas Lacko', 'Federico Delbonis', 'Guido Pella', 'Radu Albot', 'Daniel Evans', 'Taylor Harry Fritz', 'Rafael Nadal', 'Matteo Berrettini', 'Marton Fucsovics', 'Lucas Pouille', 'Benoit Paire', 'Tomas Berdych', 'Denis Istomin', 'Alexander Zverev', 'Fabio Fognini', 'Andrey Rublev', 'Novak Djokovic', 'Borna Coric', 'Jeremy Chardy', 'John Millman', 'Denis Kudla', 'Richard Gasquet', 'Kyle Edmund', 'Alex De Minaur', 'Steve Johnson', 'Hyeon Chung', 'Gilles Simon', 'Dusan Lajovic', 'Joao Sousa', 'Tennys Sandgren', 'Damir Dzumhur', 'John Isner', 'Hubert Hurkacz', 'Grigor Dimitrov', 'Stefanos Tsitsipas', 'Milos Raonic', 'Robin Haase', 'Dominic Thiem', 'Pierre Hugues Herbert', 'Lorenzo Sonego', 'Mischa Zverev', 'Ruben Bemelmans', 'Leonardo Mayer', 'Andreas Seppi', 'Juan Martin Del Potro', 'Roger Federer', 'Kevin Anderson', 'Filip Krajinovic', 'Yoshihito Nishioka', 'Philipp Kohlschreiber', 'Aljaz Bedene', 'Lloyd George Muirhead Harris']
# {('Oscar Otte',
#   'Jan Lennard Struff'): Text(0.9721881748081553, 0.16443332399188398, '1'),
#  ('Oscar Otte',
#   'Tennys Sandgren'): Text(0.32571399414511043, -0.468641002409022, '1'),
#  ('Oscar Otte',
#   'Matteo Berrettini'): Text(0.09549147162451183, 0.2938926003982374, '1'),
#  ('Oscar Otte',
#   'Roger Federer'): Text(0.9164605441219675, -0.2766958673924158, '1'),
#  ('Oscar Otte',
#   'Lorenzo Sonego'): Text(0.731648043604458, -0.44310175330402174, '1'),
#  ('Oscar Otte',
#   'Radu Albot'): Text(0.21464321253270335, 0.41057462285758234, '1'),
#  ('Jay Clarke',
#   'Roger Federer'): Text(0.9147069754779451, -0.23485694591160391, '1'),
#  ('Jay Clarke',
#   'Juan Ignacio Londero'): Text(0.914707064884912, 0.31853468784335515, '1'),
#  ('Jay Clarke',
#   'Lucas Pouille'): Text(0.050390544407137805, 0.2641565361131494, '1'),
#  ('Daniil Medvedev',
#   'Rafael Nadal'): Text(0.11450043586754421, 0.4100946341052291, '4'),
#  ('Daniil Medvedev',
#   'Novak Djokovic'): Text(-0.0030593543904477993, 0.020717816141574183, '5'),
#  ('Daniil Medvedev',
#   'Roberto Bautista Agut'): Text(0.7609113760026724, 0.5055483431823216, '1'),
#  ('Daniil Medvedev',
#   'Dusan Lajovic'): Text(0.2429980509379813, -0.34962834148841526, '2'),
#  ('Daniil Medvedev',
#   'Nick Kyrgios'): Text(0.6071734440210464, 0.570173844620808, '2'),
#  ('Daniil Medvedev',
#   'David Goffin'): Text(0.6475064914090364, 0.558912649710267, '3'),
#  ('Daniil Medvedev',
#   'Kevin Anderson'): Text(0.9311513306779338, -0.15749247160910096, '2'),
#  ('Daniil Medvedev',
#   'Gilles Simon'): Text(0.20764118671107828, -0.32719020283246997, '2'),
#  ('Daniil Medvedev',
#   'Gael Monfils'): Text(0.8275632863458207, 0.4549568149186727, '2'),
#  ('Daniil Medvedev',
#   'Borna Coric'): Text(0.0039242237936747415, -0.02057151326315719, '5'),
#  ('Daniil Medvedev',
#   'Dominic Thiem'): Text(0.6475065659148421, -0.39214385764178117, '5'),
#  ('Daniil Medvedev',
#   'Guido Pella'): Text(0.24299797643217558, 0.5163970739522564, '1'),
#  ('Daniil Medvedev',
#   'Stefanos Tsitsipas'): Text(0.5243932842599455, -0.4156289816823823, '6'),
#  ('Daniil Medvedev',
#   'Denis Shapovalov'): Text(0.8848447207096664, 0.39395825610386953, '2'),
#  ('Daniil Medvedev',
#   'Stanislas Wawrinka'): Text(0.5243932544576232, 0.5823977439485458, '2'),
#  ('Daniil Medvedev',
#   'Fernando Verdasco'): Text(0.4825268096008464, 0.5832747070844908, '3'),
#  ('Daniil Medvedev',
#   'Marton Fucsovics'): Text(0.06531587523959026, 0.3423978841446304, '3'),
#  ('Daniil Medvedev',
#   'Pierre Hugues Herbert'): Text(0.686755732643171, -0.3775472166219549, '2'),
#  ('Daniil Medvedev',
#   'Jeremy Chardy'): Text(0.014338257890568917, -0.061131535137769685, '3'),
#  ('Daniil Medvedev',
#   'Filip Krajinovic'): Text(0.9497707785685294, -0.1199838648111113, '1'),
#  ('Daniil Medvedev',
#   'Kyle Edmund'): Text(0.08848953520985359, -0.21050829958241424, '3'),
#  ('Daniil Medvedev',
#   'Andreas Seppi'): Text(0.8574822847357552, -0.25888921078727656, '2'),
#  ('Daniil Medvedev',
#   'Alexander Zverev'): Text(-0.0030593543904477993, 0.14605098337749217, '6'),
#  ('Daniil Medvedev',
#   'Roger Federer'): Text(0.9094585481026648, -0.19331149534904235, '3'),
#  ('Daniil Medvedev',
#   'Richard Gasquet'): Text(0.06531584543726798, -0.17562909207614458, '2'),
#  ('Daniil Medvedev',
#   'Adrian Mannarino'): Text(0.7952975636911639, 0.4816493244896439, '2'),
#  ('Daniil Medvedev',
#   'Steve Johnson'): Text(0.14316633601180895, -0.27385197333653544, '3'),
#  ('Daniil Medvedev',
#   'Kei Nishikori'): Text(0.9497707189638849, 0.2867527015830805, '4'),
#  ('Daniil Medvedev',
#   'Robin Haase'): Text(0.6071734142187242, -0.40340508235464456, '2'),
#  ('Daniil Medvedev',
#   'Joao Sousa'): Text(0.2801082900938118, -0.3690291168627013, '3'),
#  ('Daniil Medvedev',
#   'Lucas Pouille'): Text(0.04514211703185744, 0.30570198667571097, '3'),
#  ('Daniil Medvedev',
#   'Hyeon Chung'): Text(0.17428609976945775, -0.301872295575178, '1'),
#  ('Daniil Medvedev',
#   'Jan Lennard Struff'): Text(0.9651861787888525, 0.24781769603525744, '1'),
#  ('Daniil Medvedev',
#   'Milos Raonic'): Text(0.5660396305846473, -0.41125176559484344, '3'),
#  ('Daniil Medvedev',
#   'Philipp Kohlschreiber'): Text(0.9772895873275389, -0.040960526194268876, '1'),
#  ('Daniil Medvedev',
#   'Casper Ruud'): Text(0.686755822050138, 0.5443159490857961, '1'),
#  ('Daniil Medvedev',
#   'Jo Wilfried Tsonga'): Text(0.8574823145380774, 0.4256579432511178, '2'),
#  ('Daniil Medvedev',
#   'Federico Delbonis'): Text(0.28010831989613405, 0.5357978791288648, '1'),
#  ('Daniil Medvedev',
#   'Marin Cilic'): Text(0.9311513306779338, 0.32426123387526445, '1'),
#  ('Daniil Medvedev',
#   'John Isner'): Text(0.3993073198369099, -0.4077592314447247, '1'),
#  ('Daniil Medvedev',
#   'Grigor Dimitrov'): Text(0.4825267173999117, -0.4165059448183273, '1'),
#  ('Daniil Medvedev',
#   'Matteo Berrettini'): Text(0.08848947560520903, 0.37727697244161085, '1'),
#  ('Daniil Medvedev',
#   'Benoit Paire'): Text(0.028109762012926698, 0.26744668269254146, '1'),
#  ('Daniil Medvedev',
#   'Albert Ramos'): Text(0.566039548628261, 0.5780205278610069, '1'),
#  ('Daniil Medvedev',
#   'Fabio Fognini'): Text(-0.006563422039295885, 0.10432221314253935, '3'),
#  ('Daniil Medvedev',
#   'Peter Gojowczyk'): Text(0.9772895873275389, 0.20772933316391584, '1'),
#  ('Daniil Medvedev',
#   'Andrey Rublev'): Text(-0.006563422039295885, 0.06244658078859158, '3'),
#  ('Daniil Medvedev',
#   'Lloyd George Muirhead Harris'): Text(0.9912444353366747, 0.04154545220168929, '1'),
#  ('Daniil Medvedev',
#   'Aljaz Bedene'): Text(0.9859960079613944, -9.521841976001255e-08, '1'),
#  ('Daniil Medvedev',
#   'Alex De Minaur'): Text(0.11450049547218877, -0.24332593144371018, '3'),
#  ('Daniil Medvedev',
#   'Thanasi Kokkinakis'): Text(0.724646017782833, 0.526486173329134, '1'),
#  ('Daniil Medvedev',
#   'Radu Albot'): Text(0.20764121651340056, 0.4939589949009558, '1'),
#  ('Peter Gojowczyk',
#   'Milos Raonic'): Text(0.5573332099507918, -0.37029118560738283, '1'),
#  ('Peter Gojowczyk',
#   'Damir Dzumhur'): Text(0.34983177678461763, -0.35723633792932835, '2'),
#  ('Peter Gojowczyk',
#   'Kyle Edmund'): Text(0.07978311457599807, -0.16954771959495363, '2'),
#  ('Peter Gojowczyk',
#   'Filip Krajinovic'): Text(0.9410643579346739, -0.07902328482365067, '2'),
#  ('Peter Gojowczyk',
#   'Marton Fucsovics'): Text(0.056609454605734744, 0.383358464132091, '2'),
#  ('Peter Gojowczyk',
#   'Jo Wilfried Tsonga'): Text(0.848775893904222, 0.4666185232385784, '2'),
#  ('Peter Gojowczyk',
#   'John Isner'): Text(0.3906008992030544, -0.3667986514572641, '1'),
#  ('Peter Gojowczyk',
#   'Matteo Berrettini'): Text(0.07978305497135352, 0.41823755242907146, '1'),
#  ('Peter Gojowczyk',
#   'Steve Johnson'): Text(0.13445991537795343, -0.23289139334907483, '1'),
#  ('Peter Gojowczyk',
#   'Joao Sousa'): Text(0.27140186945995626, -0.3280685368752407, '1'),
#  ('Peter Gojowczyk',
#   'Fabio Fognini'): Text(-0.015269842673151401, 0.14528279312999998, '3'),
#  ('Peter Gojowczyk',
#   'Guido Pella'): Text(0.23429155579832006, 0.5573576539397171, '3'),
#  ('Peter Gojowczyk',
#   'Andreas Seppi'): Text(0.8487758641018996, -0.21792863079981595, '3'),
#  ('Peter Gojowczyk',
#   'Roberto Bautista Agut'): Text(0.7522049553688168, 0.5465089231697822, '2'),
#  ('Peter Gojowczyk',
#   'Gilles Simon'): Text(0.19893476607722277, -0.28622962284500936, '2'),
#  ('Peter Gojowczyk',
#   'Gael Monfils'): Text(0.8188568657119651, 0.4959173949061333, '1'),
#  ('Peter Gojowczyk',
#   'Borna Coric'): Text(-0.004782196840180775, 0.020389066724303434, '1'),
#  ('Peter Gojowczyk',
#   'Hubert Hurkacz'): Text(0.4320274161479047, -0.37291599534146896, '1'),
#  ('Peter Gojowczyk',
#   'Stefanos Tsitsipas'): Text(0.51568686362609, -0.3746684016949217, '1'),
#  ('Peter Gojowczyk',
#   'John Millman'): Text(0.01940334137907118, -0.05971731063659502, '2'),
#  ('Peter Gojowczyk',
#   'Fernando Verdasco'): Text(0.47382038896699086, 0.6242352870719514, '1'),
#  ('Peter Gojowczyk',
#   'Albert Ramos'): Text(0.5573331279944055, 0.6189811078484675, '1'),
#  ('Peter Gojowczyk',
#   'Federico Delbonis'): Text(0.27140189926227853, 0.5767584591163254, '1'),
#  ('Peter Gojowczyk',
#   'Alexander Zverev'): Text(-0.011765775024303315, 0.1870115633649528, '2'),
#  ('Peter Gojowczyk',
#   'Roger Federer'): Text(0.9007521274688093, -0.15235091536158174, '3'),
#  ('Peter Gojowczyk',
#   'Richard Gasquet'): Text(0.05660942480341247, -0.13466851208868397, '1'),
#  ('Peter Gojowczyk',
#   'Adrian Mannarino'): Text(0.7865911430573084, 0.5226099044771045, '1'),
#  ('Peter Gojowczyk',
#   'Kei Nishikori'): Text(0.9410642983300294, 0.32771328157054114, '1'),
#  ('Peter Gojowczyk',
#   'Robin Haase'): Text(0.5984669935848687, -0.36244450236718395, '1'),
#  ('Peter Gojowczyk',
#   'Matthew Ebden'): Text(0.43202733046622804, 0.6216059175825537, '1'),
#  ('Peter Gojowczyk',
#   'Juan Martin Del Potro'): Text(0.8761383298781331, -0.18622891385024543, '1'),
#  ('Peter Gojowczyk',
#   'Andrey Rublev'): Text(-0.015269842673151401, 0.1034071607760522, '1'),
#  ('Peter Gojowczyk',
#   'Lloyd George Muirhead Harris'): Text(0.9825380147028193, 0.08250603218914991, '1'),
#  ('Peter Gojowczyk',
#   'Lorenzo Sonego'): Text(0.7159396269512998, -0.3187568012731877, '1'),
#  ('Peter Gojowczyk',
#   'Lukas Lacko'): Text(0.31000554768962985, 0.5929859428169504, '1'),
#  ('Peter Gojowczyk',
#   'Alex De Minaur'): Text(0.10579407483833325, -0.20236535145624956, '1'),
#  ('Jan Lennard Struff',
#   'Denis Shapovalov'): Text(0.8640348915371243, 0.47500719896267174, '5'),
#  ('Jan Lennard Struff',
#   'Novak Djokovic'): Text(-0.023869183562989726, 0.1017667590003764, '4'),
#  ('Jan Lennard Struff',
#   'Roberto Bautista Agut'): Text(0.7401015468301304, 0.5865972860411238, '2'),
#  ('Jan Lennard Struff',
#   'Rafael Nadal'): Text(0.09369060669500229, 0.4911435769640313, '1'),
#  ('Jan Lennard Struff',
#   'Daniel Evans'): Text(0.15347618118994888, 0.5496899410954992, '1'),
#  ('Jan Lennard Struff',
#   'Nick Kyrgios'): Text(0.5863636148485045, 0.6512227874796103, '3'),
#  ('Jan Lennard Struff',
#   'David Goffin'): Text(0.6266966622364945, 0.6399615925690691, '3'),
#  ('Jan Lennard Struff',
#   'Gael Monfils'): Text(0.8067534571732787, 0.5360057577774748, '1'),
#  ('Jan Lennard Struff',
#   'Yoshihito Nishioka'): Text(0.9443763496163106, -5.051493631724746e-08, '2'),
#  ('Jan Lennard Struff',
#   'Grigor Dimitrov'): Text(0.4617168882273698, -0.3354570019595251, '2'),
#  ('Jan Lennard Struff',
#   'Borna Coric'): Text(-0.016885605378867186, 0.06047742959564503, '2'),
#  ('Jan Lennard Struff',
#   'Marin Cilic'): Text(0.9103415015053917, 0.40531017673406666, '3'),
#  ('Jan Lennard Struff',
#   'Dominic Thiem'): Text(0.6266967367423002, -0.31109491478297896, '1'),
#  ('Jan Lennard Struff',
#   'Stefanos Tsitsipas'): Text(0.5035834550874035, -0.3345800388235801, '5'),
#  ('Jan Lennard Struff',
#   'Alex De Minaur'): Text(0.09369066629964684, -0.16227698858490797, '3'),
#  ('Jan Lennard Struff',
#   'John Millman'): Text(0.007299932840384771, -0.019628947765253424, '3'),
#  ('Jan Lennard Struff',
#   'Marton Fucsovics'): Text(0.04450604606704833, 0.4234468270034326, '1'),
#  ('Jan Lennard Struff',
#   'Pierre Hugues Herbert'): Text(0.6659459034706291, -0.2964982737631527, '1'),
#  ('Jan Lennard Struff',
#   'Jeremy Chardy'): Text(-0.00647157128197301, 0.019917407721032537, '2'),
#  ('Jan Lennard Struff',
#   'John Isner'): Text(0.378497490664368, -0.3267102885859225, '1'),
#  ('Jan Lennard Struff',
#   'Alexander Zverev'): Text(-0.023869183562989726, 0.2270999262362944, '3'),
#  ('Jan Lennard Struff',
#   'Matteo Berrettini'): Text(0.0676796464326671, 0.45832591530041306, '2'),
#  ('Jan Lennard Struff',
#   'Roger Federer'): Text(0.8886487189301229, -0.11226255249024014, '3'),
#  ('Jan Lennard Struff',
#   'Milos Raonic'): Text(0.5452298014121054, -0.33020282273604123, '2'),
#  ('Jan Lennard Struff',
#   'Richard Gasquet'): Text(0.044506016264726056, -0.09458014921734237, '1'),
#  ('Jan Lennard Struff',
#   'Steve Johnson'): Text(0.12235650683926702, -0.19280303047773323, '1'),
#  ('Jan Lennard Struff',
#   'Kei Nishikori'): Text(0.928960889791343, 0.3678016444418828, '1'),
#  ('Jan Lennard Struff',
#   'Damir Dzumhur'): Text(0.3377283682459312, -0.31714797505798675, '1'),
#  ('Jan Lennard Struff',
#   'Jo Wilfried Tsonga'): Text(0.8366724853655356, 0.50670688610992, '2'),
#  ('Jan Lennard Struff',
#   'Matthew Ebden'): Text(0.41992392192754163, 0.6616942804538952, '1'),
#  ('Jan Lennard Struff',
#   'Casper Ruud'): Text(0.665945992877596, 0.6253648919445983, '1'),
#  ('Jan Lennard Struff',
#   'Lucas Pouille'): Text(0.024332287859315516, 0.3867509295345132, '1'),
#  ('Jan Lennard Struff',
#   'Taylor Harry Fritz'): Text(0.1223565366415893, 0.5216696784615011, '1'),
#  ('Jan Lennard Struff',
#   'Benoit Paire'): Text(0.007299932840384771, 0.34849562555134367, '1'),
#  ('Jan Lennard Struff',
#   'Tomas Berdych'): Text(-0.006471541479650678, 0.3089492700650577, '1'),
#  ('Jan Lennard Struff',
#   'Fabio Fognini'): Text(-0.027373251211837812, 0.18537115600134157, '1'),
#  ('Jan Lennard Struff',
#   'Marius Copil'): Text(0.3784975204666903, 0.6555769365696904, '1'),
#  ('Jan Lennard Struff',
#   'Andrey Rublev'): Text(-0.027373251211837812, 0.14349552364739382, '1'),
#  ('Jan Lennard Struff',
#   'Leonardo Mayer'): Text(0.8067535465802456, -0.2071390501890623, '1'),
#  ('Jan Lennard Struff',
#   'Radu Albot'): Text(0.18683138734085863, 0.575007937759758, '2'),
#  ('Kei Nishikori',
#   'Denis Shapovalov'): Text(0.8486194317121567, 0.5139422045104949, '2'),
#  ('Kei Nishikori',
#   'Gael Monfils'): Text(0.7913379973483111, 0.574940763325298, '1'),
#  ('Kei Nishikori',
#   'Kevin Anderson'): Text(0.8949260416804241, -0.037508523202475635, '4'),
#  ('Kei Nishikori',
#   'Roger Federer'): Text(0.8732332591051553, -0.07332754694241703, '4'),
#  ('Kei Nishikori',
#   'Dominic Thiem'): Text(0.6112812769173326, -0.2721599092351559, '3'),
#  ('Kei Nishikori',
#   'Stefanos Tsitsipas'): Text(0.4881679952624359, -0.295645033275757, '1'),
#  ('Kei Nishikori',
#   'Philipp Kohlschreiber'): Text(0.9410642983300294, 0.07902342221235646, '2'),
#  ('Kei Nishikori',
#   'Alexander Zverev'): Text(-0.03928464338795734, 0.2660349317841175, '2'),
#  ('Kei Nishikori',
#   'Marton Fucsovics'): Text(0.029090586242080718, 0.46238183255125576, '1'),
#  ('Kei Nishikori',
#   'Novak Djokovic'): Text(-0.03928464338795734, 0.14070176454819952, '5'),
#  ('Kei Nishikori',
#   'Dusan Lajovic'): Text(0.20677276194047176, -0.22964439308178994, '1'),
#  ('Kei Nishikori',
#   'Rafael Nadal'): Text(0.07827514687003467, 0.5300785825118545, '2'),
#  ('Kei Nishikori',
#   'Yoshihito Nishioka'): Text(0.928960889791343, 0.0389349550328868, '1'),
#  ('Kei Nishikori',
#   'Hubert Hurkacz'): Text(0.40450854778425066, -0.2938926269223042, '2'),
#  ('Kei Nishikori',
#   'Alex De Minaur'): Text(0.07827520647467923, -0.12334198303708485, '1'),
#  ('Kei Nishikori',
#   'Stanislas Wawrinka'): Text(0.4881679654601136, 0.7023816923551712, '3'),
#  ('Kei Nishikori',
#   'Pierre Hugues Herbert'): Text(0.6505304436456615, -0.2575632682153296, '2'),
#  ('Kei Nishikori',
#   'Richard Gasquet'): Text(0.02909055643975844, -0.055645143669519254, '2'),
#  ('Kei Nishikori',
#   'Robin Haase'): Text(0.5709481252212146, -0.28342113394801927, '1'),
#  ('Kei Nishikori',
#   'Juan Martin Del Potro'): Text(0.8486194615144791, -0.10720554543108071, '1'),
#  ('Kei Nishikori',
#   'Jo Wilfried Tsonga'): Text(0.821257025540568, 0.5456418916577431, '1'),
#  ('Kei Nishikori',
#   'Taylor Harry Fritz'): Text(0.10694107681662168, 0.5606046840093243, '2'),
#  ('Kei Nishikori',
#   'Marin Cilic'): Text(0.8949260416804241, 0.4442451822818898, '2'),
#  ('Kei Nishikori',
#   'Jeremy Chardy'): Text(-0.021887031106940624, 0.05885241326885565, '1'),
#  ('Kei Nishikori',
#   'Denis Kudla'): Text(0.008916828034347901, -0.018949246200599817, '1'),
#  ('Kei Nishikori',
#   'John Millman'): Text(-0.008115526984582844, 0.01930605778256969, '1'),
#  ('Kei Nishikori',
#   'Grigor Dimitrov'): Text(0.44630142840240217, -0.29652199641170196, '2'),
#  ('Kei Nishikori',
#   'Benoit Paire'): Text(-0.008115526984582844, 0.38743063109916676, '4'),
#  ('Kei Nishikori',
#   'Albert Ramos'): Text(0.5298142596307515, 0.6980044762676323, '1'),
#  ('Kei Nishikori',
#   'Adrian Mannarino'): Text(0.7590722746936543, 0.6016332728962692, '2'),
#  ('Kei Nishikori',
#   'Steve Johnson'): Text(0.1069410470142994, -0.1538680249299101, '1'),
#  ('Kei Nishikori',
#   'Joao Sousa'): Text(0.24388300109630223, -0.24904516845607597, '1'),
#  ('Kei Nishikori',
#   'Nick Kyrgios'): Text(0.5709481550235369, 0.6901577930274334, '1'),
#  ('Kei Nishikori',
#   'Gilles Simon'): Text(0.17141589771356874, -0.20720625442584464, '1'),
#  ('Kei Nishikori',
#   'Tomas Berdych'): Text(-0.021887001304618292, 0.3478842756128808, '1'),
#  ('Kei Nishikori',
#   'Andreas Seppi'): Text(0.8212569957382456, -0.13890526238065123, '1'),
#  ('Kei Nishikori',
#   'Andrey Rublev'): Text(-0.04278871103680543, 0.18243052919521693, '1'),
#  ('Kei Nishikori',
#   'Daniel Evans'): Text(0.13806072136498126, 0.5886249466433222, '1'),
#  ('Kei Nishikori',
#   'Radu Albot'): Text(0.17141592751589102, 0.6139429433075811, '1'),
#  ('Marin Cilic',
#   'Rafael Nadal'): Text(0.05965575858408351, 0.5675871148040383, '3'),
#  ('Marin Cilic',
#   'Denis Shapovalov'): Text(0.8300000434262056, 0.5514507368026788, '4'),
#  ('Marin Cilic',
#   'Yoshihito Nishioka'): Text(0.9103415015053917, 0.07644348732507072, '1'),
#  ('Marin Cilic',
#   'Milos Raonic'): Text(0.5111949533011866, -0.25375928489603417, '2'),
#  ('Marin Cilic',
#   'Philipp Kohlschreiber'): Text(0.9224449100440781, 0.11653195450454039, '2'),
#  ('Marin Cilic',
#   'Roberto Bautista Agut'): Text(0.7060666987192117, 0.6630408238811308, '2'),
#  ('Marin Cilic',
#   'Kyle Edmund'): Text(0.03364485792639288, -0.05301581888360499, '1'),
#  ('Marin Cilic',
#   'Borna Coric'): Text(-0.050920453489785966, 0.13692096743565207, '1'),
#  ('Marin Cilic',
#   'Marton Fucsovics'): Text(0.010471197956129552, 0.4998903648434396, '1'),
#  ('Marin Cilic',
#   'Lucas Pouille'): Text(-0.009702560251603265, 0.4631944673745202, '1'),
#  ('Marin Cilic',
#   'Jo Wilfried Tsonga'): Text(0.8026376372546168, 0.583150423949927, '1'),
#  ('Marin Cilic',
#   'Novak Djokovic'): Text(-0.05790403167390851, 0.17821029684038345, '5'),
#  ('Marin Cilic',
#   'David Goffin'): Text(0.5926618141255756, 0.7164051304090763, '3'),
#  ('Marin Cilic',
#   'Benoit Paire'): Text(-0.02673491527053401, 0.42493916339135074, '3'),
#  ('Marin Cilic',
#   'Gilles Simon'): Text(0.15279650942761758, -0.16969772213366072, '1'),
#  ('Marin Cilic',
#   'Gael Monfils'): Text(0.7727186090623599, 0.612449295617482, '2'),
#  ('Marin Cilic',
#   'Grigor Dimitrov'): Text(0.42768204011645106, -0.2590134641195181, '2'),
#  ('Marin Cilic',
#   'Casper Ruud'): Text(0.6319111447666772, 0.7018084297846053, '1'),
#  ('Marin Cilic',
#   'Dominic Thiem'): Text(0.5926618886313814, -0.23465137694297192, '3'),
#  ('Marin Cilic',
#   'Guido Pella'): Text(0.18815329914871487, 0.6738895546510657, '3'),
#  ('Marin Cilic',
#   'Andrey Rublev'): Text(-0.06140809932275659, 0.21993906148740086, '2'),
#  ('Marin Cilic',
#   'Stanislas Wawrinka'): Text(0.46954857717416243, 0.7398902246473551, '1'),
#  ('Marin Cilic',
#   'Albert Ramos'): Text(0.5111948713448004, 0.7355130085598162, '1'),
#  ('Marin Cilic',
#   'John Isner'): Text(0.34446264255344916, -0.2502667507459154, '3'),
#  ('Marin Cilic',
#   'Alexander Zverev'): Text(-0.05790403167390851, 0.30354346407630145, '2'),
#  ('Marin Cilic',
#   'Roger Federer'): Text(0.8546138708192041, -0.0358190146502331, '1'),
#  ('Marin Cilic',
#   'Steve Johnson'): Text(0.08832165872834824, -0.11635949263772619, '2'),
#  ('Marin Cilic',
#   'Radu Albot'): Text(0.15279653922993985, 0.651451475599765, '1'),
#  ('Marin Cilic',
#   'Joao Sousa'): Text(0.22526361281035107, -0.21153663616389204, '2'),
#  ('Marin Cilic',
#   'Hyeon Chung'): Text(0.11944142248599704, -0.14437981487636872, '1'),
#  ('Marin Cilic',
#   'Marius Copil'): Text(0.3444626723557715, 0.7320204744096975, '4'),
#  ('Marin Cilic',
#   'Juan Martin Del Potro'): Text(0.830000073228528, -0.06969701313889679, '1'),
#  ('Marin Cilic',
#   'Jeremy Chardy'): Text(-0.04050641939289179, 0.09636094556103958, '1'),
#  ('Marin Cilic',
#   'Hubert Hurkacz'): Text(0.3858891594982995, -0.25638409463012035, '3'),
#  ('Marin Cilic',
#   'Denis Kudla'): Text(-0.009702560251603265, 0.01855928609158411, '1'),
#  ('Marin Cilic',
#   'John Millman'): Text(-0.02673491527053401, 0.05681459007475362, '1'),
#  ('Marin Cilic',
#   'Dusan Lajovic'): Text(0.1881533736545206, -0.192135860789606, '1'),
#  ('Marin Cilic',
#   'Fernando Verdasco'): Text(0.42768213231738567, 0.7407671877833001, '3'),
#  ('Marin Cilic',
#   'Adrian Mannarino'): Text(0.7404528864077031, 0.6391418051884532, '1'),
#  ('Marin Cilic',
#   'Nick Kyrgios'): Text(0.5523287667375858, 0.7276663253196173, '1'),
#  ('Marin Cilic',
#   'Fabio Fognini'): Text(-0.06140809932275659, 0.26181469384134864, '1'),
#  ('Marin Cilic',
#   'Pierre Hugues Herbert'): Text(0.6319110553597104, -0.22005473592314564, '2'),
#  ('Marin Cilic',
#   'Alex De Minaur'): Text(0.05965581818872806, -0.08583345074490092, '1'),
#  ('Marin Cilic',
#   'Sumit Nagal'): Text(0.30369344562920664, 0.7224581608817617, '1'),
#  ('Juan Ignacio Londero',
#   'Federico Delbonis'): Text(0.20357094944437132, 0.7291092643583262, '3'),
#  ('Juan Ignacio Londero',
#   'Novak Djokovic'): Text(-0.07959672484221053, 0.21402920137103565, '1'),
#  ('Juan Ignacio Londero',
#   'Dusan Lajovic'): Text(0.16646068048621857, -0.1563169562589538, '1'),
#  ('Juan Ignacio Londero',
#   'Rafael Nadal'): Text(0.03796306541578148, 0.6034060193346906, '1'),
#  ('Juan Ignacio Londero',
#   'Daniel Evans'): Text(0.09774863991072807, 0.6619523834661584, '1'),
#  ('Juan Ignacio Londero',
#   'Benoit Paire'): Text(-0.048427608438836034, 0.4607580679220029, '2'),
#  ('Juan Ignacio Londero',
#   'Grigor Dimitrov'): Text(0.40598934694814903, -0.22319455958886586, '1'),
#  ('Juan Ignacio Londero',
#   'Casper Ruud'): Text(0.6102184515983752, 0.7376273343152575, '1'),
#  ('Juan Ignacio Londero',
#   'Borna Coric'): Text(-0.07261314665808799, 0.17273987196630428, '2'),
#  ('Juan Ignacio Londero',
#   'Fernando Verdasco'): Text(0.40598943914908364, 0.7765860923139523, '1'),
#  ('Juan Ignacio Londero',
#   'Alexander Zverev'): Text(-0.07959672484221053, 0.3393623686069537, '1'),
#  ('Juan Ignacio Londero',
#   'Roger Federer'): Text(0.832921177650902, -1.1011958089834906e-07, '1'),
#  ('Juan Ignacio Londero',
#   'Richard Gasquet'): Text(-0.011221525014494749, 0.017682293153316875, '3'),
#  ('Juan Ignacio Londero',
#   'Radu Albot'): Text(0.13110384606163783, 0.6872703801304172, '1'),
#  ('Juan Ignacio Londero',
#   'Joao Sousa'): Text(0.20357091964204904, -0.17571773163323984, '1'),
#  ('Juan Ignacio Londero',
#   'Matteo Berrettini'): Text(0.011952105153446302, 0.5705883576710723, '1'),
#  ('Juan Ignacio Londero',
#   'Albert Ramos'): Text(0.4895021781764983, 0.7713319130904683, '1'),
#  ('Juan Ignacio Londero',
#   'Guido Pella'): Text(0.16646060598041285, 0.709708459181718, '2'),
#  ('Juan Ignacio Londero',
#   'Lorenzo Sonego'): Text(0.6481086771333925, -0.16640599603118683, '1'),
#  ('Juan Ignacio Londero',
#   'Mischa Zverev'): Text(0.684373945946265, -0.14546825529134128, '1'),
#  ('Denis Shapovalov',
#   'Rafael Nadal'): Text(0.013349148615816098, 0.6372841370326434, '3'),
#  ('Denis Shapovalov',
#   'Novak Djokovic'): Text(-0.10421064164217592, 0.2479073190689885, '5'),
#  ('Denis Shapovalov',
#   'David Goffin'): Text(0.5463552041573082, 0.7861021526376812, '2'),
#  ('Denis Shapovalov',
#   'Benoit Paire'): Text(-0.07304152523880142, 0.49463618561995576, '3'),
#  ('Denis Shapovalov',
#   'Kevin Anderson'): Text(0.8300000434262056, 0.06969703131831334, '1'),
#  ('Denis Shapovalov',
#   'Gilles Simon'): Text(0.10648989945935017, -0.10000069990505567, '3'),
#  ('Denis Shapovalov',
#   'Gael Monfils'): Text(0.7264119990940925, 0.6821463178460869, '2'),
#  ('Denis Shapovalov',
#   'Yoshihito Nishioka'): Text(0.8640348915371243, 0.14614050955367577, '1'),
#  ('Denis Shapovalov',
#   'Grigor Dimitrov'): Text(0.38137543014818365, -0.189316441890913, '2'),
#  ('Denis Shapovalov',
#   'Borna Coric'): Text(-0.09722706345805338, 0.20661798966425712, '2'),
#  ('Denis Shapovalov',
#   'Dominic Thiem'): Text(0.546355278663114, -0.16495435471436687, '2'),
#  ('Denis Shapovalov',
#   'Hubert Hurkacz'): Text(0.3395825495300321, -0.18668707240151527, '2'),
#  ('Denis Shapovalov',
#   'Stefanos Tsitsipas'): Text(0.42324199700821735, -0.18843947875496803, '4'),
#  ('Denis Shapovalov',
#   'Alex De Minaur'): Text(0.013349208220460651, -0.016136428516295875, '2'),
#  ('Denis Shapovalov',
#   'Andrey Rublev'): Text(-0.107714709291024, 0.2896360837160059, '3'),
#  ('Denis Shapovalov',
#   'Stanislas Wawrinka'): Text(0.423241967205895, 0.8095872468759602, '3'),
#  ('Denis Shapovalov',
#   'Marton Fucsovics'): Text(-0.03583541201213786, 0.5695873870720447, '1'),
#  ('Denis Shapovalov',
#   'Pierre Hugues Herbert'): Text(0.585604445391443, -0.1503577136945406, '2'),
#  ('Denis Shapovalov',
#   'Kyle Edmund'): Text(-0.01266175204187453, 0.016681203345000062, '3'),
#  ('Denis Shapovalov',
#   'Alexander Zverev'): Text(-0.10421064164217592, 0.37324048630490647, '3'),
#  ('Denis Shapovalov',
#   'Roger Federer'): Text(0.8083072608509367, 0.03387800757837195, '1'),
#  ('Denis Shapovalov',
#   'Milos Raonic'): Text(0.46488834333291923, -0.18406226266742914, '2'),
#  ('Denis Shapovalov',
#   'Richard Gasquet'): Text(-0.035835441814460134, 0.05156041085126972, '1'),
#  ('Denis Shapovalov',
#   'Radu Albot'): Text(0.10648992926167244, 0.7211484978283701, '1'),
#  ('Denis Shapovalov',
#   'Mischa Zverev'): Text(0.6597600291462997, -0.11159013759338843, '1'),
#  ('Denis Shapovalov',
#   'Robin Haase'): Text(0.506022126966996, -0.17621557942723026, '3'),
#  ('Denis Shapovalov',
#   'Joao Sousa'): Text(0.17895700284208366, -0.141839613935287, '2'),
#  ('Denis Shapovalov',
#   'Jo Wilfried Tsonga'): Text(0.7563310272863494, 0.6528474461785321, '1'),
#  ('Denis Shapovalov',
#   'Lucas Pouille'): Text(-0.056009170219870674, 0.5328914896031253, '1'),
#  ('Denis Shapovalov',
#   'Juan Martin Del Potro'): Text(0.7836934632602606, 9.089708263854135e-09, '2'),
#  ('Denis Shapovalov',
#   'Tennys Sandgren'): Text(0.21756071087407952, -0.15806712743823426, '2'),
#  ('Denis Shapovalov',
#   'Damir Dzumhur'): Text(0.257386910166745, -0.17100741498937466, '1'),
#  ('Denis Shapovalov',
#   'Filip Krajinovic'): Text(0.8486194913168013, 0.10720563811630301, '1'),
#  ('Denis Shapovalov',
#   'Taylor Harry Fritz'): Text(0.04201507856240311, 0.6678102385301132, '3'),
#  ('Denis Shapovalov',
#   'Jeremy Chardy'): Text(-0.0868130293611592, 0.16605796778964463, '2'),
#  ('Denis Shapovalov',
#   'John Millman'): Text(-0.07304152523880142, 0.12651161230335867, '1'),
#  ('Denis Shapovalov',
#   'Matteo Berrettini'): Text(-0.012661811646519083, 0.6044664753690252, '2'),
#  ('Denis Shapovalov',
#   'Steve Johnson'): Text(0.04201504876008083, -0.04666247040912114, '1'),
#  ('Denis Shapovalov',
#   'Tomas Berdych'): Text(-0.08681299955883687, 0.45508983013366977, '2'),
#  ('Denis Shapovalov',
#   'Fabio Fognini'): Text(-0.107714709291024, 0.33151171606995367, '2'),
#  ('Denis Shapovalov',
#   'Guido Pella'): Text(0.14184668918044746, 0.7435865768796708, '1'),
#  ('Denis Shapovalov',
#   'Andreas Seppi'): Text(0.7563309974840271, -0.03169970785986226, '1'),
#  ('Denis Shapovalov',
#   'Daniel Evans'): Text(0.07313472311076269, 0.6958305011641113, '1'),
#  ('Denis Shapovalov',
#   'Hyeon Chung'): Text(0.07313481251772963, -0.07468279264776367, '1'),
#  ('Jo Wilfried Tsonga',
#   'Kyle Edmund'): Text(-0.040024158213463334, 0.04838089049224831, '2'),
#  ('Jo Wilfried Tsonga',
#   'Lucas Pouille'): Text(-0.08337157639145948, 0.5645911767503735, '2'),
#  ('Jo Wilfried Tsonga',
#   'Novak Djokovic'): Text(-0.13157304781376472, 0.27960700621623674, '1'),
#  ('Jo Wilfried Tsonga',
#   'Rafael Nadal'): Text(-0.014013257555772707, 0.6689838241798917, '2'),
#  ('Jo Wilfried Tsonga',
#   'Nick Kyrgios'): Text(0.4786597505977295, 0.8290630346954706, '1'),
#  ('Jo Wilfried Tsonga',
#   'Benoit Paire'): Text(-0.10040393141039022, 0.5263358727672041, '2'),
#  ('Jo Wilfried Tsonga',
#   'Gilles Simon'): Text(0.07912749328776136, -0.06830101275780742, '2'),
#  ('Jo Wilfried Tsonga',
#   'Gael Monfils'): Text(0.6990495929225038, 0.7138460049933353, '1'),
#  ('Jo Wilfried Tsonga',
#   'Fabio Fognini'): Text(-0.1350771154626128, 0.3632114032172019, '1'),
#  ('Jo Wilfried Tsonga',
#   'Taylor Harry Fritz'): Text(0.014652672390814303, 0.6995099256773616, '1'),
#  ('Jo Wilfried Tsonga',
#   'Dominic Thiem'): Text(0.5189928724915251, -0.13325466756711862, '1'),
#  ('Jo Wilfried Tsonga',
#   'Andrey Rublev'): Text(-0.1350771154626128, 0.32133577086325416, '3'),
#  ('Jo Wilfried Tsonga',
#   'Filip Krajinovic'): Text(0.8212570851452126, 0.13890532526355126, '1'),
#  ('Jo Wilfried Tsonga',
#   'Tennys Sandgren'): Text(0.19019830470249072, -0.126367440290986, '1'),
#  ('Jo Wilfried Tsonga',
#   'Roger Federer'): Text(0.7809448546793478, 0.0655776947256202, '1'),
#  ('Jo Wilfried Tsonga',
#   'Milos Raonic'): Text(0.4375259371613304, -0.1523625755201809, '2'),
#  ('Jo Wilfried Tsonga',
#   'Jeremy Chardy'): Text(-0.114175435532748, 0.19775765493689287, '1'),
#  ('Jo Wilfried Tsonga',
#   'Matteo Berrettini'): Text(-0.04002421781810789, 0.6361661625162733, '1'),
#  ('Jo Wilfried Tsonga',
#   'Dusan Lajovic'): Text(0.11448435751466438, -0.09073915141375272, '1'),
#  ('Jo Wilfried Tsonga',
#   'Guido Pella'): Text(0.11448428300885866, 0.775286264026919, '1'),
#  ('Jo Wilfried Tsonga',
#   'Pierre Hugues Herbert'): Text(0.5582420392198542, -0.11865802654729235, '2'),
#  ('Jo Wilfried Tsonga',
#   'Lorenzo Sonego'): Text(0.5961323541618383, -0.10082819118598574, '2'),
#  ('Jo Wilfried Tsonga',
#   'Aljaz Bedene'): Text(0.8574823145380774, 0.2588890948562428, '1'),
#  ('Jo Wilfried Tsonga',
#   'Alex De Minaur'): Text(-0.014013197951128153, 0.01556325863095237, '1'),
#  ('Jo Wilfried Tsonga',
#   'Mischa Zverev'): Text(0.6323976229747108, -0.07989045044614018, '1'),
#  ('Jo Wilfried Tsonga',
#   'Thanasi Kokkinakis'): Text(0.596132324359516, 0.7853753634037967, '1'),
#  ('Jo Wilfried Tsonga',
#   'Radu Albot'): Text(0.07912752309008364, 0.7528481849756183, '1'),
#  ('Gael Monfils',
#   'Novak Djokovic'): Text(-0.16149207600602156, 0.30890587788379165, '3'),
#  ('Gael Monfils',
#   'Rafael Nadal'): Text(-0.04393228574802954, 0.6982826958474466, '2'),
#  ('Gael Monfils',
#   'David Goffin'): Text(0.4890737697934626, 0.8471007114524844, '2'),
#  ('Gael Monfils',
#   'Kevin Anderson'): Text(0.7727186090623599, 0.1306955901331165, '1'),
#  ('Gael Monfils',
#   'Lloyd George Muirhead Harris'): Text(0.8328117137211011, 0.32973351394390676, '1'),
#  ('Gael Monfils',
#   'Yoshihito Nishioka'): Text(0.8067534571732787, 0.20713906836847892, '1'),
#  ('Gael Monfils',
#   'Fabio Fognini'): Text(-0.16499614365486964, 0.3925102748847568, '1'),
#  ('Gael Monfils',
#   'Taylor Harry Fritz'): Text(-0.015266355801442533, 0.7288087973449164, '1'),
#  ('Gael Monfils',
#   'Dominic Thiem'): Text(0.48907384429926837, -0.10395579589956372, '5'),
#  ('Gael Monfils',
#   'Hubert Hurkacz'): Text(0.28230111516618644, -0.12568851358671213, '2'),
#  ('Gael Monfils',
#   'Stefanos Tsitsipas'): Text(0.3659605626443717, -0.12744091994016488, '3'),
#  ('Gael Monfils',
#   'Fernando Verdasco'): Text(0.3240940879852726, 0.8714627688267083, '2'),
#  ('Gael Monfils',
#   'Pierre Hugues Herbert'): Text(0.5283230110275973, -0.08935915487973745, '2'),
#  ('Gael Monfils',
#   'Albert Ramos'): Text(0.40760682701268725, 0.8662085896032243, '4'),
#  ('Gael Monfils',
#   'John Isner'): Text(0.24087459822133614, -0.11957116970250725, '3'),
#  ('Gael Monfils',
#   'Kyle Edmund'): Text(-0.06994318640572017, 0.07767976215980321, '1'),
#  ('Gael Monfils',
#   'Matteo Berrettini'): Text(-0.06994324601036472, 0.6654650341838283, '1'),
#  ('Gael Monfils',
#   'Roger Federer'): Text(0.751025826487091, 0.0948765663931751, '1'),
#  ('Gael Monfils',
#   'Adrian Mannarino'): Text(0.6368648420755901, 0.7698373862318614, '3'),
#  ('Gael Monfils',
#   'Denis Kudla'): Text(-0.11329060458371631, 0.1492548671349923, '1'),
#  ('Gael Monfils',
#   'Leonardo Mayer'): Text(0.6691306541372137, 6.869435292822246e-08, '3'),
#  ('Gael Monfils',
#   'Philipp Kohlschreiber'): Text(0.8188568657119651, 0.24722753554794857, '1'),
#  ('Gael Monfils',
#   'Roberto Bautista Agut'): Text(0.6024786543870986, 0.793736404924539, '1'),
#  ('Gael Monfils',
#   'Damir Dzumhur'): Text(0.20010547580289936, -0.11000885617457151, '2'),
#  ('Gael Monfils',
#   'Casper Ruud'): Text(0.5283231004345642, 0.8325040108280135, '1'),
#  ('Gael Monfils',
#   'Filip Krajinovic'): Text(0.7913380569529557, 0.16820419693110616, '2'),
#  ('Gael Monfils',
#   'Marton Fucsovics'): Text(-0.0931168463759835, 0.6305859458868479, '2'),
#  ('Gael Monfils',
#   'Benoit Paire'): Text(-0.13032295960264706, 0.5556347444347589, '1'),
#  ('Gael Monfils',
#   'Dusan Lajovic'): Text(0.08456532932240754, -0.06144027974619781, '1'),
#  ('Gael Monfils',
#   'Steve Johnson'): Text(-0.01526638560376481, 0.014336088405682013, '2'),
#  ('Gael Monfils',
#   'Richard Gasquet'): Text(-0.09311687617830577, 0.11255896966607287, '2'),
#  ('Gael Monfils',
#   'Joao Sousa'): Text(0.12167556847823802, -0.08084105512048384, '1'),
#  ('Gael Monfils',
#   'Gilles Simon'): Text(0.04920846509550453, -0.03900214109025252, '1'),
#  ('Gael Monfils',
#   'Stanislas Wawrinka'): Text(0.3659605328420494, 0.8705858056907634, '1'),
#  ('Gael Monfils',
#   'Matthew Ebden'): Text(0.2823010294845098, 0.8688333993373105, '1'),
#  ('Gael Monfils',
#   'Andreas Seppi'): Text(0.6990495631201814, 0.02929885095494089, '2'),
#  ('Gael Monfils',
#   'Marius Copil'): Text(0.24087462802365844, 0.8627160554531057, '1'),
#  ('Gael Monfils',
#   'Andrey Rublev'): Text(-0.16499614365486964, 0.35063464253080906, '1'),
#  ('Gael Monfils',
#   'Lorenzo Sonego'): Text(0.5662133259695815, -0.07152931951843083, '1'),
#  ('Gael Monfils',
#   'Aljaz Bedene'): Text(0.8275632863458207, 0.2881879665237977, '1'),
#  ('Gael Monfils',
#   'Daniel Evans'): Text(0.01585328874691705, 0.7568290599789144, '1'),
#  ('Gael Monfils',
#   'Radu Albot'): Text(0.049208494897826804, 0.7821470566431732, '1'),
#  ('Gael Monfils',
#   'Ruben Bemelmans'): Text(0.6368648122732679, -0.02669253028358526, '1'),
#  ('Adrian Mannarino',
#   'Yoshihito Nishioka'): Text(0.774487734518622, 0.23383157793945017, '1'),
#  ('Adrian Mannarino',
#   'Stefanos Tsitsipas'): Text(0.33369483998971494, -0.10074841036919363, '2'),
#  ('Adrian Mannarino',
#   'Tennys Sandgren'): Text(0.1280135538555771, -0.07037605905245986, '2'),
#  ('Adrian Mannarino',
#   'Damir Dzumhur'): Text(0.1678397531482426, -0.08331634660360027, '3'),
#  ('Adrian Mannarino',
#   'Casper Ruud'): Text(0.49605737777990744, 0.8591965203989849, '1'),
#  ('Adrian Mannarino',
#   'Borna Coric'): Text(-0.18677422047655579, 0.2943090580500315, '2'),
#  ('Adrian Mannarino',
#   'David Goffin'): Text(0.45680804713880585, 0.8737932210234557, '2'),
#  ('Adrian Mannarino',
#   'Matteo Berrettini'): Text(-0.1022089686650215, 0.6921575437547995, '1'),
#  ('Adrian Mannarino',
#   'Albert Ramos'): Text(0.3753411043580305, 0.8929010991741957, '3'),
#  ('Adrian Mannarino',
#   'Dusan Lajovic'): Text(0.05229960666775077, -0.03474777017522657, '5'),
#  ('Adrian Mannarino',
#   'Fernando Verdasco'): Text(0.29182836533061585, 0.8981552783976796, '1'),
#  ('Adrian Mannarino',
#   'Novak Djokovic'): Text(-0.19375779866067833, 0.3355983874547629, '2'),
#  ('Adrian Mannarino',
#   'Rafael Nadal'): Text(-0.07619800840268631, 0.7249752054184178, '1'),
#  ('Adrian Mannarino',
#   'Daniel Evans'): Text(-0.01641243390773972, 0.7835215695498856, '2'),
#  ('Adrian Mannarino',
#   'Kevin Anderson'): Text(0.7404528864077031, 0.15738809970408774, '2'),
#  ('Adrian Mannarino',
#   'Gilles Simon'): Text(0.016942742440847758, -0.012309631519281272, '1'),
#  ('Adrian Mannarino',
#   'Grigor Dimitrov'): Text(0.2918282731296812, -0.10162537350513862, '1'),
#  ('Adrian Mannarino',
#   'Fabio Fognini'): Text(-0.1972618663095264, 0.41920278445572806, '2'),
#  ('Adrian Mannarino',
#   'Dominic Thiem'): Text(0.4568081216446116, -0.07726328632859247, '2'),
#  ('Adrian Mannarino',
#   'Alex De Minaur'): Text(-0.07619794879804176, 0.07155463986947852, '1'),
#  ('Adrian Mannarino',
#   'John Millman'): Text(-0.16258868225730383, 0.21420268068913306, '3'),
#  ('Adrian Mannarino',
#   'Andrey Rublev'): Text(-0.1972618663095264, 0.3773271521017803, '1'),
#  ('Adrian Mannarino',
#   'Marton Fucsovics'): Text(-0.12538256903064027, 0.657278455457819, '1'),
#  ('Adrian Mannarino',
#   'Jeremy Chardy'): Text(-0.1763601863796616, 0.253749036175419, '2'),
#  ('Adrian Mannarino',
#   'John Isner'): Text(0.20860887556667937, -0.092878660131536, '2'),
#  ('Adrian Mannarino',
#   'Andreas Seppi'): Text(0.6667838404655246, 0.05599136052591214, '4'),
#  ('Adrian Mannarino',
#   'Alexander Zverev'): Text(-0.19375779866067833, 0.4609315546906809, '3'),
#  ('Adrian Mannarino',
#   'Roger Federer'): Text(0.7187601038324343, 0.12156907596414634, '1'),
#  ('Adrian Mannarino',
#   'Milos Raonic'): Text(0.3753411863144168, -0.09637119428165475, '2'),
#  ('Adrian Mannarino',
#   'Steve Johnson'): Text(-0.04753210825842158, 0.04102859797665326, '2'),
#  ('Adrian Mannarino',
#   'Lorenzo Sonego'): Text(0.5339476033149247, -0.04483680994745959, '3'),
#  ('Adrian Mannarino',
#   'Joao Sousa'): Text(0.08940984582358125, -0.054148545549512594, '2'),
#  ('Adrian Mannarino',
#   'Robin Haase'): Text(0.41647496994849365, -0.08852451104145587, '1'),
#  ('Adrian Mannarino',
#   'Denis Istomin'): Text(-0.18677425027887812, 0.5022207574355425, '1'),
#  ('Adrian Mannarino',
#   'Aljaz Bedene'): Text(0.7952975636911639, 0.31488047609476894, '1'),
#  ('Adrian Mannarino',
#   'Radu Albot'): Text(0.016942772243170034, 0.8088395662141445, '1'),
#  ('Roberto Bautista Agut',
#   'Novak Djokovic'): Text(-0.22814398634916983, 0.3594974061474406, '5'),
#  ('Roberto Bautista Agut',
#   'Rafael Nadal'): Text(-0.11058419609117781, 0.7488742241110955, '1'),
#  ('Roberto Bautista Agut',
#   'David Goffin'): Text(0.4224218594503143, 0.8976922397161333, '2'),
#  ('Roberto Bautista Agut',
#   'Gilles Simon'): Text(-0.01744344524764374, 0.011589387173396415, '2'),
#  ('Roberto Bautista Agut',
#   'Yoshihito Nishioka'): Text(0.7401015468301304, 0.25773059663212783, '1'),
#  ('Roberto Bautista Agut',
#   'Grigor Dimitrov'): Text(0.25744208544118974, -0.07772635481246093, '1'),
#  ('Roberto Bautista Agut',
#   'Fabio Fognini'): Text(-0.2316480539980179, 0.44310180314840575, '2'),
#  ('Roberto Bautista Agut',
#   'Taylor Harry Fritz'): Text(-0.0819182661445908, 0.7794003256085653, '3'),
#  ('Roberto Bautista Agut',
#   'Borna Coric'): Text(-0.22116040816504728, 0.31820807674270923, '3'),
#  ('Roberto Bautista Agut',
#   'Dominic Thiem'): Text(0.42242193395612004, -0.053364267635914786, '1'),
#  ('Roberto Bautista Agut',
#   'Stefanos Tsitsipas'): Text(0.29930865230122344, -0.07684939167651594, '1'),
#  ('Roberto Bautista Agut',
#   'Alex De Minaur'): Text(-0.11058413648653326, 0.09545365856215621, '2'),
#  ('Roberto Bautista Agut',
#   'Andrey Rublev'): Text(-0.2316480539980179, 0.401226170794458, '3'),
#  ('Roberto Bautista Agut',
#   'Fernando Verdasco'): Text(0.25744217764212435, 0.9220542970903572, '1'),
#  ('Roberto Bautista Agut',
#   'Marton Fucsovics'): Text(-0.15976875671913177, 0.6811774741504968, '2'),
#  ('Roberto Bautista Agut',
#   'John Isner'): Text(0.17422268787818787, -0.06897964143885832, '1'),
#  ('Roberto Bautista Agut',
#   'Alexander Zverev'): Text(-0.22814398634916983, 0.48483057338335855, '2'),
#  ('Roberto Bautista Agut',
#   'Matteo Berrettini'): Text(-0.136595156353513, 0.7160565624474773, '4'),
#  ('Roberto Bautista Agut',
#   'Roger Federer'): Text(0.6843739161439428, 0.14546809465682403, '2'),
#  ('Roberto Bautista Agut',
#   'Philipp Kohlschreiber'): Text(0.7522049553688168, 0.2978190638115975, '2'),
#  ('Roberto Bautista Agut',
#   'Richard Gasquet'): Text(-0.15976878652145404, 0.1631504979297218, '6'),
#  ('Roberto Bautista Agut',
#   'Joao Sousa'): Text(0.05502365813508975, -0.030249526856834907, '2'),
#  ('Roberto Bautista Agut',
#   'Lucas Pouille'): Text(-0.17994251492686458, 0.6444815766815774, '2'),
#  ('Roberto Bautista Agut',
#   'Tennys Sandgren'): Text(0.09362736616708561, -0.046477040359782174, '1'),
#  ('Roberto Bautista Agut',
#   'Casper Ruud'): Text(0.4616711900914159, 0.8830955390916625, '1'),
#  ('Roberto Bautista Agut',
#   'Juan Martin Del Potro'): Text(0.6597601185532667, 0.11159009616816035, '1'),
#  ('Roberto Bautista Agut',
#   'Hubert Hurkacz'): Text(0.21564920482303815, -0.07509698532306319, '2'),
#  ('Roberto Bautista Agut',
#   'John Millman'): Text(-0.19697486994579533, 0.23810169938181075, '2'),
#  ('Roberto Bautista Agut',
#   'Benoit Paire'): Text(-0.19697486994579533, 0.6062262726984078, '1'),
#  ('Roberto Bautista Agut',
#   'Dusan Lajovic'): Text(0.01791341897925927, -0.01084875148254888, '2'),
#  ('Roberto Bautista Agut',
#   'Steve Johnson'): Text(-0.08191829594691308, 0.06492761666933095, '3'),
#  ('Roberto Bautista Agut',
#   'Nick Kyrgios'): Text(0.3820888120623244, 0.9089534346266744, '1'),
#  ('Roberto Bautista Agut',
#   'Tomas Berdych'): Text(-0.21074634426583078, 0.5666799172121219, '1'),
#  ('Roberto Bautista Agut',
#   'Stanislas Wawrinka'): Text(0.2993086224989011, 0.9211773339544123, '1'),
#  ('Roberto Bautista Agut',
#   'Matthew Ebden'): Text(0.21564911914136153, 0.9194249276009594, '1'),
#  ('Roberto Bautista Agut',
#   'Guido Pella'): Text(0.017913344473453552, 0.8551766639581229, '2'),
#  ('Roberto Bautista Agut',
#   'Andreas Seppi'): Text(0.6323976527770332, 0.07989037921858982, '2'),
#  ('Roberto Bautista Agut',
#   'Marius Copil'): Text(0.17422271768051018, 0.9133075837167546, '1'),
#  ('Roberto Bautista Agut',
#   'Robin Haase'): Text(0.38208878226000215, -0.06462549234877818, '2'),
#  ('Roberto Bautista Agut',
#   'Pierre Hugues Herbert'): Text(0.46167110068444905, -0.03876762661608851, '1'),
#  ('Roberto Bautista Agut',
#   'Denis Istomin'): Text(-0.22116043796736962, 0.5261197761282201, '1'),
#  ('Thanasi Kokkinakis',
#   'Roger Federer'): Text(0.6481085579241034, 0.16640592480363653, '1'),
#  ('Thanasi Kokkinakis',
#   'Lucas Pouille'): Text(-0.216207873146704, 0.6654194068283898, '1'),
#  ('Thanasi Kokkinakis',
#   'Rafael Nadal'): Text(-0.14684955431101723, 0.769812054257908, '1'),
#  ('Thanasi Kokkinakis',
#   'Taylor Harry Fritz'): Text(-0.11818362436443022, 0.8003381557553779, '1'),
#  ('Thanasi Kokkinakis',
#   'Fernando Verdasco'): Text(0.2211768194222849, 0.9429921272371697, '1'),
#  ('Thanasi Kokkinakis',
#   'Radu Albot'): Text(-0.053708773665160886, 0.8536764150536347, '1'),
#  ('Casper Ruud',
#   'Novak Djokovic'): Text(-0.30229954030170425, 0.3982650120509151, '1'),
#  ('Casper Ruud',
#   'Borna Coric'): Text(-0.2953159621175817, 0.35697568264618373, '1'),
#  ('Casper Ruud',
#   'Dominic Thiem'): Text(0.3482663800035856, -0.014596661732440286, '1'),
#  ('Casper Ruud',
#   'Guido Pella'): Text(-0.0562422094790809, 0.8939442698615974, '2'),
#  ('Casper Ruud',
#   'Andrey Rublev'): Text(-0.3058036079505524, 0.4399937766979325, '2'),
#  ('Casper Ruud',
#   'Filip Krajinovic'): Text(0.650530592657273, 0.2575633310982296, '1'),
#  ('Casper Ruud',
#   'Albert Ramos'): Text(0.26679936271700455, 0.9555677237703478, '3'),
#  ('Casper Ruud',
#   'John Isner'): Text(0.10006713392565342, -0.03021203553538382, '2'),
#  ('Casper Ruud',
#   'Matteo Berrettini'): Text(-0.21075071030604745, 0.7548241683509518, '3'),
#  ('Casper Ruud',
#   'Roger Federer'): Text(0.6102183621914083, 0.18423570056029853, '1'),
#  ('Casper Ruud',
#   'Richard Gasquet'): Text(-0.2339243404739885, 0.2019181038331963, '1'),
#  ('Casper Ruud',
#   'Steve Johnson'): Text(-0.15607384989944753, 0.10369522257280545, '1'),
#  ('Casper Ruud',
#   'Robin Haase'): Text(0.30793322830746767, -0.02585788644530368, '2'),
#  ('Casper Ruud',
#   'Damir Dzumhur'): Text(0.05929801150721664, -0.02064972200744808, '1'),
#  ('Casper Ruud',
#   'Juan Martin Del Potro'): Text(0.5856045646007322, 0.15035770207163485, '1'),
#  ('Casper Ruud',
#   'Federico Delbonis'): Text(-0.01913186601512243, 0.9133450750382057, '1'),
#  ('Casper Ruud',
#   'Benoit Paire'): Text(-0.27113042389832975, 0.6449938786018823, '1'),
#  ('Casper Ruud',
#   'Dusan Lajovic'): Text(-0.05624213497327518, 0.02791885442092562, '1'),
#  ('Casper Ruud',
#   'Joao Sousa'): Text(-0.019131895817444705, 0.008518079046639593, '2'),
#  ('Casper Ruud',
#   'Nick Kyrgios'): Text(0.30793325810979, 0.9477210405301489, '1'),
#  ('Casper Ruud',
#   'Fabio Fognini'): Text(-0.3058036079505524, 0.48186940905188025, '2'),
#  ('Casper Ruud',
#   'Marius Copil'): Text(0.10006716372797572, 0.9520751896202291, '1'),
#  ('Casper Ruud',
#   'Lloyd George Muirhead Harris'): Text(0.6920042494254183, 0.4190926481110302, '1'),
#  ('Casper Ruud',
#   'Lorenzo Sonego'): Text(0.42540586167389877, 0.0178298146486926, '1'),
#  ('Casper Ruud',
#   'Daniel Evans'): Text(-0.12495417554876567, 0.8461881941460379, '1'),
#  ('David Goffin',
#   'Rafael Nadal'): Text(-0.22398908068481385, 0.8022385306390409, '3'),
#  ('David Goffin',
#   'Kevin Anderson'): Text(0.5926618141255756, 0.2346514249247108, '1'),
#  ('David Goffin',
#   'Yoshihito Nishioka'): Text(0.6266966622364945, 0.31109490316007327, '2'),
#  ('David Goffin',
#   'Stefanos Tsitsipas'): Text(0.18590376770758738, -0.02348508514857056, '5'),
#  ('David Goffin',
#   'Filip Krajinovic'): Text(0.6112812620161714, 0.2721600317227005, '3'),
#  ('David Goffin',
#   'Borna Coric'): Text(-0.3345652927586833, 0.37157238327065456, '1'),
#  ('David Goffin',
#   'Alexander Zverev'): Text(-0.34154887094280584, 0.538194879911304, '2'),
#  ('David Goffin',
#   'Marton Fucsovics'): Text(-0.2731736413127678, 0.7345417806784422, '2'),
#  ('David Goffin',
#   'Taylor Harry Fritz'): Text(-0.19532315073822684, 0.8327646321365108, '1'),
#  ('David Goffin',
#   'Jeremy Chardy'): Text(-0.3241512586617892, 0.33101236139604207, '2'),
#  ('David Goffin',
#   'Juan Martin Del Potro'): Text(0.5463552339596306, 0.16495440269610573, '3'),
#  ('David Goffin',
#   'Novak Djokovic'): Text(-0.34154887094280584, 0.41286171267538596, '2'),
#  ('David Goffin',
#   'Dusan Lajovic'): Text(-0.09549146561437677, 0.0425155550453965, '1'),
#  ('David Goffin',
#   'Daniel Evans'): Text(-0.16420350618986726, 0.8607848947705087, '1'),
#  ('David Goffin',
#   'Grigor Dimitrov'): Text(0.14403720084755367, -0.024362048284515547, '4'),
#  ('David Goffin',
#   'Guido Pella'): Text(-0.09549154012018249, 0.9085409704860683, '3'),
#  ('David Goffin',
#   'Alex De Minaur'): Text(-0.2239890210801693, 0.1488179650901016, '1'),
#  ('David Goffin',
#   'Andrey Rublev'): Text(-0.345052938591654, 0.4545904773224034, '1'),
#  ('David Goffin',
#   'Kyle Edmund'): Text(-0.24999998134250448, 0.18163559695139753, '1'),
#  ('David Goffin',
#   'Roger Federer'): Text(0.5709690315503068, 0.19883240118476941, '4'),
#  ('David Goffin',
#   'Milos Raonic'): Text(0.22755011403228928, -0.01910786906103168, '1'),
#  ('David Goffin',
#   'Richard Gasquet'): Text(-0.27317367111509006, 0.2165148044576672, '3'),
#  ('David Goffin',
#   'Joao Sousa'): Text(-0.05838122645854629, 0.023114779671110475, '2'),
#  ('David Goffin',
#   'Matthew Ebden'): Text(0.10224423454772551, 0.9727892341289048, '1'),
#  ('David Goffin',
#   'Matteo Berrettini'): Text(-0.250000040947149, 0.7694208689754226, '1'),
#  ('David Goffin',
#   'Benoit Paire'): Text(-0.31037975453943134, 0.6595905792263532, '2'),
#  ('David Goffin',
#   'Fernando Verdasco'): Text(0.14403729304848828, 0.9754186036183026, '1'),
#  ('David Goffin',
#   'Gilles Simon'): Text(-0.13084832984127978, 0.0649536937013418, '2'),
#  ('David Goffin',
#   'Tomas Berdych'): Text(-0.3241512288594668, 0.6200442237400673, '1'),
#  ('David Goffin',
# ...
#  ('Matteo Berrettini',
#   'Jeremy Chardy'): Text(-0.8831682744656164, 0.14937668412738594, '1'),
#  ('Matteo Berrettini',
#   'Denis Kudla'): Text(-0.8523644153243279, 0.07157502465793047, '4'),
#  ('Matteo Berrettini',
#   'Grigor Dimitrov'): Text(-0.4149798149562737, -0.2059977255531717, '2'),
#  ('Matteo Berrettini',
#   'Novak Djokovic'): Text(-0.9005658867466332, 0.2312260354067298, '1'),
#  ('Matteo Berrettini',
#   'Gilles Simon'): Text(-0.6898653456451072, -0.11668198356731435, '2'),
#  ('Matteo Berrettini',
#   'Hubert Hurkacz'): Text(-0.4567726955744252, -0.20336835606377396, '1'),
#  ('Matteo Berrettini',
#   'Stefanos Tsitsipas'): Text(-0.3731132480962399, -0.2051207624172267, '1'),
#  ('Matteo Berrettini',
#   'Andrey Rublev'): Text(-0.9040699543954813, 0.2729548000537472, '5'),
#  ('Matteo Berrettini',
#   'Aljaz Bedene'): Text(0.08848947560520903, 0.21050812404673586, '3'),
#  ('Matteo Berrettini',
#   'Marton Fucsovics'): Text(-0.8321906571165951, 0.552906103409786, '1'),
#  ('Matteo Berrettini',
#   'Andreas Seppi'): Text(-0.04002424762043022, -0.04838099152212094, '2'),
#  ('Matteo Berrettini',
#   'Tennys Sandgren'): Text(-0.5787945342303777, -0.17474841110049294, '1'),
#  ('Matteo Berrettini',
#   'Roger Federer'): Text(0.011952015746479416, 0.017196723916113266, '2'),
#  ('Matteo Berrettini',
#   'Leonardo Mayer'): Text(-0.06994315660339784, -0.0776797737827089, '3'),
#  ('Matteo Berrettini',
#   'Hyeon Chung'): Text(-0.7232204325867276, -0.09136407631002236, '1'),
#  ('Matteo Berrettini',
#   'Richard Gasquet'): Text(-0.8321906869189174, 0.03487912718901104, '1'),
#  ('Matteo Berrettini',
#   'Denis Istomin'): Text(-0.8935823383648329, 0.39784840538750943, '2'),
#  ('Matteo Berrettini',
#   'Lloyd George Muirhead Harris'): Text(0.0937379029804894, 0.25205367146684493, '1'),
#  ('Marton Fucsovics',
#   'Philipp Kohlschreiber'): Text(0.056609454605734744, 0.1346686047739063, '2'),
#  ('Marton Fucsovics',
#   'Damir Dzumhur'): Text(-0.562141935303331, -0.2225677869486138, '2'),
#  ('Marton Fucsovics',
#   'Novak Djokovic'): Text(-0.923739487112252, 0.19634694710974937, '2'),
#  ('Marton Fucsovics',
#   'Benoit Paire'): Text(-0.8925703707088775, 0.44307581366071663, '3'),
#  ('Marton Fucsovics',
#   'Gilles Simon'): Text(-0.7130389460107258, -0.1515610718642948, '1'),
#  ('Marton Fucsovics',
#   'Lloyd George Muirhead Harris'): Text(0.07056430261487062, 0.2171745831698645, '1'),
#  ('Marton Fucsovics',
#   'Fabio Fognini'): Text(-0.9272435547611, 0.27995134411071454, '4'),
#  ('Marton Fucsovics',
#   'Borna Coric'): Text(-0.9167559089281294, 0.155057617705018, '3'),
#  ('Marton Fucsovics',
#   'Dominic Thiem'): Text(-0.27317356680696203, -0.216514726673606, '1'),
#  ('Marton Fucsovics',
#   'Stefanos Tsitsipas'): Text(-0.3962868484618587, -0.23999985071420715, '1'),
#  ('Marton Fucsovics',
#   'John Millman'): Text(-0.8925703707088775, 0.07495124034411954, '1'),
#  ('Marton Fucsovics',
#   'Andrey Rublev'): Text(-0.9272435547611, 0.23807571175676678, '1'),
#  ('Marton Fucsovics',
#   'Filip Krajinovic'): Text(0.02909064584672527, 0.05564526615706389, '1'),
#  ('Marton Fucsovics',
#   'Kyle Edmund'): Text(-0.8321905975119506, -0.034879168614239064, '1'),
#  ('Marton Fucsovics',
#   'Roger Federer'): Text(-0.011221584619139358, -0.017682364380867177, '3'),
#  ('Marton Fucsovics',
#   'Milos Raonic'): Text(-0.3546405021371568, -0.23562263462666827, '2'),
#  ('Marton Fucsovics',
#   'Ruben Bemelmans'): Text(-0.12538259883296254, -0.13925146105762753, '2'),
#  ('Marton Fucsovics',
#   'Hubert Hurkacz'): Text(-0.47994629594004395, -0.2382474443607544, '1'),
#  ('Marton Fucsovics',
#   'Denis Kudla'): Text(-0.8755380156899467, 0.03669593636095003, '2'),
#  ('Marton Fucsovics',
#   'Grigor Dimitrov'): Text(-0.43815341532189245, -0.24087681385015214, '2'),
#  ('Marton Fucsovics',
#   'Steve Johnson'): Text(-0.7775137967099952, -0.09822284236836026, '1'),
#  ('Marton Fucsovics',
#   'Joao Sousa'): Text(-0.6405718426279924, -0.19339998589452612, '1'),
#  ('Marton Fucsovics',
#   'Andreas Seppi'): Text(-0.063197847986049, -0.08326007981910138, '2'),
#  ('Marton Fucsovics',
#   'Lorenzo Sonego'): Text(-0.1960340851366489, -0.1840882502924731, '2'),
#  ('Lucas Pouille',
#   'Yoshihito Nishioka'): Text(0.024332287859315516, 0.05788424012551721, '1'),
#  ('Lucas Pouille',
#   'Milos Raonic'): Text(-0.3748142603448896, -0.2723185320955877, '3'),
#  ('Lucas Pouille',
#   'Philipp Kohlschreiber'): Text(0.03643569639800193, 0.09797270730498688, '2'),
#  ('Lucas Pouille',
#   'Filip Krajinovic'): Text(0.008916887638992455, 0.018949368688144452, '3'),
#  ('Lucas Pouille',
#   'Borna Coric'): Text(-0.9369296671358622, 0.11836172023609856, '3'),
#  ('Lucas Pouille',
#   'Novak Djokovic'): Text(-0.9439132453199848, 0.15965104964082993, '3'),
#  ('Lucas Pouille',
#   'Benoit Paire'): Text(-0.9127441289166103, 0.4063799161917972, '2'),
#  ('Lucas Pouille',
#   'Gilles Simon'): Text(-0.7332127042184586, -0.18825696933321423, '1'),
#  ('Lucas Pouille',
#   'Hubert Hurkacz'): Text(-0.5001200541477768, -0.27494334182967384, '3'),
#  ('Lucas Pouille',
#   'Stefanos Tsitsipas'): Text(-0.4164606066695915, -0.2766957481831266, '1'),
#  ('Lucas Pouille',
#   'John Millman'): Text(-0.9127441289166103, 0.038255342875200105, '1'),
#  ('Lucas Pouille',
#   'Andrey Rublev'): Text(-0.9474173129688328, 0.20137981428784735, '2'),
#  ('Lucas Pouille',
#   'John Isner'): Text(-0.541546571092627, -0.26882599794546896, '1'),
#  ('Lucas Pouille',
#   'Kyle Edmund'): Text(-0.8523643557196834, -0.0715750660831585, '1'),
#  ('Lucas Pouille',
#   'Tennys Sandgren'): Text(-0.6221418928037293, -0.24632339686639282, '1'),
#  ('Lucas Pouille',
#   'Roger Federer'): Text(-0.031395342826872175, -0.05437826184978661, '1'),
#  ('Lucas Pouille',
#   'Mischa Zverev'): Text(-0.1799425745315092, -0.199846407021547, '1'),
#  ('Lucas Pouille',
#   'Ruben Bemelmans'): Text(-0.14555635704069536, -0.17594735852654697, '1'),
#  ('Lucas Pouille',
#   'Joao Sousa'): Text(-0.6607456008357252, -0.23009588336344555, '1'),
#  ('Lucas Pouille',
#   'Denis Kudla'): Text(-0.8957117738976795, 3.8892030596038296e-08, '3'),
#  ('Lucas Pouille',
#   'Leonardo Mayer'): Text(-0.11329051517674943, -0.14925475954860878, '1'),
#  ('Lucas Pouille',
#   'Richard Gasquet'): Text(-0.875538045492269, -0.03669585857688884, '2'),
#  ('Lucas Pouille',
#   'Fabio Fognini'): Text(-0.9474173129688328, 0.2432554466417951, '1'),
#  ('Lucas Pouille',
#   'Andreas Seppi'): Text(-0.08337160619378181, -0.11995597728802082, '2'),
#  ('Lucas Pouille',
#   'Pierre Hugues Herbert'): Text(-0.25409815828636595, -0.23861398312269916, '1'),
#  ('Lucas Pouille',
#   'Denis Istomin'): Text(-0.9369296969381846, 0.32627341962160955, '1'),
#  ('Lucas Pouille',
#   'Lorenzo Sonego'): Text(-0.21620784334438173, -0.22078414776139255, '1'),
#  ('Benoit Paire',
#   'Yoshihito Nishioka'): Text(0.007299932840384771, 0.019628936142347703, '1'),
#  ('Benoit Paire',
#   'Damir Dzumhur'): Text(-0.5993480485299946, -0.29751898840070273, '1'),
#  ('Benoit Paire',
#   'Hubert Hurkacz'): Text(-0.5171524091667076, -0.31319864581284335, '2'),
#  ('Benoit Paire',
#   'John Millman'): Text(-0.929776483935541, 3.8892030596038296e-08, '2'),
#  ('Benoit Paire',
#   'John Isner'): Text(-0.5585789261115578, -0.3070813019286385, '1'),
#  ('Benoit Paire',
#   'Novak Djokovic'): Text(-0.9609456003389155, 0.12139574565766043, '2'),
#  ('Benoit Paire',
#   'Kevin Anderson'): Text(-0.02673491527053401, -0.05681454209301473, '2'),
#  ('Benoit Paire',
#   'Gilles Simon'): Text(-0.7502450592373895, -0.22651227331638374, '2'),
#  ('Benoit Paire',
#   'Borna Coric'): Text(-0.953962022154793, 0.08010641625292905, '2'),
#  ('Benoit Paire',
#   'Dominic Thiem'): Text(-0.3103796800336256, -0.29146592812569494, '1'),
#  ('Benoit Paire',
#   'Stefanos Tsitsipas'): Text(-0.43349296168852225, -0.3149510521662961, '1'),
#  ('Benoit Paire',
#   'Alex De Minaur'): Text(-0.843385750476279, -0.14264800192762395, '2'),
#  ('Benoit Paire',
#   'Aljaz Bedene'): Text(0.028109762012926698, 0.10067783429766648, '5'),
#  ('Benoit Paire',
#   'Jeremy Chardy'): Text(-0.9435479880578987, 0.03954639437831656, '1'),
#  ('Benoit Paire',
#   'Filip Krajinovic'): Text(-0.00811546737993829, -0.019305935295025056, '1'),
#  ('Benoit Paire',
#   'Roger Federer'): Text(-0.04842769784580292, -0.09263356583295612, '2'),
#  ('Benoit Paire',
#   'Richard Gasquet'): Text(-0.8925704005111997, -0.07495116256005835, '5'),
#  ('Benoit Paire',
#   'Tomas Berdych'): Text(-0.9435479582555765, 0.32857825672234175, '2'),
#  ('Benoit Paire',
#   'Juan Martin Del Potro'): Text(-0.07304149543647909, -0.1265115643216198, '1'),
#  ('Benoit Paire',
#   'Dusan Lajovic'): Text(-0.7148881950104864, -0.24895041197232903, '1'),
#  ('Benoit Paire',
#   'Steve Johnson'): Text(-0.8147199099366588, -0.1731740438204492, '2'),
#  ('Benoit Paire',
#   'Robin Haase'): Text(-0.35071283172974355, -0.30272715283855833, '1'),
#  ('Benoit Paire',
#   'Pierre Hugues Herbert'): Text(-0.2711305133052967, -0.27686928710586867, '2'),
#  ('Benoit Paire',
#   'Mischa Zverev'): Text(-0.19697492955043994, -0.2381017110047165, '3'),
#  ('Benoit Paire',
#   'Leonardo Mayer'): Text(-0.13032287019568017, -0.1875100635317783, '1'),
#  ('Tomas Berdych',
#   'Yoshihito Nishioka'): Text(-0.006471541479650678, -0.01991741934393826, '1'),
#  ('Tomas Berdych',
#   'Philipp Kohlschreiber'): Text(0.005631867059035733, 0.020171047835531405, '1'),
#  ('Tomas Berdych',
#   'Damir Dzumhur'): Text(-0.61311952285003, -0.3370653438869887, '1'),
#  ('Tomas Berdych',
#   'Kyle Edmund'): Text(-0.8831681850586496, -0.14937672555261397, '1'),
#  ('Tomas Berdych',
#   'Filip Krajinovic'): Text(-0.02188694169997374, -0.05885229078131102, '2'),
#  ('Tomas Berdych',
#   'Juan Martin Del Potro'): Text(-0.08681296975651454, -0.16605791980790577, '1'),
#  ('Tomas Berdych',
#   'Gilles Simon'): Text(-0.7640165335574249, -0.2660586288026697, '1'),
#  ('Tomas Berdych',
#   'Borna Coric'): Text(-0.9677334964748284, 0.04056006076664309, '1'),
#  ('Tomas Berdych',
#   'Pierre Hugues Herbert'): Text(-0.28490198762533214, -0.3164156425921546, '2'),
#  ('Tomas Berdych',
#   'Jeremy Chardy'): Text(-0.9573194623779342, 3.8892030596038296e-08, '1'),
#  ('Tomas Berdych',
#   'Roger Federer'): Text(-0.06219917216583837, -0.13217992131924208, '1'),
#  ('Tomas Berdych',
#   'Milos Raonic'): Text(-0.4056180896838558, -0.35012019156504315, '1'),
#  ('Tomas Berdych',
#   'Richard Gasquet'): Text(-0.9063418748312352, -0.11449751804634431, '1'),
#  ('Tomas Berdych',
#   'Hyeon Chung'): Text(-0.7973716204990454, -0.2407407215453777, '1'),
#  ('Tomas Berdych',
#   'Fabio Fognini'): Text(-0.9782211423077991, 0.16545378717233963, '1'),
#  ('Tomas Berdych',
#   'Andreas Seppi'): Text(-0.114175435532748, -0.1977576367574763, '1'),
#  ('Tomas Berdych',
#   'Robin Haase'): Text(-0.364484306049779, -0.34227350832484427, '1'),
#  ('Tomas Berdych',
#   'Alex De Minaur'): Text(-0.8571572247963144, -0.1821943574139099, '1'),
#  ('Tomas Berdych',
#   'Mischa Zverev'): Text(-0.21074640387047539, -0.2776480664910025, '1'),
#  ('Denis Istomin',
#   'Philipp Kohlschreiber'): Text(-0.004782226642503107, -0.02038909324837028, '2'),
#  ('Denis Istomin',
#   'Damir Dzumhur'): Text(-0.6235336165515689, -0.3776254849708904, '1'),
#  ('Denis Istomin',
#   'Dusan Lajovic'): Text(-0.7390737630320607, -0.3290569085425167, '2'),
#  ('Denis Istomin',
#   'Andreas Seppi'): Text(-0.12458952923428684, -0.23831777784137798, '1'),
#  ('Denis Istomin',
#   'Pierre Hugues Herbert'): Text(-0.2953160813268709, -0.3569757836760563, '1'),
#  ('Denis Istomin',
#   'Filip Krajinovic'): Text(-0.03230103540151258, -0.0994124318652127, '1'),
#  ('Denis Istomin',
#   'Kyle Edmund'): Text(-0.8935822787601884, -0.18993686663651566, '1'),
#  ('Denis Istomin',
#   'Tennys Sandgren'): Text(-0.6633598158442344, -0.36468519741975, '1'),
#  ('Denis Istomin',
#   'Alexander Zverev'): Text(-0.9851311683604898, 0.16662241632339078, '1'),
#  ('Denis Istomin',
#   'Roger Federer'): Text(-0.07261326586737721, -0.17274006240314377, '1'),
#  ('Denis Istomin',
#   'Milos Raonic'): Text(-0.41603218338539466, -0.39068033264894486, '1'),
#  ('Denis Istomin',
#   'Steve Johnson'): Text(-0.838905477958233, -0.25328054039063685, '1'),
#  ('Denis Istomin',
#   'Robin Haase'): Text(-0.37489839975131783, -0.382833649408746, '1'),
#  ('Alexander Zverev',
#   'Kevin Anderson'): Text(-0.05790403167390851, -0.178210241408064, '1'),
#  ('Alexander Zverev',
#   'Roger Federer'): Text(-0.07959681424917742, -0.21402926514800538, '2'),
#  ('Alexander Zverev',
#   'Dominic Thiem'): Text(-0.3415487964370001, -0.41286162744074417, '5'),
#  ('Alexander Zverev',
#   'Stefanos Tsitsipas'): Text(-0.46466207809189675, -0.4363467514813454, '6'),
#  ('Alexander Zverev',
#   'Philipp Kohlschreiber'): Text(-0.011765775024303315, -0.061678295993231894, '2'),
#  ('Alexander Zverev',
#   'Damir Dzumhur'): Text(-0.6305171649333691, -0.418914687715752, '1'),
#  ('Alexander Zverev',
#   'Kyle Edmund'): Text(-0.9005658271419886, -0.23122606938137727, '2'),
#  ('Alexander Zverev',
#   'Filip Krajinovic'): Text(-0.03928458378331279, -0.14070163461007432, '1'),
#  ('Alexander Zverev',
#   'Borna Coric'): Text(-0.9851311385581675, -0.04128928306212021, '3'),
#  ('Alexander Zverev',
#   'Novak Djokovic'): Text(-0.99211471674229, 4.634261116520655e-08, '5'),
#  ('Alexander Zverev',
#   'Fabio Fognini'): Text(-0.9956187843911382, 0.08360444334357633, '2'),
#  ('Alexander Zverev',
#   'Alex De Minaur'): Text(-0.8745548668796534, -0.2640437012426732, '5'),
#  ('Alexander Zverev',
#   'John Isner'): Text(-0.5897480425149323, -0.4284770012436877, '3'),
#  ('Alexander Zverev',
#   'Andreas Seppi'): Text(-0.13157307761608705, -0.27960698058623956, '1'),
#  ('Alexander Zverev',
#   'Milos Raonic'): Text(-0.42301573176719487, -0.43196953539380645, '1'),
#  ('Alexander Zverev',
#   'Robin Haase'): Text(-0.38188194813311804, -0.42412285215360757, '3'),
#  ('Alexander Zverev',
#   'Joao Sousa'): Text(-0.7089470722580304, -0.38974688666166435, '1'),
#  ('Alexander Zverev',
#   'Hyeon Chung'): Text(-0.8147692625823845, -0.32259006537414103, '2'),
#  ('Alexander Zverev',
#   'Juan Martin Del Potro'): Text(-0.10421061183985358, -0.24790726363666907, '1'),
#  ('Alexander Zverev',
#   'Jeremy Chardy'): Text(-0.9747171044612732, -0.0818493049367327, '2'),
#  ('Alexander Zverev',
#   'Hubert Hurkacz'): Text(-0.5483215255700821, -0.43459434512789263, '1'),
#  ('Alexander Zverev',
#   'John Millman'): Text(-0.9609456003389155, -0.12139566042301866, '2'),
#  ('Alexander Zverev',
#   'Dusan Lajovic'): Text(-0.7460573114138609, -0.37034611128737827, '2'),
#  ('Alexander Zverev',
#   'Steve Johnson'): Text(-0.8458890263400333, -0.29456974313549844, '1'),
#  ('Alexander Zverev',
#   'Richard Gasquet'): Text(-0.9237395169145742, -0.1963468618751076, '1'),
#  ('Alexander Zverev',
#   'Pierre Hugues Herbert'): Text(-0.3022996297086712, -0.3982649864209179, '1'),
#  ('Alexander Zverev',
#   'Andrey Rublev'): Text(-0.9956187843911382, 0.041728810989628565, '2'),
#  ('Alexander Zverev',
#   'Lloyd George Muirhead Harris'): Text(0.002189072984832563, 0.02082768240272627, '1'),
#  ('Alexander Zverev',
#   'Aljaz Bedene'): Text(-0.0030593543904477993, -0.020717865017382778, '2'),
#  ('Alexander Zverev',
#   'Mischa Zverev'): Text(-0.22814404595381443, -0.3594974103197658, '1'),
#  ('Alexander Zverev',
#   'Leonardo Mayer'): Text(-0.16149198659905467, -0.3089057628468276, '1'),
#  ('Fabio Fognini',
#   'Yoshihito Nishioka'): Text(-0.027373251211837812, -0.1434955334076544, '1'),
#  ('Fabio Fognini',
#   'Dominic Thiem'): Text(-0.34505286408584823, -0.45459039767569703, '2'),
#  ('Fabio Fognini',
#   'Philipp Kohlschreiber'): Text(-0.015269842673151401, -0.10340706622818473, '2'),
#  ('Fabio Fognini',
#   'Tennys Sandgren'): Text(-0.6738474318748826, -0.4477031703995644, '4'),
#  ('Fabio Fognini',
#   'Damir Dzumhur'): Text(-0.6340212325822172, -0.4606434579507048, '1'),
#  ('Fabio Fognini',
#   'Kyle Edmund'): Text(-0.9040698947908368, -0.2729548396163301, '2'),
#  ('Fabio Fognini',
#   'Borna Coric'): Text(-0.9886352062070156, -0.08301805329707304, '1'),
#  ('Fabio Fognini',
#   'Jeremy Chardy'): Text(-0.9782211721101214, -0.12357807517168554, '2'),
#  ('Fabio Fognini',
#   'Juan Martin Del Potro'): Text(-0.10771467948870167, -0.2896360338716219, '2'),
#  ('Fabio Fognini',
#   'John Millman'): Text(-0.9644496679877637, -0.1631244306579715, '2'),
#  ('Fabio Fognini',
#   'John Isner'): Text(-0.5932521101637804, -0.47020577147864057, '1'),
#  ...}

# %%
#CENTRALNOSTI
def calculate_centralities(G):

    DC_dict = nx.degree_centrality(G)
    CC_dict = nx.closeness_centrality(G)
    BC_dict = nx.betweenness_centrality(G)
    EVC_dict = nx.eigenvector_centrality(G)

    df1 = pd.DataFrame.from_dict(DC_dict, orient='index', columns=['DC'])
    df2 = pd.DataFrame.from_dict(CC_dict, orient='index', columns=['CC'])
    df3 = pd.DataFrame.from_dict(BC_dict, orient='index', columns=['BC'])
    df4 = pd.DataFrame.from_dict(EVC_dict, orient='index', columns=['EVC'])
    df = pd.concat([df1, df2, df3, df4], axis=1)
    return df
df = calculate_centralities(G)
print(df)
# Out:
#                           DC        CC        BC           EVC
# Harri Heliovaara    0.013793  0.304138  0.004155  3.150171e-03
# Francisco Llanes    0.001724  0.183766  0.000000  9.178401e-07
# Jan Lennard Struff  0.160345  0.414845  0.018454  1.142690e-01
# Constant Lestienne  0.008621  0.315721  0.000138  5.626168e-03
# Takanyi Garanganga  0.008621  0.298486  0.006564  2.411757e-03
# ...                      ...       ...       ...           ...
# Dustin Brown        0.012069  0.319052  0.000039  9.715286e-03
# Roger Federer       0.127586  0.402816  0.002760  1.112588e-01
# Finn Tearney        0.001724  0.151219  0.000000  7.059424e-09
# Ernesto Escobedo    0.022414  0.329061  0.000245  1.324418e-02
# Cheng Yu Yu         0.001724  0.197310  0.000000  1.983439e-06
#
# [581 rows x 4 columns]

# %%
#Korelacija - kako jedna metrika zavisi od druge, pozitivna korelacija znači da veća vrednost jedne od metrikka povlači veću vrednost druge metrike. 
#Interesantno je posmatrati Kendalovu tau korelaciju (korelaciju po rangu, ne po numeričkoj vrednosti) između različitih mera centralnosti ove mreže.

# %%
import scipy.stats as stats
labele = ['DC', 'CC', 'BC', 'EVC']
cross_correlation_matrix = pd.DataFrame(columns = ['DC', 'CC', 'BC', 'EVC'], index = ['DC', 'CC', 'BC', 'EVC'])
p_val_matrix = pd.DataFrame(columns = ['DC', 'CC', 'BC', 'EVC'], index = ['DC', 'CC', 'BC', 'EVC'])
for ind in labele:
    for col in labele:
        cross_correlation_matrix[ind][col], p_val_matrix[ind][col] =  stats.kendalltau(df[ind], df[col])
print(cross_correlation_matrix)
# Out:
#            DC        CC        BC       EVC
# DC          1  0.823807  0.717742  0.819532
# CC   0.823807         1  0.565221  0.956007
# BC   0.717742  0.565221         1   0.54637
# EVC  0.819532  0.956007   0.54637         1

# %%
#BC-posmatra samo puteve, najslabije sa EVC

# %%
print(p_val_matrix)
#p treba da bude sto manji, kako ne bi bilo da se slucajno desilo
# Out:
#                DC            CC            BC           EVC
# DC   7.27304e-241  1.28116e-177  2.65134e-127  5.94403e-176
# CC   1.28116e-177  3.17396e-282   3.74667e-86  2.39684e-258
# BC   2.65134e-127   3.74667e-86  1.39453e-249   1.07616e-80
# EVC  5.94403e-176  2.39684e-258   1.07616e-80  1.03532e-282

# %%
df = calculate_centralities(G)

df_ = df
for metric in labele:
    df_[f"{metric}_rank"] = df[f"{metric}"].rank(ascending=False) 
    
df_['composite_rank'] = df_['DC_rank'] * df_['CC_rank'] * df_['BC_rank'] * df_['EVC_rank']

df_.sort_values(['composite_rank'], ascending = True)
df_.sort_values(['CC'], ascending = False, inplace=True)
print(df_)
# Out:
#                                   DC        CC        BC           EVC  \
# Karen Khachanov             0.177586  0.431564  0.018198  1.313909e-01
# Stefanos Tsitsipas          0.170690  0.427259  0.068153  1.302291e-01
# Gael Monfils                0.162069  0.423388  0.009965  1.243215e-01
# Alexander Zverev            0.163793  0.421306  0.013706  1.249850e-01
# Dusan Lajovic               0.153448  0.419929  0.015747  1.167182e-01
# ...                              ...       ...       ...           ...
# Jorge Brian Panta Herreros  0.001724  0.001724  0.000000  3.129437e-12
# Lukas Hellum Lilleengen     0.001724  0.001724  0.000000  3.129437e-12
# Mark Chigaazira             0.001724  0.001724  0.000000  3.129437e-12
# Skyler Butts                0.001724  0.001724  0.000000  3.129437e-12
# Anthony Jackie Tang         0.001724  0.001724  0.000000  3.129437e-12
#
#                             DC_rank  CC_rank  BC_rank  EVC_rank  \
# Karen Khachanov                 1.0      1.0     20.0       1.0
# Stefanos Tsitsipas              2.0      2.0      1.0       2.0
# Gael Monfils                    6.0      3.0     66.0       5.0
# Alexander Zverev                5.0      4.0     40.0       4.0
# Dusan Lajovic                  15.5      5.0     26.0      12.0
# ...                             ...      ...      ...       ...
# Jorge Brian Panta Herreros    502.0    564.5    495.0     564.5
# Lukas Hellum Lilleengen       502.0    564.5    495.0     564.5
# Mark Chigaazira               502.0    564.5    495.0     564.5
# Skyler Butts                  502.0    564.5    495.0     564.5
# Anthony Jackie Tang           502.0    564.5    495.0     564.5
#
#                             composite_rank
# Karen Khachanov               2.000000e+01
# Stefanos Tsitsipas            8.000000e+00
# Gael Monfils                  5.940000e+03
# Alexander Zverev              3.200000e+03
# Dusan Lajovic                 2.418000e+04
# ...                                    ...
# Jorge Brian Panta Herreros    7.918389e+10
# Lukas Hellum Lilleengen       7.918389e+10
# Mark Chigaazira               7.918389e+10
# Skyler Butts                  7.918389e+10
# Anthony Jackie Tang           7.918389e+10
#
# [581 rows x 9 columns]
